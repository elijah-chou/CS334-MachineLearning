# %% [markdown]
# # Racial Bias Analysis

# %% [markdown]
# ### Setting up environment and loading Preprocessed Training/Test Data

# %%
import pandas as pd
import numpy as np
from scipy.stats import sem
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, roc_curve

# %%
xTrain=pd.read_csv('xTrain.csv')
xTest=pd.read_csv('xTest.csv')
yTrain=pd.read_csv('yTrain.csv')
yTest=pd.read_csv('yTest.csv')
xTest.head()
xTrain = xTrain.drop(columns=['Unnamed: 0'])
xTest = xTest.drop(columns=['Unnamed: 0'])

# %% [markdown]
# ### Creating test sets with only specific races for Bias Analysis

# %%
frames = [xTest, yTest]
TestSet = pd.concat(frames, axis=1)
TestSet = TestSet.drop(columns=['Unnamed: 0'])
TestSet.head()
# Out:
#    admission_location  insurance  marital_status       los  sofa_24hours  \
# 0           -1.019256   1.114127        1.039934 -0.421911      0.302118
# 1           -1.019256  -0.897564       -0.961600 -0.570071     -1.053692
# 2           -1.019256  -0.897564       -0.961600 -0.239893      0.648933
# 3           -1.019256  -0.897564        1.039934 -0.257870     -0.071899
# 4           -1.019256  -0.897564        1.039934 -0.484447     -0.171696
#
#    AMBULATORY OBSERVATION  DIRECT EMER.  DIRECT OBSERVATION  ELECTIVE  \
# 0               -0.176476      -0.18199            3.728497 -0.173346
# 1               -0.176476      -0.18199           -0.268205 -0.173346
# 2               -0.176476      -0.18199           -0.268205 -0.173346
# 3               -0.176476      -0.18199           -0.268205 -0.173346
# 4               -0.176476      -0.18199            3.728497 -0.173346
#
#    EU OBSERVATION  EW EMER.  OBSERVATION ADMIT  SURGICAL SAME DAY ADMISSION  \
# 0       -0.467674 -0.759136          -0.307624                    -0.305007
# 1       -0.467674 -0.759136           3.250718                    -0.305007
# 2       -0.467674 -0.759136          -0.307624                    -0.305007
# 3       -0.467674 -0.759136          -0.307624                     3.278612
# 4       -0.467674 -0.759136          -0.307624                    -0.305007
#
#      URGENT     ASIAN  BLACK/AFRICAN AMERICAN  HISPANIC/LATINO     WHITE  \
# 0 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
# 1 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
# 2  2.647779 -0.188538               -0.351233        -0.210781  0.479094
# 3 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
# 4 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
#
#   ethnicity  hospital_expire_flag
# 0     WHITE                     0
# 1     WHITE                     0
# 2     WHITE                     0
# 3     WHITE                     0
# 4     WHITE                     0

# %%
TestWhite = TestSet[TestSet['ethnicity'] == 'WHITE']
TestBlack = TestSet[TestSet['ethnicity'] == 'BLACK/AFRICAN AMERICAN']
TestHisp = TestSet[TestSet['ethnicity'] == 'HISPANIC/LATINO']
TestAsian = TestSet[TestSet['ethnicity'] == 'ASIAN']

# %%
xTestWhite = TestWhite.drop(columns=['ethnicity', 'hospital_expire_flag'])
yTestWhite = TestWhite['hospital_expire_flag'].reset_index()
yTestWhite = yTestWhite.drop(columns=['index'])
xTestBlack = TestBlack.drop(columns=['ethnicity', 'hospital_expire_flag'])
yTestBlack = TestBlack['hospital_expire_flag'].reset_index()
yTestBlack = yTestBlack.drop(columns=['index'])
xTestHisp = TestHisp.drop(columns=['ethnicity', 'hospital_expire_flag'])
yTestHisp = TestHisp['hospital_expire_flag'].reset_index()
yTestHisp = yTestHisp.drop(columns=['index'])
xTestAsian = TestAsian.drop(columns=['ethnicity', 'hospital_expire_flag'])
yTestAsian = TestAsian['hospital_expire_flag'].reset_index()
yTestAsian = yTestAsian.drop(columns=['index'])

# %% [markdown]
# Final edit to training and testing dataset

# %%
xTrain=xTrain.drop(columns=['ethnicity'])
xTest=xTest.drop(columns=['ethnicity'])
yTrain=yTrain['hospital_expire_flag']
yTest=yTest['hospital_expire_flag']

# %%
xTest.head()
# Out:
#    admission_location  insurance  marital_status       los  sofa_24hours  \
# 0           -1.019256   1.114127        1.039934 -0.421911      0.302118
# 1           -1.019256  -0.897564       -0.961600 -0.570071     -1.053692
# 2           -1.019256  -0.897564       -0.961600 -0.239893      0.648933
# 3           -1.019256  -0.897564        1.039934 -0.257870     -0.071899
# 4           -1.019256  -0.897564        1.039934 -0.484447     -0.171696
#
#    AMBULATORY OBSERVATION  DIRECT EMER.  DIRECT OBSERVATION  ELECTIVE  \
# 0               -0.176476      -0.18199            3.728497 -0.173346
# 1               -0.176476      -0.18199           -0.268205 -0.173346
# 2               -0.176476      -0.18199           -0.268205 -0.173346
# 3               -0.176476      -0.18199           -0.268205 -0.173346
# 4               -0.176476      -0.18199            3.728497 -0.173346
#
#    EU OBSERVATION  EW EMER.  OBSERVATION ADMIT  SURGICAL SAME DAY ADMISSION  \
# 0       -0.467674 -0.759136          -0.307624                    -0.305007
# 1       -0.467674 -0.759136           3.250718                    -0.305007
# 2       -0.467674 -0.759136          -0.307624                    -0.305007
# 3       -0.467674 -0.759136          -0.307624                     3.278612
# 4       -0.467674 -0.759136          -0.307624                    -0.305007
#
#      URGENT     ASIAN  BLACK/AFRICAN AMERICAN  HISPANIC/LATINO     WHITE
# 0 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
# 1 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
# 2  2.647779 -0.188538               -0.351233        -0.210781  0.479094
# 3 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
# 4 -0.377675 -0.188538               -0.351233        -0.210781  0.479094

# %%
xTestWhite.head()
# Out:
#    admission_location  insurance  marital_status       los  sofa_24hours  \
# 0           -1.019256   1.114127        1.039934 -0.421911      0.302118
# 1           -1.019256  -0.897564       -0.961600 -0.570071     -1.053692
# 2           -1.019256  -0.897564       -0.961600 -0.239893      0.648933
# 3           -1.019256  -0.897564        1.039934 -0.257870     -0.071899
# 4           -1.019256  -0.897564        1.039934 -0.484447     -0.171696
#
#    AMBULATORY OBSERVATION  DIRECT EMER.  DIRECT OBSERVATION  ELECTIVE  \
# 0               -0.176476      -0.18199            3.728497 -0.173346
# 1               -0.176476      -0.18199           -0.268205 -0.173346
# 2               -0.176476      -0.18199           -0.268205 -0.173346
# 3               -0.176476      -0.18199           -0.268205 -0.173346
# 4               -0.176476      -0.18199            3.728497 -0.173346
#
#    EU OBSERVATION  EW EMER.  OBSERVATION ADMIT  SURGICAL SAME DAY ADMISSION  \
# 0       -0.467674 -0.759136          -0.307624                    -0.305007
# 1       -0.467674 -0.759136           3.250718                    -0.305007
# 2       -0.467674 -0.759136          -0.307624                    -0.305007
# 3       -0.467674 -0.759136          -0.307624                     3.278612
# 4       -0.467674 -0.759136          -0.307624                    -0.305007
#
#      URGENT     ASIAN  BLACK/AFRICAN AMERICAN  HISPANIC/LATINO     WHITE
# 0 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
# 1 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
# 2  2.647779 -0.188538               -0.351233        -0.210781  0.479094
# 3 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
# 4 -0.377675 -0.188538               -0.351233        -0.210781  0.479094

# %%
xTrain.head()
# Out:
#    admission_location  insurance  marital_status       los  sofa_24hours  \
# 0            0.981108  -0.897564       -0.961600 -0.551279     -0.669286
# 1           -1.019256   1.114127        1.039934 -0.516693      0.215728
# 2           -1.019256   1.114127       -0.961600 -0.300452      0.345313
# 3            0.981108   1.114127        1.039934 -0.502843     -0.890060
# 4           -1.019256   1.114127       -0.961600 -0.220871      0.002331
#
#    AMBULATORY OBSERVATION  DIRECT EMER.  DIRECT OBSERVATION  ELECTIVE  \
# 0               -0.176476     -0.181990           -0.268205 -0.173346
# 1               -0.176476     -0.181990           -0.268205 -0.173346
# 2               -0.176476     -0.181990           -0.268205 -0.173346
# 3               -0.176476     -0.181990           -0.268205 -0.173346
# 4               -0.176476      5.494809           -0.268205 -0.173346
#
#    EU OBSERVATION  EW EMER.  OBSERVATION ADMIT  SURGICAL SAME DAY ADMISSION  \
# 0        2.138243 -0.759136          -0.307624                    -0.305007
# 1       -0.467674 -0.759136           3.250718                    -0.305007
# 2       -0.467674 -0.759136          -0.307624                    -0.305007
# 3        2.138243 -0.759136          -0.307624                    -0.305007
# 4       -0.467674 -0.759136          -0.307624                    -0.305007
#
#      URGENT     ASIAN  BLACK/AFRICAN AMERICAN  HISPANIC/LATINO     WHITE
# 0 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
# 1 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
# 2  2.647779 -0.188538               -0.351233        -0.210781  0.479094
# 3 -0.377675 -0.188538               -0.351233        -0.210781  0.479094
# 4 -0.377675 -0.188538               -0.351233        -0.210781  0.479094

# %% [markdown]
# ## Calculating overall AUROC w/ 95% Confidence Intervals for Chosen Model

# %%
model=RandomForestClassifier(n_estimators = 400, criterion='entropy', max_depth=20, min_samples_leaf=50, max_features=17, bootstrap=True, oob_score=True)
model.fit(xTrain, yTrain)
y_pred = model.predict_proba(xTest)

# %%
print("Original ROC area: {:0.3f}".format(roc_auc_score(yTest, y_pred[:,1])))
# Out:
# Original ROC area: 0.853

# %%
n_bootstraps = 1000
rng_seed = 42  # control reproducibility
bootstrapped_scores = []

rng = np.random.RandomState(rng_seed)
for i in range(n_bootstraps):
    # bootstrap by sampling with replacement on the prediction indices
    indices = rng.randint(0, len(y_pred), len(y_pred))
    if len(np.unique(yTest[indices])) < 2:
        # We need at least one positive and one negative sample for ROC AUC
        # to be defined: reject the sample
        continue

    score = roc_auc_score(yTest[indices], y_pred[indices, 1])
    bootstrapped_scores.append(score)
    print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))
# Out:
# Bootstrap #1 ROC area: 0.848
# Bootstrap #2 ROC area: 0.851
# Bootstrap #3 ROC area: 0.858
# Bootstrap #4 ROC area: 0.863
# Bootstrap #5 ROC area: 0.857
# Bootstrap #6 ROC area: 0.860
# Bootstrap #7 ROC area: 0.856
# Bootstrap #8 ROC area: 0.858
# Bootstrap #9 ROC area: 0.853
# Bootstrap #10 ROC area: 0.856
# Bootstrap #11 ROC area: 0.845
# Bootstrap #12 ROC area: 0.845
# Bootstrap #13 ROC area: 0.860
# Bootstrap #14 ROC area: 0.862
# Bootstrap #15 ROC area: 0.853
# Bootstrap #16 ROC area: 0.847
# Bootstrap #17 ROC area: 0.854
# Bootstrap #18 ROC area: 0.846
# Bootstrap #19 ROC area: 0.835
# Bootstrap #20 ROC area: 0.848
# Bootstrap #21 ROC area: 0.841
# Bootstrap #22 ROC area: 0.867
# Bootstrap #23 ROC area: 0.855
# Bootstrap #24 ROC area: 0.854
# Bootstrap #25 ROC area: 0.850
# Bootstrap #26 ROC area: 0.845
# Bootstrap #27 ROC area: 0.848
# Bootstrap #28 ROC area: 0.854
# Bootstrap #29 ROC area: 0.858
# Bootstrap #30 ROC area: 0.850
# Bootstrap #31 ROC area: 0.857
# Bootstrap #32 ROC area: 0.854
# Bootstrap #33 ROC area: 0.848
# Bootstrap #34 ROC area: 0.848
# Bootstrap #35 ROC area: 0.848
# Bootstrap #36 ROC area: 0.852
# Bootstrap #37 ROC area: 0.850
# Bootstrap #38 ROC area: 0.854
# Bootstrap #39 ROC area: 0.847
# Bootstrap #40 ROC area: 0.862
# Bootstrap #41 ROC area: 0.861
# Bootstrap #42 ROC area: 0.854
# Bootstrap #43 ROC area: 0.856
# Bootstrap #44 ROC area: 0.868
# Bootstrap #45 ROC area: 0.847
# Bootstrap #46 ROC area: 0.831
# Bootstrap #47 ROC area: 0.870
# Bootstrap #48 ROC area: 0.854
# Bootstrap #49 ROC area: 0.848
# Bootstrap #50 ROC area: 0.849
# Bootstrap #51 ROC area: 0.857
# Bootstrap #52 ROC area: 0.852
# Bootstrap #53 ROC area: 0.854
# Bootstrap #54 ROC area: 0.848
# Bootstrap #55 ROC area: 0.848
# Bootstrap #56 ROC area: 0.857
# Bootstrap #57 ROC area: 0.857
# Bootstrap #58 ROC area: 0.845
# Bootstrap #59 ROC area: 0.851
# Bootstrap #60 ROC area: 0.866
# Bootstrap #61 ROC area: 0.860
# Bootstrap #62 ROC area: 0.862
# Bootstrap #63 ROC area: 0.849
# Bootstrap #64 ROC area: 0.855
# Bootstrap #65 ROC area: 0.847
# Bootstrap #66 ROC area: 0.858
# Bootstrap #67 ROC area: 0.851
# Bootstrap #68 ROC area: 0.862
# Bootstrap #69 ROC area: 0.841
# Bootstrap #70 ROC area: 0.845
# Bootstrap #71 ROC area: 0.853
# Bootstrap #72 ROC area: 0.862
# Bootstrap #73 ROC area: 0.854
# Bootstrap #74 ROC area: 0.865
# Bootstrap #75 ROC area: 0.853
# Bootstrap #76 ROC area: 0.847
# Bootstrap #77 ROC area: 0.843
# Bootstrap #78 ROC area: 0.859
# Bootstrap #79 ROC area: 0.856
# Bootstrap #80 ROC area: 0.854
# Bootstrap #81 ROC area: 0.847
# Bootstrap #82 ROC area: 0.852
# Bootstrap #83 ROC area: 0.842
# Bootstrap #84 ROC area: 0.865
# Bootstrap #85 ROC area: 0.864
# Bootstrap #86 ROC area: 0.850
# Bootstrap #87 ROC area: 0.852
# Bootstrap #88 ROC area: 0.851
# Bootstrap #89 ROC area: 0.858
# Bootstrap #90 ROC area: 0.855
# Bootstrap #91 ROC area: 0.855
# Bootstrap #92 ROC area: 0.851
# Bootstrap #93 ROC area: 0.856
# Bootstrap #94 ROC area: 0.843
# Bootstrap #95 ROC area: 0.862
# Bootstrap #96 ROC area: 0.864
# Bootstrap #97 ROC area: 0.852
# Bootstrap #98 ROC area: 0.852
# Bootstrap #99 ROC area: 0.851
# Bootstrap #100 ROC area: 0.847
# Bootstrap #101 ROC area: 0.851
# Bootstrap #102 ROC area: 0.856
# Bootstrap #103 ROC area: 0.849
# Bootstrap #104 ROC area: 0.859
# Bootstrap #105 ROC area: 0.851
# Bootstrap #106 ROC area: 0.848
# Bootstrap #107 ROC area: 0.853
# Bootstrap #108 ROC area: 0.858
# Bootstrap #109 ROC area: 0.855
# Bootstrap #110 ROC area: 0.847
# Bootstrap #111 ROC area: 0.858
# Bootstrap #112 ROC area: 0.863
# Bootstrap #113 ROC area: 0.847
# Bootstrap #114 ROC area: 0.854
# Bootstrap #115 ROC area: 0.848
# Bootstrap #116 ROC area: 0.850
# Bootstrap #117 ROC area: 0.853
# Bootstrap #118 ROC area: 0.854
# Bootstrap #119 ROC area: 0.848
# Bootstrap #120 ROC area: 0.858
# Bootstrap #121 ROC area: 0.859
# Bootstrap #122 ROC area: 0.859
# Bootstrap #123 ROC area: 0.838
# Bootstrap #124 ROC area: 0.847
# Bootstrap #125 ROC area: 0.854
# Bootstrap #126 ROC area: 0.858
# Bootstrap #127 ROC area: 0.859
# Bootstrap #128 ROC area: 0.848
# Bootstrap #129 ROC area: 0.855
# Bootstrap #130 ROC area: 0.853
# Bootstrap #131 ROC area: 0.838
# Bootstrap #132 ROC area: 0.846
# Bootstrap #133 ROC area: 0.854
# Bootstrap #134 ROC area: 0.869
# Bootstrap #135 ROC area: 0.856
# Bootstrap #136 ROC area: 0.853
# Bootstrap #137 ROC area: 0.846
# Bootstrap #138 ROC area: 0.870
# Bootstrap #139 ROC area: 0.855
# Bootstrap #140 ROC area: 0.864
# Bootstrap #141 ROC area: 0.856
# Bootstrap #142 ROC area: 0.843
# Bootstrap #143 ROC area: 0.862
# Bootstrap #144 ROC area: 0.859
# Bootstrap #145 ROC area: 0.860
# Bootstrap #146 ROC area: 0.865
# Bootstrap #147 ROC area: 0.854
# Bootstrap #148 ROC area: 0.856
# Bootstrap #149 ROC area: 0.853
# Bootstrap #150 ROC area: 0.849
# Bootstrap #151 ROC area: 0.855
# Bootstrap #152 ROC area: 0.864
# Bootstrap #153 ROC area: 0.855
# Bootstrap #154 ROC area: 0.850
# Bootstrap #155 ROC area: 0.851
# Bootstrap #156 ROC area: 0.850
# Bootstrap #157 ROC area: 0.850
# Bootstrap #158 ROC area: 0.858
# Bootstrap #159 ROC area: 0.849
# Bootstrap #160 ROC area: 0.850
# Bootstrap #161 ROC area: 0.850
# Bootstrap #162 ROC area: 0.863
# Bootstrap #163 ROC area: 0.848
# Bootstrap #164 ROC area: 0.856
# Bootstrap #165 ROC area: 0.845
# Bootstrap #166 ROC area: 0.867
# Bootstrap #167 ROC area: 0.858
# Bootstrap #168 ROC area: 0.844
# Bootstrap #169 ROC area: 0.853
# Bootstrap #170 ROC area: 0.850
# Bootstrap #171 ROC area: 0.842
# Bootstrap #172 ROC area: 0.853
# Bootstrap #173 ROC area: 0.854
# Bootstrap #174 ROC area: 0.844
# Bootstrap #175 ROC area: 0.855
# Bootstrap #176 ROC area: 0.859
# Bootstrap #177 ROC area: 0.849
# Bootstrap #178 ROC area: 0.854
# Bootstrap #179 ROC area: 0.844
# Bootstrap #180 ROC area: 0.848
# Bootstrap #181 ROC area: 0.846
# Bootstrap #182 ROC area: 0.845
# Bootstrap #183 ROC area: 0.848
# Bootstrap #184 ROC area: 0.842
# Bootstrap #185 ROC area: 0.856
# Bootstrap #186 ROC area: 0.852
# Bootstrap #187 ROC area: 0.856
# Bootstrap #188 ROC area: 0.849
# Bootstrap #189 ROC area: 0.856
# Bootstrap #190 ROC area: 0.857
# Bootstrap #191 ROC area: 0.848
# Bootstrap #192 ROC area: 0.843
# Bootstrap #193 ROC area: 0.856
# Bootstrap #194 ROC area: 0.847
# Bootstrap #195 ROC area: 0.857
# Bootstrap #196 ROC area: 0.846
# Bootstrap #197 ROC area: 0.848
# Bootstrap #198 ROC area: 0.852
# Bootstrap #199 ROC area: 0.856
# Bootstrap #200 ROC area: 0.858
# Bootstrap #201 ROC area: 0.856
# Bootstrap #202 ROC area: 0.858
# Bootstrap #203 ROC area: 0.855
# Bootstrap #204 ROC area: 0.851
# Bootstrap #205 ROC area: 0.841
# Bootstrap #206 ROC area: 0.847
# Bootstrap #207 ROC area: 0.861
# Bootstrap #208 ROC area: 0.861
# Bootstrap #209 ROC area: 0.856
# Bootstrap #210 ROC area: 0.848
# Bootstrap #211 ROC area: 0.836
# Bootstrap #212 ROC area: 0.856
# Bootstrap #213 ROC area: 0.843
# Bootstrap #214 ROC area: 0.838
# Bootstrap #215 ROC area: 0.853
# Bootstrap #216 ROC area: 0.848
# Bootstrap #217 ROC area: 0.853
# Bootstrap #218 ROC area: 0.846
# Bootstrap #219 ROC area: 0.855
# Bootstrap #220 ROC area: 0.852
# Bootstrap #221 ROC area: 0.860
# Bootstrap #222 ROC area: 0.851
# Bootstrap #223 ROC area: 0.857
# Bootstrap #224 ROC area: 0.853
# Bootstrap #225 ROC area: 0.856
# Bootstrap #226 ROC area: 0.843
# Bootstrap #227 ROC area: 0.849
# Bootstrap #228 ROC area: 0.857
# Bootstrap #229 ROC area: 0.862
# Bootstrap #230 ROC area: 0.859
# Bootstrap #231 ROC area: 0.868
# Bootstrap #232 ROC area: 0.841
# Bootstrap #233 ROC area: 0.850
# Bootstrap #234 ROC area: 0.857
# Bootstrap #235 ROC area: 0.851
# Bootstrap #236 ROC area: 0.853
# Bootstrap #237 ROC area: 0.856
# Bootstrap #238 ROC area: 0.850
# Bootstrap #239 ROC area: 0.859
# Bootstrap #240 ROC area: 0.854
# Bootstrap #241 ROC area: 0.848
# Bootstrap #242 ROC area: 0.858
# Bootstrap #243 ROC area: 0.851
# Bootstrap #244 ROC area: 0.856
# Bootstrap #245 ROC area: 0.851
# Bootstrap #246 ROC area: 0.846
# Bootstrap #247 ROC area: 0.844
# Bootstrap #248 ROC area: 0.845
# Bootstrap #249 ROC area: 0.865
# Bootstrap #250 ROC area: 0.848
# Bootstrap #251 ROC area: 0.850
# Bootstrap #252 ROC area: 0.860
# Bootstrap #253 ROC area: 0.859
# Bootstrap #254 ROC area: 0.858
# Bootstrap #255 ROC area: 0.857
# Bootstrap #256 ROC area: 0.856
# Bootstrap #257 ROC area: 0.855
# Bootstrap #258 ROC area: 0.856
# Bootstrap #259 ROC area: 0.852
# Bootstrap #260 ROC area: 0.849
# Bootstrap #261 ROC area: 0.841
# Bootstrap #262 ROC area: 0.851
# Bootstrap #263 ROC area: 0.854
# Bootstrap #264 ROC area: 0.853
# Bootstrap #265 ROC area: 0.865
# Bootstrap #266 ROC area: 0.854
# Bootstrap #267 ROC area: 0.844
# Bootstrap #268 ROC area: 0.857
# Bootstrap #269 ROC area: 0.843
# Bootstrap #270 ROC area: 0.849
# Bootstrap #271 ROC area: 0.855
# Bootstrap #272 ROC area: 0.850
# Bootstrap #273 ROC area: 0.850
# Bootstrap #274 ROC area: 0.856
# Bootstrap #275 ROC area: 0.855
# Bootstrap #276 ROC area: 0.856
# Bootstrap #277 ROC area: 0.854
# Bootstrap #278 ROC area: 0.854
# Bootstrap #279 ROC area: 0.848
# Bootstrap #280 ROC area: 0.857
# Bootstrap #281 ROC area: 0.844
# Bootstrap #282 ROC area: 0.851
# Bootstrap #283 ROC area: 0.854
# Bootstrap #284 ROC area: 0.849
# Bootstrap #285 ROC area: 0.857
# Bootstrap #286 ROC area: 0.842
# Bootstrap #287 ROC area: 0.853
# Bootstrap #288 ROC area: 0.856
# Bootstrap #289 ROC area: 0.863
# Bootstrap #290 ROC area: 0.846
# Bootstrap #291 ROC area: 0.857
# Bootstrap #292 ROC area: 0.847
# Bootstrap #293 ROC area: 0.854
# Bootstrap #294 ROC area: 0.860
# Bootstrap #295 ROC area: 0.853
# Bootstrap #296 ROC area: 0.851
# Bootstrap #297 ROC area: 0.854
# Bootstrap #298 ROC area: 0.840
# Bootstrap #299 ROC area: 0.850
# Bootstrap #300 ROC area: 0.849
# Bootstrap #301 ROC area: 0.858
# Bootstrap #302 ROC area: 0.863
# Bootstrap #303 ROC area: 0.840
# Bootstrap #304 ROC area: 0.852
# Bootstrap #305 ROC area: 0.841
# Bootstrap #306 ROC area: 0.850
# Bootstrap #307 ROC area: 0.853
# Bootstrap #308 ROC area: 0.858
# Bootstrap #309 ROC area: 0.842
# Bootstrap #310 ROC area: 0.840
# Bootstrap #311 ROC area: 0.842
# Bootstrap #312 ROC area: 0.852
# Bootstrap #313 ROC area: 0.847
# Bootstrap #314 ROC area: 0.853
# Bootstrap #315 ROC area: 0.842
# Bootstrap #316 ROC area: 0.853
# Bootstrap #317 ROC area: 0.859
# Bootstrap #318 ROC area: 0.859
# Bootstrap #319 ROC area: 0.854
# Bootstrap #320 ROC area: 0.865
# Bootstrap #321 ROC area: 0.861
# Bootstrap #322 ROC area: 0.848
# Bootstrap #323 ROC area: 0.856
# Bootstrap #324 ROC area: 0.853
# Bootstrap #325 ROC area: 0.852
# Bootstrap #326 ROC area: 0.855
# Bootstrap #327 ROC area: 0.853
# Bootstrap #328 ROC area: 0.850
# Bootstrap #329 ROC area: 0.857
# Bootstrap #330 ROC area: 0.850
# Bootstrap #331 ROC area: 0.851
# Bootstrap #332 ROC area: 0.857
# Bootstrap #333 ROC area: 0.853
# Bootstrap #334 ROC area: 0.858
# Bootstrap #335 ROC area: 0.855
# Bootstrap #336 ROC area: 0.860
# Bootstrap #337 ROC area: 0.853
# Bootstrap #338 ROC area: 0.854
# Bootstrap #339 ROC area: 0.843
# Bootstrap #340 ROC area: 0.851
# Bootstrap #341 ROC area: 0.850
# Bootstrap #342 ROC area: 0.853
# Bootstrap #343 ROC area: 0.855
# Bootstrap #344 ROC area: 0.865
# Bootstrap #345 ROC area: 0.845
# Bootstrap #346 ROC area: 0.851
# Bootstrap #347 ROC area: 0.852
# Bootstrap #348 ROC area: 0.853
# Bootstrap #349 ROC area: 0.857
# Bootstrap #350 ROC area: 0.856
# Bootstrap #351 ROC area: 0.859
# Bootstrap #352 ROC area: 0.850
# Bootstrap #353 ROC area: 0.851
# Bootstrap #354 ROC area: 0.856
# Bootstrap #355 ROC area: 0.852
# Bootstrap #356 ROC area: 0.859
# Bootstrap #357 ROC area: 0.843
# Bootstrap #358 ROC area: 0.844
# Bootstrap #359 ROC area: 0.858
# Bootstrap #360 ROC area: 0.855
# Bootstrap #361 ROC area: 0.850
# Bootstrap #362 ROC area: 0.847
# Bootstrap #363 ROC area: 0.851
# Bootstrap #364 ROC area: 0.851
# Bootstrap #365 ROC area: 0.856
# Bootstrap #366 ROC area: 0.852
# Bootstrap #367 ROC area: 0.840
# Bootstrap #368 ROC area: 0.860
# Bootstrap #369 ROC area: 0.855
# Bootstrap #370 ROC area: 0.861
# Bootstrap #371 ROC area: 0.860
# Bootstrap #372 ROC area: 0.857
# Bootstrap #373 ROC area: 0.851
# Bootstrap #374 ROC area: 0.865
# Bootstrap #375 ROC area: 0.857
# Bootstrap #376 ROC area: 0.853
# Bootstrap #377 ROC area: 0.854
# Bootstrap #378 ROC area: 0.860
# Bootstrap #379 ROC area: 0.848
# Bootstrap #380 ROC area: 0.844
# Bootstrap #381 ROC area: 0.849
# Bootstrap #382 ROC area: 0.860
# Bootstrap #383 ROC area: 0.857
# Bootstrap #384 ROC area: 0.863
# Bootstrap #385 ROC area: 0.851
# Bootstrap #386 ROC area: 0.862
# Bootstrap #387 ROC area: 0.861
# Bootstrap #388 ROC area: 0.855
# Bootstrap #389 ROC area: 0.851
# Bootstrap #390 ROC area: 0.865
# Bootstrap #391 ROC area: 0.845
# Bootstrap #392 ROC area: 0.860
# Bootstrap #393 ROC area: 0.860
# Bootstrap #394 ROC area: 0.865
# Bootstrap #395 ROC area: 0.851
# Bootstrap #396 ROC area: 0.862
# Bootstrap #397 ROC area: 0.853
# Bootstrap #398 ROC area: 0.851
# Bootstrap #399 ROC area: 0.856
# Bootstrap #400 ROC area: 0.851
# Bootstrap #401 ROC area: 0.851
# Bootstrap #402 ROC area: 0.851
# Bootstrap #403 ROC area: 0.841
# Bootstrap #404 ROC area: 0.851
# Bootstrap #405 ROC area: 0.852
# Bootstrap #406 ROC area: 0.857
# Bootstrap #407 ROC area: 0.856
# Bootstrap #408 ROC area: 0.848
# Bootstrap #409 ROC area: 0.848
# Bootstrap #410 ROC area: 0.849
# Bootstrap #411 ROC area: 0.861
# Bootstrap #412 ROC area: 0.852
# Bootstrap #413 ROC area: 0.850
# Bootstrap #414 ROC area: 0.849
# Bootstrap #415 ROC area: 0.848
# Bootstrap #416 ROC area: 0.864
# Bootstrap #417 ROC area: 0.855
# Bootstrap #418 ROC area: 0.852
# Bootstrap #419 ROC area: 0.853
# Bootstrap #420 ROC area: 0.859
# Bootstrap #421 ROC area: 0.853
# Bootstrap #422 ROC area: 0.847
# Bootstrap #423 ROC area: 0.858
# Bootstrap #424 ROC area: 0.868
# Bootstrap #425 ROC area: 0.849
# Bootstrap #426 ROC area: 0.859
# Bootstrap #427 ROC area: 0.860
# Bootstrap #428 ROC area: 0.854
# Bootstrap #429 ROC area: 0.857
# Bootstrap #430 ROC area: 0.842
# Bootstrap #431 ROC area: 0.847
# Bootstrap #432 ROC area: 0.853
# Bootstrap #433 ROC area: 0.851
# Bootstrap #434 ROC area: 0.852
# Bootstrap #435 ROC area: 0.858
# Bootstrap #436 ROC area: 0.857
# Bootstrap #437 ROC area: 0.848
# Bootstrap #438 ROC area: 0.861
# Bootstrap #439 ROC area: 0.853
# Bootstrap #440 ROC area: 0.850
# Bootstrap #441 ROC area: 0.848
# Bootstrap #442 ROC area: 0.846
# Bootstrap #443 ROC area: 0.854
# Bootstrap #444 ROC area: 0.854
# Bootstrap #445 ROC area: 0.849
# Bootstrap #446 ROC area: 0.850
# Bootstrap #447 ROC area: 0.857
# Bootstrap #448 ROC area: 0.847
# Bootstrap #449 ROC area: 0.856
# Bootstrap #450 ROC area: 0.844
# Bootstrap #451 ROC area: 0.845
# Bootstrap #452 ROC area: 0.849
# Bootstrap #453 ROC area: 0.853
# Bootstrap #454 ROC area: 0.843
# Bootstrap #455 ROC area: 0.848
# Bootstrap #456 ROC area: 0.853
# Bootstrap #457 ROC area: 0.853
# Bootstrap #458 ROC area: 0.850
# Bootstrap #459 ROC area: 0.854
# Bootstrap #460 ROC area: 0.846
# Bootstrap #461 ROC area: 0.860
# Bootstrap #462 ROC area: 0.870
# Bootstrap #463 ROC area: 0.852
# Bootstrap #464 ROC area: 0.860
# Bootstrap #465 ROC area: 0.857
# Bootstrap #466 ROC area: 0.853
# Bootstrap #467 ROC area: 0.861
# Bootstrap #468 ROC area: 0.850
# Bootstrap #469 ROC area: 0.849
# Bootstrap #470 ROC area: 0.855
# Bootstrap #471 ROC area: 0.848
# Bootstrap #472 ROC area: 0.863
# Bootstrap #473 ROC area: 0.847
# Bootstrap #474 ROC area: 0.849
# Bootstrap #475 ROC area: 0.854
# Bootstrap #476 ROC area: 0.855
# Bootstrap #477 ROC area: 0.853
# Bootstrap #478 ROC area: 0.853
# Bootstrap #479 ROC area: 0.857
# Bootstrap #480 ROC area: 0.859
# Bootstrap #481 ROC area: 0.853
# Bootstrap #482 ROC area: 0.849
# Bootstrap #483 ROC area: 0.859
# Bootstrap #484 ROC area: 0.843
# Bootstrap #485 ROC area: 0.852
# Bootstrap #486 ROC area: 0.852
# Bootstrap #487 ROC area: 0.845
# Bootstrap #488 ROC area: 0.856
# Bootstrap #489 ROC area: 0.856
# Bootstrap #490 ROC area: 0.862
# Bootstrap #491 ROC area: 0.843
# Bootstrap #492 ROC area: 0.850
# Bootstrap #493 ROC area: 0.858
# Bootstrap #494 ROC area: 0.850
# Bootstrap #495 ROC area: 0.856
# Bootstrap #496 ROC area: 0.855
# Bootstrap #497 ROC area: 0.856
# Bootstrap #498 ROC area: 0.845
# Bootstrap #499 ROC area: 0.848
# Bootstrap #500 ROC area: 0.858
# Bootstrap #501 ROC area: 0.856
# Bootstrap #502 ROC area: 0.845
# Bootstrap #503 ROC area: 0.859
# Bootstrap #504 ROC area: 0.851
# Bootstrap #505 ROC area: 0.843
# Bootstrap #506 ROC area: 0.855
# Bootstrap #507 ROC area: 0.856
# Bootstrap #508 ROC area: 0.860
# Bootstrap #509 ROC area: 0.851
# Bootstrap #510 ROC area: 0.857
# Bootstrap #511 ROC area: 0.858
# Bootstrap #512 ROC area: 0.855
# Bootstrap #513 ROC area: 0.845
# Bootstrap #514 ROC area: 0.857
# Bootstrap #515 ROC area: 0.849
# Bootstrap #516 ROC area: 0.843
# Bootstrap #517 ROC area: 0.842
# Bootstrap #518 ROC area: 0.861
# Bootstrap #519 ROC area: 0.846
# Bootstrap #520 ROC area: 0.852
# Bootstrap #521 ROC area: 0.862
# Bootstrap #522 ROC area: 0.844
# Bootstrap #523 ROC area: 0.864
# Bootstrap #524 ROC area: 0.862
# Bootstrap #525 ROC area: 0.848
# Bootstrap #526 ROC area: 0.856
# Bootstrap #527 ROC area: 0.849
# Bootstrap #528 ROC area: 0.856
# Bootstrap #529 ROC area: 0.863
# Bootstrap #530 ROC area: 0.857
# Bootstrap #531 ROC area: 0.855
# Bootstrap #532 ROC area: 0.847
# Bootstrap #533 ROC area: 0.855
# Bootstrap #534 ROC area: 0.857
# Bootstrap #535 ROC area: 0.859
# Bootstrap #536 ROC area: 0.865
# Bootstrap #537 ROC area: 0.860
# Bootstrap #538 ROC area: 0.850
# Bootstrap #539 ROC area: 0.845
# Bootstrap #540 ROC area: 0.856
# Bootstrap #541 ROC area: 0.851
# Bootstrap #542 ROC area: 0.852
# Bootstrap #543 ROC area: 0.851
# Bootstrap #544 ROC area: 0.850
# Bootstrap #545 ROC area: 0.857
# Bootstrap #546 ROC area: 0.849
# Bootstrap #547 ROC area: 0.861
# Bootstrap #548 ROC area: 0.848
# Bootstrap #549 ROC area: 0.858
# Bootstrap #550 ROC area: 0.852
# Bootstrap #551 ROC area: 0.858
# Bootstrap #552 ROC area: 0.855
# Bootstrap #553 ROC area: 0.849
# Bootstrap #554 ROC area: 0.864
# Bootstrap #555 ROC area: 0.847
# Bootstrap #556 ROC area: 0.852
# Bootstrap #557 ROC area: 0.849
# Bootstrap #558 ROC area: 0.857
# Bootstrap #559 ROC area: 0.850
# Bootstrap #560 ROC area: 0.854
# Bootstrap #561 ROC area: 0.862
# Bootstrap #562 ROC area: 0.852
# Bootstrap #563 ROC area: 0.863
# Bootstrap #564 ROC area: 0.855
# Bootstrap #565 ROC area: 0.855
# Bootstrap #566 ROC area: 0.857
# Bootstrap #567 ROC area: 0.843
# Bootstrap #568 ROC area: 0.859
# Bootstrap #569 ROC area: 0.863
# Bootstrap #570 ROC area: 0.861
# Bootstrap #571 ROC area: 0.847
# Bootstrap #572 ROC area: 0.860
# Bootstrap #573 ROC area: 0.850
# Bootstrap #574 ROC area: 0.849
# Bootstrap #575 ROC area: 0.846
# Bootstrap #576 ROC area: 0.849
# Bootstrap #577 ROC area: 0.853
# Bootstrap #578 ROC area: 0.852
# Bootstrap #579 ROC area: 0.847
# Bootstrap #580 ROC area: 0.859
# Bootstrap #581 ROC area: 0.858
# Bootstrap #582 ROC area: 0.851
# Bootstrap #583 ROC area: 0.864
# Bootstrap #584 ROC area: 0.837
# Bootstrap #585 ROC area: 0.863
# Bootstrap #586 ROC area: 0.856
# Bootstrap #587 ROC area: 0.862
# Bootstrap #588 ROC area: 0.849
# Bootstrap #589 ROC area: 0.844
# Bootstrap #590 ROC area: 0.853
# Bootstrap #591 ROC area: 0.856
# Bootstrap #592 ROC area: 0.853
# Bootstrap #593 ROC area: 0.855
# Bootstrap #594 ROC area: 0.854
# Bootstrap #595 ROC area: 0.844
# Bootstrap #596 ROC area: 0.844
# Bootstrap #597 ROC area: 0.854
# Bootstrap #598 ROC area: 0.845
# Bootstrap #599 ROC area: 0.846
# Bootstrap #600 ROC area: 0.849
# Bootstrap #601 ROC area: 0.847
# Bootstrap #602 ROC area: 0.850
# Bootstrap #603 ROC area: 0.857
# Bootstrap #604 ROC area: 0.862
# Bootstrap #605 ROC area: 0.846
# Bootstrap #606 ROC area: 0.849
# Bootstrap #607 ROC area: 0.853
# Bootstrap #608 ROC area: 0.848
# Bootstrap #609 ROC area: 0.856
# Bootstrap #610 ROC area: 0.855
# Bootstrap #611 ROC area: 0.861
# Bootstrap #612 ROC area: 0.848
# Bootstrap #613 ROC area: 0.862
# Bootstrap #614 ROC area: 0.858
# Bootstrap #615 ROC area: 0.863
# Bootstrap #616 ROC area: 0.840
# Bootstrap #617 ROC area: 0.862
# Bootstrap #618 ROC area: 0.857
# Bootstrap #619 ROC area: 0.855
# Bootstrap #620 ROC area: 0.849
# Bootstrap #621 ROC area: 0.863
# Bootstrap #622 ROC area: 0.857
# Bootstrap #623 ROC area: 0.847
# Bootstrap #624 ROC area: 0.850
# Bootstrap #625 ROC area: 0.854
# Bootstrap #626 ROC area: 0.859
# Bootstrap #627 ROC area: 0.838
# Bootstrap #628 ROC area: 0.844
# Bootstrap #629 ROC area: 0.853
# Bootstrap #630 ROC area: 0.850
# Bootstrap #631 ROC area: 0.862
# Bootstrap #632 ROC area: 0.853
# Bootstrap #633 ROC area: 0.859
# Bootstrap #634 ROC area: 0.849
# Bootstrap #635 ROC area: 0.858
# Bootstrap #636 ROC area: 0.854
# Bootstrap #637 ROC area: 0.861
# Bootstrap #638 ROC area: 0.844
# Bootstrap #639 ROC area: 0.840
# Bootstrap #640 ROC area: 0.849
# Bootstrap #641 ROC area: 0.849
# Bootstrap #642 ROC area: 0.857
# Bootstrap #643 ROC area: 0.846
# Bootstrap #644 ROC area: 0.848
# Bootstrap #645 ROC area: 0.857
# Bootstrap #646 ROC area: 0.861
# Bootstrap #647 ROC area: 0.855
# Bootstrap #648 ROC area: 0.856
# Bootstrap #649 ROC area: 0.864
# Bootstrap #650 ROC area: 0.843
# Bootstrap #651 ROC area: 0.854
# Bootstrap #652 ROC area: 0.847
# Bootstrap #653 ROC area: 0.861
# Bootstrap #654 ROC area: 0.855
# Bootstrap #655 ROC area: 0.860
# Bootstrap #656 ROC area: 0.854
# Bootstrap #657 ROC area: 0.853
# Bootstrap #658 ROC area: 0.848
# Bootstrap #659 ROC area: 0.860
# Bootstrap #660 ROC area: 0.842
# Bootstrap #661 ROC area: 0.851
# Bootstrap #662 ROC area: 0.857
# Bootstrap #663 ROC area: 0.848
# Bootstrap #664 ROC area: 0.856
# Bootstrap #665 ROC area: 0.851
# Bootstrap #666 ROC area: 0.842
# Bootstrap #667 ROC area: 0.849
# Bootstrap #668 ROC area: 0.859
# Bootstrap #669 ROC area: 0.848
# Bootstrap #670 ROC area: 0.854
# Bootstrap #671 ROC area: 0.851
# Bootstrap #672 ROC area: 0.853
# Bootstrap #673 ROC area: 0.862
# Bootstrap #674 ROC area: 0.850
# Bootstrap #675 ROC area: 0.851
# Bootstrap #676 ROC area: 0.855
# Bootstrap #677 ROC area: 0.844
# Bootstrap #678 ROC area: 0.858
# Bootstrap #679 ROC area: 0.856
# Bootstrap #680 ROC area: 0.837
# Bootstrap #681 ROC area: 0.860
# Bootstrap #682 ROC area: 0.857
# Bootstrap #683 ROC area: 0.846
# Bootstrap #684 ROC area: 0.858
# Bootstrap #685 ROC area: 0.852
# Bootstrap #686 ROC area: 0.852
# Bootstrap #687 ROC area: 0.841
# Bootstrap #688 ROC area: 0.849
# Bootstrap #689 ROC area: 0.845
# Bootstrap #690 ROC area: 0.856
# Bootstrap #691 ROC area: 0.851
# Bootstrap #692 ROC area: 0.853
# Bootstrap #693 ROC area: 0.843
# Bootstrap #694 ROC area: 0.844
# Bootstrap #695 ROC area: 0.852
# Bootstrap #696 ROC area: 0.861
# Bootstrap #697 ROC area: 0.849
# Bootstrap #698 ROC area: 0.839
# Bootstrap #699 ROC area: 0.863
# Bootstrap #700 ROC area: 0.843
# Bootstrap #701 ROC area: 0.857
# Bootstrap #702 ROC area: 0.848
# Bootstrap #703 ROC area: 0.861
# Bootstrap #704 ROC area: 0.837
# Bootstrap #705 ROC area: 0.852
# Bootstrap #706 ROC area: 0.850
# Bootstrap #707 ROC area: 0.859
# Bootstrap #708 ROC area: 0.854
# Bootstrap #709 ROC area: 0.854
# Bootstrap #710 ROC area: 0.849
# Bootstrap #711 ROC area: 0.853
# Bootstrap #712 ROC area: 0.846
# Bootstrap #713 ROC area: 0.861
# Bootstrap #714 ROC area: 0.858
# Bootstrap #715 ROC area: 0.850
# Bootstrap #716 ROC area: 0.858
# Bootstrap #717 ROC area: 0.853
# Bootstrap #718 ROC area: 0.858
# Bootstrap #719 ROC area: 0.851
# Bootstrap #720 ROC area: 0.854
# Bootstrap #721 ROC area: 0.857
# Bootstrap #722 ROC area: 0.858
# Bootstrap #723 ROC area: 0.856
# Bootstrap #724 ROC area: 0.852
# Bootstrap #725 ROC area: 0.860
# Bootstrap #726 ROC area: 0.838
# Bootstrap #727 ROC area: 0.847
# Bootstrap #728 ROC area: 0.845
# Bootstrap #729 ROC area: 0.845
# Bootstrap #730 ROC area: 0.860
# Bootstrap #731 ROC area: 0.850
# Bootstrap #732 ROC area: 0.857
# Bootstrap #733 ROC area: 0.856
# Bootstrap #734 ROC area: 0.848
# Bootstrap #735 ROC area: 0.845
# Bootstrap #736 ROC area: 0.858
# Bootstrap #737 ROC area: 0.841
# Bootstrap #738 ROC area: 0.861
# Bootstrap #739 ROC area: 0.854
# Bootstrap #740 ROC area: 0.851
# Bootstrap #741 ROC area: 0.843
# Bootstrap #742 ROC area: 0.862
# Bootstrap #743 ROC area: 0.845
# Bootstrap #744 ROC area: 0.857
# Bootstrap #745 ROC area: 0.853
# Bootstrap #746 ROC area: 0.854
# Bootstrap #747 ROC area: 0.855
# Bootstrap #748 ROC area: 0.864
# Bootstrap #749 ROC area: 0.849
# Bootstrap #750 ROC area: 0.856
# Bootstrap #751 ROC area: 0.858
# Bootstrap #752 ROC area: 0.856
# Bootstrap #753 ROC area: 0.854
# Bootstrap #754 ROC area: 0.866
# Bootstrap #755 ROC area: 0.847
# Bootstrap #756 ROC area: 0.853
# Bootstrap #757 ROC area: 0.863
# Bootstrap #758 ROC area: 0.851
# Bootstrap #759 ROC area: 0.859
# Bootstrap #760 ROC area: 0.859
# Bootstrap #761 ROC area: 0.858
# Bootstrap #762 ROC area: 0.856
# Bootstrap #763 ROC area: 0.838
# Bootstrap #764 ROC area: 0.846
# Bootstrap #765 ROC area: 0.853
# Bootstrap #766 ROC area: 0.855
# Bootstrap #767 ROC area: 0.854
# Bootstrap #768 ROC area: 0.850
# Bootstrap #769 ROC area: 0.851
# Bootstrap #770 ROC area: 0.854
# Bootstrap #771 ROC area: 0.855
# Bootstrap #772 ROC area: 0.847
# Bootstrap #773 ROC area: 0.864
# Bootstrap #774 ROC area: 0.845
# Bootstrap #775 ROC area: 0.871
# Bootstrap #776 ROC area: 0.865
# Bootstrap #777 ROC area: 0.838
# Bootstrap #778 ROC area: 0.852
# Bootstrap #779 ROC area: 0.849
# Bootstrap #780 ROC area: 0.855
# Bootstrap #781 ROC area: 0.851
# Bootstrap #782 ROC area: 0.848
# Bootstrap #783 ROC area: 0.855
# Bootstrap #784 ROC area: 0.853
# Bootstrap #785 ROC area: 0.863
# Bootstrap #786 ROC area: 0.852
# Bootstrap #787 ROC area: 0.848
# Bootstrap #788 ROC area: 0.854
# Bootstrap #789 ROC area: 0.847
# Bootstrap #790 ROC area: 0.838
# Bootstrap #791 ROC area: 0.857
# Bootstrap #792 ROC area: 0.854
# Bootstrap #793 ROC area: 0.868
# Bootstrap #794 ROC area: 0.845
# Bootstrap #795 ROC area: 0.861
# Bootstrap #796 ROC area: 0.844
# Bootstrap #797 ROC area: 0.844
# Bootstrap #798 ROC area: 0.854
# Bootstrap #799 ROC area: 0.870
# Bootstrap #800 ROC area: 0.855
# Bootstrap #801 ROC area: 0.857
# Bootstrap #802 ROC area: 0.855
# Bootstrap #803 ROC area: 0.857
# Bootstrap #804 ROC area: 0.846
# Bootstrap #805 ROC area: 0.856
# Bootstrap #806 ROC area: 0.860
# Bootstrap #807 ROC area: 0.860
# Bootstrap #808 ROC area: 0.854
# Bootstrap #809 ROC area: 0.842
# Bootstrap #810 ROC area: 0.858
# Bootstrap #811 ROC area: 0.849
# Bootstrap #812 ROC area: 0.853
# Bootstrap #813 ROC area: 0.849
# Bootstrap #814 ROC area: 0.858
# Bootstrap #815 ROC area: 0.852
# Bootstrap #816 ROC area: 0.868
# Bootstrap #817 ROC area: 0.854
# Bootstrap #818 ROC area: 0.853
# Bootstrap #819 ROC area: 0.847
# Bootstrap #820 ROC area: 0.852
# Bootstrap #821 ROC area: 0.863
# Bootstrap #822 ROC area: 0.849
# Bootstrap #823 ROC area: 0.852
# Bootstrap #824 ROC area: 0.856
# Bootstrap #825 ROC area: 0.847
# Bootstrap #826 ROC area: 0.862
# Bootstrap #827 ROC area: 0.857
# Bootstrap #828 ROC area: 0.860
# Bootstrap #829 ROC area: 0.849
# Bootstrap #830 ROC area: 0.856
# Bootstrap #831 ROC area: 0.855
# Bootstrap #832 ROC area: 0.858
# Bootstrap #833 ROC area: 0.846
# Bootstrap #834 ROC area: 0.854
# Bootstrap #835 ROC area: 0.858
# Bootstrap #836 ROC area: 0.848
# Bootstrap #837 ROC area: 0.853
# Bootstrap #838 ROC area: 0.856
# Bootstrap #839 ROC area: 0.855
# Bootstrap #840 ROC area: 0.850
# Bootstrap #841 ROC area: 0.852
# Bootstrap #842 ROC area: 0.864
# Bootstrap #843 ROC area: 0.852
# Bootstrap #844 ROC area: 0.855
# Bootstrap #845 ROC area: 0.858
# Bootstrap #846 ROC area: 0.848
# Bootstrap #847 ROC area: 0.851
# Bootstrap #848 ROC area: 0.861
# Bootstrap #849 ROC area: 0.843
# Bootstrap #850 ROC area: 0.858
# Bootstrap #851 ROC area: 0.842
# Bootstrap #852 ROC area: 0.840
# Bootstrap #853 ROC area: 0.853
# Bootstrap #854 ROC area: 0.851
# Bootstrap #855 ROC area: 0.862
# Bootstrap #856 ROC area: 0.858
# Bootstrap #857 ROC area: 0.838
# Bootstrap #858 ROC area: 0.849
# Bootstrap #859 ROC area: 0.861
# Bootstrap #860 ROC area: 0.848
# Bootstrap #861 ROC area: 0.853
# Bootstrap #862 ROC area: 0.859
# Bootstrap #863 ROC area: 0.855
# Bootstrap #864 ROC area: 0.860
# Bootstrap #865 ROC area: 0.846
# Bootstrap #866 ROC area: 0.863
# Bootstrap #867 ROC area: 0.856
# Bootstrap #868 ROC area: 0.848
# Bootstrap #869 ROC area: 0.853
# Bootstrap #870 ROC area: 0.860
# Bootstrap #871 ROC area: 0.861
# Bootstrap #872 ROC area: 0.849
# Bootstrap #873 ROC area: 0.854
# Bootstrap #874 ROC area: 0.847
# Bootstrap #875 ROC area: 0.850
# Bootstrap #876 ROC area: 0.847
# Bootstrap #877 ROC area: 0.853
# Bootstrap #878 ROC area: 0.854
# Bootstrap #879 ROC area: 0.857
# Bootstrap #880 ROC area: 0.843
# Bootstrap #881 ROC area: 0.845
# Bootstrap #882 ROC area: 0.848
# Bootstrap #883 ROC area: 0.853
# Bootstrap #884 ROC area: 0.855
# Bootstrap #885 ROC area: 0.839
# Bootstrap #886 ROC area: 0.857
# Bootstrap #887 ROC area: 0.846
# Bootstrap #888 ROC area: 0.849
# Bootstrap #889 ROC area: 0.860
# Bootstrap #890 ROC area: 0.843
# Bootstrap #891 ROC area: 0.851
# Bootstrap #892 ROC area: 0.851
# Bootstrap #893 ROC area: 0.852
# Bootstrap #894 ROC area: 0.858
# Bootstrap #895 ROC area: 0.851
# Bootstrap #896 ROC area: 0.854
# Bootstrap #897 ROC area: 0.844
# Bootstrap #898 ROC area: 0.850
# Bootstrap #899 ROC area: 0.834
# Bootstrap #900 ROC area: 0.854
# Bootstrap #901 ROC area: 0.841
# Bootstrap #902 ROC area: 0.856
# Bootstrap #903 ROC area: 0.848
# Bootstrap #904 ROC area: 0.844
# Bootstrap #905 ROC area: 0.857
# Bootstrap #906 ROC area: 0.854
# Bootstrap #907 ROC area: 0.857
# Bootstrap #908 ROC area: 0.851
# Bootstrap #909 ROC area: 0.852
# Bootstrap #910 ROC area: 0.851
# Bootstrap #911 ROC area: 0.855
# Bootstrap #912 ROC area: 0.851
# Bootstrap #913 ROC area: 0.855
# Bootstrap #914 ROC area: 0.849
# Bootstrap #915 ROC area: 0.855
# Bootstrap #916 ROC area: 0.852
# Bootstrap #917 ROC area: 0.855
# Bootstrap #918 ROC area: 0.852
# Bootstrap #919 ROC area: 0.861
# Bootstrap #920 ROC area: 0.848
# Bootstrap #921 ROC area: 0.859
# Bootstrap #922 ROC area: 0.836
# Bootstrap #923 ROC area: 0.858
# Bootstrap #924 ROC area: 0.851
# Bootstrap #925 ROC area: 0.853
# Bootstrap #926 ROC area: 0.849
# Bootstrap #927 ROC area: 0.848
# Bootstrap #928 ROC area: 0.853
# Bootstrap #929 ROC area: 0.855
# Bootstrap #930 ROC area: 0.849
# Bootstrap #931 ROC area: 0.851
# Bootstrap #932 ROC area: 0.846
# Bootstrap #933 ROC area: 0.856
# Bootstrap #934 ROC area: 0.855
# Bootstrap #935 ROC area: 0.847
# Bootstrap #936 ROC area: 0.855
# Bootstrap #937 ROC area: 0.847
# Bootstrap #938 ROC area: 0.866
# Bootstrap #939 ROC area: 0.853
# Bootstrap #940 ROC area: 0.861
# Bootstrap #941 ROC area: 0.853
# Bootstrap #942 ROC area: 0.856
# Bootstrap #943 ROC area: 0.848
# Bootstrap #944 ROC area: 0.852
# Bootstrap #945 ROC area: 0.855
# Bootstrap #946 ROC area: 0.859
# Bootstrap #947 ROC area: 0.853
# Bootstrap #948 ROC area: 0.853
# Bootstrap #949 ROC area: 0.849
# Bootstrap #950 ROC area: 0.849
# Bootstrap #951 ROC area: 0.846
# Bootstrap #952 ROC area: 0.856
# Bootstrap #953 ROC area: 0.855
# Bootstrap #954 ROC area: 0.861
# Bootstrap #955 ROC area: 0.844
# Bootstrap #956 ROC area: 0.845
# Bootstrap #957 ROC area: 0.863
# Bootstrap #958 ROC area: 0.850
# Bootstrap #959 ROC area: 0.855
# Bootstrap #960 ROC area: 0.850
# Bootstrap #961 ROC area: 0.847
# Bootstrap #962 ROC area: 0.853
# Bootstrap #963 ROC area: 0.855
# Bootstrap #964 ROC area: 0.851
# Bootstrap #965 ROC area: 0.856
# Bootstrap #966 ROC area: 0.851
# Bootstrap #967 ROC area: 0.856
# Bootstrap #968 ROC area: 0.855
# Bootstrap #969 ROC area: 0.859
# Bootstrap #970 ROC area: 0.846
# Bootstrap #971 ROC area: 0.859
# Bootstrap #972 ROC area: 0.860
# Bootstrap #973 ROC area: 0.856
# Bootstrap #974 ROC area: 0.848
# Bootstrap #975 ROC area: 0.846
# Bootstrap #976 ROC area: 0.854
# Bootstrap #977 ROC area: 0.855
# Bootstrap #978 ROC area: 0.838
# Bootstrap #979 ROC area: 0.842
# Bootstrap #980 ROC area: 0.854
# Bootstrap #981 ROC area: 0.862
# Bootstrap #982 ROC area: 0.843
# Bootstrap #983 ROC area: 0.858
# Bootstrap #984 ROC area: 0.858
# Bootstrap #985 ROC area: 0.859
# Bootstrap #986 ROC area: 0.855
# Bootstrap #987 ROC area: 0.858
# Bootstrap #988 ROC area: 0.841
# Bootstrap #989 ROC area: 0.852
# Bootstrap #990 ROC area: 0.858
# Bootstrap #991 ROC area: 0.858
# Bootstrap #992 ROC area: 0.854
# Bootstrap #993 ROC area: 0.857
# Bootstrap #994 ROC area: 0.858
# Bootstrap #995 ROC area: 0.849
# Bootstrap #996 ROC area: 0.843
# Bootstrap #997 ROC area: 0.845
# Bootstrap #998 ROC area: 0.846
# Bootstrap #999 ROC area: 0.842
# Bootstrap #1000 ROC area: 0.849

# %%
sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

# Computing the lower and upper bound of the 90% confidence interval
# You can change the bounds percentiles to 0.025 and 0.975 to get
# a 95% confidence interval instead.
confidence_lower = sorted_scores[int(0.05 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.95 * len(sorted_scores))]
print("Confidence interval for the score: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Confidence interval for the score: [0.842 - 0.863]

# %% [markdown]
# ### Calculating 95% CI for individual races for Chosen Model

# %% [markdown]
# #### For White Patients Set

# %%
y_pred_white = model.predict_proba(xTestWhite)
print("Original ROC area: {:0.3f}".format(roc_auc_score(yTestWhite, y_pred_white[:,1])))
# Out:
# Original ROC area: 0.854

# %%
n_bootstraps = 1000
rng_seed = 42  # control reproducibility
bootstrapped_scores = []

rng = np.random.RandomState(rng_seed)
for i in range(n_bootstraps):
    # bootstrap by sampling with replacement on the prediction indices
    indices = rng.randint(0, len(y_pred_white), len(y_pred_white))

    score = roc_auc_score(yTestWhite.to_numpy()[indices], y_pred_white[indices, 1])
    bootstrapped_scores.append(score)
    print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))
# Out:
# Bootstrap #1 ROC area: 0.862
# Bootstrap #2 ROC area: 0.851
# Bootstrap #3 ROC area: 0.843
# Bootstrap #4 ROC area: 0.844
# Bootstrap #5 ROC area: 0.864
# Bootstrap #6 ROC area: 0.845
# Bootstrap #7 ROC area: 0.865
# Bootstrap #8 ROC area: 0.844
# Bootstrap #9 ROC area: 0.839
# Bootstrap #10 ROC area: 0.856
# Bootstrap #11 ROC area: 0.839
# Bootstrap #12 ROC area: 0.853
# Bootstrap #13 ROC area: 0.857
# Bootstrap #14 ROC area: 0.851
# Bootstrap #15 ROC area: 0.845
# Bootstrap #16 ROC area: 0.864
# Bootstrap #17 ROC area: 0.853
# Bootstrap #18 ROC area: 0.862
# Bootstrap #19 ROC area: 0.857
# Bootstrap #20 ROC area: 0.853
# Bootstrap #21 ROC area: 0.861
# Bootstrap #22 ROC area: 0.845
# Bootstrap #23 ROC area: 0.859
# Bootstrap #24 ROC area: 0.852
# Bootstrap #25 ROC area: 0.854
# Bootstrap #26 ROC area: 0.853
# Bootstrap #27 ROC area: 0.854
# Bootstrap #28 ROC area: 0.861
# Bootstrap #29 ROC area: 0.849
# Bootstrap #30 ROC area: 0.865
# Bootstrap #31 ROC area: 0.841
# Bootstrap #32 ROC area: 0.859
# Bootstrap #33 ROC area: 0.872
# Bootstrap #34 ROC area: 0.854
# Bootstrap #35 ROC area: 0.856
# Bootstrap #36 ROC area: 0.852
# Bootstrap #37 ROC area: 0.859
# Bootstrap #38 ROC area: 0.854
# Bootstrap #39 ROC area: 0.854
# Bootstrap #40 ROC area: 0.853
# Bootstrap #41 ROC area: 0.847
# Bootstrap #42 ROC area: 0.858
# Bootstrap #43 ROC area: 0.859
# Bootstrap #44 ROC area: 0.854
# Bootstrap #45 ROC area: 0.853
# Bootstrap #46 ROC area: 0.849
# Bootstrap #47 ROC area: 0.848
# Bootstrap #48 ROC area: 0.851
# Bootstrap #49 ROC area: 0.852
# Bootstrap #50 ROC area: 0.860
# Bootstrap #51 ROC area: 0.853
# Bootstrap #52 ROC area: 0.859
# Bootstrap #53 ROC area: 0.845
# Bootstrap #54 ROC area: 0.851
# Bootstrap #55 ROC area: 0.837
# Bootstrap #56 ROC area: 0.856
# Bootstrap #57 ROC area: 0.857
# Bootstrap #58 ROC area: 0.861
# Bootstrap #59 ROC area: 0.860
# Bootstrap #60 ROC area: 0.856
# Bootstrap #61 ROC area: 0.852
# Bootstrap #62 ROC area: 0.848
# Bootstrap #63 ROC area: 0.855
# Bootstrap #64 ROC area: 0.850
# Bootstrap #65 ROC area: 0.838
# Bootstrap #66 ROC area: 0.847
# Bootstrap #67 ROC area: 0.851
# Bootstrap #68 ROC area: 0.860
# Bootstrap #69 ROC area: 0.861
# Bootstrap #70 ROC area: 0.853
# Bootstrap #71 ROC area: 0.849
# Bootstrap #72 ROC area: 0.865
# Bootstrap #73 ROC area: 0.846
# Bootstrap #74 ROC area: 0.850
# Bootstrap #75 ROC area: 0.855
# Bootstrap #76 ROC area: 0.857
# Bootstrap #77 ROC area: 0.859
# Bootstrap #78 ROC area: 0.854
# Bootstrap #79 ROC area: 0.862
# Bootstrap #80 ROC area: 0.840
# Bootstrap #81 ROC area: 0.861
# Bootstrap #82 ROC area: 0.860
# Bootstrap #83 ROC area: 0.857
# Bootstrap #84 ROC area: 0.863
# Bootstrap #85 ROC area: 0.855
# Bootstrap #86 ROC area: 0.847
# Bootstrap #87 ROC area: 0.858
# Bootstrap #88 ROC area: 0.838
# Bootstrap #89 ROC area: 0.865
# Bootstrap #90 ROC area: 0.858
# Bootstrap #91 ROC area: 0.853
# Bootstrap #92 ROC area: 0.858
# Bootstrap #93 ROC area: 0.852
# Bootstrap #94 ROC area: 0.859
# Bootstrap #95 ROC area: 0.862
# Bootstrap #96 ROC area: 0.861
# Bootstrap #97 ROC area: 0.855
# Bootstrap #98 ROC area: 0.848
# Bootstrap #99 ROC area: 0.856
# Bootstrap #100 ROC area: 0.866
# Bootstrap #101 ROC area: 0.861
# Bootstrap #102 ROC area: 0.864
# Bootstrap #103 ROC area: 0.852
# Bootstrap #104 ROC area: 0.846
# Bootstrap #105 ROC area: 0.853
# Bootstrap #106 ROC area: 0.854
# Bootstrap #107 ROC area: 0.852
# Bootstrap #108 ROC area: 0.849
# Bootstrap #109 ROC area: 0.856
# Bootstrap #110 ROC area: 0.858
# Bootstrap #111 ROC area: 0.854
# Bootstrap #112 ROC area: 0.856
# Bootstrap #113 ROC area: 0.855
# Bootstrap #114 ROC area: 0.850
# Bootstrap #115 ROC area: 0.863
# Bootstrap #116 ROC area: 0.852
# Bootstrap #117 ROC area: 0.850
# Bootstrap #118 ROC area: 0.857
# Bootstrap #119 ROC area: 0.857
# Bootstrap #120 ROC area: 0.853
# Bootstrap #121 ROC area: 0.856
# Bootstrap #122 ROC area: 0.862
# Bootstrap #123 ROC area: 0.855
# Bootstrap #124 ROC area: 0.847
# Bootstrap #125 ROC area: 0.857
# Bootstrap #126 ROC area: 0.858
# Bootstrap #127 ROC area: 0.856
# Bootstrap #128 ROC area: 0.857
# Bootstrap #129 ROC area: 0.854
# Bootstrap #130 ROC area: 0.856
# Bootstrap #131 ROC area: 0.852
# Bootstrap #132 ROC area: 0.869
# Bootstrap #133 ROC area: 0.854
# Bootstrap #134 ROC area: 0.839
# Bootstrap #135 ROC area: 0.859
# Bootstrap #136 ROC area: 0.845
# Bootstrap #137 ROC area: 0.845
# Bootstrap #138 ROC area: 0.867
# Bootstrap #139 ROC area: 0.850
# Bootstrap #140 ROC area: 0.863
# Bootstrap #141 ROC area: 0.853
# Bootstrap #142 ROC area: 0.848
# Bootstrap #143 ROC area: 0.862
# Bootstrap #144 ROC area: 0.860
# Bootstrap #145 ROC area: 0.860
# Bootstrap #146 ROC area: 0.842
# Bootstrap #147 ROC area: 0.848
# Bootstrap #148 ROC area: 0.851
# Bootstrap #149 ROC area: 0.855
# Bootstrap #150 ROC area: 0.853
# Bootstrap #151 ROC area: 0.848
# Bootstrap #152 ROC area: 0.855
# Bootstrap #153 ROC area: 0.853
# Bootstrap #154 ROC area: 0.855
# Bootstrap #155 ROC area: 0.860
# Bootstrap #156 ROC area: 0.858
# Bootstrap #157 ROC area: 0.846
# Bootstrap #158 ROC area: 0.869
# Bootstrap #159 ROC area: 0.842
# Bootstrap #160 ROC area: 0.856
# Bootstrap #161 ROC area: 0.855
# Bootstrap #162 ROC area: 0.848
# Bootstrap #163 ROC area: 0.856
# Bootstrap #164 ROC area: 0.843
# Bootstrap #165 ROC area: 0.849
# Bootstrap #166 ROC area: 0.852
# Bootstrap #167 ROC area: 0.846
# Bootstrap #168 ROC area: 0.866
# Bootstrap #169 ROC area: 0.837
# Bootstrap #170 ROC area: 0.859
# Bootstrap #171 ROC area: 0.860
# Bootstrap #172 ROC area: 0.849
# Bootstrap #173 ROC area: 0.843
# Bootstrap #174 ROC area: 0.856
# Bootstrap #175 ROC area: 0.852
# Bootstrap #176 ROC area: 0.859
# Bootstrap #177 ROC area: 0.850
# Bootstrap #178 ROC area: 0.857
# Bootstrap #179 ROC area: 0.848
# Bootstrap #180 ROC area: 0.867
# Bootstrap #181 ROC area: 0.848
# Bootstrap #182 ROC area: 0.855
# Bootstrap #183 ROC area: 0.853
# Bootstrap #184 ROC area: 0.855
# Bootstrap #185 ROC area: 0.855
# Bootstrap #186 ROC area: 0.867
# Bootstrap #187 ROC area: 0.855
# Bootstrap #188 ROC area: 0.832
# Bootstrap #189 ROC area: 0.851
# Bootstrap #190 ROC area: 0.853
# Bootstrap #191 ROC area: 0.841
# Bootstrap #192 ROC area: 0.839
# Bootstrap #193 ROC area: 0.861
# Bootstrap #194 ROC area: 0.856
# Bootstrap #195 ROC area: 0.866
# Bootstrap #196 ROC area: 0.867
# Bootstrap #197 ROC area: 0.867
# Bootstrap #198 ROC area: 0.854
# Bootstrap #199 ROC area: 0.859
# Bootstrap #200 ROC area: 0.863
# Bootstrap #201 ROC area: 0.866
# Bootstrap #202 ROC area: 0.851
# Bootstrap #203 ROC area: 0.851
# Bootstrap #204 ROC area: 0.852
# Bootstrap #205 ROC area: 0.858
# Bootstrap #206 ROC area: 0.856
# Bootstrap #207 ROC area: 0.858
# Bootstrap #208 ROC area: 0.850
# Bootstrap #209 ROC area: 0.849
# Bootstrap #210 ROC area: 0.855
# Bootstrap #211 ROC area: 0.862
# Bootstrap #212 ROC area: 0.859
# Bootstrap #213 ROC area: 0.854
# Bootstrap #214 ROC area: 0.859
# Bootstrap #215 ROC area: 0.860
# Bootstrap #216 ROC area: 0.843
# Bootstrap #217 ROC area: 0.853
# Bootstrap #218 ROC area: 0.854
# Bootstrap #219 ROC area: 0.844
# Bootstrap #220 ROC area: 0.866
# Bootstrap #221 ROC area: 0.859
# Bootstrap #222 ROC area: 0.849
# Bootstrap #223 ROC area: 0.852
# Bootstrap #224 ROC area: 0.864
# Bootstrap #225 ROC area: 0.851
# Bootstrap #226 ROC area: 0.857
# Bootstrap #227 ROC area: 0.851
# Bootstrap #228 ROC area: 0.848
# Bootstrap #229 ROC area: 0.851
# Bootstrap #230 ROC area: 0.859
# Bootstrap #231 ROC area: 0.851
# Bootstrap #232 ROC area: 0.861
# Bootstrap #233 ROC area: 0.863
# Bootstrap #234 ROC area: 0.853
# Bootstrap #235 ROC area: 0.860
# Bootstrap #236 ROC area: 0.858
# Bootstrap #237 ROC area: 0.857
# Bootstrap #238 ROC area: 0.858
# Bootstrap #239 ROC area: 0.849
# Bootstrap #240 ROC area: 0.848
# Bootstrap #241 ROC area: 0.858
# Bootstrap #242 ROC area: 0.853
# Bootstrap #243 ROC area: 0.863
# Bootstrap #244 ROC area: 0.852
# Bootstrap #245 ROC area: 0.852
# Bootstrap #246 ROC area: 0.846
# Bootstrap #247 ROC area: 0.851
# Bootstrap #248 ROC area: 0.850
# Bootstrap #249 ROC area: 0.848
# Bootstrap #250 ROC area: 0.846
# Bootstrap #251 ROC area: 0.852
# Bootstrap #252 ROC area: 0.862
# Bootstrap #253 ROC area: 0.858
# Bootstrap #254 ROC area: 0.851
# Bootstrap #255 ROC area: 0.848
# Bootstrap #256 ROC area: 0.852
# Bootstrap #257 ROC area: 0.854
# Bootstrap #258 ROC area: 0.855
# Bootstrap #259 ROC area: 0.857
# Bootstrap #260 ROC area: 0.870
# Bootstrap #261 ROC area: 0.843
# Bootstrap #262 ROC area: 0.859
# Bootstrap #263 ROC area: 0.853
# Bootstrap #264 ROC area: 0.855
# Bootstrap #265 ROC area: 0.854
# Bootstrap #266 ROC area: 0.849
# Bootstrap #267 ROC area: 0.859
# Bootstrap #268 ROC area: 0.859
# Bootstrap #269 ROC area: 0.862
# Bootstrap #270 ROC area: 0.840
# Bootstrap #271 ROC area: 0.842
# Bootstrap #272 ROC area: 0.851
# Bootstrap #273 ROC area: 0.848
# Bootstrap #274 ROC area: 0.857
# Bootstrap #275 ROC area: 0.844
# Bootstrap #276 ROC area: 0.854
# Bootstrap #277 ROC area: 0.855
# Bootstrap #278 ROC area: 0.850
# Bootstrap #279 ROC area: 0.858
# Bootstrap #280 ROC area: 0.844
# Bootstrap #281 ROC area: 0.855
# Bootstrap #282 ROC area: 0.859
# Bootstrap #283 ROC area: 0.849
# Bootstrap #284 ROC area: 0.848
# Bootstrap #285 ROC area: 0.865
# Bootstrap #286 ROC area: 0.846
# Bootstrap #287 ROC area: 0.848
# Bootstrap #288 ROC area: 0.845
# Bootstrap #289 ROC area: 0.847
# Bootstrap #290 ROC area: 0.848
# Bootstrap #291 ROC area: 0.854
# Bootstrap #292 ROC area: 0.853
# Bootstrap #293 ROC area: 0.846
# Bootstrap #294 ROC area: 0.850
# Bootstrap #295 ROC area: 0.857
# Bootstrap #296 ROC area: 0.849
# Bootstrap #297 ROC area: 0.855
# Bootstrap #298 ROC area: 0.866
# Bootstrap #299 ROC area: 0.864
# Bootstrap #300 ROC area: 0.845
# Bootstrap #301 ROC area: 0.862
# Bootstrap #302 ROC area: 0.863
# Bootstrap #303 ROC area: 0.862
# Bootstrap #304 ROC area: 0.851
# Bootstrap #305 ROC area: 0.852
# Bootstrap #306 ROC area: 0.860
# Bootstrap #307 ROC area: 0.844
# Bootstrap #308 ROC area: 0.841
# Bootstrap #309 ROC area: 0.861
# Bootstrap #310 ROC area: 0.867
# Bootstrap #311 ROC area: 0.859
# Bootstrap #312 ROC area: 0.855
# Bootstrap #313 ROC area: 0.850
# Bootstrap #314 ROC area: 0.861
# Bootstrap #315 ROC area: 0.854
# Bootstrap #316 ROC area: 0.853
# Bootstrap #317 ROC area: 0.866
# Bootstrap #318 ROC area: 0.859
# Bootstrap #319 ROC area: 0.861
# Bootstrap #320 ROC area: 0.847
# Bootstrap #321 ROC area: 0.842
# Bootstrap #322 ROC area: 0.855
# Bootstrap #323 ROC area: 0.855
# Bootstrap #324 ROC area: 0.857
# Bootstrap #325 ROC area: 0.852
# Bootstrap #326 ROC area: 0.844
# Bootstrap #327 ROC area: 0.859
# Bootstrap #328 ROC area: 0.862
# Bootstrap #329 ROC area: 0.852
# Bootstrap #330 ROC area: 0.863
# Bootstrap #331 ROC area: 0.860
# Bootstrap #332 ROC area: 0.866
# Bootstrap #333 ROC area: 0.859
# Bootstrap #334 ROC area: 0.848
# Bootstrap #335 ROC area: 0.861
# Bootstrap #336 ROC area: 0.840
# Bootstrap #337 ROC area: 0.849
# Bootstrap #338 ROC area: 0.862
# Bootstrap #339 ROC area: 0.855
# Bootstrap #340 ROC area: 0.868
# Bootstrap #341 ROC area: 0.851
# Bootstrap #342 ROC area: 0.854
# Bootstrap #343 ROC area: 0.855
# Bootstrap #344 ROC area: 0.852
# Bootstrap #345 ROC area: 0.855
# Bootstrap #346 ROC area: 0.856
# Bootstrap #347 ROC area: 0.861
# Bootstrap #348 ROC area: 0.848
# Bootstrap #349 ROC area: 0.857
# Bootstrap #350 ROC area: 0.854
# Bootstrap #351 ROC area: 0.854
# Bootstrap #352 ROC area: 0.850
# Bootstrap #353 ROC area: 0.850
# Bootstrap #354 ROC area: 0.858
# Bootstrap #355 ROC area: 0.847
# Bootstrap #356 ROC area: 0.858
# Bootstrap #357 ROC area: 0.857
# Bootstrap #358 ROC area: 0.861
# Bootstrap #359 ROC area: 0.850
# Bootstrap #360 ROC area: 0.860
# Bootstrap #361 ROC area: 0.868
# Bootstrap #362 ROC area: 0.858
# Bootstrap #363 ROC area: 0.850
# Bootstrap #364 ROC area: 0.855
# Bootstrap #365 ROC area: 0.852
# Bootstrap #366 ROC area: 0.862
# Bootstrap #367 ROC area: 0.844
# Bootstrap #368 ROC area: 0.858
# Bootstrap #369 ROC area: 0.856
# Bootstrap #370 ROC area: 0.855
# Bootstrap #371 ROC area: 0.860
# Bootstrap #372 ROC area: 0.851
# Bootstrap #373 ROC area: 0.855
# Bootstrap #374 ROC area: 0.852
# Bootstrap #375 ROC area: 0.854
# Bootstrap #376 ROC area: 0.852
# Bootstrap #377 ROC area: 0.849
# Bootstrap #378 ROC area: 0.857
# Bootstrap #379 ROC area: 0.856
# Bootstrap #380 ROC area: 0.850
# Bootstrap #381 ROC area: 0.856
# Bootstrap #382 ROC area: 0.851
# Bootstrap #383 ROC area: 0.854
# Bootstrap #384 ROC area: 0.856
# Bootstrap #385 ROC area: 0.855
# Bootstrap #386 ROC area: 0.854
# Bootstrap #387 ROC area: 0.858
# Bootstrap #388 ROC area: 0.859
# Bootstrap #389 ROC area: 0.844
# Bootstrap #390 ROC area: 0.861
# Bootstrap #391 ROC area: 0.850
# Bootstrap #392 ROC area: 0.844
# Bootstrap #393 ROC area: 0.852
# Bootstrap #394 ROC area: 0.853
# Bootstrap #395 ROC area: 0.847
# Bootstrap #396 ROC area: 0.840
# Bootstrap #397 ROC area: 0.849
# Bootstrap #398 ROC area: 0.853
# Bootstrap #399 ROC area: 0.864
# Bootstrap #400 ROC area: 0.866
# Bootstrap #401 ROC area: 0.854
# Bootstrap #402 ROC area: 0.856
# Bootstrap #403 ROC area: 0.848
# Bootstrap #404 ROC area: 0.852
# Bootstrap #405 ROC area: 0.854
# Bootstrap #406 ROC area: 0.854
# Bootstrap #407 ROC area: 0.846
# Bootstrap #408 ROC area: 0.850
# Bootstrap #409 ROC area: 0.842
# Bootstrap #410 ROC area: 0.860
# Bootstrap #411 ROC area: 0.855
# Bootstrap #412 ROC area: 0.868
# Bootstrap #413 ROC area: 0.852
# Bootstrap #414 ROC area: 0.860
# Bootstrap #415 ROC area: 0.844
# Bootstrap #416 ROC area: 0.863
# Bootstrap #417 ROC area: 0.853
# Bootstrap #418 ROC area: 0.866
# Bootstrap #419 ROC area: 0.861
# Bootstrap #420 ROC area: 0.855
# Bootstrap #421 ROC area: 0.859
# Bootstrap #422 ROC area: 0.861
# Bootstrap #423 ROC area: 0.858
# Bootstrap #424 ROC area: 0.863
# Bootstrap #425 ROC area: 0.860
# Bootstrap #426 ROC area: 0.856
# Bootstrap #427 ROC area: 0.846
# Bootstrap #428 ROC area: 0.863
# Bootstrap #429 ROC area: 0.846
# Bootstrap #430 ROC area: 0.859
# Bootstrap #431 ROC area: 0.856
# Bootstrap #432 ROC area: 0.849
# Bootstrap #433 ROC area: 0.847
# Bootstrap #434 ROC area: 0.852
# Bootstrap #435 ROC area: 0.845
# Bootstrap #436 ROC area: 0.845
# Bootstrap #437 ROC area: 0.865
# Bootstrap #438 ROC area: 0.860
# Bootstrap #439 ROC area: 0.845
# Bootstrap #440 ROC area: 0.840
# Bootstrap #441 ROC area: 0.846
# Bootstrap #442 ROC area: 0.850
# Bootstrap #443 ROC area: 0.844
# Bootstrap #444 ROC area: 0.847
# Bootstrap #445 ROC area: 0.860
# Bootstrap #446 ROC area: 0.863
# Bootstrap #447 ROC area: 0.856
# Bootstrap #448 ROC area: 0.858
# Bootstrap #449 ROC area: 0.856
# Bootstrap #450 ROC area: 0.851
# Bootstrap #451 ROC area: 0.849
# Bootstrap #452 ROC area: 0.855
# Bootstrap #453 ROC area: 0.856
# Bootstrap #454 ROC area: 0.854
# Bootstrap #455 ROC area: 0.865
# Bootstrap #456 ROC area: 0.851
# Bootstrap #457 ROC area: 0.843
# Bootstrap #458 ROC area: 0.841
# Bootstrap #459 ROC area: 0.860
# Bootstrap #460 ROC area: 0.849
# Bootstrap #461 ROC area: 0.855
# Bootstrap #462 ROC area: 0.863
# Bootstrap #463 ROC area: 0.840
# Bootstrap #464 ROC area: 0.844
# Bootstrap #465 ROC area: 0.864
# Bootstrap #466 ROC area: 0.851
# Bootstrap #467 ROC area: 0.857
# Bootstrap #468 ROC area: 0.846
# Bootstrap #469 ROC area: 0.844
# Bootstrap #470 ROC area: 0.860
# Bootstrap #471 ROC area: 0.856
# Bootstrap #472 ROC area: 0.852
# Bootstrap #473 ROC area: 0.857
# Bootstrap #474 ROC area: 0.854
# Bootstrap #475 ROC area: 0.843
# Bootstrap #476 ROC area: 0.854
# Bootstrap #477 ROC area: 0.849
# Bootstrap #478 ROC area: 0.858
# Bootstrap #479 ROC area: 0.857
# Bootstrap #480 ROC area: 0.848
# Bootstrap #481 ROC area: 0.850
# Bootstrap #482 ROC area: 0.855
# Bootstrap #483 ROC area: 0.856
# Bootstrap #484 ROC area: 0.857
# Bootstrap #485 ROC area: 0.849
# Bootstrap #486 ROC area: 0.855
# Bootstrap #487 ROC area: 0.859
# Bootstrap #488 ROC area: 0.831
# Bootstrap #489 ROC area: 0.854
# Bootstrap #490 ROC area: 0.857
# Bootstrap #491 ROC area: 0.850
# Bootstrap #492 ROC area: 0.843
# Bootstrap #493 ROC area: 0.843
# Bootstrap #494 ROC area: 0.848
# Bootstrap #495 ROC area: 0.846
# Bootstrap #496 ROC area: 0.865
# Bootstrap #497 ROC area: 0.852
# Bootstrap #498 ROC area: 0.861
# Bootstrap #499 ROC area: 0.864
# Bootstrap #500 ROC area: 0.848
# Bootstrap #501 ROC area: 0.851
# Bootstrap #502 ROC area: 0.858
# Bootstrap #503 ROC area: 0.851
# Bootstrap #504 ROC area: 0.849
# Bootstrap #505 ROC area: 0.848
# Bootstrap #506 ROC area: 0.850
# Bootstrap #507 ROC area: 0.849
# Bootstrap #508 ROC area: 0.859
# Bootstrap #509 ROC area: 0.852
# Bootstrap #510 ROC area: 0.853
# Bootstrap #511 ROC area: 0.856
# Bootstrap #512 ROC area: 0.849
# Bootstrap #513 ROC area: 0.838
# Bootstrap #514 ROC area: 0.855
# Bootstrap #515 ROC area: 0.862
# Bootstrap #516 ROC area: 0.853
# Bootstrap #517 ROC area: 0.863
# Bootstrap #518 ROC area: 0.861
# Bootstrap #519 ROC area: 0.857
# Bootstrap #520 ROC area: 0.862
# Bootstrap #521 ROC area: 0.864
# Bootstrap #522 ROC area: 0.854
# Bootstrap #523 ROC area: 0.865
# Bootstrap #524 ROC area: 0.853
# Bootstrap #525 ROC area: 0.854
# Bootstrap #526 ROC area: 0.840
# Bootstrap #527 ROC area: 0.861
# Bootstrap #528 ROC area: 0.851
# Bootstrap #529 ROC area: 0.859
# Bootstrap #530 ROC area: 0.864
# Bootstrap #531 ROC area: 0.868
# Bootstrap #532 ROC area: 0.859
# Bootstrap #533 ROC area: 0.847
# Bootstrap #534 ROC area: 0.845
# Bootstrap #535 ROC area: 0.859
# Bootstrap #536 ROC area: 0.855
# Bootstrap #537 ROC area: 0.853
# Bootstrap #538 ROC area: 0.853
# Bootstrap #539 ROC area: 0.851
# Bootstrap #540 ROC area: 0.864
# Bootstrap #541 ROC area: 0.855
# Bootstrap #542 ROC area: 0.844
# Bootstrap #543 ROC area: 0.846
# Bootstrap #544 ROC area: 0.855
# Bootstrap #545 ROC area: 0.847
# Bootstrap #546 ROC area: 0.853
# Bootstrap #547 ROC area: 0.850
# Bootstrap #548 ROC area: 0.846
# Bootstrap #549 ROC area: 0.868
# Bootstrap #550 ROC area: 0.864
# Bootstrap #551 ROC area: 0.844
# Bootstrap #552 ROC area: 0.853
# Bootstrap #553 ROC area: 0.856
# Bootstrap #554 ROC area: 0.848
# Bootstrap #555 ROC area: 0.852
# Bootstrap #556 ROC area: 0.859
# Bootstrap #557 ROC area: 0.866
# Bootstrap #558 ROC area: 0.856
# Bootstrap #559 ROC area: 0.853
# Bootstrap #560 ROC area: 0.851
# Bootstrap #561 ROC area: 0.845
# Bootstrap #562 ROC area: 0.865
# Bootstrap #563 ROC area: 0.866
# Bootstrap #564 ROC area: 0.845
# Bootstrap #565 ROC area: 0.857
# Bootstrap #566 ROC area: 0.856
# Bootstrap #567 ROC area: 0.853
# Bootstrap #568 ROC area: 0.862
# Bootstrap #569 ROC area: 0.853
# Bootstrap #570 ROC area: 0.854
# Bootstrap #571 ROC area: 0.851
# Bootstrap #572 ROC area: 0.854
# Bootstrap #573 ROC area: 0.863
# Bootstrap #574 ROC area: 0.849
# Bootstrap #575 ROC area: 0.862
# Bootstrap #576 ROC area: 0.848
# Bootstrap #577 ROC area: 0.865
# Bootstrap #578 ROC area: 0.854
# Bootstrap #579 ROC area: 0.852
# Bootstrap #580 ROC area: 0.868
# Bootstrap #581 ROC area: 0.845
# Bootstrap #582 ROC area: 0.853
# Bootstrap #583 ROC area: 0.864
# Bootstrap #584 ROC area: 0.859
# Bootstrap #585 ROC area: 0.856
# Bootstrap #586 ROC area: 0.853
# Bootstrap #587 ROC area: 0.854
# Bootstrap #588 ROC area: 0.859
# Bootstrap #589 ROC area: 0.847
# Bootstrap #590 ROC area: 0.838
# Bootstrap #591 ROC area: 0.840
# Bootstrap #592 ROC area: 0.850
# Bootstrap #593 ROC area: 0.846
# Bootstrap #594 ROC area: 0.861
# Bootstrap #595 ROC area: 0.853
# Bootstrap #596 ROC area: 0.855
# Bootstrap #597 ROC area: 0.855
# Bootstrap #598 ROC area: 0.859
# Bootstrap #599 ROC area: 0.860
# Bootstrap #600 ROC area: 0.851
# Bootstrap #601 ROC area: 0.853
# Bootstrap #602 ROC area: 0.848
# Bootstrap #603 ROC area: 0.842
# Bootstrap #604 ROC area: 0.851
# Bootstrap #605 ROC area: 0.843
# Bootstrap #606 ROC area: 0.858
# Bootstrap #607 ROC area: 0.858
# Bootstrap #608 ROC area: 0.849
# Bootstrap #609 ROC area: 0.862
# Bootstrap #610 ROC area: 0.858
# Bootstrap #611 ROC area: 0.850
# Bootstrap #612 ROC area: 0.829
# Bootstrap #613 ROC area: 0.858
# Bootstrap #614 ROC area: 0.854
# Bootstrap #615 ROC area: 0.859
# Bootstrap #616 ROC area: 0.860
# Bootstrap #617 ROC area: 0.864
# Bootstrap #618 ROC area: 0.847
# Bootstrap #619 ROC area: 0.851
# Bootstrap #620 ROC area: 0.858
# Bootstrap #621 ROC area: 0.860
# Bootstrap #622 ROC area: 0.851
# Bootstrap #623 ROC area: 0.854
# Bootstrap #624 ROC area: 0.854
# Bootstrap #625 ROC area: 0.855
# Bootstrap #626 ROC area: 0.852
# Bootstrap #627 ROC area: 0.845
# Bootstrap #628 ROC area: 0.847
# Bootstrap #629 ROC area: 0.858
# Bootstrap #630 ROC area: 0.850
# Bootstrap #631 ROC area: 0.860
# Bootstrap #632 ROC area: 0.858
# Bootstrap #633 ROC area: 0.848
# Bootstrap #634 ROC area: 0.852
# Bootstrap #635 ROC area: 0.856
# Bootstrap #636 ROC area: 0.865
# Bootstrap #637 ROC area: 0.863
# Bootstrap #638 ROC area: 0.859
# Bootstrap #639 ROC area: 0.862
# Bootstrap #640 ROC area: 0.852
# Bootstrap #641 ROC area: 0.845
# Bootstrap #642 ROC area: 0.851
# Bootstrap #643 ROC area: 0.846
# Bootstrap #644 ROC area: 0.862
# Bootstrap #645 ROC area: 0.851
# Bootstrap #646 ROC area: 0.860
# Bootstrap #647 ROC area: 0.856
# Bootstrap #648 ROC area: 0.855
# Bootstrap #649 ROC area: 0.857
# Bootstrap #650 ROC area: 0.851
# Bootstrap #651 ROC area: 0.858
# Bootstrap #652 ROC area: 0.858
# Bootstrap #653 ROC area: 0.841
# Bootstrap #654 ROC area: 0.860
# Bootstrap #655 ROC area: 0.855
# Bootstrap #656 ROC area: 0.847
# Bootstrap #657 ROC area: 0.849
# Bootstrap #658 ROC area: 0.857
# Bootstrap #659 ROC area: 0.853
# Bootstrap #660 ROC area: 0.859
# Bootstrap #661 ROC area: 0.852
# Bootstrap #662 ROC area: 0.848
# Bootstrap #663 ROC area: 0.851
# Bootstrap #664 ROC area: 0.851
# Bootstrap #665 ROC area: 0.857
# Bootstrap #666 ROC area: 0.861
# Bootstrap #667 ROC area: 0.852
# Bootstrap #668 ROC area: 0.848
# Bootstrap #669 ROC area: 0.868
# Bootstrap #670 ROC area: 0.855
# Bootstrap #671 ROC area: 0.854
# Bootstrap #672 ROC area: 0.850
# Bootstrap #673 ROC area: 0.858
# Bootstrap #674 ROC area: 0.853
# Bootstrap #675 ROC area: 0.850
# Bootstrap #676 ROC area: 0.859
# Bootstrap #677 ROC area: 0.864
# Bootstrap #678 ROC area: 0.848
# Bootstrap #679 ROC area: 0.851
# Bootstrap #680 ROC area: 0.862
# Bootstrap #681 ROC area: 0.840
# Bootstrap #682 ROC area: 0.853
# Bootstrap #683 ROC area: 0.841
# Bootstrap #684 ROC area: 0.858
# Bootstrap #685 ROC area: 0.851
# Bootstrap #686 ROC area: 0.848
# Bootstrap #687 ROC area: 0.851
# Bootstrap #688 ROC area: 0.855
# Bootstrap #689 ROC area: 0.854
# Bootstrap #690 ROC area: 0.856
# Bootstrap #691 ROC area: 0.855
# Bootstrap #692 ROC area: 0.857
# Bootstrap #693 ROC area: 0.841
# Bootstrap #694 ROC area: 0.858
# Bootstrap #695 ROC area: 0.847
# Bootstrap #696 ROC area: 0.860
# Bootstrap #697 ROC area: 0.852
# Bootstrap #698 ROC area: 0.865
# Bootstrap #699 ROC area: 0.853
# Bootstrap #700 ROC area: 0.863
# Bootstrap #701 ROC area: 0.855
# Bootstrap #702 ROC area: 0.843
# Bootstrap #703 ROC area: 0.859
# Bootstrap #704 ROC area: 0.848
# Bootstrap #705 ROC area: 0.846
# Bootstrap #706 ROC area: 0.846
# Bootstrap #707 ROC area: 0.856
# Bootstrap #708 ROC area: 0.862
# Bootstrap #709 ROC area: 0.860
# Bootstrap #710 ROC area: 0.858
# Bootstrap #711 ROC area: 0.847
# Bootstrap #712 ROC area: 0.862
# Bootstrap #713 ROC area: 0.861
# Bootstrap #714 ROC area: 0.856
# Bootstrap #715 ROC area: 0.851
# Bootstrap #716 ROC area: 0.847
# Bootstrap #717 ROC area: 0.854
# Bootstrap #718 ROC area: 0.852
# Bootstrap #719 ROC area: 0.856
# Bootstrap #720 ROC area: 0.850
# Bootstrap #721 ROC area: 0.855
# Bootstrap #722 ROC area: 0.854
# Bootstrap #723 ROC area: 0.855
# Bootstrap #724 ROC area: 0.841
# Bootstrap #725 ROC area: 0.855
# Bootstrap #726 ROC area: 0.845
# Bootstrap #727 ROC area: 0.857
# Bootstrap #728 ROC area: 0.856
# Bootstrap #729 ROC area: 0.857
# Bootstrap #730 ROC area: 0.852
# Bootstrap #731 ROC area: 0.863
# Bootstrap #732 ROC area: 0.867
# Bootstrap #733 ROC area: 0.855
# Bootstrap #734 ROC area: 0.857
# Bootstrap #735 ROC area: 0.845
# Bootstrap #736 ROC area: 0.850
# Bootstrap #737 ROC area: 0.848
# Bootstrap #738 ROC area: 0.843
# Bootstrap #739 ROC area: 0.851
# Bootstrap #740 ROC area: 0.847
# Bootstrap #741 ROC area: 0.857
# Bootstrap #742 ROC area: 0.853
# Bootstrap #743 ROC area: 0.851
# Bootstrap #744 ROC area: 0.864
# Bootstrap #745 ROC area: 0.859
# Bootstrap #746 ROC area: 0.849
# Bootstrap #747 ROC area: 0.848
# Bootstrap #748 ROC area: 0.854
# Bootstrap #749 ROC area: 0.859
# Bootstrap #750 ROC area: 0.849
# Bootstrap #751 ROC area: 0.848
# Bootstrap #752 ROC area: 0.850
# Bootstrap #753 ROC area: 0.841
# Bootstrap #754 ROC area: 0.871
# Bootstrap #755 ROC area: 0.855
# Bootstrap #756 ROC area: 0.838
# Bootstrap #757 ROC area: 0.865
# Bootstrap #758 ROC area: 0.856
# Bootstrap #759 ROC area: 0.855
# Bootstrap #760 ROC area: 0.854
# Bootstrap #761 ROC area: 0.854
# Bootstrap #762 ROC area: 0.856
# Bootstrap #763 ROC area: 0.850
# Bootstrap #764 ROC area: 0.845
# Bootstrap #765 ROC area: 0.857
# Bootstrap #766 ROC area: 0.849
# Bootstrap #767 ROC area: 0.846
# Bootstrap #768 ROC area: 0.861
# Bootstrap #769 ROC area: 0.853
# Bootstrap #770 ROC area: 0.853
# Bootstrap #771 ROC area: 0.855
# Bootstrap #772 ROC area: 0.848
# Bootstrap #773 ROC area: 0.857
# Bootstrap #774 ROC area: 0.854
# Bootstrap #775 ROC area: 0.859
# Bootstrap #776 ROC area: 0.855
# Bootstrap #777 ROC area: 0.856
# Bootstrap #778 ROC area: 0.861
# Bootstrap #779 ROC area: 0.862
# Bootstrap #780 ROC area: 0.855
# Bootstrap #781 ROC area: 0.856
# Bootstrap #782 ROC area: 0.851
# Bootstrap #783 ROC area: 0.866
# Bootstrap #784 ROC area: 0.860
# Bootstrap #785 ROC area: 0.857
# Bootstrap #786 ROC area: 0.852
# Bootstrap #787 ROC area: 0.844
# Bootstrap #788 ROC area: 0.856
# Bootstrap #789 ROC area: 0.838
# Bootstrap #790 ROC area: 0.854
# Bootstrap #791 ROC area: 0.859
# Bootstrap #792 ROC area: 0.850
# Bootstrap #793 ROC area: 0.845
# Bootstrap #794 ROC area: 0.855
# Bootstrap #795 ROC area: 0.859
# Bootstrap #796 ROC area: 0.860
# Bootstrap #797 ROC area: 0.861
# Bootstrap #798 ROC area: 0.855
# Bootstrap #799 ROC area: 0.846
# Bootstrap #800 ROC area: 0.845
# Bootstrap #801 ROC area: 0.851
# Bootstrap #802 ROC area: 0.862
# Bootstrap #803 ROC area: 0.848
# Bootstrap #804 ROC area: 0.838
# Bootstrap #805 ROC area: 0.852
# Bootstrap #806 ROC area: 0.859
# Bootstrap #807 ROC area: 0.852
# Bootstrap #808 ROC area: 0.858
# Bootstrap #809 ROC area: 0.853
# Bootstrap #810 ROC area: 0.840
# Bootstrap #811 ROC area: 0.850
# Bootstrap #812 ROC area: 0.843
# Bootstrap #813 ROC area: 0.849
# Bootstrap #814 ROC area: 0.854
# Bootstrap #815 ROC area: 0.856
# Bootstrap #816 ROC area: 0.857
# Bootstrap #817 ROC area: 0.855
# Bootstrap #818 ROC area: 0.844
# Bootstrap #819 ROC area: 0.855
# Bootstrap #820 ROC area: 0.847
# Bootstrap #821 ROC area: 0.861
# Bootstrap #822 ROC area: 0.848
# Bootstrap #823 ROC area: 0.840
# Bootstrap #824 ROC area: 0.857
# Bootstrap #825 ROC area: 0.845
# Bootstrap #826 ROC area: 0.847
# Bootstrap #827 ROC area: 0.849
# Bootstrap #828 ROC area: 0.857
# Bootstrap #829 ROC area: 0.852
# Bootstrap #830 ROC area: 0.857
# Bootstrap #831 ROC area: 0.853
# Bootstrap #832 ROC area: 0.860
# Bootstrap #833 ROC area: 0.845
# Bootstrap #834 ROC area: 0.849
# Bootstrap #835 ROC area: 0.843
# Bootstrap #836 ROC area: 0.851
# Bootstrap #837 ROC area: 0.853
# Bootstrap #838 ROC area: 0.858
# Bootstrap #839 ROC area: 0.862
# Bootstrap #840 ROC area: 0.854
# Bootstrap #841 ROC area: 0.864
# Bootstrap #842 ROC area: 0.855
# Bootstrap #843 ROC area: 0.839
# Bootstrap #844 ROC area: 0.835
# Bootstrap #845 ROC area: 0.846
# Bootstrap #846 ROC area: 0.852
# Bootstrap #847 ROC area: 0.849
# Bootstrap #848 ROC area: 0.862
# Bootstrap #849 ROC area: 0.855
# Bootstrap #850 ROC area: 0.862
# Bootstrap #851 ROC area: 0.857
# Bootstrap #852 ROC area: 0.849
# Bootstrap #853 ROC area: 0.853
# Bootstrap #854 ROC area: 0.854
# Bootstrap #855 ROC area: 0.852
# Bootstrap #856 ROC area: 0.856
# Bootstrap #857 ROC area: 0.863
# Bootstrap #858 ROC area: 0.849
# Bootstrap #859 ROC area: 0.850
# Bootstrap #860 ROC area: 0.848
# Bootstrap #861 ROC area: 0.856
# Bootstrap #862 ROC area: 0.855
# Bootstrap #863 ROC area: 0.862
# Bootstrap #864 ROC area: 0.855
# Bootstrap #865 ROC area: 0.855
# Bootstrap #866 ROC area: 0.853
# Bootstrap #867 ROC area: 0.854
# Bootstrap #868 ROC area: 0.852
# Bootstrap #869 ROC area: 0.849
# Bootstrap #870 ROC area: 0.860
# Bootstrap #871 ROC area: 0.856
# Bootstrap #872 ROC area: 0.863
# Bootstrap #873 ROC area: 0.859
# Bootstrap #874 ROC area: 0.849
# Bootstrap #875 ROC area: 0.855
# Bootstrap #876 ROC area: 0.865
# Bootstrap #877 ROC area: 0.864
# Bootstrap #878 ROC area: 0.851
# Bootstrap #879 ROC area: 0.849
# Bootstrap #880 ROC area: 0.845
# Bootstrap #881 ROC area: 0.846
# Bootstrap #882 ROC area: 0.855
# Bootstrap #883 ROC area: 0.834
# Bootstrap #884 ROC area: 0.857
# Bootstrap #885 ROC area: 0.850
# Bootstrap #886 ROC area: 0.853
# Bootstrap #887 ROC area: 0.849
# Bootstrap #888 ROC area: 0.847
# Bootstrap #889 ROC area: 0.873
# Bootstrap #890 ROC area: 0.845
# Bootstrap #891 ROC area: 0.852
# Bootstrap #892 ROC area: 0.851
# Bootstrap #893 ROC area: 0.854
# Bootstrap #894 ROC area: 0.853
# Bootstrap #895 ROC area: 0.853
# Bootstrap #896 ROC area: 0.855
# Bootstrap #897 ROC area: 0.855
# Bootstrap #898 ROC area: 0.855
# Bootstrap #899 ROC area: 0.856
# Bootstrap #900 ROC area: 0.861
# Bootstrap #901 ROC area: 0.853
# Bootstrap #902 ROC area: 0.869
# Bootstrap #903 ROC area: 0.842
# Bootstrap #904 ROC area: 0.855
# Bootstrap #905 ROC area: 0.843
# Bootstrap #906 ROC area: 0.853
# Bootstrap #907 ROC area: 0.850
# Bootstrap #908 ROC area: 0.857
# Bootstrap #909 ROC area: 0.867
# Bootstrap #910 ROC area: 0.858
# Bootstrap #911 ROC area: 0.852
# Bootstrap #912 ROC area: 0.860
# Bootstrap #913 ROC area: 0.837
# Bootstrap #914 ROC area: 0.854
# Bootstrap #915 ROC area: 0.846
# Bootstrap #916 ROC area: 0.852
# Bootstrap #917 ROC area: 0.853
# Bootstrap #918 ROC area: 0.852
# Bootstrap #919 ROC area: 0.861
# Bootstrap #920 ROC area: 0.852
# Bootstrap #921 ROC area: 0.857
# Bootstrap #922 ROC area: 0.848
# Bootstrap #923 ROC area: 0.858
# Bootstrap #924 ROC area: 0.857
# Bootstrap #925 ROC area: 0.852
# Bootstrap #926 ROC area: 0.844
# Bootstrap #927 ROC area: 0.856
# Bootstrap #928 ROC area: 0.861
# Bootstrap #929 ROC area: 0.854
# Bootstrap #930 ROC area: 0.851
# Bootstrap #931 ROC area: 0.852
# Bootstrap #932 ROC area: 0.857
# Bootstrap #933 ROC area: 0.857
# Bootstrap #934 ROC area: 0.856
# Bootstrap #935 ROC area: 0.857
# Bootstrap #936 ROC area: 0.851
# Bootstrap #937 ROC area: 0.852
# Bootstrap #938 ROC area: 0.857
# Bootstrap #939 ROC area: 0.861
# Bootstrap #940 ROC area: 0.846
# Bootstrap #941 ROC area: 0.859
# Bootstrap #942 ROC area: 0.854
# Bootstrap #943 ROC area: 0.861
# Bootstrap #944 ROC area: 0.862
# Bootstrap #945 ROC area: 0.848
# Bootstrap #946 ROC area: 0.846
# Bootstrap #947 ROC area: 0.854
# Bootstrap #948 ROC area: 0.858
# Bootstrap #949 ROC area: 0.864
# Bootstrap #950 ROC area: 0.845
# Bootstrap #951 ROC area: 0.848
# Bootstrap #952 ROC area: 0.841
# Bootstrap #953 ROC area: 0.846
# Bootstrap #954 ROC area: 0.856
# Bootstrap #955 ROC area: 0.852
# Bootstrap #956 ROC area: 0.844
# Bootstrap #957 ROC area: 0.851
# Bootstrap #958 ROC area: 0.851
# Bootstrap #959 ROC area: 0.839
# Bootstrap #960 ROC area: 0.853
# Bootstrap #961 ROC area: 0.850
# Bootstrap #962 ROC area: 0.847
# Bootstrap #963 ROC area: 0.853
# Bootstrap #964 ROC area: 0.849
# Bootstrap #965 ROC area: 0.852
# Bootstrap #966 ROC area: 0.852
# Bootstrap #967 ROC area: 0.863
# Bootstrap #968 ROC area: 0.853
# Bootstrap #969 ROC area: 0.855
# Bootstrap #970 ROC area: 0.853
# Bootstrap #971 ROC area: 0.847
# Bootstrap #972 ROC area: 0.851
# Bootstrap #973 ROC area: 0.852
# Bootstrap #974 ROC area: 0.848
# Bootstrap #975 ROC area: 0.845
# Bootstrap #976 ROC area: 0.841
# Bootstrap #977 ROC area: 0.852
# Bootstrap #978 ROC area: 0.845
# Bootstrap #979 ROC area: 0.850
# Bootstrap #980 ROC area: 0.856
# Bootstrap #981 ROC area: 0.847
# Bootstrap #982 ROC area: 0.852
# Bootstrap #983 ROC area: 0.856
# Bootstrap #984 ROC area: 0.849
# Bootstrap #985 ROC area: 0.868
# Bootstrap #986 ROC area: 0.857
# Bootstrap #987 ROC area: 0.853
# Bootstrap #988 ROC area: 0.843
# Bootstrap #989 ROC area: 0.850
# Bootstrap #990 ROC area: 0.852
# Bootstrap #991 ROC area: 0.842
# Bootstrap #992 ROC area: 0.858
# Bootstrap #993 ROC area: 0.846
# Bootstrap #994 ROC area: 0.858
# Bootstrap #995 ROC area: 0.848
# Bootstrap #996 ROC area: 0.871
# Bootstrap #997 ROC area: 0.866
# Bootstrap #998 ROC area: 0.844
# Bootstrap #999 ROC area: 0.858
# Bootstrap #1000 ROC area: 0.852

# %%
sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

confidence_lower = sorted_scores[int(0.05 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.95 * len(sorted_scores))]
print("Confidence interval for the score on White patients: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Confidence interval for the score on White patients: [0.842 - 0.865]

# %% [markdown]
# #### For Black Patient Set

# %%
y_pred_black = model.predict_proba(xTestBlack)
print("Original ROC area: {:0.3f}".format(roc_auc_score(yTestBlack, y_pred_black[:,1])))
# Out:
# Original ROC area: 0.886

# %%
n_bootstraps = 1000
rng_seed = 42  # control reproducibility
bootstrapped_scores = []

rng = np.random.RandomState(rng_seed)
for i in range(n_bootstraps):
    indices = rng.randint(0, len(y_pred_black), len(y_pred_black))

    score = roc_auc_score(yTestBlack.to_numpy()[indices], y_pred_black[indices, 1])
    bootstrapped_scores.append(score)
    print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))
# Out:
# Bootstrap #1 ROC area: 0.921
# Bootstrap #2 ROC area: 0.881
# Bootstrap #3 ROC area: 0.876
# Bootstrap #4 ROC area: 0.847
# Bootstrap #5 ROC area: 0.856
# Bootstrap #6 ROC area: 0.893
# Bootstrap #7 ROC area: 0.886
# Bootstrap #8 ROC area: 0.858
# Bootstrap #9 ROC area: 0.866
# Bootstrap #10 ROC area: 0.882
# Bootstrap #11 ROC area: 0.892
# Bootstrap #12 ROC area: 0.908
# Bootstrap #13 ROC area: 0.896
# Bootstrap #14 ROC area: 0.906
# Bootstrap #15 ROC area: 0.897
# Bootstrap #16 ROC area: 0.924
# Bootstrap #17 ROC area: 0.884
# Bootstrap #18 ROC area: 0.892
# Bootstrap #19 ROC area: 0.860
# Bootstrap #20 ROC area: 0.850
# Bootstrap #21 ROC area: 0.852
# Bootstrap #22 ROC area: 0.884
# Bootstrap #23 ROC area: 0.895
# Bootstrap #24 ROC area: 0.881
# Bootstrap #25 ROC area: 0.894
# Bootstrap #26 ROC area: 0.906
# Bootstrap #27 ROC area: 0.879
# Bootstrap #28 ROC area: 0.888
# Bootstrap #29 ROC area: 0.893
# Bootstrap #30 ROC area: 0.873
# Bootstrap #31 ROC area: 0.911
# Bootstrap #32 ROC area: 0.881
# Bootstrap #33 ROC area: 0.862
# Bootstrap #34 ROC area: 0.849
# Bootstrap #35 ROC area: 0.875
# Bootstrap #36 ROC area: 0.887
# Bootstrap #37 ROC area: 0.890
# Bootstrap #38 ROC area: 0.900
# Bootstrap #39 ROC area: 0.874
# Bootstrap #40 ROC area: 0.890
# Bootstrap #41 ROC area: 0.897
# Bootstrap #42 ROC area: 0.889
# Bootstrap #43 ROC area: 0.889
# Bootstrap #44 ROC area: 0.834
# Bootstrap #45 ROC area: 0.899
# Bootstrap #46 ROC area: 0.889
# Bootstrap #47 ROC area: 0.902
# Bootstrap #48 ROC area: 0.884
# Bootstrap #49 ROC area: 0.889
# Bootstrap #50 ROC area: 0.871
# Bootstrap #51 ROC area: 0.890
# Bootstrap #52 ROC area: 0.887
# Bootstrap #53 ROC area: 0.865
# Bootstrap #54 ROC area: 0.901
# Bootstrap #55 ROC area: 0.899
# Bootstrap #56 ROC area: 0.867
# Bootstrap #57 ROC area: 0.924
# Bootstrap #58 ROC area: 0.890
# Bootstrap #59 ROC area: 0.879
# Bootstrap #60 ROC area: 0.882
# Bootstrap #61 ROC area: 0.906
# Bootstrap #62 ROC area: 0.884
# Bootstrap #63 ROC area: 0.897
# Bootstrap #64 ROC area: 0.889
# Bootstrap #65 ROC area: 0.867
# Bootstrap #66 ROC area: 0.865
# Bootstrap #67 ROC area: 0.879
# Bootstrap #68 ROC area: 0.867
# Bootstrap #69 ROC area: 0.881
# Bootstrap #70 ROC area: 0.884
# Bootstrap #71 ROC area: 0.888
# Bootstrap #72 ROC area: 0.882
# Bootstrap #73 ROC area: 0.859
# Bootstrap #74 ROC area: 0.881
# Bootstrap #75 ROC area: 0.890
# Bootstrap #76 ROC area: 0.891
# Bootstrap #77 ROC area: 0.889
# Bootstrap #78 ROC area: 0.861
# Bootstrap #79 ROC area: 0.874
# Bootstrap #80 ROC area: 0.895
# Bootstrap #81 ROC area: 0.894
# Bootstrap #82 ROC area: 0.892
# Bootstrap #83 ROC area: 0.890
# Bootstrap #84 ROC area: 0.869
# Bootstrap #85 ROC area: 0.886
# Bootstrap #86 ROC area: 0.884
# Bootstrap #87 ROC area: 0.906
# Bootstrap #88 ROC area: 0.861
# Bootstrap #89 ROC area: 0.877
# Bootstrap #90 ROC area: 0.891
# Bootstrap #91 ROC area: 0.872
# Bootstrap #92 ROC area: 0.899
# Bootstrap #93 ROC area: 0.892
# Bootstrap #94 ROC area: 0.855
# Bootstrap #95 ROC area: 0.884
# Bootstrap #96 ROC area: 0.917
# Bootstrap #97 ROC area: 0.860
# Bootstrap #98 ROC area: 0.884
# Bootstrap #99 ROC area: 0.884
# Bootstrap #100 ROC area: 0.932
# Bootstrap #101 ROC area: 0.898
# Bootstrap #102 ROC area: 0.863
# Bootstrap #103 ROC area: 0.889
# Bootstrap #104 ROC area: 0.871
# Bootstrap #105 ROC area: 0.912
# Bootstrap #106 ROC area: 0.882
# Bootstrap #107 ROC area: 0.887
# Bootstrap #108 ROC area: 0.905
# Bootstrap #109 ROC area: 0.893
# Bootstrap #110 ROC area: 0.901
# Bootstrap #111 ROC area: 0.892
# Bootstrap #112 ROC area: 0.909
# Bootstrap #113 ROC area: 0.900
# Bootstrap #114 ROC area: 0.894
# Bootstrap #115 ROC area: 0.879
# Bootstrap #116 ROC area: 0.888
# Bootstrap #117 ROC area: 0.883
# Bootstrap #118 ROC area: 0.909
# Bootstrap #119 ROC area: 0.892
# Bootstrap #120 ROC area: 0.893
# Bootstrap #121 ROC area: 0.896
# Bootstrap #122 ROC area: 0.889
# Bootstrap #123 ROC area: 0.884
# Bootstrap #124 ROC area: 0.868
# Bootstrap #125 ROC area: 0.858
# Bootstrap #126 ROC area: 0.911
# Bootstrap #127 ROC area: 0.882
# Bootstrap #128 ROC area: 0.886
# Bootstrap #129 ROC area: 0.879
# Bootstrap #130 ROC area: 0.914
# Bootstrap #131 ROC area: 0.867
# Bootstrap #132 ROC area: 0.898
# Bootstrap #133 ROC area: 0.896
# Bootstrap #134 ROC area: 0.892
# Bootstrap #135 ROC area: 0.893
# Bootstrap #136 ROC area: 0.868
# Bootstrap #137 ROC area: 0.903
# Bootstrap #138 ROC area: 0.865
# Bootstrap #139 ROC area: 0.899
# Bootstrap #140 ROC area: 0.859
# Bootstrap #141 ROC area: 0.858
# Bootstrap #142 ROC area: 0.885
# Bootstrap #143 ROC area: 0.885
# Bootstrap #144 ROC area: 0.892
# Bootstrap #145 ROC area: 0.908
# Bootstrap #146 ROC area: 0.885
# Bootstrap #147 ROC area: 0.892
# Bootstrap #148 ROC area: 0.868
# Bootstrap #149 ROC area: 0.877
# Bootstrap #150 ROC area: 0.876
# Bootstrap #151 ROC area: 0.920
# Bootstrap #152 ROC area: 0.879
# Bootstrap #153 ROC area: 0.880
# Bootstrap #154 ROC area: 0.894
# Bootstrap #155 ROC area: 0.887
# Bootstrap #156 ROC area: 0.930
# Bootstrap #157 ROC area: 0.859
# Bootstrap #158 ROC area: 0.880
# Bootstrap #159 ROC area: 0.890
# Bootstrap #160 ROC area: 0.852
# Bootstrap #161 ROC area: 0.878
# Bootstrap #162 ROC area: 0.916
# Bootstrap #163 ROC area: 0.878
# Bootstrap #164 ROC area: 0.892
# Bootstrap #165 ROC area: 0.880
# Bootstrap #166 ROC area: 0.883
# Bootstrap #167 ROC area: 0.886
# Bootstrap #168 ROC area: 0.913
# Bootstrap #169 ROC area: 0.892
# Bootstrap #170 ROC area: 0.872
# Bootstrap #171 ROC area: 0.883
# Bootstrap #172 ROC area: 0.915
# Bootstrap #173 ROC area: 0.890
# Bootstrap #174 ROC area: 0.898
# Bootstrap #175 ROC area: 0.882
# Bootstrap #176 ROC area: 0.879
# Bootstrap #177 ROC area: 0.878
# Bootstrap #178 ROC area: 0.872
# Bootstrap #179 ROC area: 0.913
# Bootstrap #180 ROC area: 0.916
# Bootstrap #181 ROC area: 0.897
# Bootstrap #182 ROC area: 0.869
# Bootstrap #183 ROC area: 0.855
# Bootstrap #184 ROC area: 0.865
# Bootstrap #185 ROC area: 0.914
# Bootstrap #186 ROC area: 0.826
# Bootstrap #187 ROC area: 0.897
# Bootstrap #188 ROC area: 0.897
# Bootstrap #189 ROC area: 0.887
# Bootstrap #190 ROC area: 0.843
# Bootstrap #191 ROC area: 0.864
# Bootstrap #192 ROC area: 0.847
# Bootstrap #193 ROC area: 0.843
# Bootstrap #194 ROC area: 0.883
# Bootstrap #195 ROC area: 0.901
# Bootstrap #196 ROC area: 0.906
# Bootstrap #197 ROC area: 0.870
# Bootstrap #198 ROC area: 0.887
# Bootstrap #199 ROC area: 0.878
# Bootstrap #200 ROC area: 0.884
# Bootstrap #201 ROC area: 0.861
# Bootstrap #202 ROC area: 0.869
# Bootstrap #203 ROC area: 0.899
# Bootstrap #204 ROC area: 0.883
# Bootstrap #205 ROC area: 0.892
# Bootstrap #206 ROC area: 0.894
# Bootstrap #207 ROC area: 0.877
# Bootstrap #208 ROC area: 0.877
# Bootstrap #209 ROC area: 0.893
# Bootstrap #210 ROC area: 0.871
# Bootstrap #211 ROC area: 0.898
# Bootstrap #212 ROC area: 0.885
# Bootstrap #213 ROC area: 0.900
# Bootstrap #214 ROC area: 0.848
# Bootstrap #215 ROC area: 0.859
# Bootstrap #216 ROC area: 0.865
# Bootstrap #217 ROC area: 0.883
# Bootstrap #218 ROC area: 0.883
# Bootstrap #219 ROC area: 0.877
# Bootstrap #220 ROC area: 0.874
# Bootstrap #221 ROC area: 0.895
# Bootstrap #222 ROC area: 0.867
# Bootstrap #223 ROC area: 0.909
# Bootstrap #224 ROC area: 0.865
# Bootstrap #225 ROC area: 0.859
# Bootstrap #226 ROC area: 0.885
# Bootstrap #227 ROC area: 0.854
# Bootstrap #228 ROC area: 0.930
# Bootstrap #229 ROC area: 0.888
# Bootstrap #230 ROC area: 0.889
# Bootstrap #231 ROC area: 0.875
# Bootstrap #232 ROC area: 0.928
# Bootstrap #233 ROC area: 0.878
# Bootstrap #234 ROC area: 0.900
# Bootstrap #235 ROC area: 0.895
# Bootstrap #236 ROC area: 0.837
# Bootstrap #237 ROC area: 0.884
# Bootstrap #238 ROC area: 0.896
# Bootstrap #239 ROC area: 0.878
# Bootstrap #240 ROC area: 0.878
# Bootstrap #241 ROC area: 0.894
# Bootstrap #242 ROC area: 0.923
# Bootstrap #243 ROC area: 0.841
# Bootstrap #244 ROC area: 0.894
# Bootstrap #245 ROC area: 0.868
# Bootstrap #246 ROC area: 0.881
# Bootstrap #247 ROC area: 0.860
# Bootstrap #248 ROC area: 0.870
# Bootstrap #249 ROC area: 0.888
# Bootstrap #250 ROC area: 0.884
# Bootstrap #251 ROC area: 0.843
# Bootstrap #252 ROC area: 0.882
# Bootstrap #253 ROC area: 0.849
# Bootstrap #254 ROC area: 0.896
# Bootstrap #255 ROC area: 0.916
# Bootstrap #256 ROC area: 0.903
# Bootstrap #257 ROC area: 0.907
# Bootstrap #258 ROC area: 0.870
# Bootstrap #259 ROC area: 0.868
# Bootstrap #260 ROC area: 0.873
# Bootstrap #261 ROC area: 0.899
# Bootstrap #262 ROC area: 0.893
# Bootstrap #263 ROC area: 0.888
# Bootstrap #264 ROC area: 0.886
# Bootstrap #265 ROC area: 0.889
# Bootstrap #266 ROC area: 0.895
# Bootstrap #267 ROC area: 0.881
# Bootstrap #268 ROC area: 0.878
# Bootstrap #269 ROC area: 0.884
# Bootstrap #270 ROC area: 0.882
# Bootstrap #271 ROC area: 0.875
# Bootstrap #272 ROC area: 0.918
# Bootstrap #273 ROC area: 0.917
# Bootstrap #274 ROC area: 0.885
# Bootstrap #275 ROC area: 0.837
# Bootstrap #276 ROC area: 0.874
# Bootstrap #277 ROC area: 0.910
# Bootstrap #278 ROC area: 0.877
# Bootstrap #279 ROC area: 0.861
# Bootstrap #280 ROC area: 0.908
# Bootstrap #281 ROC area: 0.889
# Bootstrap #282 ROC area: 0.861
# Bootstrap #283 ROC area: 0.916
# Bootstrap #284 ROC area: 0.865
# Bootstrap #285 ROC area: 0.884
# Bootstrap #286 ROC area: 0.840
# Bootstrap #287 ROC area: 0.892
# Bootstrap #288 ROC area: 0.906
# Bootstrap #289 ROC area: 0.867
# Bootstrap #290 ROC area: 0.884
# Bootstrap #291 ROC area: 0.885
# Bootstrap #292 ROC area: 0.916
# Bootstrap #293 ROC area: 0.897
# Bootstrap #294 ROC area: 0.863
# Bootstrap #295 ROC area: 0.910
# Bootstrap #296 ROC area: 0.884
# Bootstrap #297 ROC area: 0.878
# Bootstrap #298 ROC area: 0.876
# Bootstrap #299 ROC area: 0.899
# Bootstrap #300 ROC area: 0.897
# Bootstrap #301 ROC area: 0.884
# Bootstrap #302 ROC area: 0.915
# Bootstrap #303 ROC area: 0.906
# Bootstrap #304 ROC area: 0.913
# Bootstrap #305 ROC area: 0.893
# Bootstrap #306 ROC area: 0.892
# Bootstrap #307 ROC area: 0.912
# Bootstrap #308 ROC area: 0.899
# Bootstrap #309 ROC area: 0.880
# Bootstrap #310 ROC area: 0.890
# Bootstrap #311 ROC area: 0.892
# Bootstrap #312 ROC area: 0.905
# Bootstrap #313 ROC area: 0.866
# Bootstrap #314 ROC area: 0.911
# Bootstrap #315 ROC area: 0.909
# Bootstrap #316 ROC area: 0.870
# Bootstrap #317 ROC area: 0.902
# Bootstrap #318 ROC area: 0.856
# Bootstrap #319 ROC area: 0.877
# Bootstrap #320 ROC area: 0.919
# Bootstrap #321 ROC area: 0.889
# Bootstrap #322 ROC area: 0.912
# Bootstrap #323 ROC area: 0.897
# Bootstrap #324 ROC area: 0.933
# Bootstrap #325 ROC area: 0.888
# Bootstrap #326 ROC area: 0.904
# Bootstrap #327 ROC area: 0.927
# Bootstrap #328 ROC area: 0.885
# Bootstrap #329 ROC area: 0.917
# Bootstrap #330 ROC area: 0.863
# Bootstrap #331 ROC area: 0.876
# Bootstrap #332 ROC area: 0.877
# Bootstrap #333 ROC area: 0.874
# Bootstrap #334 ROC area: 0.895
# Bootstrap #335 ROC area: 0.876
# Bootstrap #336 ROC area: 0.866
# Bootstrap #337 ROC area: 0.901
# Bootstrap #338 ROC area: 0.865
# Bootstrap #339 ROC area: 0.878
# Bootstrap #340 ROC area: 0.849
# Bootstrap #341 ROC area: 0.880
# Bootstrap #342 ROC area: 0.904
# Bootstrap #343 ROC area: 0.883
# Bootstrap #344 ROC area: 0.896
# Bootstrap #345 ROC area: 0.864
# Bootstrap #346 ROC area: 0.895
# Bootstrap #347 ROC area: 0.888
# Bootstrap #348 ROC area: 0.910
# Bootstrap #349 ROC area: 0.883
# Bootstrap #350 ROC area: 0.882
# Bootstrap #351 ROC area: 0.860
# Bootstrap #352 ROC area: 0.865
# Bootstrap #353 ROC area: 0.896
# Bootstrap #354 ROC area: 0.851
# Bootstrap #355 ROC area: 0.903
# Bootstrap #356 ROC area: 0.893
# Bootstrap #357 ROC area: 0.850
# Bootstrap #358 ROC area: 0.870
# Bootstrap #359 ROC area: 0.897
# Bootstrap #360 ROC area: 0.887
# Bootstrap #361 ROC area: 0.871
# Bootstrap #362 ROC area: 0.896
# Bootstrap #363 ROC area: 0.888
# Bootstrap #364 ROC area: 0.874
# Bootstrap #365 ROC area: 0.899
# Bootstrap #366 ROC area: 0.911
# Bootstrap #367 ROC area: 0.881
# Bootstrap #368 ROC area: 0.876
# Bootstrap #369 ROC area: 0.874
# Bootstrap #370 ROC area: 0.900
# Bootstrap #371 ROC area: 0.867
# Bootstrap #372 ROC area: 0.922
# Bootstrap #373 ROC area: 0.894
# Bootstrap #374 ROC area: 0.862
# Bootstrap #375 ROC area: 0.877
# Bootstrap #376 ROC area: 0.843
# Bootstrap #377 ROC area: 0.889
# Bootstrap #378 ROC area: 0.869
# Bootstrap #379 ROC area: 0.913
# Bootstrap #380 ROC area: 0.903
# Bootstrap #381 ROC area: 0.871
# Bootstrap #382 ROC area: 0.887
# Bootstrap #383 ROC area: 0.920
# Bootstrap #384 ROC area: 0.893
# Bootstrap #385 ROC area: 0.866
# Bootstrap #386 ROC area: 0.861
# Bootstrap #387 ROC area: 0.874
# Bootstrap #388 ROC area: 0.887
# Bootstrap #389 ROC area: 0.857
# Bootstrap #390 ROC area: 0.878
# Bootstrap #391 ROC area: 0.885
# Bootstrap #392 ROC area: 0.852
# Bootstrap #393 ROC area: 0.875
# Bootstrap #394 ROC area: 0.899
# Bootstrap #395 ROC area: 0.891
# Bootstrap #396 ROC area: 0.871
# Bootstrap #397 ROC area: 0.899
# Bootstrap #398 ROC area: 0.869
# Bootstrap #399 ROC area: 0.911
# Bootstrap #400 ROC area: 0.906
# Bootstrap #401 ROC area: 0.905
# Bootstrap #402 ROC area: 0.884
# Bootstrap #403 ROC area: 0.913
# Bootstrap #404 ROC area: 0.917
# Bootstrap #405 ROC area: 0.877
# Bootstrap #406 ROC area: 0.910
# Bootstrap #407 ROC area: 0.895
# Bootstrap #408 ROC area: 0.878
# Bootstrap #409 ROC area: 0.910
# Bootstrap #410 ROC area: 0.842
# Bootstrap #411 ROC area: 0.852
# Bootstrap #412 ROC area: 0.875
# Bootstrap #413 ROC area: 0.891
# Bootstrap #414 ROC area: 0.863
# Bootstrap #415 ROC area: 0.888
# Bootstrap #416 ROC area: 0.849
# Bootstrap #417 ROC area: 0.912
# Bootstrap #418 ROC area: 0.915
# Bootstrap #419 ROC area: 0.886
# Bootstrap #420 ROC area: 0.881
# Bootstrap #421 ROC area: 0.885
# Bootstrap #422 ROC area: 0.893
# Bootstrap #423 ROC area: 0.874
# Bootstrap #424 ROC area: 0.913
# Bootstrap #425 ROC area: 0.893
# Bootstrap #426 ROC area: 0.911
# Bootstrap #427 ROC area: 0.872
# Bootstrap #428 ROC area: 0.918
# Bootstrap #429 ROC area: 0.889
# Bootstrap #430 ROC area: 0.870
# Bootstrap #431 ROC area: 0.857
# Bootstrap #432 ROC area: 0.892
# Bootstrap #433 ROC area: 0.906
# Bootstrap #434 ROC area: 0.900
# Bootstrap #435 ROC area: 0.870
# Bootstrap #436 ROC area: 0.903
# Bootstrap #437 ROC area: 0.889
# Bootstrap #438 ROC area: 0.887
# Bootstrap #439 ROC area: 0.875
# Bootstrap #440 ROC area: 0.862
# Bootstrap #441 ROC area: 0.894
# Bootstrap #442 ROC area: 0.863
# Bootstrap #443 ROC area: 0.878
# Bootstrap #444 ROC area: 0.873
# Bootstrap #445 ROC area: 0.883
# Bootstrap #446 ROC area: 0.893
# Bootstrap #447 ROC area: 0.872
# Bootstrap #448 ROC area: 0.880
# Bootstrap #449 ROC area: 0.883
# Bootstrap #450 ROC area: 0.882
# Bootstrap #451 ROC area: 0.891
# Bootstrap #452 ROC area: 0.909
# Bootstrap #453 ROC area: 0.906
# Bootstrap #454 ROC area: 0.894
# Bootstrap #455 ROC area: 0.875
# Bootstrap #456 ROC area: 0.912
# Bootstrap #457 ROC area: 0.891
# Bootstrap #458 ROC area: 0.883
# Bootstrap #459 ROC area: 0.856
# Bootstrap #460 ROC area: 0.914
# Bootstrap #461 ROC area: 0.904
# Bootstrap #462 ROC area: 0.902
# Bootstrap #463 ROC area: 0.849
# Bootstrap #464 ROC area: 0.922
# Bootstrap #465 ROC area: 0.888
# Bootstrap #466 ROC area: 0.881
# Bootstrap #467 ROC area: 0.880
# Bootstrap #468 ROC area: 0.853
# Bootstrap #469 ROC area: 0.869
# Bootstrap #470 ROC area: 0.921
# Bootstrap #471 ROC area: 0.882
# Bootstrap #472 ROC area: 0.882
# Bootstrap #473 ROC area: 0.893
# Bootstrap #474 ROC area: 0.874
# Bootstrap #475 ROC area: 0.906
# Bootstrap #476 ROC area: 0.892
# Bootstrap #477 ROC area: 0.898
# Bootstrap #478 ROC area: 0.892
# Bootstrap #479 ROC area: 0.902
# Bootstrap #480 ROC area: 0.886
# Bootstrap #481 ROC area: 0.911
# Bootstrap #482 ROC area: 0.906
# Bootstrap #483 ROC area: 0.891
# Bootstrap #484 ROC area: 0.884
# Bootstrap #485 ROC area: 0.869
# Bootstrap #486 ROC area: 0.904
# Bootstrap #487 ROC area: 0.892
# Bootstrap #488 ROC area: 0.898
# Bootstrap #489 ROC area: 0.850
# Bootstrap #490 ROC area: 0.873
# Bootstrap #491 ROC area: 0.866
# Bootstrap #492 ROC area: 0.880
# Bootstrap #493 ROC area: 0.885
# Bootstrap #494 ROC area: 0.892
# Bootstrap #495 ROC area: 0.867
# Bootstrap #496 ROC area: 0.913
# Bootstrap #497 ROC area: 0.911
# Bootstrap #498 ROC area: 0.882
# Bootstrap #499 ROC area: 0.889
# Bootstrap #500 ROC area: 0.897
# Bootstrap #501 ROC area: 0.881
# Bootstrap #502 ROC area: 0.870
# Bootstrap #503 ROC area: 0.898
# Bootstrap #504 ROC area: 0.855
# Bootstrap #505 ROC area: 0.900
# Bootstrap #506 ROC area: 0.844
# Bootstrap #507 ROC area: 0.889
# Bootstrap #508 ROC area: 0.872
# Bootstrap #509 ROC area: 0.897
# Bootstrap #510 ROC area: 0.876
# Bootstrap #511 ROC area: 0.880
# Bootstrap #512 ROC area: 0.886
# Bootstrap #513 ROC area: 0.844
# Bootstrap #514 ROC area: 0.880
# Bootstrap #515 ROC area: 0.931
# Bootstrap #516 ROC area: 0.885
# Bootstrap #517 ROC area: 0.932
# Bootstrap #518 ROC area: 0.892
# Bootstrap #519 ROC area: 0.895
# Bootstrap #520 ROC area: 0.899
# Bootstrap #521 ROC area: 0.884
# Bootstrap #522 ROC area: 0.875
# Bootstrap #523 ROC area: 0.900
# Bootstrap #524 ROC area: 0.887
# Bootstrap #525 ROC area: 0.870
# Bootstrap #526 ROC area: 0.892
# Bootstrap #527 ROC area: 0.880
# Bootstrap #528 ROC area: 0.840
# Bootstrap #529 ROC area: 0.887
# Bootstrap #530 ROC area: 0.898
# Bootstrap #531 ROC area: 0.901
# Bootstrap #532 ROC area: 0.884
# Bootstrap #533 ROC area: 0.872
# Bootstrap #534 ROC area: 0.868
# Bootstrap #535 ROC area: 0.897
# Bootstrap #536 ROC area: 0.894
# Bootstrap #537 ROC area: 0.880
# Bootstrap #538 ROC area: 0.898
# Bootstrap #539 ROC area: 0.851
# Bootstrap #540 ROC area: 0.885
# Bootstrap #541 ROC area: 0.891
# Bootstrap #542 ROC area: 0.916
# Bootstrap #543 ROC area: 0.899
# Bootstrap #544 ROC area: 0.853
# Bootstrap #545 ROC area: 0.876
# Bootstrap #546 ROC area: 0.909
# Bootstrap #547 ROC area: 0.862
# Bootstrap #548 ROC area: 0.845
# Bootstrap #549 ROC area: 0.897
# Bootstrap #550 ROC area: 0.906
# Bootstrap #551 ROC area: 0.913
# Bootstrap #552 ROC area: 0.862
# Bootstrap #553 ROC area: 0.900
# Bootstrap #554 ROC area: 0.885
# Bootstrap #555 ROC area: 0.870
# Bootstrap #556 ROC area: 0.857
# Bootstrap #557 ROC area: 0.911
# Bootstrap #558 ROC area: 0.896
# Bootstrap #559 ROC area: 0.885
# Bootstrap #560 ROC area: 0.895
# Bootstrap #561 ROC area: 0.908
# Bootstrap #562 ROC area: 0.887
# Bootstrap #563 ROC area: 0.859
# Bootstrap #564 ROC area: 0.901
# Bootstrap #565 ROC area: 0.892
# Bootstrap #566 ROC area: 0.878
# Bootstrap #567 ROC area: 0.900
# Bootstrap #568 ROC area: 0.896
# Bootstrap #569 ROC area: 0.922
# Bootstrap #570 ROC area: 0.891
# Bootstrap #571 ROC area: 0.908
# Bootstrap #572 ROC area: 0.908
# Bootstrap #573 ROC area: 0.911
# Bootstrap #574 ROC area: 0.899
# Bootstrap #575 ROC area: 0.915
# Bootstrap #576 ROC area: 0.888
# Bootstrap #577 ROC area: 0.883
# Bootstrap #578 ROC area: 0.904
# Bootstrap #579 ROC area: 0.917
# Bootstrap #580 ROC area: 0.864
# Bootstrap #581 ROC area: 0.860
# Bootstrap #582 ROC area: 0.871
# Bootstrap #583 ROC area: 0.857
# Bootstrap #584 ROC area: 0.887
# Bootstrap #585 ROC area: 0.884
# Bootstrap #586 ROC area: 0.845
# Bootstrap #587 ROC area: 0.853
# Bootstrap #588 ROC area: 0.888
# Bootstrap #589 ROC area: 0.867
# Bootstrap #590 ROC area: 0.880
# Bootstrap #591 ROC area: 0.862
# Bootstrap #592 ROC area: 0.904
# Bootstrap #593 ROC area: 0.876
# Bootstrap #594 ROC area: 0.878
# Bootstrap #595 ROC area: 0.848
# Bootstrap #596 ROC area: 0.878
# Bootstrap #597 ROC area: 0.872
# Bootstrap #598 ROC area: 0.873
# Bootstrap #599 ROC area: 0.876
# Bootstrap #600 ROC area: 0.882
# Bootstrap #601 ROC area: 0.890
# Bootstrap #602 ROC area: 0.887
# Bootstrap #603 ROC area: 0.899
# Bootstrap #604 ROC area: 0.892
# Bootstrap #605 ROC area: 0.865
# Bootstrap #606 ROC area: 0.894
# Bootstrap #607 ROC area: 0.856
# Bootstrap #608 ROC area: 0.875
# Bootstrap #609 ROC area: 0.875
# Bootstrap #610 ROC area: 0.818
# Bootstrap #611 ROC area: 0.891
# Bootstrap #612 ROC area: 0.875
# Bootstrap #613 ROC area: 0.901
# Bootstrap #614 ROC area: 0.894
# Bootstrap #615 ROC area: 0.878
# Bootstrap #616 ROC area: 0.835
# Bootstrap #617 ROC area: 0.904
# Bootstrap #618 ROC area: 0.874
# Bootstrap #619 ROC area: 0.887
# Bootstrap #620 ROC area: 0.900
# Bootstrap #621 ROC area: 0.880
# Bootstrap #622 ROC area: 0.916
# Bootstrap #623 ROC area: 0.879
# Bootstrap #624 ROC area: 0.919
# Bootstrap #625 ROC area: 0.903
# Bootstrap #626 ROC area: 0.853
# Bootstrap #627 ROC area: 0.903
# Bootstrap #628 ROC area: 0.884
# Bootstrap #629 ROC area: 0.883
# Bootstrap #630 ROC area: 0.856
# Bootstrap #631 ROC area: 0.878
# Bootstrap #632 ROC area: 0.870
# Bootstrap #633 ROC area: 0.864
# Bootstrap #634 ROC area: 0.891
# Bootstrap #635 ROC area: 0.894
# Bootstrap #636 ROC area: 0.883
# Bootstrap #637 ROC area: 0.889
# Bootstrap #638 ROC area: 0.903
# Bootstrap #639 ROC area: 0.899
# Bootstrap #640 ROC area: 0.898
# Bootstrap #641 ROC area: 0.884
# Bootstrap #642 ROC area: 0.890
# Bootstrap #643 ROC area: 0.874
# Bootstrap #644 ROC area: 0.880
# Bootstrap #645 ROC area: 0.904
# Bootstrap #646 ROC area: 0.893
# Bootstrap #647 ROC area: 0.883
# Bootstrap #648 ROC area: 0.857
# Bootstrap #649 ROC area: 0.901
# Bootstrap #650 ROC area: 0.890
# Bootstrap #651 ROC area: 0.872
# Bootstrap #652 ROC area: 0.877
# Bootstrap #653 ROC area: 0.882
# Bootstrap #654 ROC area: 0.851
# Bootstrap #655 ROC area: 0.878
# Bootstrap #656 ROC area: 0.870
# Bootstrap #657 ROC area: 0.883
# Bootstrap #658 ROC area: 0.881
# Bootstrap #659 ROC area: 0.877
# Bootstrap #660 ROC area: 0.891
# Bootstrap #661 ROC area: 0.883
# Bootstrap #662 ROC area: 0.888
# Bootstrap #663 ROC area: 0.898
# Bootstrap #664 ROC area: 0.874
# Bootstrap #665 ROC area: 0.915
# Bootstrap #666 ROC area: 0.879
# Bootstrap #667 ROC area: 0.885
# Bootstrap #668 ROC area: 0.892
# Bootstrap #669 ROC area: 0.910
# Bootstrap #670 ROC area: 0.868
# Bootstrap #671 ROC area: 0.898
# Bootstrap #672 ROC area: 0.912
# Bootstrap #673 ROC area: 0.890
# Bootstrap #674 ROC area: 0.905
# Bootstrap #675 ROC area: 0.886
# Bootstrap #676 ROC area: 0.890
# Bootstrap #677 ROC area: 0.910
# Bootstrap #678 ROC area: 0.871
# Bootstrap #679 ROC area: 0.888
# Bootstrap #680 ROC area: 0.879
# Bootstrap #681 ROC area: 0.910
# Bootstrap #682 ROC area: 0.883
# Bootstrap #683 ROC area: 0.880
# Bootstrap #684 ROC area: 0.847
# Bootstrap #685 ROC area: 0.902
# Bootstrap #686 ROC area: 0.903
# Bootstrap #687 ROC area: 0.844
# Bootstrap #688 ROC area: 0.900
# Bootstrap #689 ROC area: 0.857
# Bootstrap #690 ROC area: 0.891
# Bootstrap #691 ROC area: 0.885
# Bootstrap #692 ROC area: 0.904
# Bootstrap #693 ROC area: 0.907
# Bootstrap #694 ROC area: 0.913
# Bootstrap #695 ROC area: 0.882
# Bootstrap #696 ROC area: 0.883
# Bootstrap #697 ROC area: 0.857
# Bootstrap #698 ROC area: 0.897
# Bootstrap #699 ROC area: 0.870
# Bootstrap #700 ROC area: 0.869
# Bootstrap #701 ROC area: 0.905
# Bootstrap #702 ROC area: 0.871
# Bootstrap #703 ROC area: 0.907
# Bootstrap #704 ROC area: 0.893
# Bootstrap #705 ROC area: 0.891
# Bootstrap #706 ROC area: 0.921
# Bootstrap #707 ROC area: 0.854
# Bootstrap #708 ROC area: 0.906
# Bootstrap #709 ROC area: 0.905
# Bootstrap #710 ROC area: 0.902
# Bootstrap #711 ROC area: 0.883
# Bootstrap #712 ROC area: 0.883
# Bootstrap #713 ROC area: 0.875
# Bootstrap #714 ROC area: 0.906
# Bootstrap #715 ROC area: 0.873
# Bootstrap #716 ROC area: 0.892
# Bootstrap #717 ROC area: 0.872
# Bootstrap #718 ROC area: 0.883
# Bootstrap #719 ROC area: 0.909
# Bootstrap #720 ROC area: 0.912
# Bootstrap #721 ROC area: 0.872
# Bootstrap #722 ROC area: 0.870
# Bootstrap #723 ROC area: 0.878
# Bootstrap #724 ROC area: 0.882
# Bootstrap #725 ROC area: 0.888
# Bootstrap #726 ROC area: 0.879
# Bootstrap #727 ROC area: 0.903
# Bootstrap #728 ROC area: 0.867
# Bootstrap #729 ROC area: 0.866
# Bootstrap #730 ROC area: 0.899
# Bootstrap #731 ROC area: 0.925
# Bootstrap #732 ROC area: 0.903
# Bootstrap #733 ROC area: 0.881
# Bootstrap #734 ROC area: 0.879
# Bootstrap #735 ROC area: 0.879
# Bootstrap #736 ROC area: 0.858
# Bootstrap #737 ROC area: 0.862
# Bootstrap #738 ROC area: 0.898
# Bootstrap #739 ROC area: 0.896
# Bootstrap #740 ROC area: 0.891
# Bootstrap #741 ROC area: 0.889
# Bootstrap #742 ROC area: 0.887
# Bootstrap #743 ROC area: 0.852
# Bootstrap #744 ROC area: 0.895
# Bootstrap #745 ROC area: 0.886
# Bootstrap #746 ROC area: 0.881
# Bootstrap #747 ROC area: 0.869
# Bootstrap #748 ROC area: 0.892
# Bootstrap #749 ROC area: 0.874
# Bootstrap #750 ROC area: 0.874
# Bootstrap #751 ROC area: 0.883
# Bootstrap #752 ROC area: 0.883
# Bootstrap #753 ROC area: 0.880
# Bootstrap #754 ROC area: 0.905
# Bootstrap #755 ROC area: 0.864
# Bootstrap #756 ROC area: 0.915
# Bootstrap #757 ROC area: 0.900
# Bootstrap #758 ROC area: 0.901
# Bootstrap #759 ROC area: 0.869
# Bootstrap #760 ROC area: 0.875
# Bootstrap #761 ROC area: 0.877
# Bootstrap #762 ROC area: 0.868
# Bootstrap #763 ROC area: 0.898
# Bootstrap #764 ROC area: 0.887
# Bootstrap #765 ROC area: 0.884
# Bootstrap #766 ROC area: 0.879
# Bootstrap #767 ROC area: 0.861
# Bootstrap #768 ROC area: 0.889
# Bootstrap #769 ROC area: 0.912
# Bootstrap #770 ROC area: 0.879
# Bootstrap #771 ROC area: 0.912
# Bootstrap #772 ROC area: 0.892
# Bootstrap #773 ROC area: 0.892
# Bootstrap #774 ROC area: 0.834
# Bootstrap #775 ROC area: 0.901
# Bootstrap #776 ROC area: 0.892
# Bootstrap #777 ROC area: 0.886
# Bootstrap #778 ROC area: 0.865
# Bootstrap #779 ROC area: 0.887
# Bootstrap #780 ROC area: 0.913
# Bootstrap #781 ROC area: 0.899
# Bootstrap #782 ROC area: 0.878
# Bootstrap #783 ROC area: 0.870
# Bootstrap #784 ROC area: 0.857
# Bootstrap #785 ROC area: 0.898
# Bootstrap #786 ROC area: 0.873
# Bootstrap #787 ROC area: 0.866
# Bootstrap #788 ROC area: 0.900
# Bootstrap #789 ROC area: 0.883
# Bootstrap #790 ROC area: 0.860
# Bootstrap #791 ROC area: 0.882
# Bootstrap #792 ROC area: 0.913
# Bootstrap #793 ROC area: 0.909
# Bootstrap #794 ROC area: 0.876
# Bootstrap #795 ROC area: 0.886
# Bootstrap #796 ROC area: 0.917
# Bootstrap #797 ROC area: 0.890
# Bootstrap #798 ROC area: 0.891
# Bootstrap #799 ROC area: 0.886
# Bootstrap #800 ROC area: 0.898
# Bootstrap #801 ROC area: 0.907
# Bootstrap #802 ROC area: 0.881
# Bootstrap #803 ROC area: 0.897
# Bootstrap #804 ROC area: 0.896
# Bootstrap #805 ROC area: 0.876
# Bootstrap #806 ROC area: 0.873
# Bootstrap #807 ROC area: 0.938
# Bootstrap #808 ROC area: 0.871
# Bootstrap #809 ROC area: 0.852
# Bootstrap #810 ROC area: 0.883
# Bootstrap #811 ROC area: 0.911
# Bootstrap #812 ROC area: 0.904
# Bootstrap #813 ROC area: 0.846
# Bootstrap #814 ROC area: 0.872
# Bootstrap #815 ROC area: 0.884
# Bootstrap #816 ROC area: 0.890
# Bootstrap #817 ROC area: 0.890
# Bootstrap #818 ROC area: 0.890
# Bootstrap #819 ROC area: 0.871
# Bootstrap #820 ROC area: 0.890
# Bootstrap #821 ROC area: 0.887
# Bootstrap #822 ROC area: 0.885
# Bootstrap #823 ROC area: 0.910
# Bootstrap #824 ROC area: 0.884
# Bootstrap #825 ROC area: 0.869
# Bootstrap #826 ROC area: 0.898
# Bootstrap #827 ROC area: 0.877
# Bootstrap #828 ROC area: 0.908
# Bootstrap #829 ROC area: 0.873
# Bootstrap #830 ROC area: 0.890
# Bootstrap #831 ROC area: 0.900
# Bootstrap #832 ROC area: 0.869
# Bootstrap #833 ROC area: 0.893
# Bootstrap #834 ROC area: 0.914
# Bootstrap #835 ROC area: 0.886
# Bootstrap #836 ROC area: 0.874
# Bootstrap #837 ROC area: 0.883
# Bootstrap #838 ROC area: 0.881
# Bootstrap #839 ROC area: 0.869
# Bootstrap #840 ROC area: 0.874
# Bootstrap #841 ROC area: 0.863
# Bootstrap #842 ROC area: 0.880
# Bootstrap #843 ROC area: 0.904
# Bootstrap #844 ROC area: 0.897
# Bootstrap #845 ROC area: 0.847
# Bootstrap #846 ROC area: 0.900
# Bootstrap #847 ROC area: 0.877
# Bootstrap #848 ROC area: 0.886
# Bootstrap #849 ROC area: 0.865
# Bootstrap #850 ROC area: 0.861
# Bootstrap #851 ROC area: 0.863
# Bootstrap #852 ROC area: 0.897
# Bootstrap #853 ROC area: 0.865
# Bootstrap #854 ROC area: 0.823
# Bootstrap #855 ROC area: 0.863
# Bootstrap #856 ROC area: 0.859
# Bootstrap #857 ROC area: 0.879
# Bootstrap #858 ROC area: 0.885
# Bootstrap #859 ROC area: 0.878
# Bootstrap #860 ROC area: 0.922
# Bootstrap #861 ROC area: 0.887
# Bootstrap #862 ROC area: 0.891
# Bootstrap #863 ROC area: 0.887
# Bootstrap #864 ROC area: 0.857
# Bootstrap #865 ROC area: 0.904
# Bootstrap #866 ROC area: 0.888
# Bootstrap #867 ROC area: 0.878
# Bootstrap #868 ROC area: 0.887
# Bootstrap #869 ROC area: 0.874
# Bootstrap #870 ROC area: 0.893
# Bootstrap #871 ROC area: 0.849
# Bootstrap #872 ROC area: 0.847
# Bootstrap #873 ROC area: 0.890
# Bootstrap #874 ROC area: 0.913
# Bootstrap #875 ROC area: 0.888
# Bootstrap #876 ROC area: 0.892
# Bootstrap #877 ROC area: 0.889
# Bootstrap #878 ROC area: 0.864
# Bootstrap #879 ROC area: 0.882
# Bootstrap #880 ROC area: 0.895
# Bootstrap #881 ROC area: 0.881
# Bootstrap #882 ROC area: 0.899
# Bootstrap #883 ROC area: 0.904
# Bootstrap #884 ROC area: 0.880
# Bootstrap #885 ROC area: 0.896
# Bootstrap #886 ROC area: 0.894
# Bootstrap #887 ROC area: 0.917
# Bootstrap #888 ROC area: 0.907
# Bootstrap #889 ROC area: 0.891
# Bootstrap #890 ROC area: 0.896
# Bootstrap #891 ROC area: 0.872
# Bootstrap #892 ROC area: 0.868
# Bootstrap #893 ROC area: 0.871
# Bootstrap #894 ROC area: 0.869
# Bootstrap #895 ROC area: 0.896
# Bootstrap #896 ROC area: 0.895
# Bootstrap #897 ROC area: 0.877
# Bootstrap #898 ROC area: 0.895
# Bootstrap #899 ROC area: 0.897
# Bootstrap #900 ROC area: 0.886
# Bootstrap #901 ROC area: 0.921
# Bootstrap #902 ROC area: 0.905
# Bootstrap #903 ROC area: 0.897
# Bootstrap #904 ROC area: 0.868
# Bootstrap #905 ROC area: 0.895
# Bootstrap #906 ROC area: 0.876
# Bootstrap #907 ROC area: 0.911
# Bootstrap #908 ROC area: 0.850
# Bootstrap #909 ROC area: 0.884
# Bootstrap #910 ROC area: 0.872
# Bootstrap #911 ROC area: 0.853
# Bootstrap #912 ROC area: 0.888
# Bootstrap #913 ROC area: 0.908
# Bootstrap #914 ROC area: 0.914
# Bootstrap #915 ROC area: 0.904
# Bootstrap #916 ROC area: 0.899
# Bootstrap #917 ROC area: 0.909
# Bootstrap #918 ROC area: 0.894
# Bootstrap #919 ROC area: 0.885
# Bootstrap #920 ROC area: 0.906
# Bootstrap #921 ROC area: 0.889
# Bootstrap #922 ROC area: 0.895
# Bootstrap #923 ROC area: 0.850
# Bootstrap #924 ROC area: 0.848
# Bootstrap #925 ROC area: 0.876
# Bootstrap #926 ROC area: 0.872
# Bootstrap #927 ROC area: 0.921
# Bootstrap #928 ROC area: 0.876
# Bootstrap #929 ROC area: 0.870
# Bootstrap #930 ROC area: 0.905
# Bootstrap #931 ROC area: 0.875
# Bootstrap #932 ROC area: 0.886
# Bootstrap #933 ROC area: 0.869
# Bootstrap #934 ROC area: 0.902
# Bootstrap #935 ROC area: 0.857
# Bootstrap #936 ROC area: 0.902
# Bootstrap #937 ROC area: 0.833
# Bootstrap #938 ROC area: 0.865
# Bootstrap #939 ROC area: 0.894
# Bootstrap #940 ROC area: 0.896
# Bootstrap #941 ROC area: 0.892
# Bootstrap #942 ROC area: 0.890
# Bootstrap #943 ROC area: 0.903
# Bootstrap #944 ROC area: 0.877
# Bootstrap #945 ROC area: 0.893
# Bootstrap #946 ROC area: 0.884
# Bootstrap #947 ROC area: 0.878
# Bootstrap #948 ROC area: 0.852
# Bootstrap #949 ROC area: 0.876
# Bootstrap #950 ROC area: 0.865
# Bootstrap #951 ROC area: 0.880
# Bootstrap #952 ROC area: 0.855
# Bootstrap #953 ROC area: 0.907
# Bootstrap #954 ROC area: 0.904
# Bootstrap #955 ROC area: 0.865
# Bootstrap #956 ROC area: 0.905
# Bootstrap #957 ROC area: 0.908
# Bootstrap #958 ROC area: 0.890
# Bootstrap #959 ROC area: 0.890
# Bootstrap #960 ROC area: 0.882
# Bootstrap #961 ROC area: 0.921
# Bootstrap #962 ROC area: 0.856
# Bootstrap #963 ROC area: 0.860
# Bootstrap #964 ROC area: 0.891
# Bootstrap #965 ROC area: 0.889
# Bootstrap #966 ROC area: 0.896
# Bootstrap #967 ROC area: 0.877
# Bootstrap #968 ROC area: 0.890
# Bootstrap #969 ROC area: 0.879
# Bootstrap #970 ROC area: 0.903
# Bootstrap #971 ROC area: 0.874
# Bootstrap #972 ROC area: 0.882
# Bootstrap #973 ROC area: 0.897
# Bootstrap #974 ROC area: 0.889
# Bootstrap #975 ROC area: 0.909
# Bootstrap #976 ROC area: 0.855
# Bootstrap #977 ROC area: 0.909
# Bootstrap #978 ROC area: 0.884
# Bootstrap #979 ROC area: 0.882
# Bootstrap #980 ROC area: 0.896
# Bootstrap #981 ROC area: 0.874
# Bootstrap #982 ROC area: 0.852
# Bootstrap #983 ROC area: 0.891
# Bootstrap #984 ROC area: 0.912
# Bootstrap #985 ROC area: 0.897
# Bootstrap #986 ROC area: 0.917
# Bootstrap #987 ROC area: 0.884
# Bootstrap #988 ROC area: 0.888
# Bootstrap #989 ROC area: 0.854
# Bootstrap #990 ROC area: 0.899
# Bootstrap #991 ROC area: 0.865
# Bootstrap #992 ROC area: 0.889
# Bootstrap #993 ROC area: 0.919
# Bootstrap #994 ROC area: 0.918
# Bootstrap #995 ROC area: 0.872
# Bootstrap #996 ROC area: 0.909
# Bootstrap #997 ROC area: 0.880
# Bootstrap #998 ROC area: 0.892
# Bootstrap #999 ROC area: 0.912
# Bootstrap #1000 ROC area: 0.888

# %%
sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score on Black patients: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Confidence interval for the score on Black patients: [0.847 - 0.92]

# %% [markdown]
# #### For Hispanic Patient Set

# %%
y_pred_hispanic = model.predict_proba(xTestHisp)
print("Original ROC area: {:0.3f}".format(roc_auc_score(yTestHisp, y_pred_hispanic[:,1])))
# Out:
# Original ROC area: 0.803

# %%
n_bootstraps = 1000
rng_seed = 42  # control reproducibility
bootstrapped_scores = []

rng = np.random.RandomState(rng_seed)
for i in range(n_bootstraps):
    indices = rng.randint(0, len(y_pred_hispanic), len(y_pred_hispanic))

    score = roc_auc_score(yTestHisp.to_numpy()[indices], y_pred_hispanic[indices, 1])
    bootstrapped_scores.append(score)
    print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))
# Out:
# Bootstrap #1 ROC area: 0.808
# Bootstrap #2 ROC area: 0.824
# Bootstrap #3 ROC area: 0.844
# Bootstrap #4 ROC area: 0.776
# Bootstrap #5 ROC area: 0.854
# Bootstrap #6 ROC area: 0.759
# Bootstrap #7 ROC area: 0.798
# Bootstrap #8 ROC area: 0.787
# Bootstrap #9 ROC area: 0.730
# Bootstrap #10 ROC area: 0.827
# Bootstrap #11 ROC area: 0.822
# Bootstrap #12 ROC area: 0.779
# Bootstrap #13 ROC area: 0.838
# Bootstrap #14 ROC area: 0.784
# Bootstrap #15 ROC area: 0.791
# Bootstrap #16 ROC area: 0.852
# Bootstrap #17 ROC area: 0.826
# Bootstrap #18 ROC area: 0.825
# Bootstrap #19 ROC area: 0.855
# Bootstrap #20 ROC area: 0.819
# Bootstrap #21 ROC area: 0.735
# Bootstrap #22 ROC area: 0.798
# Bootstrap #23 ROC area: 0.800
# Bootstrap #24 ROC area: 0.853
# Bootstrap #25 ROC area: 0.795
# Bootstrap #26 ROC area: 0.841
# Bootstrap #27 ROC area: 0.851
# Bootstrap #28 ROC area: 0.810
# Bootstrap #29 ROC area: 0.758
# Bootstrap #30 ROC area: 0.815
# Bootstrap #31 ROC area: 0.770
# Bootstrap #32 ROC area: 0.789
# Bootstrap #33 ROC area: 0.841
# Bootstrap #34 ROC area: 0.820
# Bootstrap #35 ROC area: 0.808
# Bootstrap #36 ROC area: 0.852
# Bootstrap #37 ROC area: 0.763
# Bootstrap #38 ROC area: 0.796
# Bootstrap #39 ROC area: 0.782
# Bootstrap #40 ROC area: 0.784
# Bootstrap #41 ROC area: 0.788
# Bootstrap #42 ROC area: 0.857
# Bootstrap #43 ROC area: 0.767
# Bootstrap #44 ROC area: 0.857
# Bootstrap #45 ROC area: 0.830
# Bootstrap #46 ROC area: 0.814
# Bootstrap #47 ROC area: 0.805
# Bootstrap #48 ROC area: 0.851
# Bootstrap #49 ROC area: 0.830
# Bootstrap #50 ROC area: 0.833
# Bootstrap #51 ROC area: 0.792
# Bootstrap #52 ROC area: 0.788
# Bootstrap #53 ROC area: 0.786
# Bootstrap #54 ROC area: 0.843
# Bootstrap #55 ROC area: 0.825
# Bootstrap #56 ROC area: 0.828
# Bootstrap #57 ROC area: 0.768
# Bootstrap #58 ROC area: 0.844
# Bootstrap #59 ROC area: 0.797
# Bootstrap #60 ROC area: 0.806
# Bootstrap #61 ROC area: 0.840
# Bootstrap #62 ROC area: 0.828
# Bootstrap #63 ROC area: 0.770
# Bootstrap #64 ROC area: 0.818
# Bootstrap #65 ROC area: 0.793
# Bootstrap #66 ROC area: 0.848
# Bootstrap #67 ROC area: 0.785
# Bootstrap #68 ROC area: 0.780
# Bootstrap #69 ROC area: 0.786
# Bootstrap #70 ROC area: 0.858
# Bootstrap #71 ROC area: 0.808
# Bootstrap #72 ROC area: 0.768
# Bootstrap #73 ROC area: 0.830
# Bootstrap #74 ROC area: 0.761
# Bootstrap #75 ROC area: 0.774
# Bootstrap #76 ROC area: 0.833
# Bootstrap #77 ROC area: 0.771
# Bootstrap #78 ROC area: 0.817
# Bootstrap #79 ROC area: 0.800
# Bootstrap #80 ROC area: 0.813
# Bootstrap #81 ROC area: 0.807
# Bootstrap #82 ROC area: 0.876
# Bootstrap #83 ROC area: 0.792
# Bootstrap #84 ROC area: 0.788
# Bootstrap #85 ROC area: 0.866
# Bootstrap #86 ROC area: 0.789
# Bootstrap #87 ROC area: 0.735
# Bootstrap #88 ROC area: 0.815
# Bootstrap #89 ROC area: 0.815
# Bootstrap #90 ROC area: 0.821
# Bootstrap #91 ROC area: 0.809
# Bootstrap #92 ROC area: 0.853
# Bootstrap #93 ROC area: 0.809
# Bootstrap #94 ROC area: 0.787
# Bootstrap #95 ROC area: 0.836
# Bootstrap #96 ROC area: 0.800
# Bootstrap #97 ROC area: 0.785
# Bootstrap #98 ROC area: 0.758
# Bootstrap #99 ROC area: 0.778
# Bootstrap #100 ROC area: 0.802
# Bootstrap #101 ROC area: 0.837
# Bootstrap #102 ROC area: 0.848
# Bootstrap #103 ROC area: 0.748
# Bootstrap #104 ROC area: 0.806
# Bootstrap #105 ROC area: 0.774
# Bootstrap #106 ROC area: 0.828
# Bootstrap #107 ROC area: 0.783
# Bootstrap #108 ROC area: 0.770
# Bootstrap #109 ROC area: 0.765
# Bootstrap #110 ROC area: 0.841
# Bootstrap #111 ROC area: 0.865
# Bootstrap #112 ROC area: 0.822
# Bootstrap #113 ROC area: 0.785
# Bootstrap #114 ROC area: 0.767
# Bootstrap #115 ROC area: 0.824
# Bootstrap #116 ROC area: 0.840
# Bootstrap #117 ROC area: 0.797
# Bootstrap #118 ROC area: 0.771
# Bootstrap #119 ROC area: 0.812
# Bootstrap #120 ROC area: 0.771
# Bootstrap #121 ROC area: 0.742
# Bootstrap #122 ROC area: 0.777
# Bootstrap #123 ROC area: 0.798
# Bootstrap #124 ROC area: 0.812
# Bootstrap #125 ROC area: 0.823
# Bootstrap #126 ROC area: 0.827
# Bootstrap #127 ROC area: 0.763
# Bootstrap #128 ROC area: 0.767
# Bootstrap #129 ROC area: 0.799
# Bootstrap #130 ROC area: 0.781
# Bootstrap #131 ROC area: 0.813
# Bootstrap #132 ROC area: 0.815
# Bootstrap #133 ROC area: 0.806
# Bootstrap #134 ROC area: 0.766
# Bootstrap #135 ROC area: 0.822
# Bootstrap #136 ROC area: 0.793
# Bootstrap #137 ROC area: 0.811
# Bootstrap #138 ROC area: 0.783
# Bootstrap #139 ROC area: 0.775
# Bootstrap #140 ROC area: 0.746
# Bootstrap #141 ROC area: 0.839
# Bootstrap #142 ROC area: 0.811
# Bootstrap #143 ROC area: 0.775
# Bootstrap #144 ROC area: 0.794
# Bootstrap #145 ROC area: 0.787
# Bootstrap #146 ROC area: 0.843
# Bootstrap #147 ROC area: 0.730
# Bootstrap #148 ROC area: 0.840
# Bootstrap #149 ROC area: 0.781
# Bootstrap #150 ROC area: 0.780
# Bootstrap #151 ROC area: 0.822
# Bootstrap #152 ROC area: 0.796
# Bootstrap #153 ROC area: 0.798
# Bootstrap #154 ROC area: 0.836
# Bootstrap #155 ROC area: 0.806
# Bootstrap #156 ROC area: 0.765
# Bootstrap #157 ROC area: 0.833
# Bootstrap #158 ROC area: 0.846
# Bootstrap #159 ROC area: 0.820
# Bootstrap #160 ROC area: 0.819
# Bootstrap #161 ROC area: 0.789
# Bootstrap #162 ROC area: 0.772
# Bootstrap #163 ROC area: 0.780
# Bootstrap #164 ROC area: 0.873
# Bootstrap #165 ROC area: 0.822
# Bootstrap #166 ROC area: 0.752
# Bootstrap #167 ROC area: 0.834
# Bootstrap #168 ROC area: 0.820
# Bootstrap #169 ROC area: 0.802
# Bootstrap #170 ROC area: 0.788
# Bootstrap #171 ROC area: 0.821
# Bootstrap #172 ROC area: 0.783
# Bootstrap #173 ROC area: 0.841
# Bootstrap #174 ROC area: 0.795
# Bootstrap #175 ROC area: 0.815
# Bootstrap #176 ROC area: 0.755
# Bootstrap #177 ROC area: 0.807
# Bootstrap #178 ROC area: 0.835
# Bootstrap #179 ROC area: 0.802
# Bootstrap #180 ROC area: 0.724
# Bootstrap #181 ROC area: 0.799
# Bootstrap #182 ROC area: 0.832
# Bootstrap #183 ROC area: 0.768
# Bootstrap #184 ROC area: 0.748
# Bootstrap #185 ROC area: 0.810
# Bootstrap #186 ROC area: 0.808
# Bootstrap #187 ROC area: 0.800
# Bootstrap #188 ROC area: 0.875
# Bootstrap #189 ROC area: 0.755
# Bootstrap #190 ROC area: 0.808
# Bootstrap #191 ROC area: 0.765
# Bootstrap #192 ROC area: 0.740
# Bootstrap #193 ROC area: 0.787
# Bootstrap #194 ROC area: 0.806
# Bootstrap #195 ROC area: 0.799
# Bootstrap #196 ROC area: 0.770
# Bootstrap #197 ROC area: 0.820
# Bootstrap #198 ROC area: 0.776
# Bootstrap #199 ROC area: 0.833
# Bootstrap #200 ROC area: 0.834
# Bootstrap #201 ROC area: 0.799
# Bootstrap #202 ROC area: 0.782
# Bootstrap #203 ROC area: 0.800
# Bootstrap #204 ROC area: 0.850
# Bootstrap #205 ROC area: 0.832
# Bootstrap #206 ROC area: 0.753
# Bootstrap #207 ROC area: 0.787
# Bootstrap #208 ROC area: 0.825
# Bootstrap #209 ROC area: 0.823
# Bootstrap #210 ROC area: 0.813
# Bootstrap #211 ROC area: 0.784
# Bootstrap #212 ROC area: 0.833
# Bootstrap #213 ROC area: 0.808
# Bootstrap #214 ROC area: 0.834
# Bootstrap #215 ROC area: 0.788
# Bootstrap #216 ROC area: 0.846
# Bootstrap #217 ROC area: 0.751
# Bootstrap #218 ROC area: 0.841
# Bootstrap #219 ROC area: 0.796
# Bootstrap #220 ROC area: 0.854
# Bootstrap #221 ROC area: 0.847
# Bootstrap #222 ROC area: 0.715
# Bootstrap #223 ROC area: 0.822
# Bootstrap #224 ROC area: 0.777
# Bootstrap #225 ROC area: 0.790
# Bootstrap #226 ROC area: 0.776
# Bootstrap #227 ROC area: 0.812
# Bootstrap #228 ROC area: 0.813
# Bootstrap #229 ROC area: 0.801
# Bootstrap #230 ROC area: 0.844
# Bootstrap #231 ROC area: 0.767
# Bootstrap #232 ROC area: 0.858
# Bootstrap #233 ROC area: 0.823
# Bootstrap #234 ROC area: 0.773
# Bootstrap #235 ROC area: 0.809
# Bootstrap #236 ROC area: 0.861
# Bootstrap #237 ROC area: 0.770
# Bootstrap #238 ROC area: 0.843
# Bootstrap #239 ROC area: 0.805
# Bootstrap #240 ROC area: 0.785
# Bootstrap #241 ROC area: 0.812
# Bootstrap #242 ROC area: 0.796
# Bootstrap #243 ROC area: 0.783
# Bootstrap #244 ROC area: 0.809
# Bootstrap #245 ROC area: 0.839
# Bootstrap #246 ROC area: 0.801
# Bootstrap #247 ROC area: 0.774
# Bootstrap #248 ROC area: 0.828
# Bootstrap #249 ROC area: 0.826
# Bootstrap #250 ROC area: 0.832
# Bootstrap #251 ROC area: 0.813
# Bootstrap #252 ROC area: 0.828
# Bootstrap #253 ROC area: 0.829
# Bootstrap #254 ROC area: 0.798
# Bootstrap #255 ROC area: 0.784
# Bootstrap #256 ROC area: 0.808
# Bootstrap #257 ROC area: 0.827
# Bootstrap #258 ROC area: 0.865
# Bootstrap #259 ROC area: 0.761
# Bootstrap #260 ROC area: 0.764
# Bootstrap #261 ROC area: 0.784
# Bootstrap #262 ROC area: 0.806
# Bootstrap #263 ROC area: 0.741
# Bootstrap #264 ROC area: 0.769
# Bootstrap #265 ROC area: 0.788
# Bootstrap #266 ROC area: 0.775
# Bootstrap #267 ROC area: 0.810
# Bootstrap #268 ROC area: 0.773
# Bootstrap #269 ROC area: 0.741
# Bootstrap #270 ROC area: 0.837
# Bootstrap #271 ROC area: 0.770
# Bootstrap #272 ROC area: 0.828
# Bootstrap #273 ROC area: 0.814
# Bootstrap #274 ROC area: 0.849
# Bootstrap #275 ROC area: 0.774
# Bootstrap #276 ROC area: 0.869
# Bootstrap #277 ROC area: 0.808
# Bootstrap #278 ROC area: 0.811
# Bootstrap #279 ROC area: 0.784
# Bootstrap #280 ROC area: 0.810
# Bootstrap #281 ROC area: 0.894
# Bootstrap #282 ROC area: 0.784
# Bootstrap #283 ROC area: 0.736
# Bootstrap #284 ROC area: 0.759
# Bootstrap #285 ROC area: 0.824
# Bootstrap #286 ROC area: 0.783
# Bootstrap #287 ROC area: 0.801
# Bootstrap #288 ROC area: 0.849
# Bootstrap #289 ROC area: 0.866
# Bootstrap #290 ROC area: 0.803
# Bootstrap #291 ROC area: 0.808
# Bootstrap #292 ROC area: 0.821
# Bootstrap #293 ROC area: 0.850
# Bootstrap #294 ROC area: 0.753
# Bootstrap #295 ROC area: 0.784
# Bootstrap #296 ROC area: 0.798
# Bootstrap #297 ROC area: 0.804
# Bootstrap #298 ROC area: 0.839
# Bootstrap #299 ROC area: 0.826
# Bootstrap #300 ROC area: 0.840
# Bootstrap #301 ROC area: 0.805
# Bootstrap #302 ROC area: 0.835
# Bootstrap #303 ROC area: 0.799
# Bootstrap #304 ROC area: 0.823
# Bootstrap #305 ROC area: 0.815
# Bootstrap #306 ROC area: 0.822
# Bootstrap #307 ROC area: 0.789
# Bootstrap #308 ROC area: 0.783
# Bootstrap #309 ROC area: 0.831
# Bootstrap #310 ROC area: 0.854
# Bootstrap #311 ROC area: 0.808
# Bootstrap #312 ROC area: 0.815
# Bootstrap #313 ROC area: 0.778
# Bootstrap #314 ROC area: 0.847
# Bootstrap #315 ROC area: 0.749
# Bootstrap #316 ROC area: 0.793
# Bootstrap #317 ROC area: 0.816
# Bootstrap #318 ROC area: 0.811
# Bootstrap #319 ROC area: 0.761
# Bootstrap #320 ROC area: 0.751
# Bootstrap #321 ROC area: 0.856
# Bootstrap #322 ROC area: 0.788
# Bootstrap #323 ROC area: 0.770
# Bootstrap #324 ROC area: 0.834
# Bootstrap #325 ROC area: 0.799
# Bootstrap #326 ROC area: 0.809
# Bootstrap #327 ROC area: 0.836
# Bootstrap #328 ROC area: 0.769
# Bootstrap #329 ROC area: 0.733
# Bootstrap #330 ROC area: 0.742
# Bootstrap #331 ROC area: 0.845
# Bootstrap #332 ROC area: 0.801
# Bootstrap #333 ROC area: 0.849
# Bootstrap #334 ROC area: 0.779
# Bootstrap #335 ROC area: 0.774
# Bootstrap #336 ROC area: 0.769
# Bootstrap #337 ROC area: 0.793
# Bootstrap #338 ROC area: 0.788
# Bootstrap #339 ROC area: 0.818
# Bootstrap #340 ROC area: 0.778
# Bootstrap #341 ROC area: 0.787
# Bootstrap #342 ROC area: 0.815
# Bootstrap #343 ROC area: 0.856
# Bootstrap #344 ROC area: 0.817
# Bootstrap #345 ROC area: 0.819
# Bootstrap #346 ROC area: 0.815
# Bootstrap #347 ROC area: 0.770
# Bootstrap #348 ROC area: 0.854
# Bootstrap #349 ROC area: 0.824
# Bootstrap #350 ROC area: 0.849
# Bootstrap #351 ROC area: 0.816
# Bootstrap #352 ROC area: 0.810
# Bootstrap #353 ROC area: 0.839
# Bootstrap #354 ROC area: 0.843
# Bootstrap #355 ROC area: 0.785
# Bootstrap #356 ROC area: 0.806
# Bootstrap #357 ROC area: 0.799
# Bootstrap #358 ROC area: 0.796
# Bootstrap #359 ROC area: 0.773
# Bootstrap #360 ROC area: 0.837
# Bootstrap #361 ROC area: 0.799
# Bootstrap #362 ROC area: 0.800
# Bootstrap #363 ROC area: 0.796
# Bootstrap #364 ROC area: 0.856
# Bootstrap #365 ROC area: 0.793
# Bootstrap #366 ROC area: 0.820
# Bootstrap #367 ROC area: 0.815
# Bootstrap #368 ROC area: 0.781
# Bootstrap #369 ROC area: 0.864
# Bootstrap #370 ROC area: 0.827
# Bootstrap #371 ROC area: 0.832
# Bootstrap #372 ROC area: 0.823
# Bootstrap #373 ROC area: 0.834
# Bootstrap #374 ROC area: 0.830
# Bootstrap #375 ROC area: 0.830
# Bootstrap #376 ROC area: 0.824
# Bootstrap #377 ROC area: 0.802
# Bootstrap #378 ROC area: 0.866
# Bootstrap #379 ROC area: 0.819
# Bootstrap #380 ROC area: 0.783
# Bootstrap #381 ROC area: 0.782
# Bootstrap #382 ROC area: 0.777
# Bootstrap #383 ROC area: 0.805
# Bootstrap #384 ROC area: 0.812
# Bootstrap #385 ROC area: 0.817
# Bootstrap #386 ROC area: 0.776
# Bootstrap #387 ROC area: 0.754
# Bootstrap #388 ROC area: 0.833
# Bootstrap #389 ROC area: 0.792
# Bootstrap #390 ROC area: 0.798
# Bootstrap #391 ROC area: 0.763
# Bootstrap #392 ROC area: 0.850
# Bootstrap #393 ROC area: 0.736
# Bootstrap #394 ROC area: 0.778
# Bootstrap #395 ROC area: 0.778
# Bootstrap #396 ROC area: 0.797
# Bootstrap #397 ROC area: 0.809
# Bootstrap #398 ROC area: 0.850
# Bootstrap #399 ROC area: 0.793
# Bootstrap #400 ROC area: 0.817
# Bootstrap #401 ROC area: 0.791
# Bootstrap #402 ROC area: 0.763
# Bootstrap #403 ROC area: 0.780
# Bootstrap #404 ROC area: 0.822
# Bootstrap #405 ROC area: 0.775
# Bootstrap #406 ROC area: 0.836
# Bootstrap #407 ROC area: 0.838
# Bootstrap #408 ROC area: 0.801
# Bootstrap #409 ROC area: 0.807
# Bootstrap #410 ROC area: 0.795
# Bootstrap #411 ROC area: 0.831
# Bootstrap #412 ROC area: 0.770
# Bootstrap #413 ROC area: 0.802
# Bootstrap #414 ROC area: 0.818
# Bootstrap #415 ROC area: 0.829
# Bootstrap #416 ROC area: 0.782
# Bootstrap #417 ROC area: 0.815
# Bootstrap #418 ROC area: 0.786
# Bootstrap #419 ROC area: 0.732
# Bootstrap #420 ROC area: 0.837
# Bootstrap #421 ROC area: 0.793
# Bootstrap #422 ROC area: 0.798
# Bootstrap #423 ROC area: 0.769
# Bootstrap #424 ROC area: 0.778
# Bootstrap #425 ROC area: 0.813
# Bootstrap #426 ROC area: 0.778
# Bootstrap #427 ROC area: 0.808
# Bootstrap #428 ROC area: 0.804
# Bootstrap #429 ROC area: 0.811
# Bootstrap #430 ROC area: 0.801
# Bootstrap #431 ROC area: 0.808
# Bootstrap #432 ROC area: 0.772
# Bootstrap #433 ROC area: 0.761
# Bootstrap #434 ROC area: 0.793
# Bootstrap #435 ROC area: 0.756
# Bootstrap #436 ROC area: 0.764
# Bootstrap #437 ROC area: 0.828
# Bootstrap #438 ROC area: 0.799
# Bootstrap #439 ROC area: 0.798
# Bootstrap #440 ROC area: 0.844
# Bootstrap #441 ROC area: 0.792
# Bootstrap #442 ROC area: 0.827
# Bootstrap #443 ROC area: 0.721
# Bootstrap #444 ROC area: 0.800
# Bootstrap #445 ROC area: 0.812
# Bootstrap #446 ROC area: 0.789
# Bootstrap #447 ROC area: 0.819
# Bootstrap #448 ROC area: 0.799
# Bootstrap #449 ROC area: 0.834
# Bootstrap #450 ROC area: 0.839
# Bootstrap #451 ROC area: 0.858
# Bootstrap #452 ROC area: 0.825
# Bootstrap #453 ROC area: 0.806
# Bootstrap #454 ROC area: 0.854
# Bootstrap #455 ROC area: 0.773
# Bootstrap #456 ROC area: 0.775
# Bootstrap #457 ROC area: 0.822
# Bootstrap #458 ROC area: 0.803
# Bootstrap #459 ROC area: 0.786
# Bootstrap #460 ROC area: 0.820
# Bootstrap #461 ROC area: 0.774
# Bootstrap #462 ROC area: 0.796
# Bootstrap #463 ROC area: 0.786
# Bootstrap #464 ROC area: 0.782
# Bootstrap #465 ROC area: 0.827
# Bootstrap #466 ROC area: 0.866
# Bootstrap #467 ROC area: 0.771
# Bootstrap #468 ROC area: 0.790
# Bootstrap #469 ROC area: 0.823
# Bootstrap #470 ROC area: 0.822
# Bootstrap #471 ROC area: 0.774
# Bootstrap #472 ROC area: 0.842
# Bootstrap #473 ROC area: 0.838
# Bootstrap #474 ROC area: 0.793
# Bootstrap #475 ROC area: 0.771
# Bootstrap #476 ROC area: 0.791
# Bootstrap #477 ROC area: 0.762
# Bootstrap #478 ROC area: 0.825
# Bootstrap #479 ROC area: 0.760
# Bootstrap #480 ROC area: 0.734
# Bootstrap #481 ROC area: 0.809
# Bootstrap #482 ROC area: 0.796
# Bootstrap #483 ROC area: 0.804
# Bootstrap #484 ROC area: 0.788
# Bootstrap #485 ROC area: 0.826
# Bootstrap #486 ROC area: 0.820
# Bootstrap #487 ROC area: 0.828
# Bootstrap #488 ROC area: 0.788
# Bootstrap #489 ROC area: 0.808
# Bootstrap #490 ROC area: 0.820
# Bootstrap #491 ROC area: 0.819
# Bootstrap #492 ROC area: 0.824
# Bootstrap #493 ROC area: 0.784
# Bootstrap #494 ROC area: 0.804
# Bootstrap #495 ROC area: 0.803
# Bootstrap #496 ROC area: 0.826
# Bootstrap #497 ROC area: 0.836
# Bootstrap #498 ROC area: 0.826
# Bootstrap #499 ROC area: 0.822
# Bootstrap #500 ROC area: 0.818
# Bootstrap #501 ROC area: 0.799
# Bootstrap #502 ROC area: 0.819
# Bootstrap #503 ROC area: 0.851
# Bootstrap #504 ROC area: 0.835
# Bootstrap #505 ROC area: 0.731
# Bootstrap #506 ROC area: 0.799
# Bootstrap #507 ROC area: 0.741
# Bootstrap #508 ROC area: 0.717
# Bootstrap #509 ROC area: 0.792
# Bootstrap #510 ROC area: 0.788
# Bootstrap #511 ROC area: 0.807
# Bootstrap #512 ROC area: 0.799
# Bootstrap #513 ROC area: 0.841
# Bootstrap #514 ROC area: 0.808
# Bootstrap #515 ROC area: 0.829
# Bootstrap #516 ROC area: 0.802
# Bootstrap #517 ROC area: 0.850
# Bootstrap #518 ROC area: 0.761
# Bootstrap #519 ROC area: 0.818
# Bootstrap #520 ROC area: 0.822
# Bootstrap #521 ROC area: 0.767
# Bootstrap #522 ROC area: 0.797
# Bootstrap #523 ROC area: 0.765
# Bootstrap #524 ROC area: 0.795
# Bootstrap #525 ROC area: 0.827
# Bootstrap #526 ROC area: 0.839
# Bootstrap #527 ROC area: 0.812
# Bootstrap #528 ROC area: 0.812
# Bootstrap #529 ROC area: 0.755
# Bootstrap #530 ROC area: 0.801
# Bootstrap #531 ROC area: 0.782
# Bootstrap #532 ROC area: 0.804
# Bootstrap #533 ROC area: 0.821
# Bootstrap #534 ROC area: 0.821
# Bootstrap #535 ROC area: 0.827
# Bootstrap #536 ROC area: 0.860
# Bootstrap #537 ROC area: 0.781
# Bootstrap #538 ROC area: 0.770
# Bootstrap #539 ROC area: 0.776
# Bootstrap #540 ROC area: 0.836
# Bootstrap #541 ROC area: 0.810
# Bootstrap #542 ROC area: 0.810
# Bootstrap #543 ROC area: 0.787
# Bootstrap #544 ROC area: 0.779
# Bootstrap #545 ROC area: 0.776
# Bootstrap #546 ROC area: 0.789
# Bootstrap #547 ROC area: 0.738
# Bootstrap #548 ROC area: 0.777
# Bootstrap #549 ROC area: 0.790
# Bootstrap #550 ROC area: 0.802
# Bootstrap #551 ROC area: 0.805
# Bootstrap #552 ROC area: 0.769
# Bootstrap #553 ROC area: 0.839
# Bootstrap #554 ROC area: 0.789
# Bootstrap #555 ROC area: 0.812
# Bootstrap #556 ROC area: 0.814
# Bootstrap #557 ROC area: 0.847
# Bootstrap #558 ROC area: 0.858
# Bootstrap #559 ROC area: 0.811
# Bootstrap #560 ROC area: 0.789
# Bootstrap #561 ROC area: 0.771
# Bootstrap #562 ROC area: 0.745
# Bootstrap #563 ROC area: 0.838
# Bootstrap #564 ROC area: 0.782
# Bootstrap #565 ROC area: 0.831
# Bootstrap #566 ROC area: 0.816
# Bootstrap #567 ROC area: 0.821
# Bootstrap #568 ROC area: 0.747
# Bootstrap #569 ROC area: 0.758
# Bootstrap #570 ROC area: 0.823
# Bootstrap #571 ROC area: 0.745
# Bootstrap #572 ROC area: 0.762
# Bootstrap #573 ROC area: 0.782
# Bootstrap #574 ROC area: 0.836
# Bootstrap #575 ROC area: 0.816
# Bootstrap #576 ROC area: 0.839
# Bootstrap #577 ROC area: 0.775
# Bootstrap #578 ROC area: 0.815
# Bootstrap #579 ROC area: 0.860
# Bootstrap #580 ROC area: 0.791
# Bootstrap #581 ROC area: 0.774
# Bootstrap #582 ROC area: 0.817
# Bootstrap #583 ROC area: 0.817
# Bootstrap #584 ROC area: 0.813
# Bootstrap #585 ROC area: 0.801
# Bootstrap #586 ROC area: 0.808
# Bootstrap #587 ROC area: 0.838
# Bootstrap #588 ROC area: 0.810
# Bootstrap #589 ROC area: 0.786
# Bootstrap #590 ROC area: 0.839
# Bootstrap #591 ROC area: 0.873
# Bootstrap #592 ROC area: 0.792
# Bootstrap #593 ROC area: 0.819
# Bootstrap #594 ROC area: 0.833
# Bootstrap #595 ROC area: 0.817
# Bootstrap #596 ROC area: 0.775
# Bootstrap #597 ROC area: 0.838
# Bootstrap #598 ROC area: 0.769
# Bootstrap #599 ROC area: 0.803
# Bootstrap #600 ROC area: 0.840
# Bootstrap #601 ROC area: 0.712
# Bootstrap #602 ROC area: 0.796
# Bootstrap #603 ROC area: 0.798
# Bootstrap #604 ROC area: 0.818
# Bootstrap #605 ROC area: 0.813
# Bootstrap #606 ROC area: 0.797
# Bootstrap #607 ROC area: 0.782
# Bootstrap #608 ROC area: 0.773
# Bootstrap #609 ROC area: 0.801
# Bootstrap #610 ROC area: 0.820
# Bootstrap #611 ROC area: 0.804
# Bootstrap #612 ROC area: 0.825
# Bootstrap #613 ROC area: 0.779
# Bootstrap #614 ROC area: 0.754
# Bootstrap #615 ROC area: 0.770
# Bootstrap #616 ROC area: 0.776
# Bootstrap #617 ROC area: 0.810
# Bootstrap #618 ROC area: 0.811
# Bootstrap #619 ROC area: 0.808
# Bootstrap #620 ROC area: 0.817
# Bootstrap #621 ROC area: 0.842
# Bootstrap #622 ROC area: 0.838
# Bootstrap #623 ROC area: 0.849
# Bootstrap #624 ROC area: 0.805
# Bootstrap #625 ROC area: 0.808
# Bootstrap #626 ROC area: 0.776
# Bootstrap #627 ROC area: 0.834
# Bootstrap #628 ROC area: 0.825
# Bootstrap #629 ROC area: 0.777
# Bootstrap #630 ROC area: 0.816
# Bootstrap #631 ROC area: 0.746
# Bootstrap #632 ROC area: 0.834
# Bootstrap #633 ROC area: 0.778
# Bootstrap #634 ROC area: 0.832
# Bootstrap #635 ROC area: 0.737
# Bootstrap #636 ROC area: 0.773
# Bootstrap #637 ROC area: 0.834
# Bootstrap #638 ROC area: 0.761
# Bootstrap #639 ROC area: 0.768
# Bootstrap #640 ROC area: 0.808
# Bootstrap #641 ROC area: 0.801
# Bootstrap #642 ROC area: 0.800
# Bootstrap #643 ROC area: 0.849
# Bootstrap #644 ROC area: 0.850
# Bootstrap #645 ROC area: 0.794
# Bootstrap #646 ROC area: 0.834
# Bootstrap #647 ROC area: 0.755
# Bootstrap #648 ROC area: 0.808
# Bootstrap #649 ROC area: 0.754
# Bootstrap #650 ROC area: 0.757
# Bootstrap #651 ROC area: 0.790
# Bootstrap #652 ROC area: 0.765
# Bootstrap #653 ROC area: 0.839
# Bootstrap #654 ROC area: 0.824
# Bootstrap #655 ROC area: 0.792
# Bootstrap #656 ROC area: 0.792
# Bootstrap #657 ROC area: 0.815
# Bootstrap #658 ROC area: 0.837
# Bootstrap #659 ROC area: 0.802
# Bootstrap #660 ROC area: 0.734
# Bootstrap #661 ROC area: 0.835
# Bootstrap #662 ROC area: 0.771
# Bootstrap #663 ROC area: 0.832
# Bootstrap #664 ROC area: 0.848
# Bootstrap #665 ROC area: 0.798
# Bootstrap #666 ROC area: 0.792
# Bootstrap #667 ROC area: 0.843
# Bootstrap #668 ROC area: 0.792
# Bootstrap #669 ROC area: 0.783
# Bootstrap #670 ROC area: 0.796
# Bootstrap #671 ROC area: 0.828
# Bootstrap #672 ROC area: 0.799
# Bootstrap #673 ROC area: 0.812
# Bootstrap #674 ROC area: 0.790
# Bootstrap #675 ROC area: 0.796
# Bootstrap #676 ROC area: 0.804
# Bootstrap #677 ROC area: 0.778
# Bootstrap #678 ROC area: 0.810
# Bootstrap #679 ROC area: 0.778
# Bootstrap #680 ROC area: 0.874
# Bootstrap #681 ROC area: 0.790
# Bootstrap #682 ROC area: 0.754
# Bootstrap #683 ROC area: 0.796
# Bootstrap #684 ROC area: 0.791
# Bootstrap #685 ROC area: 0.812
# Bootstrap #686 ROC area: 0.802
# Bootstrap #687 ROC area: 0.827
# Bootstrap #688 ROC area: 0.787
# Bootstrap #689 ROC area: 0.847
# Bootstrap #690 ROC area: 0.798
# Bootstrap #691 ROC area: 0.778
# Bootstrap #692 ROC area: 0.850
# Bootstrap #693 ROC area: 0.812
# Bootstrap #694 ROC area: 0.771
# Bootstrap #695 ROC area: 0.865
# Bootstrap #696 ROC area: 0.789
# Bootstrap #697 ROC area: 0.816
# Bootstrap #698 ROC area: 0.847
# Bootstrap #699 ROC area: 0.835
# Bootstrap #700 ROC area: 0.815
# Bootstrap #701 ROC area: 0.768
# Bootstrap #702 ROC area: 0.807
# Bootstrap #703 ROC area: 0.841
# Bootstrap #704 ROC area: 0.819
# Bootstrap #705 ROC area: 0.841
# Bootstrap #706 ROC area: 0.788
# Bootstrap #707 ROC area: 0.819
# Bootstrap #708 ROC area: 0.783
# Bootstrap #709 ROC area: 0.807
# Bootstrap #710 ROC area: 0.826
# Bootstrap #711 ROC area: 0.862
# Bootstrap #712 ROC area: 0.782
# Bootstrap #713 ROC area: 0.810
# Bootstrap #714 ROC area: 0.789
# Bootstrap #715 ROC area: 0.851
# Bootstrap #716 ROC area: 0.785
# Bootstrap #717 ROC area: 0.808
# Bootstrap #718 ROC area: 0.765
# Bootstrap #719 ROC area: 0.843
# Bootstrap #720 ROC area: 0.766
# Bootstrap #721 ROC area: 0.830
# Bootstrap #722 ROC area: 0.845
# Bootstrap #723 ROC area: 0.841
# Bootstrap #724 ROC area: 0.834
# Bootstrap #725 ROC area: 0.802
# Bootstrap #726 ROC area: 0.800
# Bootstrap #727 ROC area: 0.832
# Bootstrap #728 ROC area: 0.824
# Bootstrap #729 ROC area: 0.855
# Bootstrap #730 ROC area: 0.840
# Bootstrap #731 ROC area: 0.806
# Bootstrap #732 ROC area: 0.795
# Bootstrap #733 ROC area: 0.787
# Bootstrap #734 ROC area: 0.740
# Bootstrap #735 ROC area: 0.783
# Bootstrap #736 ROC area: 0.806
# Bootstrap #737 ROC area: 0.763
# Bootstrap #738 ROC area: 0.835
# Bootstrap #739 ROC area: 0.801
# Bootstrap #740 ROC area: 0.783
# Bootstrap #741 ROC area: 0.804
# Bootstrap #742 ROC area: 0.824
# Bootstrap #743 ROC area: 0.757
# Bootstrap #744 ROC area: 0.803
# Bootstrap #745 ROC area: 0.799
# Bootstrap #746 ROC area: 0.860
# Bootstrap #747 ROC area: 0.818
# Bootstrap #748 ROC area: 0.803
# Bootstrap #749 ROC area: 0.816
# Bootstrap #750 ROC area: 0.808
# Bootstrap #751 ROC area: 0.702
# Bootstrap #752 ROC area: 0.850
# Bootstrap #753 ROC area: 0.829
# Bootstrap #754 ROC area: 0.801
# Bootstrap #755 ROC area: 0.827
# Bootstrap #756 ROC area: 0.810
# Bootstrap #757 ROC area: 0.805
# Bootstrap #758 ROC area: 0.833
# Bootstrap #759 ROC area: 0.828
# Bootstrap #760 ROC area: 0.773
# Bootstrap #761 ROC area: 0.750
# Bootstrap #762 ROC area: 0.838
# Bootstrap #763 ROC area: 0.851
# Bootstrap #764 ROC area: 0.796
# Bootstrap #765 ROC area: 0.793
# Bootstrap #766 ROC area: 0.841
# Bootstrap #767 ROC area: 0.782
# Bootstrap #768 ROC area: 0.786
# Bootstrap #769 ROC area: 0.825
# Bootstrap #770 ROC area: 0.765
# Bootstrap #771 ROC area: 0.810
# Bootstrap #772 ROC area: 0.807
# Bootstrap #773 ROC area: 0.738
# Bootstrap #774 ROC area: 0.823
# Bootstrap #775 ROC area: 0.829
# Bootstrap #776 ROC area: 0.814
# Bootstrap #777 ROC area: 0.784
# Bootstrap #778 ROC area: 0.760
# Bootstrap #779 ROC area: 0.886
# Bootstrap #780 ROC area: 0.827
# Bootstrap #781 ROC area: 0.778
# Bootstrap #782 ROC area: 0.850
# Bootstrap #783 ROC area: 0.770
# Bootstrap #784 ROC area: 0.812
# Bootstrap #785 ROC area: 0.827
# Bootstrap #786 ROC area: 0.763
# Bootstrap #787 ROC area: 0.793
# Bootstrap #788 ROC area: 0.773
# Bootstrap #789 ROC area: 0.782
# Bootstrap #790 ROC area: 0.797
# Bootstrap #791 ROC area: 0.787
# Bootstrap #792 ROC area: 0.731
# Bootstrap #793 ROC area: 0.819
# Bootstrap #794 ROC area: 0.843
# Bootstrap #795 ROC area: 0.838
# Bootstrap #796 ROC area: 0.823
# Bootstrap #797 ROC area: 0.844
# Bootstrap #798 ROC area: 0.825
# Bootstrap #799 ROC area: 0.822
# Bootstrap #800 ROC area: 0.785
# Bootstrap #801 ROC area: 0.833
# Bootstrap #802 ROC area: 0.820
# Bootstrap #803 ROC area: 0.822
# Bootstrap #804 ROC area: 0.819
# Bootstrap #805 ROC area: 0.802
# Bootstrap #806 ROC area: 0.792
# Bootstrap #807 ROC area: 0.834
# Bootstrap #808 ROC area: 0.824
# Bootstrap #809 ROC area: 0.844
# Bootstrap #810 ROC area: 0.860
# Bootstrap #811 ROC area: 0.816
# Bootstrap #812 ROC area: 0.780
# Bootstrap #813 ROC area: 0.884
# Bootstrap #814 ROC area: 0.786
# Bootstrap #815 ROC area: 0.770
# Bootstrap #816 ROC area: 0.815
# Bootstrap #817 ROC area: 0.803
# Bootstrap #818 ROC area: 0.828
# Bootstrap #819 ROC area: 0.824
# Bootstrap #820 ROC area: 0.789
# Bootstrap #821 ROC area: 0.803
# Bootstrap #822 ROC area: 0.826
# Bootstrap #823 ROC area: 0.815
# Bootstrap #824 ROC area: 0.799
# Bootstrap #825 ROC area: 0.828
# Bootstrap #826 ROC area: 0.781
# Bootstrap #827 ROC area: 0.790
# Bootstrap #828 ROC area: 0.816
# Bootstrap #829 ROC area: 0.781
# Bootstrap #830 ROC area: 0.818
# Bootstrap #831 ROC area: 0.798
# Bootstrap #832 ROC area: 0.792
# Bootstrap #833 ROC area: 0.827
# Bootstrap #834 ROC area: 0.816
# Bootstrap #835 ROC area: 0.776
# Bootstrap #836 ROC area: 0.829
# Bootstrap #837 ROC area: 0.771
# Bootstrap #838 ROC area: 0.748
# Bootstrap #839 ROC area: 0.869
# Bootstrap #840 ROC area: 0.780
# Bootstrap #841 ROC area: 0.777
# Bootstrap #842 ROC area: 0.809
# Bootstrap #843 ROC area: 0.816
# Bootstrap #844 ROC area: 0.837
# Bootstrap #845 ROC area: 0.817
# Bootstrap #846 ROC area: 0.812
# Bootstrap #847 ROC area: 0.806
# Bootstrap #848 ROC area: 0.833
# Bootstrap #849 ROC area: 0.842
# Bootstrap #850 ROC area: 0.790
# Bootstrap #851 ROC area: 0.805
# Bootstrap #852 ROC area: 0.813
# Bootstrap #853 ROC area: 0.855
# Bootstrap #854 ROC area: 0.792
# Bootstrap #855 ROC area: 0.825
# Bootstrap #856 ROC area: 0.785
# Bootstrap #857 ROC area: 0.814
# Bootstrap #858 ROC area: 0.790
# Bootstrap #859 ROC area: 0.863
# Bootstrap #860 ROC area: 0.760
# Bootstrap #861 ROC area: 0.810
# Bootstrap #862 ROC area: 0.786
# Bootstrap #863 ROC area: 0.791
# Bootstrap #864 ROC area: 0.812
# Bootstrap #865 ROC area: 0.839
# Bootstrap #866 ROC area: 0.797
# Bootstrap #867 ROC area: 0.823
# Bootstrap #868 ROC area: 0.787
# Bootstrap #869 ROC area: 0.749
# Bootstrap #870 ROC area: 0.811
# Bootstrap #871 ROC area: 0.784
# Bootstrap #872 ROC area: 0.802
# Bootstrap #873 ROC area: 0.790
# Bootstrap #874 ROC area: 0.820
# Bootstrap #875 ROC area: 0.756
# Bootstrap #876 ROC area: 0.765
# Bootstrap #877 ROC area: 0.791
# Bootstrap #878 ROC area: 0.800
# Bootstrap #879 ROC area: 0.812
# Bootstrap #880 ROC area: 0.837
# Bootstrap #881 ROC area: 0.781
# Bootstrap #882 ROC area: 0.796
# Bootstrap #883 ROC area: 0.779
# Bootstrap #884 ROC area: 0.789
# Bootstrap #885 ROC area: 0.803
# Bootstrap #886 ROC area: 0.817
# Bootstrap #887 ROC area: 0.854
# Bootstrap #888 ROC area: 0.831
# Bootstrap #889 ROC area: 0.786
# Bootstrap #890 ROC area: 0.859
# Bootstrap #891 ROC area: 0.833
# Bootstrap #892 ROC area: 0.780
# Bootstrap #893 ROC area: 0.762
# Bootstrap #894 ROC area: 0.833
# Bootstrap #895 ROC area: 0.844
# Bootstrap #896 ROC area: 0.816
# Bootstrap #897 ROC area: 0.752
# Bootstrap #898 ROC area: 0.804
# Bootstrap #899 ROC area: 0.796
# Bootstrap #900 ROC area: 0.846
# Bootstrap #901 ROC area: 0.842
# Bootstrap #902 ROC area: 0.799
# Bootstrap #903 ROC area: 0.820
# Bootstrap #904 ROC area: 0.819
# Bootstrap #905 ROC area: 0.813
# Bootstrap #906 ROC area: 0.786
# Bootstrap #907 ROC area: 0.832
# Bootstrap #908 ROC area: 0.781
# Bootstrap #909 ROC area: 0.830
# Bootstrap #910 ROC area: 0.864
# Bootstrap #911 ROC area: 0.775
# Bootstrap #912 ROC area: 0.810
# Bootstrap #913 ROC area: 0.772
# Bootstrap #914 ROC area: 0.818
# Bootstrap #915 ROC area: 0.726
# Bootstrap #916 ROC area: 0.760
# Bootstrap #917 ROC area: 0.797
# Bootstrap #918 ROC area: 0.805
# Bootstrap #919 ROC area: 0.764
# Bootstrap #920 ROC area: 0.844
# Bootstrap #921 ROC area: 0.817
# Bootstrap #922 ROC area: 0.816
# Bootstrap #923 ROC area: 0.820
# Bootstrap #924 ROC area: 0.827
# Bootstrap #925 ROC area: 0.762
# Bootstrap #926 ROC area: 0.821
# Bootstrap #927 ROC area: 0.805
# Bootstrap #928 ROC area: 0.829
# Bootstrap #929 ROC area: 0.715
# Bootstrap #930 ROC area: 0.810
# Bootstrap #931 ROC area: 0.776
# Bootstrap #932 ROC area: 0.804
# Bootstrap #933 ROC area: 0.855
# Bootstrap #934 ROC area: 0.772
# Bootstrap #935 ROC area: 0.797
# Bootstrap #936 ROC area: 0.810
# Bootstrap #937 ROC area: 0.843
# Bootstrap #938 ROC area: 0.814
# Bootstrap #939 ROC area: 0.752
# Bootstrap #940 ROC area: 0.808
# Bootstrap #941 ROC area: 0.833
# Bootstrap #942 ROC area: 0.817
# Bootstrap #943 ROC area: 0.809
# Bootstrap #944 ROC area: 0.800
# Bootstrap #945 ROC area: 0.747
# Bootstrap #946 ROC area: 0.806
# Bootstrap #947 ROC area: 0.812
# Bootstrap #948 ROC area: 0.747
# Bootstrap #949 ROC area: 0.818
# Bootstrap #950 ROC area: 0.766
# Bootstrap #951 ROC area: 0.787
# Bootstrap #952 ROC area: 0.795
# Bootstrap #953 ROC area: 0.883
# Bootstrap #954 ROC area: 0.825
# Bootstrap #955 ROC area: 0.860
# Bootstrap #956 ROC area: 0.781
# Bootstrap #957 ROC area: 0.828
# Bootstrap #958 ROC area: 0.842
# Bootstrap #959 ROC area: 0.838
# Bootstrap #960 ROC area: 0.847
# Bootstrap #961 ROC area: 0.817
# Bootstrap #962 ROC area: 0.800
# Bootstrap #963 ROC area: 0.785
# Bootstrap #964 ROC area: 0.788
# Bootstrap #965 ROC area: 0.793
# Bootstrap #966 ROC area: 0.786
# Bootstrap #967 ROC area: 0.835
# Bootstrap #968 ROC area: 0.771
# Bootstrap #969 ROC area: 0.835
# Bootstrap #970 ROC area: 0.824
# Bootstrap #971 ROC area: 0.836
# Bootstrap #972 ROC area: 0.776
# Bootstrap #973 ROC area: 0.813
# Bootstrap #974 ROC area: 0.841
# Bootstrap #975 ROC area: 0.779
# Bootstrap #976 ROC area: 0.843
# Bootstrap #977 ROC area: 0.827
# Bootstrap #978 ROC area: 0.831
# Bootstrap #979 ROC area: 0.790
# Bootstrap #980 ROC area: 0.832
# Bootstrap #981 ROC area: 0.799
# Bootstrap #982 ROC area: 0.803
# Bootstrap #983 ROC area: 0.844
# Bootstrap #984 ROC area: 0.799
# Bootstrap #985 ROC area: 0.803
# Bootstrap #986 ROC area: 0.822
# Bootstrap #987 ROC area: 0.840
# Bootstrap #988 ROC area: 0.808
# Bootstrap #989 ROC area: 0.785
# Bootstrap #990 ROC area: 0.819
# Bootstrap #991 ROC area: 0.790
# Bootstrap #992 ROC area: 0.811
# Bootstrap #993 ROC area: 0.850
# Bootstrap #994 ROC area: 0.746
# Bootstrap #995 ROC area: 0.805
# Bootstrap #996 ROC area: 0.830
# Bootstrap #997 ROC area: 0.882
# Bootstrap #998 ROC area: 0.792
# Bootstrap #999 ROC area: 0.825
# Bootstrap #1000 ROC area: 0.757

# %%
sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()
confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score on Hispanic patients: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Confidence interval for the score on Hispanic patients: [0.741 - 0.86]

# %% [markdown]
# #### For Asian Patient Set

# %%
y_pred_asian = model.predict_proba(xTestAsian)
print("Original ROC area: {:0.3f}".format(roc_auc_score(yTestAsian, y_pred_asian[:,1])))
# Out:
# Original ROC area: 0.798

# %%
n_bootstraps = 1000
rng_seed = 42  # control reproducibility
bootstrapped_scores = []

rng = np.random.RandomState(rng_seed)
for i in range(n_bootstraps):
    indices = rng.randint(0, len(y_pred_asian), len(y_pred_asian))

    score = roc_auc_score(yTestAsian.to_numpy()[indices], y_pred_asian[indices, 1])
    bootstrapped_scores.append(score)
    print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))
# Out:
# Bootstrap #1 ROC area: 0.804
# Bootstrap #2 ROC area: 0.864
# Bootstrap #3 ROC area: 0.789
# Bootstrap #4 ROC area: 0.779
# Bootstrap #5 ROC area: 0.759
# Bootstrap #6 ROC area: 0.802
# Bootstrap #7 ROC area: 0.824
# Bootstrap #8 ROC area: 0.815
# Bootstrap #9 ROC area: 0.796
# Bootstrap #10 ROC area: 0.805
# Bootstrap #11 ROC area: 0.725
# Bootstrap #12 ROC area: 0.768
# Bootstrap #13 ROC area: 0.788
# Bootstrap #14 ROC area: 0.725
# Bootstrap #15 ROC area: 0.754
# Bootstrap #16 ROC area: 0.731
# Bootstrap #17 ROC area: 0.794
# Bootstrap #18 ROC area: 0.722
# Bootstrap #19 ROC area: 0.783
# Bootstrap #20 ROC area: 0.822
# Bootstrap #21 ROC area: 0.808
# Bootstrap #22 ROC area: 0.856
# Bootstrap #23 ROC area: 0.806
# Bootstrap #24 ROC area: 0.810
# Bootstrap #25 ROC area: 0.770
# Bootstrap #26 ROC area: 0.835
# Bootstrap #27 ROC area: 0.900
# Bootstrap #28 ROC area: 0.856
# Bootstrap #29 ROC area: 0.801
# Bootstrap #30 ROC area: 0.710
# Bootstrap #31 ROC area: 0.758
# Bootstrap #32 ROC area: 0.816
# Bootstrap #33 ROC area: 0.641
# Bootstrap #34 ROC area: 0.851
# Bootstrap #35 ROC area: 0.750
# Bootstrap #36 ROC area: 0.831
# Bootstrap #37 ROC area: 0.809
# Bootstrap #38 ROC area: 0.842
# Bootstrap #39 ROC area: 0.815
# Bootstrap #40 ROC area: 0.835
# Bootstrap #41 ROC area: 0.807
# Bootstrap #42 ROC area: 0.782
# Bootstrap #43 ROC area: 0.681
# Bootstrap #44 ROC area: 0.854
# Bootstrap #45 ROC area: 0.788
# Bootstrap #46 ROC area: 0.812
# Bootstrap #47 ROC area: 0.806
# Bootstrap #48 ROC area: 0.751
# Bootstrap #49 ROC area: 0.858
# Bootstrap #50 ROC area: 0.789
# Bootstrap #51 ROC area: 0.811
# Bootstrap #52 ROC area: 0.823
# Bootstrap #53 ROC area: 0.799
# Bootstrap #54 ROC area: 0.770
# Bootstrap #55 ROC area: 0.766
# Bootstrap #56 ROC area: 0.790
# Bootstrap #57 ROC area: 0.864
# Bootstrap #58 ROC area: 0.773
# Bootstrap #59 ROC area: 0.829
# Bootstrap #60 ROC area: 0.802
# Bootstrap #61 ROC area: 0.762
# Bootstrap #62 ROC area: 0.781
# Bootstrap #63 ROC area: 0.822
# Bootstrap #64 ROC area: 0.807
# Bootstrap #65 ROC area: 0.750
# Bootstrap #66 ROC area: 0.726
# Bootstrap #67 ROC area: 0.791
# Bootstrap #68 ROC area: 0.812
# Bootstrap #69 ROC area: 0.788
# Bootstrap #70 ROC area: 0.853
# Bootstrap #71 ROC area: 0.777
# Bootstrap #72 ROC area: 0.756
# Bootstrap #73 ROC area: 0.789
# Bootstrap #74 ROC area: 0.833
# Bootstrap #75 ROC area: 0.722
# Bootstrap #76 ROC area: 0.815
# Bootstrap #77 ROC area: 0.767
# Bootstrap #78 ROC area: 0.783
# Bootstrap #79 ROC area: 0.750
# Bootstrap #80 ROC area: 0.788
# Bootstrap #81 ROC area: 0.797
# Bootstrap #82 ROC area: 0.769
# Bootstrap #83 ROC area: 0.789
# Bootstrap #84 ROC area: 0.714
# Bootstrap #85 ROC area: 0.760
# Bootstrap #86 ROC area: 0.853
# Bootstrap #87 ROC area: 0.824
# Bootstrap #88 ROC area: 0.800
# Bootstrap #89 ROC area: 0.829
# Bootstrap #90 ROC area: 0.745
# Bootstrap #91 ROC area: 0.849
# Bootstrap #92 ROC area: 0.817
# Bootstrap #93 ROC area: 0.834
# Bootstrap #94 ROC area: 0.787
# Bootstrap #95 ROC area: 0.786
# Bootstrap #96 ROC area: 0.836
# Bootstrap #97 ROC area: 0.766
# Bootstrap #98 ROC area: 0.824
# Bootstrap #99 ROC area: 0.718
# Bootstrap #100 ROC area: 0.816
# Bootstrap #101 ROC area: 0.759
# Bootstrap #102 ROC area: 0.789
# Bootstrap #103 ROC area: 0.806
# Bootstrap #104 ROC area: 0.809
# Bootstrap #105 ROC area: 0.747
# Bootstrap #106 ROC area: 0.833
# Bootstrap #107 ROC area: 0.852
# Bootstrap #108 ROC area: 0.817
# Bootstrap #109 ROC area: 0.751
# Bootstrap #110 ROC area: 0.855
# Bootstrap #111 ROC area: 0.783
# Bootstrap #112 ROC area: 0.739
# Bootstrap #113 ROC area: 0.828
# Bootstrap #114 ROC area: 0.818
# Bootstrap #115 ROC area: 0.852
# Bootstrap #116 ROC area: 0.848
# Bootstrap #117 ROC area: 0.812
# Bootstrap #118 ROC area: 0.832
# Bootstrap #119 ROC area: 0.773
# Bootstrap #120 ROC area: 0.749
# Bootstrap #121 ROC area: 0.771
# Bootstrap #122 ROC area: 0.739
# Bootstrap #123 ROC area: 0.754
# Bootstrap #124 ROC area: 0.766
# Bootstrap #125 ROC area: 0.804
# Bootstrap #126 ROC area: 0.801
# Bootstrap #127 ROC area: 0.762
# Bootstrap #128 ROC area: 0.828
# Bootstrap #129 ROC area: 0.791
# Bootstrap #130 ROC area: 0.772
# Bootstrap #131 ROC area: 0.768
# Bootstrap #132 ROC area: 0.798
# Bootstrap #133 ROC area: 0.777
# Bootstrap #134 ROC area: 0.812
# Bootstrap #135 ROC area: 0.818
# Bootstrap #136 ROC area: 0.763
# Bootstrap #137 ROC area: 0.794
# Bootstrap #138 ROC area: 0.839
# Bootstrap #139 ROC area: 0.781
# Bootstrap #140 ROC area: 0.766
# Bootstrap #141 ROC area: 0.880
# Bootstrap #142 ROC area: 0.818
# Bootstrap #143 ROC area: 0.801
# Bootstrap #144 ROC area: 0.779
# Bootstrap #145 ROC area: 0.822
# Bootstrap #146 ROC area: 0.838
# Bootstrap #147 ROC area: 0.782
# Bootstrap #148 ROC area: 0.764
# Bootstrap #149 ROC area: 0.807
# Bootstrap #150 ROC area: 0.865
# Bootstrap #151 ROC area: 0.783
# Bootstrap #152 ROC area: 0.836
# Bootstrap #153 ROC area: 0.813
# Bootstrap #154 ROC area: 0.741
# Bootstrap #155 ROC area: 0.814
# Bootstrap #156 ROC area: 0.824
# Bootstrap #157 ROC area: 0.775
# Bootstrap #158 ROC area: 0.774
# Bootstrap #159 ROC area: 0.813
# Bootstrap #160 ROC area: 0.785
# Bootstrap #161 ROC area: 0.847
# Bootstrap #162 ROC area: 0.817
# Bootstrap #163 ROC area: 0.815
# Bootstrap #164 ROC area: 0.820
# Bootstrap #165 ROC area: 0.779
# Bootstrap #166 ROC area: 0.781
# Bootstrap #167 ROC area: 0.798
# Bootstrap #168 ROC area: 0.770
# Bootstrap #169 ROC area: 0.825
# Bootstrap #170 ROC area: 0.854
# Bootstrap #171 ROC area: 0.794
# Bootstrap #172 ROC area: 0.817
# Bootstrap #173 ROC area: 0.795
# Bootstrap #174 ROC area: 0.777
# Bootstrap #175 ROC area: 0.810
# Bootstrap #176 ROC area: 0.806
# Bootstrap #177 ROC area: 0.798
# Bootstrap #178 ROC area: 0.832
# Bootstrap #179 ROC area: 0.810
# Bootstrap #180 ROC area: 0.839
# Bootstrap #181 ROC area: 0.796
# Bootstrap #182 ROC area: 0.804
# Bootstrap #183 ROC area: 0.797
# Bootstrap #184 ROC area: 0.829
# Bootstrap #185 ROC area: 0.779
# Bootstrap #186 ROC area: 0.795
# Bootstrap #187 ROC area: 0.824
# Bootstrap #188 ROC area: 0.771
# Bootstrap #189 ROC area: 0.741
# Bootstrap #190 ROC area: 0.748
# Bootstrap #191 ROC area: 0.803
# Bootstrap #192 ROC area: 0.815
# Bootstrap #193 ROC area: 0.742
# Bootstrap #194 ROC area: 0.808
# Bootstrap #195 ROC area: 0.842
# Bootstrap #196 ROC area: 0.765
# Bootstrap #197 ROC area: 0.790
# Bootstrap #198 ROC area: 0.744
# Bootstrap #199 ROC area: 0.779
# Bootstrap #200 ROC area: 0.819
# Bootstrap #201 ROC area: 0.825
# Bootstrap #202 ROC area: 0.844
# Bootstrap #203 ROC area: 0.794
# Bootstrap #204 ROC area: 0.778
# Bootstrap #205 ROC area: 0.731
# Bootstrap #206 ROC area: 0.779
# Bootstrap #207 ROC area: 0.763
# Bootstrap #208 ROC area: 0.844
# Bootstrap #209 ROC area: 0.859
# Bootstrap #210 ROC area: 0.736
# Bootstrap #211 ROC area: 0.795
# Bootstrap #212 ROC area: 0.775
# Bootstrap #213 ROC area: 0.760
# Bootstrap #214 ROC area: 0.774
# Bootstrap #215 ROC area: 0.796
# Bootstrap #216 ROC area: 0.799
# Bootstrap #217 ROC area: 0.761
# Bootstrap #218 ROC area: 0.752
# Bootstrap #219 ROC area: 0.798
# Bootstrap #220 ROC area: 0.807
# Bootstrap #221 ROC area: 0.799
# Bootstrap #222 ROC area: 0.775
# Bootstrap #223 ROC area: 0.704
# Bootstrap #224 ROC area: 0.723
# Bootstrap #225 ROC area: 0.773
# Bootstrap #226 ROC area: 0.802
# Bootstrap #227 ROC area: 0.846
# Bootstrap #228 ROC area: 0.734
# Bootstrap #229 ROC area: 0.761
# Bootstrap #230 ROC area: 0.826
# Bootstrap #231 ROC area: 0.816
# Bootstrap #232 ROC area: 0.805
# Bootstrap #233 ROC area: 0.801
# Bootstrap #234 ROC area: 0.841
# Bootstrap #235 ROC area: 0.810
# Bootstrap #236 ROC area: 0.819
# Bootstrap #237 ROC area: 0.778
# Bootstrap #238 ROC area: 0.859
# Bootstrap #239 ROC area: 0.845
# Bootstrap #240 ROC area: 0.828
# Bootstrap #241 ROC area: 0.823
# Bootstrap #242 ROC area: 0.820
# Bootstrap #243 ROC area: 0.780
# Bootstrap #244 ROC area: 0.816
# Bootstrap #245 ROC area: 0.753
# Bootstrap #246 ROC area: 0.853
# Bootstrap #247 ROC area: 0.816
# Bootstrap #248 ROC area: 0.790
# Bootstrap #249 ROC area: 0.805
# Bootstrap #250 ROC area: 0.812
# Bootstrap #251 ROC area: 0.706
# Bootstrap #252 ROC area: 0.785
# Bootstrap #253 ROC area: 0.787
# Bootstrap #254 ROC area: 0.818
# Bootstrap #255 ROC area: 0.777
# Bootstrap #256 ROC area: 0.786
# Bootstrap #257 ROC area: 0.775
# Bootstrap #258 ROC area: 0.816
# Bootstrap #259 ROC area: 0.800
# Bootstrap #260 ROC area: 0.771
# Bootstrap #261 ROC area: 0.739
# Bootstrap #262 ROC area: 0.786
# Bootstrap #263 ROC area: 0.793
# Bootstrap #264 ROC area: 0.699
# Bootstrap #265 ROC area: 0.758
# Bootstrap #266 ROC area: 0.820
# Bootstrap #267 ROC area: 0.819
# Bootstrap #268 ROC area: 0.726
# Bootstrap #269 ROC area: 0.745
# Bootstrap #270 ROC area: 0.840
# Bootstrap #271 ROC area: 0.807
# Bootstrap #272 ROC area: 0.832
# Bootstrap #273 ROC area: 0.829
# Bootstrap #274 ROC area: 0.791
# Bootstrap #275 ROC area: 0.758
# Bootstrap #276 ROC area: 0.802
# Bootstrap #277 ROC area: 0.828
# Bootstrap #278 ROC area: 0.780
# Bootstrap #279 ROC area: 0.785
# Bootstrap #280 ROC area: 0.811
# Bootstrap #281 ROC area: 0.787
# Bootstrap #282 ROC area: 0.838
# Bootstrap #283 ROC area: 0.799
# Bootstrap #284 ROC area: 0.759
# Bootstrap #285 ROC area: 0.797
# Bootstrap #286 ROC area: 0.834
# Bootstrap #287 ROC area: 0.800
# Bootstrap #288 ROC area: 0.862
# Bootstrap #289 ROC area: 0.790
# Bootstrap #290 ROC area: 0.832
# Bootstrap #291 ROC area: 0.808
# Bootstrap #292 ROC area: 0.773
# Bootstrap #293 ROC area: 0.862
# Bootstrap #294 ROC area: 0.789
# Bootstrap #295 ROC area: 0.798
# Bootstrap #296 ROC area: 0.837
# Bootstrap #297 ROC area: 0.838
# Bootstrap #298 ROC area: 0.792
# Bootstrap #299 ROC area: 0.868
# Bootstrap #300 ROC area: 0.770
# Bootstrap #301 ROC area: 0.806
# Bootstrap #302 ROC area: 0.814
# Bootstrap #303 ROC area: 0.760
# Bootstrap #304 ROC area: 0.770
# Bootstrap #305 ROC area: 0.809
# Bootstrap #306 ROC area: 0.803
# Bootstrap #307 ROC area: 0.802
# Bootstrap #308 ROC area: 0.821
# Bootstrap #309 ROC area: 0.806
# Bootstrap #310 ROC area: 0.808
# Bootstrap #311 ROC area: 0.811
# Bootstrap #312 ROC area: 0.796
# Bootstrap #313 ROC area: 0.843
# Bootstrap #314 ROC area: 0.833
# Bootstrap #315 ROC area: 0.799
# Bootstrap #316 ROC area: 0.812
# Bootstrap #317 ROC area: 0.842
# Bootstrap #318 ROC area: 0.786
# Bootstrap #319 ROC area: 0.776
# Bootstrap #320 ROC area: 0.837
# Bootstrap #321 ROC area: 0.797
# Bootstrap #322 ROC area: 0.853
# Bootstrap #323 ROC area: 0.839
# Bootstrap #324 ROC area: 0.772
# Bootstrap #325 ROC area: 0.829
# Bootstrap #326 ROC area: 0.750
# Bootstrap #327 ROC area: 0.831
# Bootstrap #328 ROC area: 0.775
# Bootstrap #329 ROC area: 0.790
# Bootstrap #330 ROC area: 0.792
# Bootstrap #331 ROC area: 0.827
# Bootstrap #332 ROC area: 0.803
# Bootstrap #333 ROC area: 0.810
# Bootstrap #334 ROC area: 0.791
# Bootstrap #335 ROC area: 0.782
# Bootstrap #336 ROC area: 0.784
# Bootstrap #337 ROC area: 0.772
# Bootstrap #338 ROC area: 0.832
# Bootstrap #339 ROC area: 0.847
# Bootstrap #340 ROC area: 0.747
# Bootstrap #341 ROC area: 0.827
# Bootstrap #342 ROC area: 0.801
# Bootstrap #343 ROC area: 0.807
# Bootstrap #344 ROC area: 0.783
# Bootstrap #345 ROC area: 0.791
# Bootstrap #346 ROC area: 0.781
# Bootstrap #347 ROC area: 0.823
# Bootstrap #348 ROC area: 0.789
# Bootstrap #349 ROC area: 0.869
# Bootstrap #350 ROC area: 0.792
# Bootstrap #351 ROC area: 0.835
# Bootstrap #352 ROC area: 0.770
# Bootstrap #353 ROC area: 0.719
# Bootstrap #354 ROC area: 0.816
# Bootstrap #355 ROC area: 0.830
# Bootstrap #356 ROC area: 0.763
# Bootstrap #357 ROC area: 0.800
# Bootstrap #358 ROC area: 0.811
# Bootstrap #359 ROC area: 0.836
# Bootstrap #360 ROC area: 0.810
# Bootstrap #361 ROC area: 0.749
# Bootstrap #362 ROC area: 0.777
# Bootstrap #363 ROC area: 0.807
# Bootstrap #364 ROC area: 0.814
# Bootstrap #365 ROC area: 0.862
# Bootstrap #366 ROC area: 0.847
# Bootstrap #367 ROC area: 0.759
# Bootstrap #368 ROC area: 0.791
# Bootstrap #369 ROC area: 0.768
# Bootstrap #370 ROC area: 0.813
# Bootstrap #371 ROC area: 0.863
# Bootstrap #372 ROC area: 0.832
# Bootstrap #373 ROC area: 0.802
# Bootstrap #374 ROC area: 0.820
# Bootstrap #375 ROC area: 0.771
# Bootstrap #376 ROC area: 0.808
# Bootstrap #377 ROC area: 0.771
# Bootstrap #378 ROC area: 0.706
# Bootstrap #379 ROC area: 0.800
# Bootstrap #380 ROC area: 0.836
# Bootstrap #381 ROC area: 0.768
# Bootstrap #382 ROC area: 0.786
# Bootstrap #383 ROC area: 0.765
# Bootstrap #384 ROC area: 0.801
# Bootstrap #385 ROC area: 0.829
# Bootstrap #386 ROC area: 0.846
# Bootstrap #387 ROC area: 0.769
# Bootstrap #388 ROC area: 0.806
# Bootstrap #389 ROC area: 0.865
# Bootstrap #390 ROC area: 0.759
# Bootstrap #391 ROC area: 0.705
# Bootstrap #392 ROC area: 0.745
# Bootstrap #393 ROC area: 0.765
# Bootstrap #394 ROC area: 0.809
# Bootstrap #395 ROC area: 0.738
# Bootstrap #396 ROC area: 0.744
# Bootstrap #397 ROC area: 0.803
# Bootstrap #398 ROC area: 0.779
# Bootstrap #399 ROC area: 0.807
# Bootstrap #400 ROC area: 0.786
# Bootstrap #401 ROC area: 0.769
# Bootstrap #402 ROC area: 0.737
# Bootstrap #403 ROC area: 0.827
# Bootstrap #404 ROC area: 0.816
# Bootstrap #405 ROC area: 0.788
# Bootstrap #406 ROC area: 0.786
# Bootstrap #407 ROC area: 0.768
# Bootstrap #408 ROC area: 0.813
# Bootstrap #409 ROC area: 0.772
# Bootstrap #410 ROC area: 0.839
# Bootstrap #411 ROC area: 0.825
# Bootstrap #412 ROC area: 0.796
# Bootstrap #413 ROC area: 0.793
# Bootstrap #414 ROC area: 0.816
# Bootstrap #415 ROC area: 0.781
# Bootstrap #416 ROC area: 0.842
# Bootstrap #417 ROC area: 0.762
# Bootstrap #418 ROC area: 0.816
# Bootstrap #419 ROC area: 0.819
# Bootstrap #420 ROC area: 0.827
# Bootstrap #421 ROC area: 0.812
# Bootstrap #422 ROC area: 0.768
# Bootstrap #423 ROC area: 0.779
# Bootstrap #424 ROC area: 0.829
# Bootstrap #425 ROC area: 0.751
# Bootstrap #426 ROC area: 0.801
# Bootstrap #427 ROC area: 0.805
# Bootstrap #428 ROC area: 0.804
# Bootstrap #429 ROC area: 0.785
# Bootstrap #430 ROC area: 0.821
# Bootstrap #431 ROC area: 0.833
# Bootstrap #432 ROC area: 0.772
# Bootstrap #433 ROC area: 0.807
# Bootstrap #434 ROC area: 0.837
# Bootstrap #435 ROC area: 0.762
# Bootstrap #436 ROC area: 0.762
# Bootstrap #437 ROC area: 0.783
# Bootstrap #438 ROC area: 0.825
# Bootstrap #439 ROC area: 0.792
# Bootstrap #440 ROC area: 0.808
# Bootstrap #441 ROC area: 0.845
# Bootstrap #442 ROC area: 0.759
# Bootstrap #443 ROC area: 0.796
# Bootstrap #444 ROC area: 0.823
# Bootstrap #445 ROC area: 0.795
# Bootstrap #446 ROC area: 0.810
# Bootstrap #447 ROC area: 0.800
# Bootstrap #448 ROC area: 0.842
# Bootstrap #449 ROC area: 0.819
# Bootstrap #450 ROC area: 0.800
# Bootstrap #451 ROC area: 0.822
# Bootstrap #452 ROC area: 0.762
# Bootstrap #453 ROC area: 0.772
# Bootstrap #454 ROC area: 0.743
# Bootstrap #455 ROC area: 0.806
# Bootstrap #456 ROC area: 0.803
# Bootstrap #457 ROC area: 0.794
# Bootstrap #458 ROC area: 0.794
# Bootstrap #459 ROC area: 0.832
# Bootstrap #460 ROC area: 0.774
# Bootstrap #461 ROC area: 0.758
# Bootstrap #462 ROC area: 0.808
# Bootstrap #463 ROC area: 0.783
# Bootstrap #464 ROC area: 0.820
# Bootstrap #465 ROC area: 0.840
# Bootstrap #466 ROC area: 0.793
# Bootstrap #467 ROC area: 0.826
# Bootstrap #468 ROC area: 0.814
# Bootstrap #469 ROC area: 0.826
# Bootstrap #470 ROC area: 0.784
# Bootstrap #471 ROC area: 0.784
# Bootstrap #472 ROC area: 0.763
# Bootstrap #473 ROC area: 0.782
# Bootstrap #474 ROC area: 0.813
# Bootstrap #475 ROC area: 0.771
# Bootstrap #476 ROC area: 0.738
# Bootstrap #477 ROC area: 0.882
# Bootstrap #478 ROC area: 0.793
# Bootstrap #479 ROC area: 0.889
# Bootstrap #480 ROC area: 0.824
# Bootstrap #481 ROC area: 0.787
# Bootstrap #482 ROC area: 0.828
# Bootstrap #483 ROC area: 0.803
# Bootstrap #484 ROC area: 0.782
# Bootstrap #485 ROC area: 0.750
# Bootstrap #486 ROC area: 0.834
# Bootstrap #487 ROC area: 0.826
# Bootstrap #488 ROC area: 0.821
# Bootstrap #489 ROC area: 0.794
# Bootstrap #490 ROC area: 0.811
# Bootstrap #491 ROC area: 0.822
# Bootstrap #492 ROC area: 0.822
# Bootstrap #493 ROC area: 0.784
# Bootstrap #494 ROC area: 0.819
# Bootstrap #495 ROC area: 0.807
# Bootstrap #496 ROC area: 0.789
# Bootstrap #497 ROC area: 0.800
# Bootstrap #498 ROC area: 0.786
# Bootstrap #499 ROC area: 0.813
# Bootstrap #500 ROC area: 0.873
# Bootstrap #501 ROC area: 0.788
# Bootstrap #502 ROC area: 0.795
# Bootstrap #503 ROC area: 0.846
# Bootstrap #504 ROC area: 0.741
# Bootstrap #505 ROC area: 0.838
# Bootstrap #506 ROC area: 0.847
# Bootstrap #507 ROC area: 0.763
# Bootstrap #508 ROC area: 0.784
# Bootstrap #509 ROC area: 0.835
# Bootstrap #510 ROC area: 0.819
# Bootstrap #511 ROC area: 0.795
# Bootstrap #512 ROC area: 0.823
# Bootstrap #513 ROC area: 0.682
# Bootstrap #514 ROC area: 0.793
# Bootstrap #515 ROC area: 0.812
# Bootstrap #516 ROC area: 0.750
# Bootstrap #517 ROC area: 0.792
# Bootstrap #518 ROC area: 0.791
# Bootstrap #519 ROC area: 0.820
# Bootstrap #520 ROC area: 0.812
# Bootstrap #521 ROC area: 0.789
# Bootstrap #522 ROC area: 0.781
# Bootstrap #523 ROC area: 0.873
# Bootstrap #524 ROC area: 0.746
# Bootstrap #525 ROC area: 0.827
# Bootstrap #526 ROC area: 0.831
# Bootstrap #527 ROC area: 0.791
# Bootstrap #528 ROC area: 0.782
# Bootstrap #529 ROC area: 0.784
# Bootstrap #530 ROC area: 0.769
# Bootstrap #531 ROC area: 0.833
# Bootstrap #532 ROC area: 0.800
# Bootstrap #533 ROC area: 0.803
# Bootstrap #534 ROC area: 0.809
# Bootstrap #535 ROC area: 0.811
# Bootstrap #536 ROC area: 0.839
# Bootstrap #537 ROC area: 0.846
# Bootstrap #538 ROC area: 0.808
# Bootstrap #539 ROC area: 0.827
# Bootstrap #540 ROC area: 0.800
# Bootstrap #541 ROC area: 0.813
# Bootstrap #542 ROC area: 0.851
# Bootstrap #543 ROC area: 0.835
# Bootstrap #544 ROC area: 0.826
# Bootstrap #545 ROC area: 0.760
# Bootstrap #546 ROC area: 0.842
# Bootstrap #547 ROC area: 0.818
# Bootstrap #548 ROC area: 0.849
# Bootstrap #549 ROC area: 0.866
# Bootstrap #550 ROC area: 0.748
# Bootstrap #551 ROC area: 0.797
# Bootstrap #552 ROC area: 0.815
# Bootstrap #553 ROC area: 0.799
# Bootstrap #554 ROC area: 0.873
# Bootstrap #555 ROC area: 0.831
# Bootstrap #556 ROC area: 0.831
# Bootstrap #557 ROC area: 0.772
# Bootstrap #558 ROC area: 0.806
# Bootstrap #559 ROC area: 0.796
# Bootstrap #560 ROC area: 0.752
# Bootstrap #561 ROC area: 0.755
# Bootstrap #562 ROC area: 0.811
# Bootstrap #563 ROC area: 0.873
# Bootstrap #564 ROC area: 0.762
# Bootstrap #565 ROC area: 0.828
# Bootstrap #566 ROC area: 0.838
# Bootstrap #567 ROC area: 0.804
# Bootstrap #568 ROC area: 0.818
# Bootstrap #569 ROC area: 0.788
# Bootstrap #570 ROC area: 0.822
# Bootstrap #571 ROC area: 0.874
# Bootstrap #572 ROC area: 0.797
# Bootstrap #573 ROC area: 0.789
# Bootstrap #574 ROC area: 0.840
# Bootstrap #575 ROC area: 0.771
# Bootstrap #576 ROC area: 0.837
# Bootstrap #577 ROC area: 0.824
# Bootstrap #578 ROC area: 0.833
# Bootstrap #579 ROC area: 0.778
# Bootstrap #580 ROC area: 0.843
# Bootstrap #581 ROC area: 0.871
# Bootstrap #582 ROC area: 0.763
# Bootstrap #583 ROC area: 0.757
# Bootstrap #584 ROC area: 0.773
# Bootstrap #585 ROC area: 0.779
# Bootstrap #586 ROC area: 0.781
# Bootstrap #587 ROC area: 0.849
# Bootstrap #588 ROC area: 0.777
# Bootstrap #589 ROC area: 0.840
# Bootstrap #590 ROC area: 0.801
# Bootstrap #591 ROC area: 0.774
# Bootstrap #592 ROC area: 0.865
# Bootstrap #593 ROC area: 0.820
# Bootstrap #594 ROC area: 0.789
# Bootstrap #595 ROC area: 0.797
# Bootstrap #596 ROC area: 0.848
# Bootstrap #597 ROC area: 0.767
# Bootstrap #598 ROC area: 0.782
# Bootstrap #599 ROC area: 0.809
# Bootstrap #600 ROC area: 0.839
# Bootstrap #601 ROC area: 0.828
# Bootstrap #602 ROC area: 0.789
# Bootstrap #603 ROC area: 0.837
# Bootstrap #604 ROC area: 0.773
# Bootstrap #605 ROC area: 0.767
# Bootstrap #606 ROC area: 0.807
# Bootstrap #607 ROC area: 0.651
# Bootstrap #608 ROC area: 0.795
# Bootstrap #609 ROC area: 0.766
# Bootstrap #610 ROC area: 0.834
# Bootstrap #611 ROC area: 0.783
# Bootstrap #612 ROC area: 0.747
# Bootstrap #613 ROC area: 0.794
# Bootstrap #614 ROC area: 0.842
# Bootstrap #615 ROC area: 0.850
# Bootstrap #616 ROC area: 0.795
# Bootstrap #617 ROC area: 0.733
# Bootstrap #618 ROC area: 0.716
# Bootstrap #619 ROC area: 0.740
# Bootstrap #620 ROC area: 0.765
# Bootstrap #621 ROC area: 0.871
# Bootstrap #622 ROC area: 0.828
# Bootstrap #623 ROC area: 0.823
# Bootstrap #624 ROC area: 0.823
# Bootstrap #625 ROC area: 0.796
# Bootstrap #626 ROC area: 0.788
# Bootstrap #627 ROC area: 0.807
# Bootstrap #628 ROC area: 0.701
# Bootstrap #629 ROC area: 0.802
# Bootstrap #630 ROC area: 0.752
# Bootstrap #631 ROC area: 0.797
# Bootstrap #632 ROC area: 0.738
# Bootstrap #633 ROC area: 0.813
# Bootstrap #634 ROC area: 0.788
# Bootstrap #635 ROC area: 0.788
# Bootstrap #636 ROC area: 0.794
# Bootstrap #637 ROC area: 0.808
# Bootstrap #638 ROC area: 0.808
# Bootstrap #639 ROC area: 0.789
# Bootstrap #640 ROC area: 0.793
# Bootstrap #641 ROC area: 0.797
# Bootstrap #642 ROC area: 0.772
# Bootstrap #643 ROC area: 0.805
# Bootstrap #644 ROC area: 0.807
# Bootstrap #645 ROC area: 0.852
# Bootstrap #646 ROC area: 0.751
# Bootstrap #647 ROC area: 0.816
# Bootstrap #648 ROC area: 0.768
# Bootstrap #649 ROC area: 0.854
# Bootstrap #650 ROC area: 0.827
# Bootstrap #651 ROC area: 0.866
# Bootstrap #652 ROC area: 0.779
# Bootstrap #653 ROC area: 0.846
# Bootstrap #654 ROC area: 0.800
# Bootstrap #655 ROC area: 0.805
# Bootstrap #656 ROC area: 0.790
# Bootstrap #657 ROC area: 0.742
# Bootstrap #658 ROC area: 0.762
# Bootstrap #659 ROC area: 0.777
# Bootstrap #660 ROC area: 0.853
# Bootstrap #661 ROC area: 0.806
# Bootstrap #662 ROC area: 0.822
# Bootstrap #663 ROC area: 0.754
# Bootstrap #664 ROC area: 0.822
# Bootstrap #665 ROC area: 0.846
# Bootstrap #666 ROC area: 0.807
# Bootstrap #667 ROC area: 0.794
# Bootstrap #668 ROC area: 0.745
# Bootstrap #669 ROC area: 0.863
# Bootstrap #670 ROC area: 0.738
# Bootstrap #671 ROC area: 0.781
# Bootstrap #672 ROC area: 0.831
# Bootstrap #673 ROC area: 0.776
# Bootstrap #674 ROC area: 0.799
# Bootstrap #675 ROC area: 0.821
# Bootstrap #676 ROC area: 0.751
# Bootstrap #677 ROC area: 0.797
# Bootstrap #678 ROC area: 0.779
# Bootstrap #679 ROC area: 0.802
# Bootstrap #680 ROC area: 0.724
# Bootstrap #681 ROC area: 0.824
# Bootstrap #682 ROC area: 0.803
# Bootstrap #683 ROC area: 0.814
# Bootstrap #684 ROC area: 0.768
# Bootstrap #685 ROC area: 0.787
# Bootstrap #686 ROC area: 0.784
# Bootstrap #687 ROC area: 0.818
# Bootstrap #688 ROC area: 0.800
# Bootstrap #689 ROC area: 0.778
# Bootstrap #690 ROC area: 0.862
# Bootstrap #691 ROC area: 0.799
# Bootstrap #692 ROC area: 0.838
# Bootstrap #693 ROC area: 0.778
# Bootstrap #694 ROC area: 0.781
# Bootstrap #695 ROC area: 0.757
# Bootstrap #696 ROC area: 0.818
# Bootstrap #697 ROC area: 0.818
# Bootstrap #698 ROC area: 0.802
# Bootstrap #699 ROC area: 0.812
# Bootstrap #700 ROC area: 0.815
# Bootstrap #701 ROC area: 0.823
# Bootstrap #702 ROC area: 0.772
# Bootstrap #703 ROC area: 0.834
# Bootstrap #704 ROC area: 0.772
# Bootstrap #705 ROC area: 0.837
# Bootstrap #706 ROC area: 0.819
# Bootstrap #707 ROC area: 0.783
# Bootstrap #708 ROC area: 0.800
# Bootstrap #709 ROC area: 0.858
# Bootstrap #710 ROC area: 0.680
# Bootstrap #711 ROC area: 0.782
# Bootstrap #712 ROC area: 0.764
# Bootstrap #713 ROC area: 0.779
# Bootstrap #714 ROC area: 0.798
# Bootstrap #715 ROC area: 0.790
# Bootstrap #716 ROC area: 0.794
# Bootstrap #717 ROC area: 0.747
# Bootstrap #718 ROC area: 0.797
# Bootstrap #719 ROC area: 0.762
# Bootstrap #720 ROC area: 0.781
# Bootstrap #721 ROC area: 0.830
# Bootstrap #722 ROC area: 0.784
# Bootstrap #723 ROC area: 0.763
# Bootstrap #724 ROC area: 0.789
# Bootstrap #725 ROC area: 0.809
# Bootstrap #726 ROC area: 0.742
# Bootstrap #727 ROC area: 0.851
# Bootstrap #728 ROC area: 0.760
# Bootstrap #729 ROC area: 0.817
# Bootstrap #730 ROC area: 0.788
# Bootstrap #731 ROC area: 0.773
# Bootstrap #732 ROC area: 0.801
# Bootstrap #733 ROC area: 0.788
# Bootstrap #734 ROC area: 0.779
# Bootstrap #735 ROC area: 0.785
# Bootstrap #736 ROC area: 0.791
# Bootstrap #737 ROC area: 0.789
# Bootstrap #738 ROC area: 0.809
# Bootstrap #739 ROC area: 0.839
# Bootstrap #740 ROC area: 0.802
# Bootstrap #741 ROC area: 0.793
# Bootstrap #742 ROC area: 0.783
# Bootstrap #743 ROC area: 0.792
# Bootstrap #744 ROC area: 0.811
# Bootstrap #745 ROC area: 0.833
# Bootstrap #746 ROC area: 0.800
# Bootstrap #747 ROC area: 0.844
# Bootstrap #748 ROC area: 0.748
# Bootstrap #749 ROC area: 0.772
# Bootstrap #750 ROC area: 0.738
# Bootstrap #751 ROC area: 0.770
# Bootstrap #752 ROC area: 0.748
# Bootstrap #753 ROC area: 0.776
# Bootstrap #754 ROC area: 0.745
# Bootstrap #755 ROC area: 0.810
# Bootstrap #756 ROC area: 0.786
# Bootstrap #757 ROC area: 0.754
# Bootstrap #758 ROC area: 0.824
# Bootstrap #759 ROC area: 0.804
# Bootstrap #760 ROC area: 0.776
# Bootstrap #761 ROC area: 0.726
# Bootstrap #762 ROC area: 0.763
# Bootstrap #763 ROC area: 0.821
# Bootstrap #764 ROC area: 0.813
# Bootstrap #765 ROC area: 0.764
# Bootstrap #766 ROC area: 0.782
# Bootstrap #767 ROC area: 0.792
# Bootstrap #768 ROC area: 0.805
# Bootstrap #769 ROC area: 0.726
# Bootstrap #770 ROC area: 0.742
# Bootstrap #771 ROC area: 0.814
# Bootstrap #772 ROC area: 0.784
# Bootstrap #773 ROC area: 0.804
# Bootstrap #774 ROC area: 0.794
# Bootstrap #775 ROC area: 0.807
# Bootstrap #776 ROC area: 0.798
# Bootstrap #777 ROC area: 0.829
# Bootstrap #778 ROC area: 0.790
# Bootstrap #779 ROC area: 0.818
# Bootstrap #780 ROC area: 0.762
# Bootstrap #781 ROC area: 0.819
# Bootstrap #782 ROC area: 0.825
# Bootstrap #783 ROC area: 0.777
# Bootstrap #784 ROC area: 0.824
# Bootstrap #785 ROC area: 0.792
# Bootstrap #786 ROC area: 0.793
# Bootstrap #787 ROC area: 0.826
# Bootstrap #788 ROC area: 0.776
# Bootstrap #789 ROC area: 0.813
# Bootstrap #790 ROC area: 0.797
# Bootstrap #791 ROC area: 0.850
# Bootstrap #792 ROC area: 0.802
# Bootstrap #793 ROC area: 0.784
# Bootstrap #794 ROC area: 0.779
# Bootstrap #795 ROC area: 0.818
# Bootstrap #796 ROC area: 0.823
# Bootstrap #797 ROC area: 0.809
# Bootstrap #798 ROC area: 0.722
# Bootstrap #799 ROC area: 0.799
# Bootstrap #800 ROC area: 0.799
# Bootstrap #801 ROC area: 0.798
# Bootstrap #802 ROC area: 0.826
# Bootstrap #803 ROC area: 0.873
# Bootstrap #804 ROC area: 0.757
# Bootstrap #805 ROC area: 0.797
# Bootstrap #806 ROC area: 0.786
# Bootstrap #807 ROC area: 0.788
# Bootstrap #808 ROC area: 0.780
# Bootstrap #809 ROC area: 0.737
# Bootstrap #810 ROC area: 0.765
# Bootstrap #811 ROC area: 0.779
# Bootstrap #812 ROC area: 0.828
# Bootstrap #813 ROC area: 0.804
# Bootstrap #814 ROC area: 0.719
# Bootstrap #815 ROC area: 0.773
# Bootstrap #816 ROC area: 0.864
# Bootstrap #817 ROC area: 0.705
# Bootstrap #818 ROC area: 0.759
# Bootstrap #819 ROC area: 0.812
# Bootstrap #820 ROC area: 0.799
# Bootstrap #821 ROC area: 0.802
# Bootstrap #822 ROC area: 0.820
# Bootstrap #823 ROC area: 0.820
# Bootstrap #824 ROC area: 0.780
# Bootstrap #825 ROC area: 0.810
# Bootstrap #826 ROC area: 0.815
# Bootstrap #827 ROC area: 0.855
# Bootstrap #828 ROC area: 0.799
# Bootstrap #829 ROC area: 0.847
# Bootstrap #830 ROC area: 0.801
# Bootstrap #831 ROC area: 0.718
# Bootstrap #832 ROC area: 0.723
# Bootstrap #833 ROC area: 0.793
# Bootstrap #834 ROC area: 0.691
# Bootstrap #835 ROC area: 0.739
# Bootstrap #836 ROC area: 0.778
# Bootstrap #837 ROC area: 0.820
# Bootstrap #838 ROC area: 0.749
# Bootstrap #839 ROC area: 0.718
# Bootstrap #840 ROC area: 0.739
# Bootstrap #841 ROC area: 0.837
# Bootstrap #842 ROC area: 0.758
# Bootstrap #843 ROC area: 0.804
# Bootstrap #844 ROC area: 0.743
# Bootstrap #845 ROC area: 0.864
# Bootstrap #846 ROC area: 0.801
# Bootstrap #847 ROC area: 0.731
# Bootstrap #848 ROC area: 0.784
# Bootstrap #849 ROC area: 0.823
# Bootstrap #850 ROC area: 0.790
# Bootstrap #851 ROC area: 0.841
# Bootstrap #852 ROC area: 0.844
# Bootstrap #853 ROC area: 0.804
# Bootstrap #854 ROC area: 0.836
# Bootstrap #855 ROC area: 0.808
# Bootstrap #856 ROC area: 0.809
# Bootstrap #857 ROC area: 0.756
# Bootstrap #858 ROC area: 0.780
# Bootstrap #859 ROC area: 0.755
# Bootstrap #860 ROC area: 0.777
# Bootstrap #861 ROC area: 0.798
# Bootstrap #862 ROC area: 0.786
# Bootstrap #863 ROC area: 0.797
# Bootstrap #864 ROC area: 0.766
# Bootstrap #865 ROC area: 0.769
# Bootstrap #866 ROC area: 0.785
# Bootstrap #867 ROC area: 0.799
# Bootstrap #868 ROC area: 0.800
# Bootstrap #869 ROC area: 0.775
# Bootstrap #870 ROC area: 0.785
# Bootstrap #871 ROC area: 0.746
# Bootstrap #872 ROC area: 0.741
# Bootstrap #873 ROC area: 0.752
# Bootstrap #874 ROC area: 0.839
# Bootstrap #875 ROC area: 0.765
# Bootstrap #876 ROC area: 0.811
# Bootstrap #877 ROC area: 0.803
# Bootstrap #878 ROC area: 0.812
# Bootstrap #879 ROC area: 0.785
# Bootstrap #880 ROC area: 0.768
# Bootstrap #881 ROC area: 0.783
# Bootstrap #882 ROC area: 0.816
# Bootstrap #883 ROC area: 0.777
# Bootstrap #884 ROC area: 0.857
# Bootstrap #885 ROC area: 0.786
# Bootstrap #886 ROC area: 0.755
# Bootstrap #887 ROC area: 0.825
# Bootstrap #888 ROC area: 0.787
# Bootstrap #889 ROC area: 0.820
# Bootstrap #890 ROC area: 0.774
# Bootstrap #891 ROC area: 0.818
# Bootstrap #892 ROC area: 0.780
# Bootstrap #893 ROC area: 0.792
# Bootstrap #894 ROC area: 0.808
# Bootstrap #895 ROC area: 0.742
# Bootstrap #896 ROC area: 0.803
# Bootstrap #897 ROC area: 0.831
# Bootstrap #898 ROC area: 0.811
# Bootstrap #899 ROC area: 0.799
# Bootstrap #900 ROC area: 0.812
# Bootstrap #901 ROC area: 0.854
# Bootstrap #902 ROC area: 0.820
# Bootstrap #903 ROC area: 0.819
# Bootstrap #904 ROC area: 0.823
# Bootstrap #905 ROC area: 0.809
# Bootstrap #906 ROC area: 0.786
# Bootstrap #907 ROC area: 0.815
# Bootstrap #908 ROC area: 0.779
# Bootstrap #909 ROC area: 0.813
# Bootstrap #910 ROC area: 0.882
# Bootstrap #911 ROC area: 0.731
# Bootstrap #912 ROC area: 0.794
# Bootstrap #913 ROC area: 0.849
# Bootstrap #914 ROC area: 0.815
# Bootstrap #915 ROC area: 0.789
# Bootstrap #916 ROC area: 0.789
# Bootstrap #917 ROC area: 0.768
# Bootstrap #918 ROC area: 0.742
# Bootstrap #919 ROC area: 0.880
# Bootstrap #920 ROC area: 0.782
# Bootstrap #921 ROC area: 0.776
# Bootstrap #922 ROC area: 0.859
# Bootstrap #923 ROC area: 0.855
# Bootstrap #924 ROC area: 0.828
# Bootstrap #925 ROC area: 0.815
# Bootstrap #926 ROC area: 0.828
# Bootstrap #927 ROC area: 0.845
# Bootstrap #928 ROC area: 0.805
# Bootstrap #929 ROC area: 0.833
# Bootstrap #930 ROC area: 0.804
# Bootstrap #931 ROC area: 0.825
# Bootstrap #932 ROC area: 0.771
# Bootstrap #933 ROC area: 0.805
# Bootstrap #934 ROC area: 0.792
# Bootstrap #935 ROC area: 0.850
# Bootstrap #936 ROC area: 0.798
# Bootstrap #937 ROC area: 0.758
# Bootstrap #938 ROC area: 0.857
# Bootstrap #939 ROC area: 0.773
# Bootstrap #940 ROC area: 0.829
# Bootstrap #941 ROC area: 0.804
# Bootstrap #942 ROC area: 0.719
# Bootstrap #943 ROC area: 0.824
# Bootstrap #944 ROC area: 0.760
# Bootstrap #945 ROC area: 0.818
# Bootstrap #946 ROC area: 0.822
# Bootstrap #947 ROC area: 0.705
# Bootstrap #948 ROC area: 0.797
# Bootstrap #949 ROC area: 0.809
# Bootstrap #950 ROC area: 0.768
# Bootstrap #951 ROC area: 0.853
# Bootstrap #952 ROC area: 0.878
# Bootstrap #953 ROC area: 0.819
# Bootstrap #954 ROC area: 0.813
# Bootstrap #955 ROC area: 0.764
# Bootstrap #956 ROC area: 0.835
# Bootstrap #957 ROC area: 0.840
# Bootstrap #958 ROC area: 0.834
# Bootstrap #959 ROC area: 0.786
# Bootstrap #960 ROC area: 0.764
# Bootstrap #961 ROC area: 0.844
# Bootstrap #962 ROC area: 0.841
# Bootstrap #963 ROC area: 0.765
# Bootstrap #964 ROC area: 0.805
# Bootstrap #965 ROC area: 0.808
# Bootstrap #966 ROC area: 0.768
# Bootstrap #967 ROC area: 0.774
# Bootstrap #968 ROC area: 0.800
# Bootstrap #969 ROC area: 0.805
# Bootstrap #970 ROC area: 0.797
# Bootstrap #971 ROC area: 0.805
# Bootstrap #972 ROC area: 0.749
# Bootstrap #973 ROC area: 0.789
# Bootstrap #974 ROC area: 0.755
# Bootstrap #975 ROC area: 0.826
# Bootstrap #976 ROC area: 0.821
# Bootstrap #977 ROC area: 0.758
# Bootstrap #978 ROC area: 0.741
# Bootstrap #979 ROC area: 0.792
# Bootstrap #980 ROC area: 0.839
# Bootstrap #981 ROC area: 0.740
# Bootstrap #982 ROC area: 0.828
# Bootstrap #983 ROC area: 0.841
# Bootstrap #984 ROC area: 0.818
# Bootstrap #985 ROC area: 0.760
# Bootstrap #986 ROC area: 0.773
# Bootstrap #987 ROC area: 0.732
# Bootstrap #988 ROC area: 0.783
# Bootstrap #989 ROC area: 0.810
# Bootstrap #990 ROC area: 0.826
# Bootstrap #991 ROC area: 0.781
# Bootstrap #992 ROC area: 0.799
# Bootstrap #993 ROC area: 0.837
# Bootstrap #994 ROC area: 0.773
# Bootstrap #995 ROC area: 0.789
# Bootstrap #996 ROC area: 0.814
# Bootstrap #997 ROC area: 0.738
# Bootstrap #998 ROC area: 0.791
# Bootstrap #999 ROC area: 0.816
# Bootstrap #1000 ROC area: 0.778

# %%
sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score on Asian patients: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Confidence interval for the score on Asian patients: [0.722 - 0.864]

# %% [markdown]
# ## Calculating overall AUROC w/ 95% Confidence Intervals for Logistic Regression Model

# %%
xTrainLog = xTrain['sofa_24hours'].to_numpy().reshape(-1,1)
xTestLog = xTest['sofa_24hours'].to_numpy().reshape(-1,1)

# %%
model=LogisticRegression()
model.fit(xTrainLog, yTrain)
y_pred = model.predict_proba(xTestLog)

# %%
print("Original ROC area: {:0.3f}".format(roc_auc_score(yTest, y_pred[:,1])))
# Out:
# Original ROC area: 0.733

# %%
n_bootstraps = 1000
rng_seed = 42  # control reproducibility
bootstrapped_scores = []

rng = np.random.RandomState(rng_seed)
for i in range(n_bootstraps):
    # bootstrap by sampling with replacement on the prediction indices
    indices = rng.randint(0, len(y_pred), len(y_pred))
    if len(np.unique(yTest[indices])) < 2:
        # We need at least one positive and one negative sample for ROC AUC
        # to be defined: reject the sample
        continue

    score = roc_auc_score(yTest[indices], y_pred[indices, 1])
    bootstrapped_scores.append(score)
    print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))
# Out:
# Bootstrap #1 ROC area: 0.720
# Bootstrap #2 ROC area: 0.726
# Bootstrap #3 ROC area: 0.743
# Bootstrap #4 ROC area: 0.751
# Bootstrap #5 ROC area: 0.742
# Bootstrap #6 ROC area: 0.742
# Bootstrap #7 ROC area: 0.732
# Bootstrap #8 ROC area: 0.743
# Bootstrap #9 ROC area: 0.728
# Bootstrap #10 ROC area: 0.740
# Bootstrap #11 ROC area: 0.725
# Bootstrap #12 ROC area: 0.730
# Bootstrap #13 ROC area: 0.731
# Bootstrap #14 ROC area: 0.731
# Bootstrap #15 ROC area: 0.738
# Bootstrap #16 ROC area: 0.740
# Bootstrap #17 ROC area: 0.745
# Bootstrap #18 ROC area: 0.727
# Bootstrap #19 ROC area: 0.720
# Bootstrap #20 ROC area: 0.714
# Bootstrap #21 ROC area: 0.725
# Bootstrap #22 ROC area: 0.755
# Bootstrap #23 ROC area: 0.742
# Bootstrap #24 ROC area: 0.731
# Bootstrap #25 ROC area: 0.731
# Bootstrap #26 ROC area: 0.722
# Bootstrap #27 ROC area: 0.739
# Bootstrap #28 ROC area: 0.732
# Bootstrap #29 ROC area: 0.732
# Bootstrap #30 ROC area: 0.736
# Bootstrap #31 ROC area: 0.734
# Bootstrap #32 ROC area: 0.736
# Bootstrap #33 ROC area: 0.731
# Bootstrap #34 ROC area: 0.729
# Bootstrap #35 ROC area: 0.728
# Bootstrap #36 ROC area: 0.731
# Bootstrap #37 ROC area: 0.732
# Bootstrap #38 ROC area: 0.737
# Bootstrap #39 ROC area: 0.725
# Bootstrap #40 ROC area: 0.738
# Bootstrap #41 ROC area: 0.735
# Bootstrap #42 ROC area: 0.738
# Bootstrap #43 ROC area: 0.730
# Bootstrap #44 ROC area: 0.755
# Bootstrap #45 ROC area: 0.725
# Bootstrap #46 ROC area: 0.695
# Bootstrap #47 ROC area: 0.759
# Bootstrap #48 ROC area: 0.732
# Bootstrap #49 ROC area: 0.734
# Bootstrap #50 ROC area: 0.724
# Bootstrap #51 ROC area: 0.728
# Bootstrap #52 ROC area: 0.734
# Bootstrap #53 ROC area: 0.729
# Bootstrap #54 ROC area: 0.716
# Bootstrap #55 ROC area: 0.732
# Bootstrap #56 ROC area: 0.732
# Bootstrap #57 ROC area: 0.734
# Bootstrap #58 ROC area: 0.721
# Bootstrap #59 ROC area: 0.750
# Bootstrap #60 ROC area: 0.745
# Bootstrap #61 ROC area: 0.746
# Bootstrap #62 ROC area: 0.746
# Bootstrap #63 ROC area: 0.739
# Bootstrap #64 ROC area: 0.726
# Bootstrap #65 ROC area: 0.725
# Bootstrap #66 ROC area: 0.749
# Bootstrap #67 ROC area: 0.734
# Bootstrap #68 ROC area: 0.743
# Bootstrap #69 ROC area: 0.731
# Bootstrap #70 ROC area: 0.728
# Bootstrap #71 ROC area: 0.730
# Bootstrap #72 ROC area: 0.737
# Bootstrap #73 ROC area: 0.730
# Bootstrap #74 ROC area: 0.751
# Bootstrap #75 ROC area: 0.731
# Bootstrap #76 ROC area: 0.731
# Bootstrap #77 ROC area: 0.720
# Bootstrap #78 ROC area: 0.733
# Bootstrap #79 ROC area: 0.744
# Bootstrap #80 ROC area: 0.734
# Bootstrap #81 ROC area: 0.733
# Bootstrap #82 ROC area: 0.738
# Bootstrap #83 ROC area: 0.722
# Bootstrap #84 ROC area: 0.731
# Bootstrap #85 ROC area: 0.740
# Bootstrap #86 ROC area: 0.741
# Bootstrap #87 ROC area: 0.732
# Bootstrap #88 ROC area: 0.733
# Bootstrap #89 ROC area: 0.738
# Bootstrap #90 ROC area: 0.728
# Bootstrap #91 ROC area: 0.731
# Bootstrap #92 ROC area: 0.737
# Bootstrap #93 ROC area: 0.731
# Bootstrap #94 ROC area: 0.723
# Bootstrap #95 ROC area: 0.741
# Bootstrap #96 ROC area: 0.743
# Bootstrap #97 ROC area: 0.740
# Bootstrap #98 ROC area: 0.739
# Bootstrap #99 ROC area: 0.723
# Bootstrap #100 ROC area: 0.726
# Bootstrap #101 ROC area: 0.725
# Bootstrap #102 ROC area: 0.724
# Bootstrap #103 ROC area: 0.726
# Bootstrap #104 ROC area: 0.754
# Bootstrap #105 ROC area: 0.734
# Bootstrap #106 ROC area: 0.734
# Bootstrap #107 ROC area: 0.736
# Bootstrap #108 ROC area: 0.730
# Bootstrap #109 ROC area: 0.734
# Bootstrap #110 ROC area: 0.728
# Bootstrap #111 ROC area: 0.743
# Bootstrap #112 ROC area: 0.747
# Bootstrap #113 ROC area: 0.728
# Bootstrap #114 ROC area: 0.736
# Bootstrap #115 ROC area: 0.741
# Bootstrap #116 ROC area: 0.730
# Bootstrap #117 ROC area: 0.732
# Bootstrap #118 ROC area: 0.731
# Bootstrap #119 ROC area: 0.727
# Bootstrap #120 ROC area: 0.744
# Bootstrap #121 ROC area: 0.732
# Bootstrap #122 ROC area: 0.744
# Bootstrap #123 ROC area: 0.734
# Bootstrap #124 ROC area: 0.734
# Bootstrap #125 ROC area: 0.724
# Bootstrap #126 ROC area: 0.756
# Bootstrap #127 ROC area: 0.737
# Bootstrap #128 ROC area: 0.729
# Bootstrap #129 ROC area: 0.749
# Bootstrap #130 ROC area: 0.724
# Bootstrap #131 ROC area: 0.725
# Bootstrap #132 ROC area: 0.723
# Bootstrap #133 ROC area: 0.724
# Bootstrap #134 ROC area: 0.738
# Bootstrap #135 ROC area: 0.743
# Bootstrap #136 ROC area: 0.735
# Bootstrap #137 ROC area: 0.714
# Bootstrap #138 ROC area: 0.744
# Bootstrap #139 ROC area: 0.743
# Bootstrap #140 ROC area: 0.740
# Bootstrap #141 ROC area: 0.740
# Bootstrap #142 ROC area: 0.735
# Bootstrap #143 ROC area: 0.733
# Bootstrap #144 ROC area: 0.741
# Bootstrap #145 ROC area: 0.731
# Bootstrap #146 ROC area: 0.739
# Bootstrap #147 ROC area: 0.732
# Bootstrap #148 ROC area: 0.741
# Bootstrap #149 ROC area: 0.738
# Bootstrap #150 ROC area: 0.729
# Bootstrap #151 ROC area: 0.747
# Bootstrap #152 ROC area: 0.731
# Bootstrap #153 ROC area: 0.736
# Bootstrap #154 ROC area: 0.728
# Bootstrap #155 ROC area: 0.727
# Bootstrap #156 ROC area: 0.729
# Bootstrap #157 ROC area: 0.732
# Bootstrap #158 ROC area: 0.735
# Bootstrap #159 ROC area: 0.734
# Bootstrap #160 ROC area: 0.739
# Bootstrap #161 ROC area: 0.726
# Bootstrap #162 ROC area: 0.748
# Bootstrap #163 ROC area: 0.741
# Bootstrap #164 ROC area: 0.741
# Bootstrap #165 ROC area: 0.719
# Bootstrap #166 ROC area: 0.753
# Bootstrap #167 ROC area: 0.736
# Bootstrap #168 ROC area: 0.725
# Bootstrap #169 ROC area: 0.727
# Bootstrap #170 ROC area: 0.738
# Bootstrap #171 ROC area: 0.711
# Bootstrap #172 ROC area: 0.735
# Bootstrap #173 ROC area: 0.728
# Bootstrap #174 ROC area: 0.734
# Bootstrap #175 ROC area: 0.740
# Bootstrap #176 ROC area: 0.734
# Bootstrap #177 ROC area: 0.737
# Bootstrap #178 ROC area: 0.731
# Bootstrap #179 ROC area: 0.738
# Bootstrap #180 ROC area: 0.729
# Bootstrap #181 ROC area: 0.737
# Bootstrap #182 ROC area: 0.730
# Bootstrap #183 ROC area: 0.725
# Bootstrap #184 ROC area: 0.724
# Bootstrap #185 ROC area: 0.748
# Bootstrap #186 ROC area: 0.720
# Bootstrap #187 ROC area: 0.721
# Bootstrap #188 ROC area: 0.715
# Bootstrap #189 ROC area: 0.729
# Bootstrap #190 ROC area: 0.745
# Bootstrap #191 ROC area: 0.725
# Bootstrap #192 ROC area: 0.726
# Bootstrap #193 ROC area: 0.734
# Bootstrap #194 ROC area: 0.716
# Bootstrap #195 ROC area: 0.735
# Bootstrap #196 ROC area: 0.721
# Bootstrap #197 ROC area: 0.734
# Bootstrap #198 ROC area: 0.732
# Bootstrap #199 ROC area: 0.733
# Bootstrap #200 ROC area: 0.755
# Bootstrap #201 ROC area: 0.744
# Bootstrap #202 ROC area: 0.753
# Bootstrap #203 ROC area: 0.748
# Bootstrap #204 ROC area: 0.728
# Bootstrap #205 ROC area: 0.711
# Bootstrap #206 ROC area: 0.717
# Bootstrap #207 ROC area: 0.737
# Bootstrap #208 ROC area: 0.744
# Bootstrap #209 ROC area: 0.732
# Bootstrap #210 ROC area: 0.725
# Bootstrap #211 ROC area: 0.728
# Bootstrap #212 ROC area: 0.744
# Bootstrap #213 ROC area: 0.737
# Bootstrap #214 ROC area: 0.711
# Bootstrap #215 ROC area: 0.737
# Bootstrap #216 ROC area: 0.726
# Bootstrap #217 ROC area: 0.724
# Bootstrap #218 ROC area: 0.717
# Bootstrap #219 ROC area: 0.725
# Bootstrap #220 ROC area: 0.728
# Bootstrap #221 ROC area: 0.744
# Bootstrap #222 ROC area: 0.715
# Bootstrap #223 ROC area: 0.736
# Bootstrap #224 ROC area: 0.722
# Bootstrap #225 ROC area: 0.719
# Bootstrap #226 ROC area: 0.722
# Bootstrap #227 ROC area: 0.738
# Bootstrap #228 ROC area: 0.741
# Bootstrap #229 ROC area: 0.746
# Bootstrap #230 ROC area: 0.744
# Bootstrap #231 ROC area: 0.747
# Bootstrap #232 ROC area: 0.732
# Bootstrap #233 ROC area: 0.738
# Bootstrap #234 ROC area: 0.722
# Bootstrap #235 ROC area: 0.733
# Bootstrap #236 ROC area: 0.734
# Bootstrap #237 ROC area: 0.740
# Bootstrap #238 ROC area: 0.714
# Bootstrap #239 ROC area: 0.745
# Bootstrap #240 ROC area: 0.736
# Bootstrap #241 ROC area: 0.724
# Bootstrap #242 ROC area: 0.738
# Bootstrap #243 ROC area: 0.732
# Bootstrap #244 ROC area: 0.729
# Bootstrap #245 ROC area: 0.729
# Bootstrap #246 ROC area: 0.721
# Bootstrap #247 ROC area: 0.723
# Bootstrap #248 ROC area: 0.723
# Bootstrap #249 ROC area: 0.746
# Bootstrap #250 ROC area: 0.710
# Bootstrap #251 ROC area: 0.735
# Bootstrap #252 ROC area: 0.753
# Bootstrap #253 ROC area: 0.749
# Bootstrap #254 ROC area: 0.740
# Bootstrap #255 ROC area: 0.727
# Bootstrap #256 ROC area: 0.731
# Bootstrap #257 ROC area: 0.736
# Bootstrap #258 ROC area: 0.735
# Bootstrap #259 ROC area: 0.727
# Bootstrap #260 ROC area: 0.722
# Bootstrap #261 ROC area: 0.734
# Bootstrap #262 ROC area: 0.722
# Bootstrap #263 ROC area: 0.737
# Bootstrap #264 ROC area: 0.723
# Bootstrap #265 ROC area: 0.747
# Bootstrap #266 ROC area: 0.740
# Bootstrap #267 ROC area: 0.725
# Bootstrap #268 ROC area: 0.728
# Bootstrap #269 ROC area: 0.714
# Bootstrap #270 ROC area: 0.720
# Bootstrap #271 ROC area: 0.732
# Bootstrap #272 ROC area: 0.730
# Bootstrap #273 ROC area: 0.727
# Bootstrap #274 ROC area: 0.734
# Bootstrap #275 ROC area: 0.723
# Bootstrap #276 ROC area: 0.729
# Bootstrap #277 ROC area: 0.720
# Bootstrap #278 ROC area: 0.737
# Bootstrap #279 ROC area: 0.727
# Bootstrap #280 ROC area: 0.733
# Bootstrap #281 ROC area: 0.724
# Bootstrap #282 ROC area: 0.732
# Bootstrap #283 ROC area: 0.736
# Bootstrap #284 ROC area: 0.732
# Bootstrap #285 ROC area: 0.725
# Bootstrap #286 ROC area: 0.733
# Bootstrap #287 ROC area: 0.726
# Bootstrap #288 ROC area: 0.748
# Bootstrap #289 ROC area: 0.750
# Bootstrap #290 ROC area: 0.718
# Bootstrap #291 ROC area: 0.731
# Bootstrap #292 ROC area: 0.726
# Bootstrap #293 ROC area: 0.740
# Bootstrap #294 ROC area: 0.728
# Bootstrap #295 ROC area: 0.726
# Bootstrap #296 ROC area: 0.716
# Bootstrap #297 ROC area: 0.719
# Bootstrap #298 ROC area: 0.716
# Bootstrap #299 ROC area: 0.729
# Bootstrap #300 ROC area: 0.730
# Bootstrap #301 ROC area: 0.733
# Bootstrap #302 ROC area: 0.750
# Bootstrap #303 ROC area: 0.710
# Bootstrap #304 ROC area: 0.735
# Bootstrap #305 ROC area: 0.713
# Bootstrap #306 ROC area: 0.734
# Bootstrap #307 ROC area: 0.730
# Bootstrap #308 ROC area: 0.739
# Bootstrap #309 ROC area: 0.729
# Bootstrap #310 ROC area: 0.704
# Bootstrap #311 ROC area: 0.722
# Bootstrap #312 ROC area: 0.727
# Bootstrap #313 ROC area: 0.737
# Bootstrap #314 ROC area: 0.745
# Bootstrap #315 ROC area: 0.726
# Bootstrap #316 ROC area: 0.747
# Bootstrap #317 ROC area: 0.739
# Bootstrap #318 ROC area: 0.736
# Bootstrap #319 ROC area: 0.731
# Bootstrap #320 ROC area: 0.740
# Bootstrap #321 ROC area: 0.736
# Bootstrap #322 ROC area: 0.738
# Bootstrap #323 ROC area: 0.730
# Bootstrap #324 ROC area: 0.732
# Bootstrap #325 ROC area: 0.726
# Bootstrap #326 ROC area: 0.733
# Bootstrap #327 ROC area: 0.727
# Bootstrap #328 ROC area: 0.738
# Bootstrap #329 ROC area: 0.737
# Bootstrap #330 ROC area: 0.723
# Bootstrap #331 ROC area: 0.712
# Bootstrap #332 ROC area: 0.746
# Bootstrap #333 ROC area: 0.723
# Bootstrap #334 ROC area: 0.726
# Bootstrap #335 ROC area: 0.739
# Bootstrap #336 ROC area: 0.733
# Bootstrap #337 ROC area: 0.732
# Bootstrap #338 ROC area: 0.725
# Bootstrap #339 ROC area: 0.721
# Bootstrap #340 ROC area: 0.726
# Bootstrap #341 ROC area: 0.734
# Bootstrap #342 ROC area: 0.730
# Bootstrap #343 ROC area: 0.735
# Bootstrap #344 ROC area: 0.748
# Bootstrap #345 ROC area: 0.727
# Bootstrap #346 ROC area: 0.727
# Bootstrap #347 ROC area: 0.728
# Bootstrap #348 ROC area: 0.721
# Bootstrap #349 ROC area: 0.737
# Bootstrap #350 ROC area: 0.752
# Bootstrap #351 ROC area: 0.738
# Bootstrap #352 ROC area: 0.723
# Bootstrap #353 ROC area: 0.739
# Bootstrap #354 ROC area: 0.726
# Bootstrap #355 ROC area: 0.740
# Bootstrap #356 ROC area: 0.743
# Bootstrap #357 ROC area: 0.717
# Bootstrap #358 ROC area: 0.708
# Bootstrap #359 ROC area: 0.746
# Bootstrap #360 ROC area: 0.737
# Bootstrap #361 ROC area: 0.742
# Bootstrap #362 ROC area: 0.719
# Bootstrap #363 ROC area: 0.733
# Bootstrap #364 ROC area: 0.729
# Bootstrap #365 ROC area: 0.736
# Bootstrap #366 ROC area: 0.735
# Bootstrap #367 ROC area: 0.704
# Bootstrap #368 ROC area: 0.731
# Bootstrap #369 ROC area: 0.724
# Bootstrap #370 ROC area: 0.752
# Bootstrap #371 ROC area: 0.745
# Bootstrap #372 ROC area: 0.745
# Bootstrap #373 ROC area: 0.725
# Bootstrap #374 ROC area: 0.749
# Bootstrap #375 ROC area: 0.734
# Bootstrap #376 ROC area: 0.730
# Bootstrap #377 ROC area: 0.733
# Bootstrap #378 ROC area: 0.742
# Bootstrap #379 ROC area: 0.736
# Bootstrap #380 ROC area: 0.733
# Bootstrap #381 ROC area: 0.727
# Bootstrap #382 ROC area: 0.738
# Bootstrap #383 ROC area: 0.746
# Bootstrap #384 ROC area: 0.739
# Bootstrap #385 ROC area: 0.723
# Bootstrap #386 ROC area: 0.751
# Bootstrap #387 ROC area: 0.735
# Bootstrap #388 ROC area: 0.738
# Bootstrap #389 ROC area: 0.712
# Bootstrap #390 ROC area: 0.742
# Bootstrap #391 ROC area: 0.727
# Bootstrap #392 ROC area: 0.745
# Bootstrap #393 ROC area: 0.740
# Bootstrap #394 ROC area: 0.739
# Bootstrap #395 ROC area: 0.723
# Bootstrap #396 ROC area: 0.743
# Bootstrap #397 ROC area: 0.730
# Bootstrap #398 ROC area: 0.726
# Bootstrap #399 ROC area: 0.755
# Bootstrap #400 ROC area: 0.741
# Bootstrap #401 ROC area: 0.726
# Bootstrap #402 ROC area: 0.729
# Bootstrap #403 ROC area: 0.719
# Bootstrap #404 ROC area: 0.744
# Bootstrap #405 ROC area: 0.736
# Bootstrap #406 ROC area: 0.746
# Bootstrap #407 ROC area: 0.743
# Bootstrap #408 ROC area: 0.723
# Bootstrap #409 ROC area: 0.731
# Bootstrap #410 ROC area: 0.740
# Bootstrap #411 ROC area: 0.741
# Bootstrap #412 ROC area: 0.733
# Bootstrap #413 ROC area: 0.721
# Bootstrap #414 ROC area: 0.728
# Bootstrap #415 ROC area: 0.730
# Bootstrap #416 ROC area: 0.751
# Bootstrap #417 ROC area: 0.738
# Bootstrap #418 ROC area: 0.727
# Bootstrap #419 ROC area: 0.732
# Bootstrap #420 ROC area: 0.721
# Bootstrap #421 ROC area: 0.737
# Bootstrap #422 ROC area: 0.733
# Bootstrap #423 ROC area: 0.746
# Bootstrap #424 ROC area: 0.742
# Bootstrap #425 ROC area: 0.734
# Bootstrap #426 ROC area: 0.732
# Bootstrap #427 ROC area: 0.750
# Bootstrap #428 ROC area: 0.730
# Bootstrap #429 ROC area: 0.734
# Bootstrap #430 ROC area: 0.711
# Bootstrap #431 ROC area: 0.720
# Bootstrap #432 ROC area: 0.743
# Bootstrap #433 ROC area: 0.725
# Bootstrap #434 ROC area: 0.742
# Bootstrap #435 ROC area: 0.735
# Bootstrap #436 ROC area: 0.728
# Bootstrap #437 ROC area: 0.724
# Bootstrap #438 ROC area: 0.739
# Bootstrap #439 ROC area: 0.732
# Bootstrap #440 ROC area: 0.730
# Bootstrap #441 ROC area: 0.728
# Bootstrap #442 ROC area: 0.726
# Bootstrap #443 ROC area: 0.730
# Bootstrap #444 ROC area: 0.728
# Bootstrap #445 ROC area: 0.734
# Bootstrap #446 ROC area: 0.744
# Bootstrap #447 ROC area: 0.743
# Bootstrap #448 ROC area: 0.723
# Bootstrap #449 ROC area: 0.742
# Bootstrap #450 ROC area: 0.721
# Bootstrap #451 ROC area: 0.726
# Bootstrap #452 ROC area: 0.729
# Bootstrap #453 ROC area: 0.732
# Bootstrap #454 ROC area: 0.723
# Bootstrap #455 ROC area: 0.731
# Bootstrap #456 ROC area: 0.740
# Bootstrap #457 ROC area: 0.735
# Bootstrap #458 ROC area: 0.730
# Bootstrap #459 ROC area: 0.722
# Bootstrap #460 ROC area: 0.725
# Bootstrap #461 ROC area: 0.734
# Bootstrap #462 ROC area: 0.749
# Bootstrap #463 ROC area: 0.734
# Bootstrap #464 ROC area: 0.736
# Bootstrap #465 ROC area: 0.728
# Bootstrap #466 ROC area: 0.734
# Bootstrap #467 ROC area: 0.751
# Bootstrap #468 ROC area: 0.724
# Bootstrap #469 ROC area: 0.727
# Bootstrap #470 ROC area: 0.737
# Bootstrap #471 ROC area: 0.728
# Bootstrap #472 ROC area: 0.739
# Bootstrap #473 ROC area: 0.726
# Bootstrap #474 ROC area: 0.707
# Bootstrap #475 ROC area: 0.733
# Bootstrap #476 ROC area: 0.731
# Bootstrap #477 ROC area: 0.736
# Bootstrap #478 ROC area: 0.752
# Bootstrap #479 ROC area: 0.735
# Bootstrap #480 ROC area: 0.730
# Bootstrap #481 ROC area: 0.733
# Bootstrap #482 ROC area: 0.735
# Bootstrap #483 ROC area: 0.730
# Bootstrap #484 ROC area: 0.728
# Bootstrap #485 ROC area: 0.727
# Bootstrap #486 ROC area: 0.742
# Bootstrap #487 ROC area: 0.739
# Bootstrap #488 ROC area: 0.734
# Bootstrap #489 ROC area: 0.720
# Bootstrap #490 ROC area: 0.744
# Bootstrap #491 ROC area: 0.728
# Bootstrap #492 ROC area: 0.724
# Bootstrap #493 ROC area: 0.723
# Bootstrap #494 ROC area: 0.724
# Bootstrap #495 ROC area: 0.717
# Bootstrap #496 ROC area: 0.746
# Bootstrap #497 ROC area: 0.724
# Bootstrap #498 ROC area: 0.720
# Bootstrap #499 ROC area: 0.735
# Bootstrap #500 ROC area: 0.741
# Bootstrap #501 ROC area: 0.739
# Bootstrap #502 ROC area: 0.718
# Bootstrap #503 ROC area: 0.744
# Bootstrap #504 ROC area: 0.737
# Bootstrap #505 ROC area: 0.714
# Bootstrap #506 ROC area: 0.721
# Bootstrap #507 ROC area: 0.722
# Bootstrap #508 ROC area: 0.740
# Bootstrap #509 ROC area: 0.741
# Bootstrap #510 ROC area: 0.731
# Bootstrap #511 ROC area: 0.739
# Bootstrap #512 ROC area: 0.730
# Bootstrap #513 ROC area: 0.723
# Bootstrap #514 ROC area: 0.737
# Bootstrap #515 ROC area: 0.727
# Bootstrap #516 ROC area: 0.720
# Bootstrap #517 ROC area: 0.711
# Bootstrap #518 ROC area: 0.741
# Bootstrap #519 ROC area: 0.726
# Bootstrap #520 ROC area: 0.730
# Bootstrap #521 ROC area: 0.762
# Bootstrap #522 ROC area: 0.723
# Bootstrap #523 ROC area: 0.743
# Bootstrap #524 ROC area: 0.753
# Bootstrap #525 ROC area: 0.722
# Bootstrap #526 ROC area: 0.733
# Bootstrap #527 ROC area: 0.733
# Bootstrap #528 ROC area: 0.729
# Bootstrap #529 ROC area: 0.745
# Bootstrap #530 ROC area: 0.730
# Bootstrap #531 ROC area: 0.746
# Bootstrap #532 ROC area: 0.719
# Bootstrap #533 ROC area: 0.724
# Bootstrap #534 ROC area: 0.742
# Bootstrap #535 ROC area: 0.737
# Bootstrap #536 ROC area: 0.751
# Bootstrap #537 ROC area: 0.739
# Bootstrap #538 ROC area: 0.716
# Bootstrap #539 ROC area: 0.719
# Bootstrap #540 ROC area: 0.733
# Bootstrap #541 ROC area: 0.730
# Bootstrap #542 ROC area: 0.733
# Bootstrap #543 ROC area: 0.731
# Bootstrap #544 ROC area: 0.728
# Bootstrap #545 ROC area: 0.743
# Bootstrap #546 ROC area: 0.728
# Bootstrap #547 ROC area: 0.751
# Bootstrap #548 ROC area: 0.714
# Bootstrap #549 ROC area: 0.728
# Bootstrap #550 ROC area: 0.736
# Bootstrap #551 ROC area: 0.726
# Bootstrap #552 ROC area: 0.727
# Bootstrap #553 ROC area: 0.732
# Bootstrap #554 ROC area: 0.749
# Bootstrap #555 ROC area: 0.720
# Bootstrap #556 ROC area: 0.736
# Bootstrap #557 ROC area: 0.724
# Bootstrap #558 ROC area: 0.730
# Bootstrap #559 ROC area: 0.718
# Bootstrap #560 ROC area: 0.736
# Bootstrap #561 ROC area: 0.740
# Bootstrap #562 ROC area: 0.734
# Bootstrap #563 ROC area: 0.746
# Bootstrap #564 ROC area: 0.737
# Bootstrap #565 ROC area: 0.737
# Bootstrap #566 ROC area: 0.733
# Bootstrap #567 ROC area: 0.721
# Bootstrap #568 ROC area: 0.739
# Bootstrap #569 ROC area: 0.739
# Bootstrap #570 ROC area: 0.733
# Bootstrap #571 ROC area: 0.733
# Bootstrap #572 ROC area: 0.742
# Bootstrap #573 ROC area: 0.722
# Bootstrap #574 ROC area: 0.729
# Bootstrap #575 ROC area: 0.726
# Bootstrap #576 ROC area: 0.726
# Bootstrap #577 ROC area: 0.731
# Bootstrap #578 ROC area: 0.736
# Bootstrap #579 ROC area: 0.722
# Bootstrap #580 ROC area: 0.739
# Bootstrap #581 ROC area: 0.742
# Bootstrap #582 ROC area: 0.727
# Bootstrap #583 ROC area: 0.752
# Bootstrap #584 ROC area: 0.715
# Bootstrap #585 ROC area: 0.745
# Bootstrap #586 ROC area: 0.735
# Bootstrap #587 ROC area: 0.743
# Bootstrap #588 ROC area: 0.725
# Bootstrap #589 ROC area: 0.715
# Bootstrap #590 ROC area: 0.730
# Bootstrap #591 ROC area: 0.728
# Bootstrap #592 ROC area: 0.736
# Bootstrap #593 ROC area: 0.719
# Bootstrap #594 ROC area: 0.728
# Bootstrap #595 ROC area: 0.733
# Bootstrap #596 ROC area: 0.718
# Bootstrap #597 ROC area: 0.740
# Bootstrap #598 ROC area: 0.719
# Bootstrap #599 ROC area: 0.730
# Bootstrap #600 ROC area: 0.725
# Bootstrap #601 ROC area: 0.721
# Bootstrap #602 ROC area: 0.720
# Bootstrap #603 ROC area: 0.738
# Bootstrap #604 ROC area: 0.739
# Bootstrap #605 ROC area: 0.729
# Bootstrap #606 ROC area: 0.727
# Bootstrap #607 ROC area: 0.719
# Bootstrap #608 ROC area: 0.720
# Bootstrap #609 ROC area: 0.729
# Bootstrap #610 ROC area: 0.733
# Bootstrap #611 ROC area: 0.736
# Bootstrap #612 ROC area: 0.714
# Bootstrap #613 ROC area: 0.741
# Bootstrap #614 ROC area: 0.743
# Bootstrap #615 ROC area: 0.729
# Bootstrap #616 ROC area: 0.730
# Bootstrap #617 ROC area: 0.742
# Bootstrap #618 ROC area: 0.747
# Bootstrap #619 ROC area: 0.731
# Bootstrap #620 ROC area: 0.737
# Bootstrap #621 ROC area: 0.733
# Bootstrap #622 ROC area: 0.754
# Bootstrap #623 ROC area: 0.721
# Bootstrap #624 ROC area: 0.723
# Bootstrap #625 ROC area: 0.740
# Bootstrap #626 ROC area: 0.748
# Bootstrap #627 ROC area: 0.718
# Bootstrap #628 ROC area: 0.725
# Bootstrap #629 ROC area: 0.728
# Bootstrap #630 ROC area: 0.737
# Bootstrap #631 ROC area: 0.738
# Bootstrap #632 ROC area: 0.726
# Bootstrap #633 ROC area: 0.747
# Bootstrap #634 ROC area: 0.720
# Bootstrap #635 ROC area: 0.752
# Bootstrap #636 ROC area: 0.730
# Bootstrap #637 ROC area: 0.755
# Bootstrap #638 ROC area: 0.710
# Bootstrap #639 ROC area: 0.719
# Bootstrap #640 ROC area: 0.737
# Bootstrap #641 ROC area: 0.730
# Bootstrap #642 ROC area: 0.738
# Bootstrap #643 ROC area: 0.722
# Bootstrap #644 ROC area: 0.728
# Bootstrap #645 ROC area: 0.742
# Bootstrap #646 ROC area: 0.741
# Bootstrap #647 ROC area: 0.741
# Bootstrap #648 ROC area: 0.723
# Bootstrap #649 ROC area: 0.741
# Bootstrap #650 ROC area: 0.722
# Bootstrap #651 ROC area: 0.728
# Bootstrap #652 ROC area: 0.739
# Bootstrap #653 ROC area: 0.741
# Bootstrap #654 ROC area: 0.735
# Bootstrap #655 ROC area: 0.737
# Bootstrap #656 ROC area: 0.736
# Bootstrap #657 ROC area: 0.739
# Bootstrap #658 ROC area: 0.724
# Bootstrap #659 ROC area: 0.735
# Bootstrap #660 ROC area: 0.733
# Bootstrap #661 ROC area: 0.728
# Bootstrap #662 ROC area: 0.732
# Bootstrap #663 ROC area: 0.722
# Bootstrap #664 ROC area: 0.728
# Bootstrap #665 ROC area: 0.740
# Bootstrap #666 ROC area: 0.723
# Bootstrap #667 ROC area: 0.722
# Bootstrap #668 ROC area: 0.745
# Bootstrap #669 ROC area: 0.736
# Bootstrap #670 ROC area: 0.742
# Bootstrap #671 ROC area: 0.734
# Bootstrap #672 ROC area: 0.720
# Bootstrap #673 ROC area: 0.740
# Bootstrap #674 ROC area: 0.737
# Bootstrap #675 ROC area: 0.725
# Bootstrap #676 ROC area: 0.725
# Bootstrap #677 ROC area: 0.726
# Bootstrap #678 ROC area: 0.739
# Bootstrap #679 ROC area: 0.734
# Bootstrap #680 ROC area: 0.719
# Bootstrap #681 ROC area: 0.742
# Bootstrap #682 ROC area: 0.738
# Bootstrap #683 ROC area: 0.728
# Bootstrap #684 ROC area: 0.744
# Bootstrap #685 ROC area: 0.738
# Bootstrap #686 ROC area: 0.740
# Bootstrap #687 ROC area: 0.713
# Bootstrap #688 ROC area: 0.721
# Bootstrap #689 ROC area: 0.734
# Bootstrap #690 ROC area: 0.744
# Bootstrap #691 ROC area: 0.736
# Bootstrap #692 ROC area: 0.739
# Bootstrap #693 ROC area: 0.722
# Bootstrap #694 ROC area: 0.714
# Bootstrap #695 ROC area: 0.716
# Bootstrap #696 ROC area: 0.744
# Bootstrap #697 ROC area: 0.737
# Bootstrap #698 ROC area: 0.723
# Bootstrap #699 ROC area: 0.738
# Bootstrap #700 ROC area: 0.729
# Bootstrap #701 ROC area: 0.735
# Bootstrap #702 ROC area: 0.710
# Bootstrap #703 ROC area: 0.744
# Bootstrap #704 ROC area: 0.715
# Bootstrap #705 ROC area: 0.721
# Bootstrap #706 ROC area: 0.723
# Bootstrap #707 ROC area: 0.741
# Bootstrap #708 ROC area: 0.737
# Bootstrap #709 ROC area: 0.734
# Bootstrap #710 ROC area: 0.726
# Bootstrap #711 ROC area: 0.726
# Bootstrap #712 ROC area: 0.721
# Bootstrap #713 ROC area: 0.741
# Bootstrap #714 ROC area: 0.734
# Bootstrap #715 ROC area: 0.729
# Bootstrap #716 ROC area: 0.736
# Bootstrap #717 ROC area: 0.732
# Bootstrap #718 ROC area: 0.737
# Bootstrap #719 ROC area: 0.734
# Bootstrap #720 ROC area: 0.740
# Bootstrap #721 ROC area: 0.739
# Bootstrap #722 ROC area: 0.735
# Bootstrap #723 ROC area: 0.736
# Bootstrap #724 ROC area: 0.734
# Bootstrap #725 ROC area: 0.728
# Bootstrap #726 ROC area: 0.714
# Bootstrap #727 ROC area: 0.735
# Bootstrap #728 ROC area: 0.729
# Bootstrap #729 ROC area: 0.742
# Bootstrap #730 ROC area: 0.743
# Bootstrap #731 ROC area: 0.719
# Bootstrap #732 ROC area: 0.748
# Bootstrap #733 ROC area: 0.745
# Bootstrap #734 ROC area: 0.725
# Bootstrap #735 ROC area: 0.727
# Bootstrap #736 ROC area: 0.748
# Bootstrap #737 ROC area: 0.721
# Bootstrap #738 ROC area: 0.740
# Bootstrap #739 ROC area: 0.732
# Bootstrap #740 ROC area: 0.721
# Bootstrap #741 ROC area: 0.712
# Bootstrap #742 ROC area: 0.749
# Bootstrap #743 ROC area: 0.722
# Bootstrap #744 ROC area: 0.738
# Bootstrap #745 ROC area: 0.733
# Bootstrap #746 ROC area: 0.735
# Bootstrap #747 ROC area: 0.743
# Bootstrap #748 ROC area: 0.742
# Bootstrap #749 ROC area: 0.727
# Bootstrap #750 ROC area: 0.733
# Bootstrap #751 ROC area: 0.747
# Bootstrap #752 ROC area: 0.737
# Bootstrap #753 ROC area: 0.731
# Bootstrap #754 ROC area: 0.741
# Bootstrap #755 ROC area: 0.726
# Bootstrap #756 ROC area: 0.731
# Bootstrap #757 ROC area: 0.750
# Bootstrap #758 ROC area: 0.734
# Bootstrap #759 ROC area: 0.732
# Bootstrap #760 ROC area: 0.726
# Bootstrap #761 ROC area: 0.746
# Bootstrap #762 ROC area: 0.722
# Bootstrap #763 ROC area: 0.734
# Bootstrap #764 ROC area: 0.724
# Bootstrap #765 ROC area: 0.736
# Bootstrap #766 ROC area: 0.734
# Bootstrap #767 ROC area: 0.748
# Bootstrap #768 ROC area: 0.738
# Bootstrap #769 ROC area: 0.733
# Bootstrap #770 ROC area: 0.727
# Bootstrap #771 ROC area: 0.731
# Bootstrap #772 ROC area: 0.729
# Bootstrap #773 ROC area: 0.749
# Bootstrap #774 ROC area: 0.719
# Bootstrap #775 ROC area: 0.760
# Bootstrap #776 ROC area: 0.735
# Bootstrap #777 ROC area: 0.728
# Bootstrap #778 ROC area: 0.720
# Bootstrap #779 ROC area: 0.745
# Bootstrap #780 ROC area: 0.727
# Bootstrap #781 ROC area: 0.731
# Bootstrap #782 ROC area: 0.725
# Bootstrap #783 ROC area: 0.722
# Bootstrap #784 ROC area: 0.716
# Bootstrap #785 ROC area: 0.727
# Bootstrap #786 ROC area: 0.739
# Bootstrap #787 ROC area: 0.723
# Bootstrap #788 ROC area: 0.745
# Bootstrap #789 ROC area: 0.719
# Bootstrap #790 ROC area: 0.714
# Bootstrap #791 ROC area: 0.732
# Bootstrap #792 ROC area: 0.733
# Bootstrap #793 ROC area: 0.739
# Bootstrap #794 ROC area: 0.721
# Bootstrap #795 ROC area: 0.735
# Bootstrap #796 ROC area: 0.721
# Bootstrap #797 ROC area: 0.723
# Bootstrap #798 ROC area: 0.731
# Bootstrap #799 ROC area: 0.755
# Bootstrap #800 ROC area: 0.736
# Bootstrap #801 ROC area: 0.747
# Bootstrap #802 ROC area: 0.733
# Bootstrap #803 ROC area: 0.743
# Bootstrap #804 ROC area: 0.728
# Bootstrap #805 ROC area: 0.732
# Bootstrap #806 ROC area: 0.742
# Bootstrap #807 ROC area: 0.751
# Bootstrap #808 ROC area: 0.733
# Bootstrap #809 ROC area: 0.719
# Bootstrap #810 ROC area: 0.729
# Bootstrap #811 ROC area: 0.722
# Bootstrap #812 ROC area: 0.715
# Bootstrap #813 ROC area: 0.727
# Bootstrap #814 ROC area: 0.739
# Bootstrap #815 ROC area: 0.725
# Bootstrap #816 ROC area: 0.738
# Bootstrap #817 ROC area: 0.746
# Bootstrap #818 ROC area: 0.741
# Bootstrap #819 ROC area: 0.725
# Bootstrap #820 ROC area: 0.729
# Bootstrap #821 ROC area: 0.749
# Bootstrap #822 ROC area: 0.730
# Bootstrap #823 ROC area: 0.731
# Bootstrap #824 ROC area: 0.741
# Bootstrap #825 ROC area: 0.732
# Bootstrap #826 ROC area: 0.750
# Bootstrap #827 ROC area: 0.742
# Bootstrap #828 ROC area: 0.737
# Bootstrap #829 ROC area: 0.725
# Bootstrap #830 ROC area: 0.746
# Bootstrap #831 ROC area: 0.735
# Bootstrap #832 ROC area: 0.735
# Bootstrap #833 ROC area: 0.727
# Bootstrap #834 ROC area: 0.740
# Bootstrap #835 ROC area: 0.743
# Bootstrap #836 ROC area: 0.735
# Bootstrap #837 ROC area: 0.724
# Bootstrap #838 ROC area: 0.730
# Bootstrap #839 ROC area: 0.729
# Bootstrap #840 ROC area: 0.729
# Bootstrap #841 ROC area: 0.726
# Bootstrap #842 ROC area: 0.750
# Bootstrap #843 ROC area: 0.721
# Bootstrap #844 ROC area: 0.734
# Bootstrap #845 ROC area: 0.732
# Bootstrap #846 ROC area: 0.724
# Bootstrap #847 ROC area: 0.721
# Bootstrap #848 ROC area: 0.739
# Bootstrap #849 ROC area: 0.734
# Bootstrap #850 ROC area: 0.731
# Bootstrap #851 ROC area: 0.734
# Bootstrap #852 ROC area: 0.713
# Bootstrap #853 ROC area: 0.748
# Bootstrap #854 ROC area: 0.720
# Bootstrap #855 ROC area: 0.745
# Bootstrap #856 ROC area: 0.726
# Bootstrap #857 ROC area: 0.721
# Bootstrap #858 ROC area: 0.731
# Bootstrap #859 ROC area: 0.751
# Bootstrap #860 ROC area: 0.742
# Bootstrap #861 ROC area: 0.733
# Bootstrap #862 ROC area: 0.740
# Bootstrap #863 ROC area: 0.734
# Bootstrap #864 ROC area: 0.743
# Bootstrap #865 ROC area: 0.723
# Bootstrap #866 ROC area: 0.745
# Bootstrap #867 ROC area: 0.733
# Bootstrap #868 ROC area: 0.728
# Bootstrap #869 ROC area: 0.737
# Bootstrap #870 ROC area: 0.740
# Bootstrap #871 ROC area: 0.735
# Bootstrap #872 ROC area: 0.749
# Bootstrap #873 ROC area: 0.725
# Bootstrap #874 ROC area: 0.724
# Bootstrap #875 ROC area: 0.735
# Bootstrap #876 ROC area: 0.732
# Bootstrap #877 ROC area: 0.731
# Bootstrap #878 ROC area: 0.735
# Bootstrap #879 ROC area: 0.735
# Bootstrap #880 ROC area: 0.744
# Bootstrap #881 ROC area: 0.730
# Bootstrap #882 ROC area: 0.720
# Bootstrap #883 ROC area: 0.737
# Bootstrap #884 ROC area: 0.727
# Bootstrap #885 ROC area: 0.702
# Bootstrap #886 ROC area: 0.728
# Bootstrap #887 ROC area: 0.718
# Bootstrap #888 ROC area: 0.718
# Bootstrap #889 ROC area: 0.731
# Bootstrap #890 ROC area: 0.726
# Bootstrap #891 ROC area: 0.741
# Bootstrap #892 ROC area: 0.726
# Bootstrap #893 ROC area: 0.731
# Bootstrap #894 ROC area: 0.731
# Bootstrap #895 ROC area: 0.718
# Bootstrap #896 ROC area: 0.719
# Bootstrap #897 ROC area: 0.723
# Bootstrap #898 ROC area: 0.739
# Bootstrap #899 ROC area: 0.720
# Bootstrap #900 ROC area: 0.747
# Bootstrap #901 ROC area: 0.723
# Bootstrap #902 ROC area: 0.762
# Bootstrap #903 ROC area: 0.725
# Bootstrap #904 ROC area: 0.717
# Bootstrap #905 ROC area: 0.735
# Bootstrap #906 ROC area: 0.736
# Bootstrap #907 ROC area: 0.748
# Bootstrap #908 ROC area: 0.734
# Bootstrap #909 ROC area: 0.742
# Bootstrap #910 ROC area: 0.730
# Bootstrap #911 ROC area: 0.736
# Bootstrap #912 ROC area: 0.740
# Bootstrap #913 ROC area: 0.724
# Bootstrap #914 ROC area: 0.729
# Bootstrap #915 ROC area: 0.746
# Bootstrap #916 ROC area: 0.740
# Bootstrap #917 ROC area: 0.741
# Bootstrap #918 ROC area: 0.734
# Bootstrap #919 ROC area: 0.745
# Bootstrap #920 ROC area: 0.732
# Bootstrap #921 ROC area: 0.720
# Bootstrap #922 ROC area: 0.707
# Bootstrap #923 ROC area: 0.752
# Bootstrap #924 ROC area: 0.735
# Bootstrap #925 ROC area: 0.742
# Bootstrap #926 ROC area: 0.726
# Bootstrap #927 ROC area: 0.737
# Bootstrap #928 ROC area: 0.740
# Bootstrap #929 ROC area: 0.746
# Bootstrap #930 ROC area: 0.721
# Bootstrap #931 ROC area: 0.727
# Bootstrap #932 ROC area: 0.724
# Bootstrap #933 ROC area: 0.735
# Bootstrap #934 ROC area: 0.746
# Bootstrap #935 ROC area: 0.726
# Bootstrap #936 ROC area: 0.734
# Bootstrap #937 ROC area: 0.729
# Bootstrap #938 ROC area: 0.739
# Bootstrap #939 ROC area: 0.733
# Bootstrap #940 ROC area: 0.728
# Bootstrap #941 ROC area: 0.730
# Bootstrap #942 ROC area: 0.728
# Bootstrap #943 ROC area: 0.711
# Bootstrap #944 ROC area: 0.731
# Bootstrap #945 ROC area: 0.742
# Bootstrap #946 ROC area: 0.729
# Bootstrap #947 ROC area: 0.722
# Bootstrap #948 ROC area: 0.737
# Bootstrap #949 ROC area: 0.740
# Bootstrap #950 ROC area: 0.730
# Bootstrap #951 ROC area: 0.727
# Bootstrap #952 ROC area: 0.744
# Bootstrap #953 ROC area: 0.731
# Bootstrap #954 ROC area: 0.728
# Bootstrap #955 ROC area: 0.724
# Bootstrap #956 ROC area: 0.716
# Bootstrap #957 ROC area: 0.742
# Bootstrap #958 ROC area: 0.731
# Bootstrap #959 ROC area: 0.738
# Bootstrap #960 ROC area: 0.733
# Bootstrap #961 ROC area: 0.710
# Bootstrap #962 ROC area: 0.731
# Bootstrap #963 ROC area: 0.738
# Bootstrap #964 ROC area: 0.730
# Bootstrap #965 ROC area: 0.743
# Bootstrap #966 ROC area: 0.738
# Bootstrap #967 ROC area: 0.732
# Bootstrap #968 ROC area: 0.729
# Bootstrap #969 ROC area: 0.733
# Bootstrap #970 ROC area: 0.721
# Bootstrap #971 ROC area: 0.726
# Bootstrap #972 ROC area: 0.739
# Bootstrap #973 ROC area: 0.732
# Bootstrap #974 ROC area: 0.728
# Bootstrap #975 ROC area: 0.734
# Bootstrap #976 ROC area: 0.739
# Bootstrap #977 ROC area: 0.732
# Bootstrap #978 ROC area: 0.719
# Bootstrap #979 ROC area: 0.713
# Bootstrap #980 ROC area: 0.745
# Bootstrap #981 ROC area: 0.742
# Bootstrap #982 ROC area: 0.712
# Bootstrap #983 ROC area: 0.722
# Bootstrap #984 ROC area: 0.739
# Bootstrap #985 ROC area: 0.731
# Bootstrap #986 ROC area: 0.729
# Bootstrap #987 ROC area: 0.745
# Bootstrap #988 ROC area: 0.713
# Bootstrap #989 ROC area: 0.726
# Bootstrap #990 ROC area: 0.727
# Bootstrap #991 ROC area: 0.747
# Bootstrap #992 ROC area: 0.751
# Bootstrap #993 ROC area: 0.737
# Bootstrap #994 ROC area: 0.725
# Bootstrap #995 ROC area: 0.730
# Bootstrap #996 ROC area: 0.723
# Bootstrap #997 ROC area: 0.727
# Bootstrap #998 ROC area: 0.716
# Bootstrap #999 ROC area: 0.728
# Bootstrap #1000 ROC area: 0.730

# %%
sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()
confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Confidence interval for the score: [0.713 - 0.751]

# %% [markdown]
# ### Selecting only SOFA score for individual race test dataset

# %%
xTestWhite = xTestWhite['sofa_24hours'].to_numpy().reshape(-1,1)
xTestBlack = xTestBlack['sofa_24hours'].to_numpy().reshape(-1,1)
xTestHisp = xTestHisp['sofa_24hours'].to_numpy().reshape(-1,1)
xTestAsian = xTestAsian['sofa_24hours'].to_numpy().reshape(-1,1)

# %% [markdown]
# #### For White Patient Set

# %%
y_pred_white = model.predict_proba(xTestWhite)
print("Original ROC area: {:0.3f}".format(roc_auc_score(yTestWhite, y_pred_white[:,1])))
# Out:
# Original ROC area: 0.734

# %%
n_bootstraps = 1000
rng_seed = 42  # control reproducibility
bootstrapped_scores = []

rng = np.random.RandomState(rng_seed)
for i in range(n_bootstraps):
    indices = rng.randint(0, len(y_pred_white), len(y_pred_white))

    score = roc_auc_score(yTestWhite.to_numpy()[indices], y_pred_white[indices, 1])
    bootstrapped_scores.append(score)
    print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))
# Out:
# Bootstrap #1 ROC area: 0.720
# Bootstrap #2 ROC area: 0.713
# Bootstrap #3 ROC area: 0.731
# Bootstrap #4 ROC area: 0.730
# Bootstrap #5 ROC area: 0.749
# Bootstrap #6 ROC area: 0.737
# Bootstrap #7 ROC area: 0.750
# Bootstrap #8 ROC area: 0.715
# Bootstrap #9 ROC area: 0.708
# Bootstrap #10 ROC area: 0.735
# Bootstrap #11 ROC area: 0.732
# Bootstrap #12 ROC area: 0.725
# Bootstrap #13 ROC area: 0.744
# Bootstrap #14 ROC area: 0.756
# Bootstrap #15 ROC area: 0.723
# Bootstrap #16 ROC area: 0.744
# Bootstrap #17 ROC area: 0.734
# Bootstrap #18 ROC area: 0.753
# Bootstrap #19 ROC area: 0.742
# Bootstrap #20 ROC area: 0.728
# Bootstrap #21 ROC area: 0.732
# Bootstrap #22 ROC area: 0.719
# Bootstrap #23 ROC area: 0.736
# Bootstrap #24 ROC area: 0.728
# Bootstrap #25 ROC area: 0.738
# Bootstrap #26 ROC area: 0.737
# Bootstrap #27 ROC area: 0.736
# Bootstrap #28 ROC area: 0.733
# Bootstrap #29 ROC area: 0.737
# Bootstrap #30 ROC area: 0.737
# Bootstrap #31 ROC area: 0.722
# Bootstrap #32 ROC area: 0.738
# Bootstrap #33 ROC area: 0.754
# Bootstrap #34 ROC area: 0.740
# Bootstrap #35 ROC area: 0.742
# Bootstrap #36 ROC area: 0.746
# Bootstrap #37 ROC area: 0.731
# Bootstrap #38 ROC area: 0.732
# Bootstrap #39 ROC area: 0.736
# Bootstrap #40 ROC area: 0.730
# Bootstrap #41 ROC area: 0.725
# Bootstrap #42 ROC area: 0.732
# Bootstrap #43 ROC area: 0.716
# Bootstrap #44 ROC area: 0.728
# Bootstrap #45 ROC area: 0.728
# Bootstrap #46 ROC area: 0.721
# Bootstrap #47 ROC area: 0.723
# Bootstrap #48 ROC area: 0.720
# Bootstrap #49 ROC area: 0.722
# Bootstrap #50 ROC area: 0.736
# Bootstrap #51 ROC area: 0.727
# Bootstrap #52 ROC area: 0.748
# Bootstrap #53 ROC area: 0.717
# Bootstrap #54 ROC area: 0.730
# Bootstrap #55 ROC area: 0.721
# Bootstrap #56 ROC area: 0.722
# Bootstrap #57 ROC area: 0.747
# Bootstrap #58 ROC area: 0.746
# Bootstrap #59 ROC area: 0.758
# Bootstrap #60 ROC area: 0.737
# Bootstrap #61 ROC area: 0.744
# Bootstrap #62 ROC area: 0.724
# Bootstrap #63 ROC area: 0.729
# Bootstrap #64 ROC area: 0.732
# Bootstrap #65 ROC area: 0.713
# Bootstrap #66 ROC area: 0.738
# Bootstrap #67 ROC area: 0.728
# Bootstrap #68 ROC area: 0.735
# Bootstrap #69 ROC area: 0.733
# Bootstrap #70 ROC area: 0.729
# Bootstrap #71 ROC area: 0.727
# Bootstrap #72 ROC area: 0.737
# Bootstrap #73 ROC area: 0.731
# Bootstrap #74 ROC area: 0.738
# Bootstrap #75 ROC area: 0.734
# Bootstrap #76 ROC area: 0.723
# Bootstrap #77 ROC area: 0.744
# Bootstrap #78 ROC area: 0.730
# Bootstrap #79 ROC area: 0.746
# Bootstrap #80 ROC area: 0.722
# Bootstrap #81 ROC area: 0.744
# Bootstrap #82 ROC area: 0.751
# Bootstrap #83 ROC area: 0.721
# Bootstrap #84 ROC area: 0.752
# Bootstrap #85 ROC area: 0.742
# Bootstrap #86 ROC area: 0.747
# Bootstrap #87 ROC area: 0.737
# Bootstrap #88 ROC area: 0.724
# Bootstrap #89 ROC area: 0.753
# Bootstrap #90 ROC area: 0.756
# Bootstrap #91 ROC area: 0.739
# Bootstrap #92 ROC area: 0.743
# Bootstrap #93 ROC area: 0.726
# Bootstrap #94 ROC area: 0.737
# Bootstrap #95 ROC area: 0.747
# Bootstrap #96 ROC area: 0.734
# Bootstrap #97 ROC area: 0.744
# Bootstrap #98 ROC area: 0.725
# Bootstrap #99 ROC area: 0.738
# Bootstrap #100 ROC area: 0.750
# Bootstrap #101 ROC area: 0.738
# Bootstrap #102 ROC area: 0.739
# Bootstrap #103 ROC area: 0.731
# Bootstrap #104 ROC area: 0.737
# Bootstrap #105 ROC area: 0.735
# Bootstrap #106 ROC area: 0.725
# Bootstrap #107 ROC area: 0.724
# Bootstrap #108 ROC area: 0.730
# Bootstrap #109 ROC area: 0.730
# Bootstrap #110 ROC area: 0.737
# Bootstrap #111 ROC area: 0.715
# Bootstrap #112 ROC area: 0.735
# Bootstrap #113 ROC area: 0.735
# Bootstrap #114 ROC area: 0.738
# Bootstrap #115 ROC area: 0.743
# Bootstrap #116 ROC area: 0.720
# Bootstrap #117 ROC area: 0.736
# Bootstrap #118 ROC area: 0.734
# Bootstrap #119 ROC area: 0.729
# Bootstrap #120 ROC area: 0.735
# Bootstrap #121 ROC area: 0.729
# Bootstrap #122 ROC area: 0.750
# Bootstrap #123 ROC area: 0.747
# Bootstrap #124 ROC area: 0.732
# Bootstrap #125 ROC area: 0.734
# Bootstrap #126 ROC area: 0.734
# Bootstrap #127 ROC area: 0.734
# Bootstrap #128 ROC area: 0.751
# Bootstrap #129 ROC area: 0.732
# Bootstrap #130 ROC area: 0.744
# Bootstrap #131 ROC area: 0.727
# Bootstrap #132 ROC area: 0.748
# Bootstrap #133 ROC area: 0.738
# Bootstrap #134 ROC area: 0.704
# Bootstrap #135 ROC area: 0.742
# Bootstrap #136 ROC area: 0.726
# Bootstrap #137 ROC area: 0.729
# Bootstrap #138 ROC area: 0.761
# Bootstrap #139 ROC area: 0.728
# Bootstrap #140 ROC area: 0.734
# Bootstrap #141 ROC area: 0.724
# Bootstrap #142 ROC area: 0.720
# Bootstrap #143 ROC area: 0.737
# Bootstrap #144 ROC area: 0.723
# Bootstrap #145 ROC area: 0.745
# Bootstrap #146 ROC area: 0.719
# Bootstrap #147 ROC area: 0.730
# Bootstrap #148 ROC area: 0.727
# Bootstrap #149 ROC area: 0.742
# Bootstrap #150 ROC area: 0.734
# Bootstrap #151 ROC area: 0.714
# Bootstrap #152 ROC area: 0.721
# Bootstrap #153 ROC area: 0.743
# Bootstrap #154 ROC area: 0.753
# Bootstrap #155 ROC area: 0.754
# Bootstrap #156 ROC area: 0.734
# Bootstrap #157 ROC area: 0.739
# Bootstrap #158 ROC area: 0.743
# Bootstrap #159 ROC area: 0.719
# Bootstrap #160 ROC area: 0.744
# Bootstrap #161 ROC area: 0.744
# Bootstrap #162 ROC area: 0.738
# Bootstrap #163 ROC area: 0.741
# Bootstrap #164 ROC area: 0.712
# Bootstrap #165 ROC area: 0.737
# Bootstrap #166 ROC area: 0.733
# Bootstrap #167 ROC area: 0.742
# Bootstrap #168 ROC area: 0.753
# Bootstrap #169 ROC area: 0.721
# Bootstrap #170 ROC area: 0.743
# Bootstrap #171 ROC area: 0.743
# Bootstrap #172 ROC area: 0.730
# Bootstrap #173 ROC area: 0.711
# Bootstrap #174 ROC area: 0.724
# Bootstrap #175 ROC area: 0.740
# Bootstrap #176 ROC area: 0.731
# Bootstrap #177 ROC area: 0.722
# Bootstrap #178 ROC area: 0.730
# Bootstrap #179 ROC area: 0.712
# Bootstrap #180 ROC area: 0.750
# Bootstrap #181 ROC area: 0.717
# Bootstrap #182 ROC area: 0.736
# Bootstrap #183 ROC area: 0.736
# Bootstrap #184 ROC area: 0.746
# Bootstrap #185 ROC area: 0.719
# Bootstrap #186 ROC area: 0.753
# Bootstrap #187 ROC area: 0.727
# Bootstrap #188 ROC area: 0.701
# Bootstrap #189 ROC area: 0.742
# Bootstrap #190 ROC area: 0.728
# Bootstrap #191 ROC area: 0.728
# Bootstrap #192 ROC area: 0.714
# Bootstrap #193 ROC area: 0.739
# Bootstrap #194 ROC area: 0.722
# Bootstrap #195 ROC area: 0.729
# Bootstrap #196 ROC area: 0.748
# Bootstrap #197 ROC area: 0.747
# Bootstrap #198 ROC area: 0.727
# Bootstrap #199 ROC area: 0.740
# Bootstrap #200 ROC area: 0.743
# Bootstrap #201 ROC area: 0.734
# Bootstrap #202 ROC area: 0.724
# Bootstrap #203 ROC area: 0.739
# Bootstrap #204 ROC area: 0.717
# Bootstrap #205 ROC area: 0.734
# Bootstrap #206 ROC area: 0.757
# Bootstrap #207 ROC area: 0.734
# Bootstrap #208 ROC area: 0.727
# Bootstrap #209 ROC area: 0.728
# Bootstrap #210 ROC area: 0.739
# Bootstrap #211 ROC area: 0.749
# Bootstrap #212 ROC area: 0.740
# Bootstrap #213 ROC area: 0.736
# Bootstrap #214 ROC area: 0.750
# Bootstrap #215 ROC area: 0.742
# Bootstrap #216 ROC area: 0.730
# Bootstrap #217 ROC area: 0.732
# Bootstrap #218 ROC area: 0.734
# Bootstrap #219 ROC area: 0.732
# Bootstrap #220 ROC area: 0.745
# Bootstrap #221 ROC area: 0.735
# Bootstrap #222 ROC area: 0.727
# Bootstrap #223 ROC area: 0.727
# Bootstrap #224 ROC area: 0.747
# Bootstrap #225 ROC area: 0.729
# Bootstrap #226 ROC area: 0.738
# Bootstrap #227 ROC area: 0.717
# Bootstrap #228 ROC area: 0.726
# Bootstrap #229 ROC area: 0.728
# Bootstrap #230 ROC area: 0.741
# Bootstrap #231 ROC area: 0.715
# Bootstrap #232 ROC area: 0.744
# Bootstrap #233 ROC area: 0.746
# Bootstrap #234 ROC area: 0.739
# Bootstrap #235 ROC area: 0.747
# Bootstrap #236 ROC area: 0.737
# Bootstrap #237 ROC area: 0.740
# Bootstrap #238 ROC area: 0.751
# Bootstrap #239 ROC area: 0.713
# Bootstrap #240 ROC area: 0.715
# Bootstrap #241 ROC area: 0.738
# Bootstrap #242 ROC area: 0.735
# Bootstrap #243 ROC area: 0.733
# Bootstrap #244 ROC area: 0.740
# Bootstrap #245 ROC area: 0.741
# Bootstrap #246 ROC area: 0.724
# Bootstrap #247 ROC area: 0.734
# Bootstrap #248 ROC area: 0.719
# Bootstrap #249 ROC area: 0.742
# Bootstrap #250 ROC area: 0.732
# Bootstrap #251 ROC area: 0.731
# Bootstrap #252 ROC area: 0.733
# Bootstrap #253 ROC area: 0.734
# Bootstrap #254 ROC area: 0.743
# Bootstrap #255 ROC area: 0.741
# Bootstrap #256 ROC area: 0.740
# Bootstrap #257 ROC area: 0.737
# Bootstrap #258 ROC area: 0.746
# Bootstrap #259 ROC area: 0.734
# Bootstrap #260 ROC area: 0.743
# Bootstrap #261 ROC area: 0.733
# Bootstrap #262 ROC area: 0.738
# Bootstrap #263 ROC area: 0.736
# Bootstrap #264 ROC area: 0.730
# Bootstrap #265 ROC area: 0.731
# Bootstrap #266 ROC area: 0.720
# Bootstrap #267 ROC area: 0.718
# Bootstrap #268 ROC area: 0.741
# Bootstrap #269 ROC area: 0.746
# Bootstrap #270 ROC area: 0.736
# Bootstrap #271 ROC area: 0.720
# Bootstrap #272 ROC area: 0.741
# Bootstrap #273 ROC area: 0.724
# Bootstrap #274 ROC area: 0.722
# Bootstrap #275 ROC area: 0.721
# Bootstrap #276 ROC area: 0.734
# Bootstrap #277 ROC area: 0.733
# Bootstrap #278 ROC area: 0.731
# Bootstrap #279 ROC area: 0.735
# Bootstrap #280 ROC area: 0.729
# Bootstrap #281 ROC area: 0.716
# Bootstrap #282 ROC area: 0.739
# Bootstrap #283 ROC area: 0.719
# Bootstrap #284 ROC area: 0.710
# Bootstrap #285 ROC area: 0.753
# Bootstrap #286 ROC area: 0.736
# Bootstrap #287 ROC area: 0.702
# Bootstrap #288 ROC area: 0.731
# Bootstrap #289 ROC area: 0.726
# Bootstrap #290 ROC area: 0.742
# Bootstrap #291 ROC area: 0.738
# Bootstrap #292 ROC area: 0.724
# Bootstrap #293 ROC area: 0.738
# Bootstrap #294 ROC area: 0.724
# Bootstrap #295 ROC area: 0.737
# Bootstrap #296 ROC area: 0.739
# Bootstrap #297 ROC area: 0.742
# Bootstrap #298 ROC area: 0.751
# Bootstrap #299 ROC area: 0.737
# Bootstrap #300 ROC area: 0.719
# Bootstrap #301 ROC area: 0.731
# Bootstrap #302 ROC area: 0.740
# Bootstrap #303 ROC area: 0.752
# Bootstrap #304 ROC area: 0.727
# Bootstrap #305 ROC area: 0.741
# Bootstrap #306 ROC area: 0.747
# Bootstrap #307 ROC area: 0.738
# Bootstrap #308 ROC area: 0.718
# Bootstrap #309 ROC area: 0.734
# Bootstrap #310 ROC area: 0.754
# Bootstrap #311 ROC area: 0.746
# Bootstrap #312 ROC area: 0.735
# Bootstrap #313 ROC area: 0.724
# Bootstrap #314 ROC area: 0.732
# Bootstrap #315 ROC area: 0.727
# Bootstrap #316 ROC area: 0.718
# Bootstrap #317 ROC area: 0.755
# Bootstrap #318 ROC area: 0.739
# Bootstrap #319 ROC area: 0.743
# Bootstrap #320 ROC area: 0.745
# Bootstrap #321 ROC area: 0.735
# Bootstrap #322 ROC area: 0.724
# Bootstrap #323 ROC area: 0.733
# Bootstrap #324 ROC area: 0.730
# Bootstrap #325 ROC area: 0.744
# Bootstrap #326 ROC area: 0.723
# Bootstrap #327 ROC area: 0.735
# Bootstrap #328 ROC area: 0.735
# Bootstrap #329 ROC area: 0.733
# Bootstrap #330 ROC area: 0.741
# Bootstrap #331 ROC area: 0.745
# Bootstrap #332 ROC area: 0.746
# Bootstrap #333 ROC area: 0.738
# Bootstrap #334 ROC area: 0.739
# Bootstrap #335 ROC area: 0.725
# Bootstrap #336 ROC area: 0.730
# Bootstrap #337 ROC area: 0.732
# Bootstrap #338 ROC area: 0.748
# Bootstrap #339 ROC area: 0.735
# Bootstrap #340 ROC area: 0.735
# Bootstrap #341 ROC area: 0.719
# Bootstrap #342 ROC area: 0.747
# Bootstrap #343 ROC area: 0.733
# Bootstrap #344 ROC area: 0.728
# Bootstrap #345 ROC area: 0.736
# Bootstrap #346 ROC area: 0.740
# Bootstrap #347 ROC area: 0.739
# Bootstrap #348 ROC area: 0.735
# Bootstrap #349 ROC area: 0.741
# Bootstrap #350 ROC area: 0.721
# Bootstrap #351 ROC area: 0.740
# Bootstrap #352 ROC area: 0.731
# Bootstrap #353 ROC area: 0.738
# Bootstrap #354 ROC area: 0.739
# Bootstrap #355 ROC area: 0.728
# Bootstrap #356 ROC area: 0.735
# Bootstrap #357 ROC area: 0.747
# Bootstrap #358 ROC area: 0.741
# Bootstrap #359 ROC area: 0.743
# Bootstrap #360 ROC area: 0.748
# Bootstrap #361 ROC area: 0.741
# Bootstrap #362 ROC area: 0.739
# Bootstrap #363 ROC area: 0.734
# Bootstrap #364 ROC area: 0.725
# Bootstrap #365 ROC area: 0.722
# Bootstrap #366 ROC area: 0.735
# Bootstrap #367 ROC area: 0.726
# Bootstrap #368 ROC area: 0.739
# Bootstrap #369 ROC area: 0.730
# Bootstrap #370 ROC area: 0.734
# Bootstrap #371 ROC area: 0.745
# Bootstrap #372 ROC area: 0.734
# Bootstrap #373 ROC area: 0.722
# Bootstrap #374 ROC area: 0.720
# Bootstrap #375 ROC area: 0.739
# Bootstrap #376 ROC area: 0.738
# Bootstrap #377 ROC area: 0.722
# Bootstrap #378 ROC area: 0.738
# Bootstrap #379 ROC area: 0.736
# Bootstrap #380 ROC area: 0.731
# Bootstrap #381 ROC area: 0.735
# Bootstrap #382 ROC area: 0.737
# Bootstrap #383 ROC area: 0.735
# Bootstrap #384 ROC area: 0.741
# Bootstrap #385 ROC area: 0.746
# Bootstrap #386 ROC area: 0.753
# Bootstrap #387 ROC area: 0.749
# Bootstrap #388 ROC area: 0.741
# Bootstrap #389 ROC area: 0.729
# Bootstrap #390 ROC area: 0.745
# Bootstrap #391 ROC area: 0.728
# Bootstrap #392 ROC area: 0.721
# Bootstrap #393 ROC area: 0.740
# Bootstrap #394 ROC area: 0.730
# Bootstrap #395 ROC area: 0.725
# Bootstrap #396 ROC area: 0.734
# Bootstrap #397 ROC area: 0.742
# Bootstrap #398 ROC area: 0.734
# Bootstrap #399 ROC area: 0.747
# Bootstrap #400 ROC area: 0.751
# Bootstrap #401 ROC area: 0.741
# Bootstrap #402 ROC area: 0.748
# Bootstrap #403 ROC area: 0.735
# Bootstrap #404 ROC area: 0.733
# Bootstrap #405 ROC area: 0.739
# Bootstrap #406 ROC area: 0.729
# Bootstrap #407 ROC area: 0.731
# Bootstrap #408 ROC area: 0.750
# Bootstrap #409 ROC area: 0.711
# Bootstrap #410 ROC area: 0.743
# Bootstrap #411 ROC area: 0.736
# Bootstrap #412 ROC area: 0.743
# Bootstrap #413 ROC area: 0.729
# Bootstrap #414 ROC area: 0.728
# Bootstrap #415 ROC area: 0.741
# Bootstrap #416 ROC area: 0.737
# Bootstrap #417 ROC area: 0.728
# Bootstrap #418 ROC area: 0.752
# Bootstrap #419 ROC area: 0.736
# Bootstrap #420 ROC area: 0.731
# Bootstrap #421 ROC area: 0.743
# Bootstrap #422 ROC area: 0.749
# Bootstrap #423 ROC area: 0.744
# Bootstrap #424 ROC area: 0.737
# Bootstrap #425 ROC area: 0.753
# Bootstrap #426 ROC area: 0.734
# Bootstrap #427 ROC area: 0.733
# Bootstrap #428 ROC area: 0.746
# Bootstrap #429 ROC area: 0.729
# Bootstrap #430 ROC area: 0.738
# Bootstrap #431 ROC area: 0.744
# Bootstrap #432 ROC area: 0.715
# Bootstrap #433 ROC area: 0.729
# Bootstrap #434 ROC area: 0.740
# Bootstrap #435 ROC area: 0.711
# Bootstrap #436 ROC area: 0.726
# Bootstrap #437 ROC area: 0.738
# Bootstrap #438 ROC area: 0.744
# Bootstrap #439 ROC area: 0.739
# Bootstrap #440 ROC area: 0.730
# Bootstrap #441 ROC area: 0.724
# Bootstrap #442 ROC area: 0.724
# Bootstrap #443 ROC area: 0.709
# Bootstrap #444 ROC area: 0.735
# Bootstrap #445 ROC area: 0.744
# Bootstrap #446 ROC area: 0.733
# Bootstrap #447 ROC area: 0.735
# Bootstrap #448 ROC area: 0.746
# Bootstrap #449 ROC area: 0.735
# Bootstrap #450 ROC area: 0.740
# Bootstrap #451 ROC area: 0.741
# Bootstrap #452 ROC area: 0.725
# Bootstrap #453 ROC area: 0.735
# Bootstrap #454 ROC area: 0.724
# Bootstrap #455 ROC area: 0.737
# Bootstrap #456 ROC area: 0.730
# Bootstrap #457 ROC area: 0.722
# Bootstrap #458 ROC area: 0.723
# Bootstrap #459 ROC area: 0.733
# Bootstrap #460 ROC area: 0.741
# Bootstrap #461 ROC area: 0.732
# Bootstrap #462 ROC area: 0.748
# Bootstrap #463 ROC area: 0.725
# Bootstrap #464 ROC area: 0.712
# Bootstrap #465 ROC area: 0.753
# Bootstrap #466 ROC area: 0.733
# Bootstrap #467 ROC area: 0.738
# Bootstrap #468 ROC area: 0.740
# Bootstrap #469 ROC area: 0.711
# Bootstrap #470 ROC area: 0.731
# Bootstrap #471 ROC area: 0.741
# Bootstrap #472 ROC area: 0.733
# Bootstrap #473 ROC area: 0.736
# Bootstrap #474 ROC area: 0.746
# Bootstrap #475 ROC area: 0.720
# Bootstrap #476 ROC area: 0.751
# Bootstrap #477 ROC area: 0.724
# Bootstrap #478 ROC area: 0.748
# Bootstrap #479 ROC area: 0.737
# Bootstrap #480 ROC area: 0.722
# Bootstrap #481 ROC area: 0.721
# Bootstrap #482 ROC area: 0.724
# Bootstrap #483 ROC area: 0.744
# Bootstrap #484 ROC area: 0.727
# Bootstrap #485 ROC area: 0.715
# Bootstrap #486 ROC area: 0.722
# Bootstrap #487 ROC area: 0.742
# Bootstrap #488 ROC area: 0.705
# Bootstrap #489 ROC area: 0.740
# Bootstrap #490 ROC area: 0.746
# Bootstrap #491 ROC area: 0.737
# Bootstrap #492 ROC area: 0.724
# Bootstrap #493 ROC area: 0.727
# Bootstrap #494 ROC area: 0.722
# Bootstrap #495 ROC area: 0.725
# Bootstrap #496 ROC area: 0.733
# Bootstrap #497 ROC area: 0.726
# Bootstrap #498 ROC area: 0.746
# Bootstrap #499 ROC area: 0.746
# Bootstrap #500 ROC area: 0.742
# Bootstrap #501 ROC area: 0.735
# Bootstrap #502 ROC area: 0.735
# Bootstrap #503 ROC area: 0.720
# Bootstrap #504 ROC area: 0.733
# Bootstrap #505 ROC area: 0.734
# Bootstrap #506 ROC area: 0.726
# Bootstrap #507 ROC area: 0.731
# Bootstrap #508 ROC area: 0.762
# Bootstrap #509 ROC area: 0.732
# Bootstrap #510 ROC area: 0.730
# Bootstrap #511 ROC area: 0.735
# Bootstrap #512 ROC area: 0.736
# Bootstrap #513 ROC area: 0.719
# Bootstrap #514 ROC area: 0.721
# Bootstrap #515 ROC area: 0.751
# Bootstrap #516 ROC area: 0.743
# Bootstrap #517 ROC area: 0.744
# Bootstrap #518 ROC area: 0.745
# Bootstrap #519 ROC area: 0.745
# Bootstrap #520 ROC area: 0.750
# Bootstrap #521 ROC area: 0.752
# Bootstrap #522 ROC area: 0.733
# Bootstrap #523 ROC area: 0.739
# Bootstrap #524 ROC area: 0.731
# Bootstrap #525 ROC area: 0.730
# Bootstrap #526 ROC area: 0.715
# Bootstrap #527 ROC area: 0.738
# Bootstrap #528 ROC area: 0.731
# Bootstrap #529 ROC area: 0.741
# Bootstrap #530 ROC area: 0.745
# Bootstrap #531 ROC area: 0.759
# Bootstrap #532 ROC area: 0.735
# Bootstrap #533 ROC area: 0.720
# Bootstrap #534 ROC area: 0.725
# Bootstrap #535 ROC area: 0.749
# Bootstrap #536 ROC area: 0.734
# Bootstrap #537 ROC area: 0.741
# Bootstrap #538 ROC area: 0.735
# Bootstrap #539 ROC area: 0.717
# Bootstrap #540 ROC area: 0.749
# Bootstrap #541 ROC area: 0.731
# Bootstrap #542 ROC area: 0.717
# Bootstrap #543 ROC area: 0.726
# Bootstrap #544 ROC area: 0.742
# Bootstrap #545 ROC area: 0.723
# Bootstrap #546 ROC area: 0.722
# Bootstrap #547 ROC area: 0.743
# Bootstrap #548 ROC area: 0.743
# Bootstrap #549 ROC area: 0.746
# Bootstrap #550 ROC area: 0.749
# Bootstrap #551 ROC area: 0.717
# Bootstrap #552 ROC area: 0.734
# Bootstrap #553 ROC area: 0.711
# Bootstrap #554 ROC area: 0.725
# Bootstrap #555 ROC area: 0.737
# Bootstrap #556 ROC area: 0.741
# Bootstrap #557 ROC area: 0.749
# Bootstrap #558 ROC area: 0.743
# Bootstrap #559 ROC area: 0.740
# Bootstrap #560 ROC area: 0.720
# Bootstrap #561 ROC area: 0.711
# Bootstrap #562 ROC area: 0.734
# Bootstrap #563 ROC area: 0.749
# Bootstrap #564 ROC area: 0.732
# Bootstrap #565 ROC area: 0.740
# Bootstrap #566 ROC area: 0.747
# Bootstrap #567 ROC area: 0.749
# Bootstrap #568 ROC area: 0.755
# Bootstrap #569 ROC area: 0.730
# Bootstrap #570 ROC area: 0.727
# Bootstrap #571 ROC area: 0.738
# Bootstrap #572 ROC area: 0.738
# Bootstrap #573 ROC area: 0.755
# Bootstrap #574 ROC area: 0.732
# Bootstrap #575 ROC area: 0.735
# Bootstrap #576 ROC area: 0.726
# Bootstrap #577 ROC area: 0.737
# Bootstrap #578 ROC area: 0.736
# Bootstrap #579 ROC area: 0.740
# Bootstrap #580 ROC area: 0.735
# Bootstrap #581 ROC area: 0.724
# Bootstrap #582 ROC area: 0.751
# Bootstrap #583 ROC area: 0.743
# Bootstrap #584 ROC area: 0.738
# Bootstrap #585 ROC area: 0.725
# Bootstrap #586 ROC area: 0.721
# Bootstrap #587 ROC area: 0.729
# Bootstrap #588 ROC area: 0.722
# Bootstrap #589 ROC area: 0.735
# Bootstrap #590 ROC area: 0.718
# Bootstrap #591 ROC area: 0.700
# Bootstrap #592 ROC area: 0.737
# Bootstrap #593 ROC area: 0.722
# Bootstrap #594 ROC area: 0.730
# Bootstrap #595 ROC area: 0.743
# Bootstrap #596 ROC area: 0.740
# Bootstrap #597 ROC area: 0.734
# Bootstrap #598 ROC area: 0.744
# Bootstrap #599 ROC area: 0.751
# Bootstrap #600 ROC area: 0.713
# Bootstrap #601 ROC area: 0.738
# Bootstrap #602 ROC area: 0.729
# Bootstrap #603 ROC area: 0.719
# Bootstrap #604 ROC area: 0.718
# Bootstrap #605 ROC area: 0.720
# Bootstrap #606 ROC area: 0.743
# Bootstrap #607 ROC area: 0.743
# Bootstrap #608 ROC area: 0.727
# Bootstrap #609 ROC area: 0.725
# Bootstrap #610 ROC area: 0.737
# Bootstrap #611 ROC area: 0.731
# Bootstrap #612 ROC area: 0.700
# Bootstrap #613 ROC area: 0.735
# Bootstrap #614 ROC area: 0.743
# Bootstrap #615 ROC area: 0.730
# Bootstrap #616 ROC area: 0.749
# Bootstrap #617 ROC area: 0.746
# Bootstrap #618 ROC area: 0.735
# Bootstrap #619 ROC area: 0.741
# Bootstrap #620 ROC area: 0.745
# Bootstrap #621 ROC area: 0.751
# Bootstrap #622 ROC area: 0.736
# Bootstrap #623 ROC area: 0.745
# Bootstrap #624 ROC area: 0.735
# Bootstrap #625 ROC area: 0.731
# Bootstrap #626 ROC area: 0.735
# Bootstrap #627 ROC area: 0.734
# Bootstrap #628 ROC area: 0.723
# Bootstrap #629 ROC area: 0.733
# Bootstrap #630 ROC area: 0.734
# Bootstrap #631 ROC area: 0.733
# Bootstrap #632 ROC area: 0.737
# Bootstrap #633 ROC area: 0.726
# Bootstrap #634 ROC area: 0.737
# Bootstrap #635 ROC area: 0.722
# Bootstrap #636 ROC area: 0.741
# Bootstrap #637 ROC area: 0.740
# Bootstrap #638 ROC area: 0.737
# Bootstrap #639 ROC area: 0.743
# Bootstrap #640 ROC area: 0.721
# Bootstrap #641 ROC area: 0.718
# Bootstrap #642 ROC area: 0.729
# Bootstrap #643 ROC area: 0.741
# Bootstrap #644 ROC area: 0.746
# Bootstrap #645 ROC area: 0.735
# Bootstrap #646 ROC area: 0.742
# Bootstrap #647 ROC area: 0.734
# Bootstrap #648 ROC area: 0.739
# Bootstrap #649 ROC area: 0.731
# Bootstrap #650 ROC area: 0.725
# Bootstrap #651 ROC area: 0.735
# Bootstrap #652 ROC area: 0.746
# Bootstrap #653 ROC area: 0.720
# Bootstrap #654 ROC area: 0.738
# Bootstrap #655 ROC area: 0.736
# Bootstrap #656 ROC area: 0.737
# Bootstrap #657 ROC area: 0.728
# Bootstrap #658 ROC area: 0.749
# Bootstrap #659 ROC area: 0.722
# Bootstrap #660 ROC area: 0.733
# Bootstrap #661 ROC area: 0.737
# Bootstrap #662 ROC area: 0.727
# Bootstrap #663 ROC area: 0.737
# Bootstrap #664 ROC area: 0.727
# Bootstrap #665 ROC area: 0.731
# Bootstrap #666 ROC area: 0.744
# Bootstrap #667 ROC area: 0.738
# Bootstrap #668 ROC area: 0.727
# Bootstrap #669 ROC area: 0.745
# Bootstrap #670 ROC area: 0.720
# Bootstrap #671 ROC area: 0.724
# Bootstrap #672 ROC area: 0.723
# Bootstrap #673 ROC area: 0.738
# Bootstrap #674 ROC area: 0.741
# Bootstrap #675 ROC area: 0.728
# Bootstrap #676 ROC area: 0.741
# Bootstrap #677 ROC area: 0.754
# Bootstrap #678 ROC area: 0.723
# Bootstrap #679 ROC area: 0.725
# Bootstrap #680 ROC area: 0.746
# Bootstrap #681 ROC area: 0.729
# Bootstrap #682 ROC area: 0.744
# Bootstrap #683 ROC area: 0.739
# Bootstrap #684 ROC area: 0.730
# Bootstrap #685 ROC area: 0.718
# Bootstrap #686 ROC area: 0.722
# Bootstrap #687 ROC area: 0.730
# Bootstrap #688 ROC area: 0.730
# Bootstrap #689 ROC area: 0.747
# Bootstrap #690 ROC area: 0.728
# Bootstrap #691 ROC area: 0.734
# Bootstrap #692 ROC area: 0.742
# Bootstrap #693 ROC area: 0.721
# Bootstrap #694 ROC area: 0.751
# Bootstrap #695 ROC area: 0.717
# Bootstrap #696 ROC area: 0.742
# Bootstrap #697 ROC area: 0.749
# Bootstrap #698 ROC area: 0.759
# Bootstrap #699 ROC area: 0.735
# Bootstrap #700 ROC area: 0.741
# Bootstrap #701 ROC area: 0.724
# Bootstrap #702 ROC area: 0.741
# Bootstrap #703 ROC area: 0.717
# Bootstrap #704 ROC area: 0.741
# Bootstrap #705 ROC area: 0.727
# Bootstrap #706 ROC area: 0.732
# Bootstrap #707 ROC area: 0.740
# Bootstrap #708 ROC area: 0.734
# Bootstrap #709 ROC area: 0.754
# Bootstrap #710 ROC area: 0.744
# Bootstrap #711 ROC area: 0.720
# Bootstrap #712 ROC area: 0.737
# Bootstrap #713 ROC area: 0.735
# Bootstrap #714 ROC area: 0.735
# Bootstrap #715 ROC area: 0.754
# Bootstrap #716 ROC area: 0.727
# Bootstrap #717 ROC area: 0.719
# Bootstrap #718 ROC area: 0.720
# Bootstrap #719 ROC area: 0.736
# Bootstrap #720 ROC area: 0.727
# Bootstrap #721 ROC area: 0.732
# Bootstrap #722 ROC area: 0.736
# Bootstrap #723 ROC area: 0.729
# Bootstrap #724 ROC area: 0.718
# Bootstrap #725 ROC area: 0.726
# Bootstrap #726 ROC area: 0.726
# Bootstrap #727 ROC area: 0.742
# Bootstrap #728 ROC area: 0.730
# Bootstrap #729 ROC area: 0.741
# Bootstrap #730 ROC area: 0.718
# Bootstrap #731 ROC area: 0.740
# Bootstrap #732 ROC area: 0.757
# Bootstrap #733 ROC area: 0.740
# Bootstrap #734 ROC area: 0.737
# Bootstrap #735 ROC area: 0.728
# Bootstrap #736 ROC area: 0.730
# Bootstrap #737 ROC area: 0.721
# Bootstrap #738 ROC area: 0.724
# Bootstrap #739 ROC area: 0.713
# Bootstrap #740 ROC area: 0.729
# Bootstrap #741 ROC area: 0.737
# Bootstrap #742 ROC area: 0.744
# Bootstrap #743 ROC area: 0.747
# Bootstrap #744 ROC area: 0.741
# Bootstrap #745 ROC area: 0.726
# Bootstrap #746 ROC area: 0.705
# Bootstrap #747 ROC area: 0.724
# Bootstrap #748 ROC area: 0.723
# Bootstrap #749 ROC area: 0.736
# Bootstrap #750 ROC area: 0.725
# Bootstrap #751 ROC area: 0.732
# Bootstrap #752 ROC area: 0.710
# Bootstrap #753 ROC area: 0.721
# Bootstrap #754 ROC area: 0.744
# Bootstrap #755 ROC area: 0.733
# Bootstrap #756 ROC area: 0.729
# Bootstrap #757 ROC area: 0.742
# Bootstrap #758 ROC area: 0.728
# Bootstrap #759 ROC area: 0.753
# Bootstrap #760 ROC area: 0.735
# Bootstrap #761 ROC area: 0.722
# Bootstrap #762 ROC area: 0.727
# Bootstrap #763 ROC area: 0.721
# Bootstrap #764 ROC area: 0.725
# Bootstrap #765 ROC area: 0.731
# Bootstrap #766 ROC area: 0.734
# Bootstrap #767 ROC area: 0.733
# Bootstrap #768 ROC area: 0.757
# Bootstrap #769 ROC area: 0.736
# Bootstrap #770 ROC area: 0.735
# Bootstrap #771 ROC area: 0.734
# Bootstrap #772 ROC area: 0.733
# Bootstrap #773 ROC area: 0.746
# Bootstrap #774 ROC area: 0.726
# Bootstrap #775 ROC area: 0.736
# Bootstrap #776 ROC area: 0.737
# Bootstrap #777 ROC area: 0.740
# Bootstrap #778 ROC area: 0.745
# Bootstrap #779 ROC area: 0.743
# Bootstrap #780 ROC area: 0.725
# Bootstrap #781 ROC area: 0.741
# Bootstrap #782 ROC area: 0.727
# Bootstrap #783 ROC area: 0.730
# Bootstrap #784 ROC area: 0.737
# Bootstrap #785 ROC area: 0.735
# Bootstrap #786 ROC area: 0.726
# Bootstrap #787 ROC area: 0.731
# Bootstrap #788 ROC area: 0.745
# Bootstrap #789 ROC area: 0.729
# Bootstrap #790 ROC area: 0.734
# Bootstrap #791 ROC area: 0.749
# Bootstrap #792 ROC area: 0.732
# Bootstrap #793 ROC area: 0.727
# Bootstrap #794 ROC area: 0.721
# Bootstrap #795 ROC area: 0.730
# Bootstrap #796 ROC area: 0.748
# Bootstrap #797 ROC area: 0.736
# Bootstrap #798 ROC area: 0.732
# Bootstrap #799 ROC area: 0.724
# Bootstrap #800 ROC area: 0.719
# Bootstrap #801 ROC area: 0.728
# Bootstrap #802 ROC area: 0.747
# Bootstrap #803 ROC area: 0.731
# Bootstrap #804 ROC area: 0.721
# Bootstrap #805 ROC area: 0.738
# Bootstrap #806 ROC area: 0.746
# Bootstrap #807 ROC area: 0.731
# Bootstrap #808 ROC area: 0.734
# Bootstrap #809 ROC area: 0.741
# Bootstrap #810 ROC area: 0.723
# Bootstrap #811 ROC area: 0.743
# Bootstrap #812 ROC area: 0.722
# Bootstrap #813 ROC area: 0.735
# Bootstrap #814 ROC area: 0.736
# Bootstrap #815 ROC area: 0.738
# Bootstrap #816 ROC area: 0.734
# Bootstrap #817 ROC area: 0.722
# Bootstrap #818 ROC area: 0.725
# Bootstrap #819 ROC area: 0.725
# Bootstrap #820 ROC area: 0.716
# Bootstrap #821 ROC area: 0.731
# Bootstrap #822 ROC area: 0.727
# Bootstrap #823 ROC area: 0.718
# Bootstrap #824 ROC area: 0.736
# Bootstrap #825 ROC area: 0.721
# Bootstrap #826 ROC area: 0.733
# Bootstrap #827 ROC area: 0.719
# Bootstrap #828 ROC area: 0.738
# Bootstrap #829 ROC area: 0.730
# Bootstrap #830 ROC area: 0.729
# Bootstrap #831 ROC area: 0.737
# Bootstrap #832 ROC area: 0.747
# Bootstrap #833 ROC area: 0.725
# Bootstrap #834 ROC area: 0.726
# Bootstrap #835 ROC area: 0.713
# Bootstrap #836 ROC area: 0.736
# Bootstrap #837 ROC area: 0.747
# Bootstrap #838 ROC area: 0.734
# Bootstrap #839 ROC area: 0.745
# Bootstrap #840 ROC area: 0.736
# Bootstrap #841 ROC area: 0.741
# Bootstrap #842 ROC area: 0.721
# Bootstrap #843 ROC area: 0.717
# Bootstrap #844 ROC area: 0.723
# Bootstrap #845 ROC area: 0.701
# Bootstrap #846 ROC area: 0.731
# Bootstrap #847 ROC area: 0.730
# Bootstrap #848 ROC area: 0.753
# Bootstrap #849 ROC area: 0.755
# Bootstrap #850 ROC area: 0.745
# Bootstrap #851 ROC area: 0.732
# Bootstrap #852 ROC area: 0.727
# Bootstrap #853 ROC area: 0.737
# Bootstrap #854 ROC area: 0.732
# Bootstrap #855 ROC area: 0.724
# Bootstrap #856 ROC area: 0.740
# Bootstrap #857 ROC area: 0.743
# Bootstrap #858 ROC area: 0.733
# Bootstrap #859 ROC area: 0.719
# Bootstrap #860 ROC area: 0.716
# Bootstrap #861 ROC area: 0.717
# Bootstrap #862 ROC area: 0.724
# Bootstrap #863 ROC area: 0.742
# Bootstrap #864 ROC area: 0.734
# Bootstrap #865 ROC area: 0.730
# Bootstrap #866 ROC area: 0.732
# Bootstrap #867 ROC area: 0.720
# Bootstrap #868 ROC area: 0.722
# Bootstrap #869 ROC area: 0.731
# Bootstrap #870 ROC area: 0.729
# Bootstrap #871 ROC area: 0.741
# Bootstrap #872 ROC area: 0.747
# Bootstrap #873 ROC area: 0.741
# Bootstrap #874 ROC area: 0.725
# Bootstrap #875 ROC area: 0.737
# Bootstrap #876 ROC area: 0.748
# Bootstrap #877 ROC area: 0.745
# Bootstrap #878 ROC area: 0.723
# Bootstrap #879 ROC area: 0.738
# Bootstrap #880 ROC area: 0.721
# Bootstrap #881 ROC area: 0.719
# Bootstrap #882 ROC area: 0.737
# Bootstrap #883 ROC area: 0.724
# Bootstrap #884 ROC area: 0.742
# Bootstrap #885 ROC area: 0.734
# Bootstrap #886 ROC area: 0.715
# Bootstrap #887 ROC area: 0.733
# Bootstrap #888 ROC area: 0.732
# Bootstrap #889 ROC area: 0.776
# Bootstrap #890 ROC area: 0.719
# Bootstrap #891 ROC area: 0.740
# Bootstrap #892 ROC area: 0.730
# Bootstrap #893 ROC area: 0.732
# Bootstrap #894 ROC area: 0.727
# Bootstrap #895 ROC area: 0.733
# Bootstrap #896 ROC area: 0.728
# Bootstrap #897 ROC area: 0.734
# Bootstrap #898 ROC area: 0.740
# Bootstrap #899 ROC area: 0.718
# Bootstrap #900 ROC area: 0.743
# Bootstrap #901 ROC area: 0.747
# Bootstrap #902 ROC area: 0.733
# Bootstrap #903 ROC area: 0.709
# Bootstrap #904 ROC area: 0.750
# Bootstrap #905 ROC area: 0.722
# Bootstrap #906 ROC area: 0.735
# Bootstrap #907 ROC area: 0.719
# Bootstrap #908 ROC area: 0.731
# Bootstrap #909 ROC area: 0.733
# Bootstrap #910 ROC area: 0.727
# Bootstrap #911 ROC area: 0.743
# Bootstrap #912 ROC area: 0.739
# Bootstrap #913 ROC area: 0.727
# Bootstrap #914 ROC area: 0.734
# Bootstrap #915 ROC area: 0.732
# Bootstrap #916 ROC area: 0.729
# Bootstrap #917 ROC area: 0.741
# Bootstrap #918 ROC area: 0.736
# Bootstrap #919 ROC area: 0.738
# Bootstrap #920 ROC area: 0.732
# Bootstrap #921 ROC area: 0.744
# Bootstrap #922 ROC area: 0.722
# Bootstrap #923 ROC area: 0.738
# Bootstrap #924 ROC area: 0.734
# Bootstrap #925 ROC area: 0.732
# Bootstrap #926 ROC area: 0.732
# Bootstrap #927 ROC area: 0.740
# Bootstrap #928 ROC area: 0.724
# Bootstrap #929 ROC area: 0.749
# Bootstrap #930 ROC area: 0.717
# Bootstrap #931 ROC area: 0.734
# Bootstrap #932 ROC area: 0.739
# Bootstrap #933 ROC area: 0.740
# Bootstrap #934 ROC area: 0.727
# Bootstrap #935 ROC area: 0.732
# Bootstrap #936 ROC area: 0.726
# Bootstrap #937 ROC area: 0.740
# Bootstrap #938 ROC area: 0.744
# Bootstrap #939 ROC area: 0.748
# Bootstrap #940 ROC area: 0.718
# Bootstrap #941 ROC area: 0.737
# Bootstrap #942 ROC area: 0.733
# Bootstrap #943 ROC area: 0.744
# Bootstrap #944 ROC area: 0.749
# Bootstrap #945 ROC area: 0.715
# Bootstrap #946 ROC area: 0.720
# Bootstrap #947 ROC area: 0.731
# Bootstrap #948 ROC area: 0.733
# Bootstrap #949 ROC area: 0.742
# Bootstrap #950 ROC area: 0.738
# Bootstrap #951 ROC area: 0.731
# Bootstrap #952 ROC area: 0.714
# Bootstrap #953 ROC area: 0.750
# Bootstrap #954 ROC area: 0.745
# Bootstrap #955 ROC area: 0.741
# Bootstrap #956 ROC area: 0.723
# Bootstrap #957 ROC area: 0.735
# Bootstrap #958 ROC area: 0.745
# Bootstrap #959 ROC area: 0.712
# Bootstrap #960 ROC area: 0.732
# Bootstrap #961 ROC area: 0.737
# Bootstrap #962 ROC area: 0.734
# Bootstrap #963 ROC area: 0.735
# Bootstrap #964 ROC area: 0.719
# Bootstrap #965 ROC area: 0.743
# Bootstrap #966 ROC area: 0.728
# Bootstrap #967 ROC area: 0.748
# Bootstrap #968 ROC area: 0.738
# Bootstrap #969 ROC area: 0.743
# Bootstrap #970 ROC area: 0.740
# Bootstrap #971 ROC area: 0.714
# Bootstrap #972 ROC area: 0.732
# Bootstrap #973 ROC area: 0.739
# Bootstrap #974 ROC area: 0.716
# Bootstrap #975 ROC area: 0.733
# Bootstrap #976 ROC area: 0.734
# Bootstrap #977 ROC area: 0.738
# Bootstrap #978 ROC area: 0.738
# Bootstrap #979 ROC area: 0.738
# Bootstrap #980 ROC area: 0.727
# Bootstrap #981 ROC area: 0.719
# Bootstrap #982 ROC area: 0.722
# Bootstrap #983 ROC area: 0.742
# Bootstrap #984 ROC area: 0.720
# Bootstrap #985 ROC area: 0.754
# Bootstrap #986 ROC area: 0.747
# Bootstrap #987 ROC area: 0.737
# Bootstrap #988 ROC area: 0.729
# Bootstrap #989 ROC area: 0.742
# Bootstrap #990 ROC area: 0.748
# Bootstrap #991 ROC area: 0.727
# Bootstrap #992 ROC area: 0.743
# Bootstrap #993 ROC area: 0.722
# Bootstrap #994 ROC area: 0.746
# Bootstrap #995 ROC area: 0.721
# Bootstrap #996 ROC area: 0.751
# Bootstrap #997 ROC area: 0.739
# Bootstrap #998 ROC area: 0.733
# Bootstrap #999 ROC area: 0.747
# Bootstrap #1000 ROC area: 0.750

# %%
sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

confidence_lower = sorted_scores[int(0.05 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.95 * len(sorted_scores))]
print("Confidence interval for the score on White patients: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Confidence interval for the score on White patients: [0.717 - 0.75]

# %% [markdown]
# #### For Black Patient Set

# %%
y_pred_black = model.predict_proba(xTestBlack)
print("Original ROC area: {:0.3f}".format(roc_auc_score(yTestBlack, y_pred_black[:,1])))
# Out:
# Original ROC area: 0.758

# %%
n_bootstraps = 1000
rng_seed = 42  # control reproducibility
bootstrapped_scores = []

rng = np.random.RandomState(rng_seed)
for i in range(n_bootstraps):
    indices = rng.randint(0, len(y_pred_black), len(y_pred_black))

    score = roc_auc_score(yTestBlack.to_numpy()[indices], y_pred_black[indices, 1])
    bootstrapped_scores.append(score)
    print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))
# Out:
# Bootstrap #1 ROC area: 0.876
# Bootstrap #2 ROC area: 0.729
# Bootstrap #3 ROC area: 0.732
# Bootstrap #4 ROC area: 0.700
# Bootstrap #5 ROC area: 0.721
# Bootstrap #6 ROC area: 0.789
# Bootstrap #7 ROC area: 0.761
# Bootstrap #8 ROC area: 0.757
# Bootstrap #9 ROC area: 0.736
# Bootstrap #10 ROC area: 0.764
# Bootstrap #11 ROC area: 0.756
# Bootstrap #12 ROC area: 0.793
# Bootstrap #13 ROC area: 0.750
# Bootstrap #14 ROC area: 0.785
# Bootstrap #15 ROC area: 0.745
# Bootstrap #16 ROC area: 0.798
# Bootstrap #17 ROC area: 0.803
# Bootstrap #18 ROC area: 0.756
# Bootstrap #19 ROC area: 0.744
# Bootstrap #20 ROC area: 0.703
# Bootstrap #21 ROC area: 0.721
# Bootstrap #22 ROC area: 0.769
# Bootstrap #23 ROC area: 0.744
# Bootstrap #24 ROC area: 0.736
# Bootstrap #25 ROC area: 0.785
# Bootstrap #26 ROC area: 0.801
# Bootstrap #27 ROC area: 0.732
# Bootstrap #28 ROC area: 0.750
# Bootstrap #29 ROC area: 0.766
# Bootstrap #30 ROC area: 0.756
# Bootstrap #31 ROC area: 0.792
# Bootstrap #32 ROC area: 0.728
# Bootstrap #33 ROC area: 0.700
# Bootstrap #34 ROC area: 0.683
# Bootstrap #35 ROC area: 0.745
# Bootstrap #36 ROC area: 0.766
# Bootstrap #37 ROC area: 0.755
# Bootstrap #38 ROC area: 0.771
# Bootstrap #39 ROC area: 0.741
# Bootstrap #40 ROC area: 0.749
# Bootstrap #41 ROC area: 0.767
# Bootstrap #42 ROC area: 0.744
# Bootstrap #43 ROC area: 0.759
# Bootstrap #44 ROC area: 0.707
# Bootstrap #45 ROC area: 0.791
# Bootstrap #46 ROC area: 0.777
# Bootstrap #47 ROC area: 0.794
# Bootstrap #48 ROC area: 0.783
# Bootstrap #49 ROC area: 0.778
# Bootstrap #50 ROC area: 0.742
# Bootstrap #51 ROC area: 0.763
# Bootstrap #52 ROC area: 0.753
# Bootstrap #53 ROC area: 0.714
# Bootstrap #54 ROC area: 0.779
# Bootstrap #55 ROC area: 0.787
# Bootstrap #56 ROC area: 0.715
# Bootstrap #57 ROC area: 0.801
# Bootstrap #58 ROC area: 0.773
# Bootstrap #59 ROC area: 0.751
# Bootstrap #60 ROC area: 0.757
# Bootstrap #61 ROC area: 0.821
# Bootstrap #62 ROC area: 0.797
# Bootstrap #63 ROC area: 0.738
# Bootstrap #64 ROC area: 0.797
# Bootstrap #65 ROC area: 0.721
# Bootstrap #66 ROC area: 0.713
# Bootstrap #67 ROC area: 0.745
# Bootstrap #68 ROC area: 0.776
# Bootstrap #69 ROC area: 0.754
# Bootstrap #70 ROC area: 0.794
# Bootstrap #71 ROC area: 0.781
# Bootstrap #72 ROC area: 0.788
# Bootstrap #73 ROC area: 0.714
# Bootstrap #74 ROC area: 0.723
# Bootstrap #75 ROC area: 0.750
# Bootstrap #76 ROC area: 0.748
# Bootstrap #77 ROC area: 0.761
# Bootstrap #78 ROC area: 0.697
# Bootstrap #79 ROC area: 0.759
# Bootstrap #80 ROC area: 0.752
# Bootstrap #81 ROC area: 0.783
# Bootstrap #82 ROC area: 0.766
# Bootstrap #83 ROC area: 0.749
# Bootstrap #84 ROC area: 0.745
# Bootstrap #85 ROC area: 0.750
# Bootstrap #86 ROC area: 0.777
# Bootstrap #87 ROC area: 0.795
# Bootstrap #88 ROC area: 0.726
# Bootstrap #89 ROC area: 0.758
# Bootstrap #90 ROC area: 0.755
# Bootstrap #91 ROC area: 0.712
# Bootstrap #92 ROC area: 0.770
# Bootstrap #93 ROC area: 0.771
# Bootstrap #94 ROC area: 0.715
# Bootstrap #95 ROC area: 0.721
# Bootstrap #96 ROC area: 0.796
# Bootstrap #97 ROC area: 0.712
# Bootstrap #98 ROC area: 0.730
# Bootstrap #99 ROC area: 0.752
# Bootstrap #100 ROC area: 0.834
# Bootstrap #101 ROC area: 0.798
# Bootstrap #102 ROC area: 0.700
# Bootstrap #103 ROC area: 0.775
# Bootstrap #104 ROC area: 0.762
# Bootstrap #105 ROC area: 0.818
# Bootstrap #106 ROC area: 0.751
# Bootstrap #107 ROC area: 0.752
# Bootstrap #108 ROC area: 0.802
# Bootstrap #109 ROC area: 0.784
# Bootstrap #110 ROC area: 0.740
# Bootstrap #111 ROC area: 0.753
# Bootstrap #112 ROC area: 0.809
# Bootstrap #113 ROC area: 0.760
# Bootstrap #114 ROC area: 0.782
# Bootstrap #115 ROC area: 0.763
# Bootstrap #116 ROC area: 0.726
# Bootstrap #117 ROC area: 0.761
# Bootstrap #118 ROC area: 0.786
# Bootstrap #119 ROC area: 0.749
# Bootstrap #120 ROC area: 0.750
# Bootstrap #121 ROC area: 0.733
# Bootstrap #122 ROC area: 0.737
# Bootstrap #123 ROC area: 0.747
# Bootstrap #124 ROC area: 0.772
# Bootstrap #125 ROC area: 0.723
# Bootstrap #126 ROC area: 0.780
# Bootstrap #127 ROC area: 0.757
# Bootstrap #128 ROC area: 0.757
# Bootstrap #129 ROC area: 0.758
# Bootstrap #130 ROC area: 0.806
# Bootstrap #131 ROC area: 0.752
# Bootstrap #132 ROC area: 0.799
# Bootstrap #133 ROC area: 0.776
# Bootstrap #134 ROC area: 0.759
# Bootstrap #135 ROC area: 0.783
# Bootstrap #136 ROC area: 0.744
# Bootstrap #137 ROC area: 0.777
# Bootstrap #138 ROC area: 0.736
# Bootstrap #139 ROC area: 0.756
# Bootstrap #140 ROC area: 0.687
# Bootstrap #141 ROC area: 0.733
# Bootstrap #142 ROC area: 0.751
# Bootstrap #143 ROC area: 0.753
# Bootstrap #144 ROC area: 0.767
# Bootstrap #145 ROC area: 0.800
# Bootstrap #146 ROC area: 0.771
# Bootstrap #147 ROC area: 0.792
# Bootstrap #148 ROC area: 0.746
# Bootstrap #149 ROC area: 0.729
# Bootstrap #150 ROC area: 0.733
# Bootstrap #151 ROC area: 0.818
# Bootstrap #152 ROC area: 0.756
# Bootstrap #153 ROC area: 0.747
# Bootstrap #154 ROC area: 0.782
# Bootstrap #155 ROC area: 0.738
# Bootstrap #156 ROC area: 0.824
# Bootstrap #157 ROC area: 0.718
# Bootstrap #158 ROC area: 0.763
# Bootstrap #159 ROC area: 0.765
# Bootstrap #160 ROC area: 0.731
# Bootstrap #161 ROC area: 0.755
# Bootstrap #162 ROC area: 0.833
# Bootstrap #163 ROC area: 0.733
# Bootstrap #164 ROC area: 0.758
# Bootstrap #165 ROC area: 0.747
# Bootstrap #166 ROC area: 0.768
# Bootstrap #167 ROC area: 0.741
# Bootstrap #168 ROC area: 0.787
# Bootstrap #169 ROC area: 0.758
# Bootstrap #170 ROC area: 0.716
# Bootstrap #171 ROC area: 0.767
# Bootstrap #172 ROC area: 0.742
# Bootstrap #173 ROC area: 0.761
# Bootstrap #174 ROC area: 0.788
# Bootstrap #175 ROC area: 0.728
# Bootstrap #176 ROC area: 0.732
# Bootstrap #177 ROC area: 0.726
# Bootstrap #178 ROC area: 0.745
# Bootstrap #179 ROC area: 0.821
# Bootstrap #180 ROC area: 0.775
# Bootstrap #181 ROC area: 0.783
# Bootstrap #182 ROC area: 0.767
# Bootstrap #183 ROC area: 0.743
# Bootstrap #184 ROC area: 0.727
# Bootstrap #185 ROC area: 0.815
# Bootstrap #186 ROC area: 0.654
# Bootstrap #187 ROC area: 0.787
# Bootstrap #188 ROC area: 0.786
# Bootstrap #189 ROC area: 0.747
# Bootstrap #190 ROC area: 0.707
# Bootstrap #191 ROC area: 0.720
# Bootstrap #192 ROC area: 0.756
# Bootstrap #193 ROC area: 0.734
# Bootstrap #194 ROC area: 0.776
# Bootstrap #195 ROC area: 0.780
# Bootstrap #196 ROC area: 0.778
# Bootstrap #197 ROC area: 0.725
# Bootstrap #198 ROC area: 0.805
# Bootstrap #199 ROC area: 0.755
# Bootstrap #200 ROC area: 0.786
# Bootstrap #201 ROC area: 0.724
# Bootstrap #202 ROC area: 0.698
# Bootstrap #203 ROC area: 0.791
# Bootstrap #204 ROC area: 0.765
# Bootstrap #205 ROC area: 0.741
# Bootstrap #206 ROC area: 0.805
# Bootstrap #207 ROC area: 0.707
# Bootstrap #208 ROC area: 0.745
# Bootstrap #209 ROC area: 0.756
# Bootstrap #210 ROC area: 0.759
# Bootstrap #211 ROC area: 0.791
# Bootstrap #212 ROC area: 0.763
# Bootstrap #213 ROC area: 0.770
# Bootstrap #214 ROC area: 0.679
# Bootstrap #215 ROC area: 0.717
# Bootstrap #216 ROC area: 0.692
# Bootstrap #217 ROC area: 0.757
# Bootstrap #218 ROC area: 0.758
# Bootstrap #219 ROC area: 0.721
# Bootstrap #220 ROC area: 0.743
# Bootstrap #221 ROC area: 0.776
# Bootstrap #222 ROC area: 0.687
# Bootstrap #223 ROC area: 0.798
# Bootstrap #224 ROC area: 0.762
# Bootstrap #225 ROC area: 0.729
# Bootstrap #226 ROC area: 0.724
# Bootstrap #227 ROC area: 0.724
# Bootstrap #228 ROC area: 0.841
# Bootstrap #229 ROC area: 0.773
# Bootstrap #230 ROC area: 0.756
# Bootstrap #231 ROC area: 0.737
# Bootstrap #232 ROC area: 0.833
# Bootstrap #233 ROC area: 0.750
# Bootstrap #234 ROC area: 0.777
# Bootstrap #235 ROC area: 0.796
# Bootstrap #236 ROC area: 0.697
# Bootstrap #237 ROC area: 0.788
# Bootstrap #238 ROC area: 0.777
# Bootstrap #239 ROC area: 0.763
# Bootstrap #240 ROC area: 0.727
# Bootstrap #241 ROC area: 0.766
# Bootstrap #242 ROC area: 0.817
# Bootstrap #243 ROC area: 0.777
# Bootstrap #244 ROC area: 0.771
# Bootstrap #245 ROC area: 0.747
# Bootstrap #246 ROC area: 0.747
# Bootstrap #247 ROC area: 0.710
# Bootstrap #248 ROC area: 0.715
# Bootstrap #249 ROC area: 0.772
# Bootstrap #250 ROC area: 0.752
# Bootstrap #251 ROC area: 0.716
# Bootstrap #252 ROC area: 0.762
# Bootstrap #253 ROC area: 0.699
# Bootstrap #254 ROC area: 0.765
# Bootstrap #255 ROC area: 0.800
# Bootstrap #256 ROC area: 0.826
# Bootstrap #257 ROC area: 0.775
# Bootstrap #258 ROC area: 0.728
# Bootstrap #259 ROC area: 0.715
# Bootstrap #260 ROC area: 0.729
# Bootstrap #261 ROC area: 0.770
# Bootstrap #262 ROC area: 0.743
# Bootstrap #263 ROC area: 0.771
# Bootstrap #264 ROC area: 0.737
# Bootstrap #265 ROC area: 0.778
# Bootstrap #266 ROC area: 0.782
# Bootstrap #267 ROC area: 0.752
# Bootstrap #268 ROC area: 0.725
# Bootstrap #269 ROC area: 0.767
# Bootstrap #270 ROC area: 0.744
# Bootstrap #271 ROC area: 0.736
# Bootstrap #272 ROC area: 0.823
# Bootstrap #273 ROC area: 0.790
# Bootstrap #274 ROC area: 0.754
# Bootstrap #275 ROC area: 0.702
# Bootstrap #276 ROC area: 0.748
# Bootstrap #277 ROC area: 0.798
# Bootstrap #278 ROC area: 0.737
# Bootstrap #279 ROC area: 0.706
# Bootstrap #280 ROC area: 0.790
# Bootstrap #281 ROC area: 0.747
# Bootstrap #282 ROC area: 0.699
# Bootstrap #283 ROC area: 0.802
# Bootstrap #284 ROC area: 0.756
# Bootstrap #285 ROC area: 0.751
# Bootstrap #286 ROC area: 0.707
# Bootstrap #287 ROC area: 0.781
# Bootstrap #288 ROC area: 0.764
# Bootstrap #289 ROC area: 0.760
# Bootstrap #290 ROC area: 0.766
# Bootstrap #291 ROC area: 0.774
# Bootstrap #292 ROC area: 0.833
# Bootstrap #293 ROC area: 0.789
# Bootstrap #294 ROC area: 0.762
# Bootstrap #295 ROC area: 0.796
# Bootstrap #296 ROC area: 0.737
# Bootstrap #297 ROC area: 0.775
# Bootstrap #298 ROC area: 0.766
# Bootstrap #299 ROC area: 0.806
# Bootstrap #300 ROC area: 0.799
# Bootstrap #301 ROC area: 0.742
# Bootstrap #302 ROC area: 0.795
# Bootstrap #303 ROC area: 0.782
# Bootstrap #304 ROC area: 0.807
# Bootstrap #305 ROC area: 0.796
# Bootstrap #306 ROC area: 0.793
# Bootstrap #307 ROC area: 0.798
# Bootstrap #308 ROC area: 0.790
# Bootstrap #309 ROC area: 0.748
# Bootstrap #310 ROC area: 0.765
# Bootstrap #311 ROC area: 0.761
# Bootstrap #312 ROC area: 0.795
# Bootstrap #313 ROC area: 0.724
# Bootstrap #314 ROC area: 0.778
# Bootstrap #315 ROC area: 0.786
# Bootstrap #316 ROC area: 0.743
# Bootstrap #317 ROC area: 0.792
# Bootstrap #318 ROC area: 0.698
# Bootstrap #319 ROC area: 0.771
# Bootstrap #320 ROC area: 0.802
# Bootstrap #321 ROC area: 0.776
# Bootstrap #322 ROC area: 0.821
# Bootstrap #323 ROC area: 0.783
# Bootstrap #324 ROC area: 0.822
# Bootstrap #325 ROC area: 0.774
# Bootstrap #326 ROC area: 0.783
# Bootstrap #327 ROC area: 0.833
# Bootstrap #328 ROC area: 0.791
# Bootstrap #329 ROC area: 0.810
# Bootstrap #330 ROC area: 0.726
# Bootstrap #331 ROC area: 0.712
# Bootstrap #332 ROC area: 0.714
# Bootstrap #333 ROC area: 0.742
# Bootstrap #334 ROC area: 0.789
# Bootstrap #335 ROC area: 0.731
# Bootstrap #336 ROC area: 0.716
# Bootstrap #337 ROC area: 0.799
# Bootstrap #338 ROC area: 0.723
# Bootstrap #339 ROC area: 0.750
# Bootstrap #340 ROC area: 0.688
# Bootstrap #341 ROC area: 0.723
# Bootstrap #342 ROC area: 0.776
# Bootstrap #343 ROC area: 0.768
# Bootstrap #344 ROC area: 0.777
# Bootstrap #345 ROC area: 0.718
# Bootstrap #346 ROC area: 0.757
# Bootstrap #347 ROC area: 0.777
# Bootstrap #348 ROC area: 0.813
# Bootstrap #349 ROC area: 0.753
# Bootstrap #350 ROC area: 0.721
# Bootstrap #351 ROC area: 0.719
# Bootstrap #352 ROC area: 0.734
# Bootstrap #353 ROC area: 0.765
# Bootstrap #354 ROC area: 0.704
# Bootstrap #355 ROC area: 0.779
# Bootstrap #356 ROC area: 0.755
# Bootstrap #357 ROC area: 0.664
# Bootstrap #358 ROC area: 0.781
# Bootstrap #359 ROC area: 0.809
# Bootstrap #360 ROC area: 0.781
# Bootstrap #361 ROC area: 0.719
# Bootstrap #362 ROC area: 0.777
# Bootstrap #363 ROC area: 0.769
# Bootstrap #364 ROC area: 0.746
# Bootstrap #365 ROC area: 0.814
# Bootstrap #366 ROC area: 0.795
# Bootstrap #367 ROC area: 0.727
# Bootstrap #368 ROC area: 0.709
# Bootstrap #369 ROC area: 0.751
# Bootstrap #370 ROC area: 0.778
# Bootstrap #371 ROC area: 0.714
# Bootstrap #372 ROC area: 0.785
# Bootstrap #373 ROC area: 0.756
# Bootstrap #374 ROC area: 0.699
# Bootstrap #375 ROC area: 0.788
# Bootstrap #376 ROC area: 0.701
# Bootstrap #377 ROC area: 0.771
# Bootstrap #378 ROC area: 0.723
# Bootstrap #379 ROC area: 0.791
# Bootstrap #380 ROC area: 0.787
# Bootstrap #381 ROC area: 0.766
# Bootstrap #382 ROC area: 0.809
# Bootstrap #383 ROC area: 0.819
# Bootstrap #384 ROC area: 0.766
# Bootstrap #385 ROC area: 0.713
# Bootstrap #386 ROC area: 0.738
# Bootstrap #387 ROC area: 0.747
# Bootstrap #388 ROC area: 0.756
# Bootstrap #389 ROC area: 0.711
# Bootstrap #390 ROC area: 0.782
# Bootstrap #391 ROC area: 0.772
# Bootstrap #392 ROC area: 0.693
# Bootstrap #393 ROC area: 0.747
# Bootstrap #394 ROC area: 0.782
# Bootstrap #395 ROC area: 0.716
# Bootstrap #396 ROC area: 0.709
# Bootstrap #397 ROC area: 0.788
# Bootstrap #398 ROC area: 0.725
# Bootstrap #399 ROC area: 0.816
# Bootstrap #400 ROC area: 0.802
# Bootstrap #401 ROC area: 0.806
# Bootstrap #402 ROC area: 0.747
# Bootstrap #403 ROC area: 0.800
# Bootstrap #404 ROC area: 0.823
# Bootstrap #405 ROC area: 0.717
# Bootstrap #406 ROC area: 0.774
# Bootstrap #407 ROC area: 0.795
# Bootstrap #408 ROC area: 0.693
# Bootstrap #409 ROC area: 0.808
# Bootstrap #410 ROC area: 0.722
# Bootstrap #411 ROC area: 0.715
# Bootstrap #412 ROC area: 0.748
# Bootstrap #413 ROC area: 0.760
# Bootstrap #414 ROC area: 0.700
# Bootstrap #415 ROC area: 0.767
# Bootstrap #416 ROC area: 0.688
# Bootstrap #417 ROC area: 0.810
# Bootstrap #418 ROC area: 0.787
# Bootstrap #419 ROC area: 0.754
# Bootstrap #420 ROC area: 0.746
# Bootstrap #421 ROC area: 0.766
# Bootstrap #422 ROC area: 0.743
# Bootstrap #423 ROC area: 0.736
# Bootstrap #424 ROC area: 0.788
# Bootstrap #425 ROC area: 0.774
# Bootstrap #426 ROC area: 0.802
# Bootstrap #427 ROC area: 0.726
# Bootstrap #428 ROC area: 0.802
# Bootstrap #429 ROC area: 0.735
# Bootstrap #430 ROC area: 0.767
# Bootstrap #431 ROC area: 0.756
# Bootstrap #432 ROC area: 0.765
# Bootstrap #433 ROC area: 0.777
# Bootstrap #434 ROC area: 0.794
# Bootstrap #435 ROC area: 0.717
# Bootstrap #436 ROC area: 0.771
# Bootstrap #437 ROC area: 0.771
# Bootstrap #438 ROC area: 0.763
# Bootstrap #439 ROC area: 0.743
# Bootstrap #440 ROC area: 0.739
# Bootstrap #441 ROC area: 0.804
# Bootstrap #442 ROC area: 0.691
# Bootstrap #443 ROC area: 0.747
# Bootstrap #444 ROC area: 0.723
# Bootstrap #445 ROC area: 0.743
# Bootstrap #446 ROC area: 0.779
# Bootstrap #447 ROC area: 0.762
# Bootstrap #448 ROC area: 0.763
# Bootstrap #449 ROC area: 0.748
# Bootstrap #450 ROC area: 0.765
# Bootstrap #451 ROC area: 0.763
# Bootstrap #452 ROC area: 0.814
# Bootstrap #453 ROC area: 0.784
# Bootstrap #454 ROC area: 0.735
# Bootstrap #455 ROC area: 0.707
# Bootstrap #456 ROC area: 0.780
# Bootstrap #457 ROC area: 0.730
# Bootstrap #458 ROC area: 0.796
# Bootstrap #459 ROC area: 0.733
# Bootstrap #460 ROC area: 0.782
# Bootstrap #461 ROC area: 0.787
# Bootstrap #462 ROC area: 0.777
# Bootstrap #463 ROC area: 0.743
# Bootstrap #464 ROC area: 0.841
# Bootstrap #465 ROC area: 0.792
# Bootstrap #466 ROC area: 0.719
# Bootstrap #467 ROC area: 0.754
# Bootstrap #468 ROC area: 0.721
# Bootstrap #469 ROC area: 0.721
# Bootstrap #470 ROC area: 0.783
# Bootstrap #471 ROC area: 0.732
# Bootstrap #472 ROC area: 0.753
# Bootstrap #473 ROC area: 0.774
# Bootstrap #474 ROC area: 0.755
# Bootstrap #475 ROC area: 0.778
# Bootstrap #476 ROC area: 0.774
# Bootstrap #477 ROC area: 0.784
# Bootstrap #478 ROC area: 0.775
# Bootstrap #479 ROC area: 0.785
# Bootstrap #480 ROC area: 0.754
# Bootstrap #481 ROC area: 0.821
# Bootstrap #482 ROC area: 0.771
# Bootstrap #483 ROC area: 0.782
# Bootstrap #484 ROC area: 0.771
# Bootstrap #485 ROC area: 0.738
# Bootstrap #486 ROC area: 0.784
# Bootstrap #487 ROC area: 0.734
# Bootstrap #488 ROC area: 0.800
# Bootstrap #489 ROC area: 0.711
# Bootstrap #490 ROC area: 0.745
# Bootstrap #491 ROC area: 0.724
# Bootstrap #492 ROC area: 0.694
# Bootstrap #493 ROC area: 0.763
# Bootstrap #494 ROC area: 0.745
# Bootstrap #495 ROC area: 0.708
# Bootstrap #496 ROC area: 0.797
# Bootstrap #497 ROC area: 0.790
# Bootstrap #498 ROC area: 0.754
# Bootstrap #499 ROC area: 0.782
# Bootstrap #500 ROC area: 0.770
# Bootstrap #501 ROC area: 0.749
# Bootstrap #502 ROC area: 0.767
# Bootstrap #503 ROC area: 0.757
# Bootstrap #504 ROC area: 0.696
# Bootstrap #505 ROC area: 0.765
# Bootstrap #506 ROC area: 0.660
# Bootstrap #507 ROC area: 0.749
# Bootstrap #508 ROC area: 0.707
# Bootstrap #509 ROC area: 0.774
# Bootstrap #510 ROC area: 0.741
# Bootstrap #511 ROC area: 0.743
# Bootstrap #512 ROC area: 0.750
# Bootstrap #513 ROC area: 0.703
# Bootstrap #514 ROC area: 0.717
# Bootstrap #515 ROC area: 0.807
# Bootstrap #516 ROC area: 0.778
# Bootstrap #517 ROC area: 0.834
# Bootstrap #518 ROC area: 0.735
# Bootstrap #519 ROC area: 0.779
# Bootstrap #520 ROC area: 0.782
# Bootstrap #521 ROC area: 0.764
# Bootstrap #522 ROC area: 0.728
# Bootstrap #523 ROC area: 0.731
# Bootstrap #524 ROC area: 0.790
# Bootstrap #525 ROC area: 0.715
# Bootstrap #526 ROC area: 0.779
# Bootstrap #527 ROC area: 0.764
# Bootstrap #528 ROC area: 0.691
# Bootstrap #529 ROC area: 0.729
# Bootstrap #530 ROC area: 0.781
# Bootstrap #531 ROC area: 0.818
# Bootstrap #532 ROC area: 0.757
# Bootstrap #533 ROC area: 0.743
# Bootstrap #534 ROC area: 0.749
# Bootstrap #535 ROC area: 0.762
# Bootstrap #536 ROC area: 0.755
# Bootstrap #537 ROC area: 0.733
# Bootstrap #538 ROC area: 0.787
# Bootstrap #539 ROC area: 0.674
# Bootstrap #540 ROC area: 0.771
# Bootstrap #541 ROC area: 0.751
# Bootstrap #542 ROC area: 0.791
# Bootstrap #543 ROC area: 0.764
# Bootstrap #544 ROC area: 0.713
# Bootstrap #545 ROC area: 0.771
# Bootstrap #546 ROC area: 0.781
# Bootstrap #547 ROC area: 0.701
# Bootstrap #548 ROC area: 0.687
# Bootstrap #549 ROC area: 0.761
# Bootstrap #550 ROC area: 0.784
# Bootstrap #551 ROC area: 0.777
# Bootstrap #552 ROC area: 0.742
# Bootstrap #553 ROC area: 0.762
# Bootstrap #554 ROC area: 0.792
# Bootstrap #555 ROC area: 0.733
# Bootstrap #556 ROC area: 0.724
# Bootstrap #557 ROC area: 0.783
# Bootstrap #558 ROC area: 0.743
# Bootstrap #559 ROC area: 0.745
# Bootstrap #560 ROC area: 0.761
# Bootstrap #561 ROC area: 0.808
# Bootstrap #562 ROC area: 0.756
# Bootstrap #563 ROC area: 0.691
# Bootstrap #564 ROC area: 0.793
# Bootstrap #565 ROC area: 0.780
# Bootstrap #566 ROC area: 0.709
# Bootstrap #567 ROC area: 0.749
# Bootstrap #568 ROC area: 0.777
# Bootstrap #569 ROC area: 0.814
# Bootstrap #570 ROC area: 0.737
# Bootstrap #571 ROC area: 0.758
# Bootstrap #572 ROC area: 0.791
# Bootstrap #573 ROC area: 0.821
# Bootstrap #574 ROC area: 0.776
# Bootstrap #575 ROC area: 0.794
# Bootstrap #576 ROC area: 0.775
# Bootstrap #577 ROC area: 0.760
# Bootstrap #578 ROC area: 0.761
# Bootstrap #579 ROC area: 0.812
# Bootstrap #580 ROC area: 0.735
# Bootstrap #581 ROC area: 0.712
# Bootstrap #582 ROC area: 0.744
# Bootstrap #583 ROC area: 0.689
# Bootstrap #584 ROC area: 0.752
# Bootstrap #585 ROC area: 0.741
# Bootstrap #586 ROC area: 0.654
# Bootstrap #587 ROC area: 0.698
# Bootstrap #588 ROC area: 0.787
# Bootstrap #589 ROC area: 0.734
# Bootstrap #590 ROC area: 0.762
# Bootstrap #591 ROC area: 0.732
# Bootstrap #592 ROC area: 0.808
# Bootstrap #593 ROC area: 0.734
# Bootstrap #594 ROC area: 0.777
# Bootstrap #595 ROC area: 0.671
# Bootstrap #596 ROC area: 0.738
# Bootstrap #597 ROC area: 0.727
# Bootstrap #598 ROC area: 0.715
# Bootstrap #599 ROC area: 0.724
# Bootstrap #600 ROC area: 0.755
# Bootstrap #601 ROC area: 0.744
# Bootstrap #602 ROC area: 0.771
# Bootstrap #603 ROC area: 0.785
# Bootstrap #604 ROC area: 0.747
# Bootstrap #605 ROC area: 0.757
# Bootstrap #606 ROC area: 0.749
# Bootstrap #607 ROC area: 0.668
# Bootstrap #608 ROC area: 0.722
# Bootstrap #609 ROC area: 0.741
# Bootstrap #610 ROC area: 0.625
# Bootstrap #611 ROC area: 0.769
# Bootstrap #612 ROC area: 0.749
# Bootstrap #613 ROC area: 0.790
# Bootstrap #614 ROC area: 0.755
# Bootstrap #615 ROC area: 0.766
# Bootstrap #616 ROC area: 0.654
# Bootstrap #617 ROC area: 0.773
# Bootstrap #618 ROC area: 0.778
# Bootstrap #619 ROC area: 0.755
# Bootstrap #620 ROC area: 0.796
# Bootstrap #621 ROC area: 0.760
# Bootstrap #622 ROC area: 0.827
# Bootstrap #623 ROC area: 0.731
# Bootstrap #624 ROC area: 0.848
# Bootstrap #625 ROC area: 0.756
# Bootstrap #626 ROC area: 0.742
# Bootstrap #627 ROC area: 0.762
# Bootstrap #628 ROC area: 0.749
# Bootstrap #629 ROC area: 0.745
# Bootstrap #630 ROC area: 0.712
# Bootstrap #631 ROC area: 0.782
# Bootstrap #632 ROC area: 0.755
# Bootstrap #633 ROC area: 0.764
# Bootstrap #634 ROC area: 0.785
# Bootstrap #635 ROC area: 0.785
# Bootstrap #636 ROC area: 0.742
# Bootstrap #637 ROC area: 0.764
# Bootstrap #638 ROC area: 0.780
# Bootstrap #639 ROC area: 0.804
# Bootstrap #640 ROC area: 0.782
# Bootstrap #641 ROC area: 0.775
# Bootstrap #642 ROC area: 0.781
# Bootstrap #643 ROC area: 0.692
# Bootstrap #644 ROC area: 0.711
# Bootstrap #645 ROC area: 0.809
# Bootstrap #646 ROC area: 0.796
# Bootstrap #647 ROC area: 0.776
# Bootstrap #648 ROC area: 0.714
# Bootstrap #649 ROC area: 0.828
# Bootstrap #650 ROC area: 0.779
# Bootstrap #651 ROC area: 0.719
# Bootstrap #652 ROC area: 0.740
# Bootstrap #653 ROC area: 0.700
# Bootstrap #654 ROC area: 0.705
# Bootstrap #655 ROC area: 0.740
# Bootstrap #656 ROC area: 0.740
# Bootstrap #657 ROC area: 0.785
# Bootstrap #658 ROC area: 0.773
# Bootstrap #659 ROC area: 0.739
# Bootstrap #660 ROC area: 0.784
# Bootstrap #661 ROC area: 0.791
# Bootstrap #662 ROC area: 0.718
# Bootstrap #663 ROC area: 0.784
# Bootstrap #664 ROC area: 0.740
# Bootstrap #665 ROC area: 0.817
# Bootstrap #666 ROC area: 0.718
# Bootstrap #667 ROC area: 0.762
# Bootstrap #668 ROC area: 0.750
# Bootstrap #669 ROC area: 0.795
# Bootstrap #670 ROC area: 0.747
# Bootstrap #671 ROC area: 0.778
# Bootstrap #672 ROC area: 0.791
# Bootstrap #673 ROC area: 0.754
# Bootstrap #674 ROC area: 0.832
# Bootstrap #675 ROC area: 0.767
# Bootstrap #676 ROC area: 0.740
# Bootstrap #677 ROC area: 0.793
# Bootstrap #678 ROC area: 0.755
# Bootstrap #679 ROC area: 0.757
# Bootstrap #680 ROC area: 0.765
# Bootstrap #681 ROC area: 0.783
# Bootstrap #682 ROC area: 0.782
# Bootstrap #683 ROC area: 0.780
# Bootstrap #684 ROC area: 0.691
# Bootstrap #685 ROC area: 0.781
# Bootstrap #686 ROC area: 0.784
# Bootstrap #687 ROC area: 0.713
# Bootstrap #688 ROC area: 0.806
# Bootstrap #689 ROC area: 0.711
# Bootstrap #690 ROC area: 0.797
# Bootstrap #691 ROC area: 0.757
# Bootstrap #692 ROC area: 0.793
# Bootstrap #693 ROC area: 0.785
# Bootstrap #694 ROC area: 0.817
# Bootstrap #695 ROC area: 0.773
# Bootstrap #696 ROC area: 0.768
# Bootstrap #697 ROC area: 0.759
# Bootstrap #698 ROC area: 0.787
# Bootstrap #699 ROC area: 0.746
# Bootstrap #700 ROC area: 0.760
# Bootstrap #701 ROC area: 0.782
# Bootstrap #702 ROC area: 0.734
# Bootstrap #703 ROC area: 0.776
# Bootstrap #704 ROC area: 0.769
# Bootstrap #705 ROC area: 0.769
# Bootstrap #706 ROC area: 0.814
# Bootstrap #707 ROC area: 0.718
# Bootstrap #708 ROC area: 0.802
# Bootstrap #709 ROC area: 0.786
# Bootstrap #710 ROC area: 0.820
# Bootstrap #711 ROC area: 0.772
# Bootstrap #712 ROC area: 0.764
# Bootstrap #713 ROC area: 0.747
# Bootstrap #714 ROC area: 0.780
# Bootstrap #715 ROC area: 0.756
# Bootstrap #716 ROC area: 0.767
# Bootstrap #717 ROC area: 0.717
# Bootstrap #718 ROC area: 0.768
# Bootstrap #719 ROC area: 0.805
# Bootstrap #720 ROC area: 0.808
# Bootstrap #721 ROC area: 0.712
# Bootstrap #722 ROC area: 0.715
# Bootstrap #723 ROC area: 0.750
# Bootstrap #724 ROC area: 0.749
# Bootstrap #725 ROC area: 0.755
# Bootstrap #726 ROC area: 0.760
# Bootstrap #727 ROC area: 0.797
# Bootstrap #728 ROC area: 0.729
# Bootstrap #729 ROC area: 0.714
# Bootstrap #730 ROC area: 0.781
# Bootstrap #731 ROC area: 0.815
# Bootstrap #732 ROC area: 0.764
# Bootstrap #733 ROC area: 0.741
# Bootstrap #734 ROC area: 0.745
# Bootstrap #735 ROC area: 0.752
# Bootstrap #736 ROC area: 0.684
# Bootstrap #737 ROC area: 0.720
# Bootstrap #738 ROC area: 0.766
# Bootstrap #739 ROC area: 0.777
# Bootstrap #740 ROC area: 0.756
# Bootstrap #741 ROC area: 0.784
# Bootstrap #742 ROC area: 0.751
# Bootstrap #743 ROC area: 0.707
# Bootstrap #744 ROC area: 0.766
# Bootstrap #745 ROC area: 0.747
# Bootstrap #746 ROC area: 0.754
# Bootstrap #747 ROC area: 0.719
# Bootstrap #748 ROC area: 0.732
# Bootstrap #749 ROC area: 0.722
# Bootstrap #750 ROC area: 0.702
# Bootstrap #751 ROC area: 0.759
# Bootstrap #752 ROC area: 0.743
# Bootstrap #753 ROC area: 0.802
# Bootstrap #754 ROC area: 0.800
# Bootstrap #755 ROC area: 0.762
# Bootstrap #756 ROC area: 0.805
# Bootstrap #757 ROC area: 0.780
# Bootstrap #758 ROC area: 0.791
# Bootstrap #759 ROC area: 0.731
# Bootstrap #760 ROC area: 0.737
# Bootstrap #761 ROC area: 0.750
# Bootstrap #762 ROC area: 0.714
# Bootstrap #763 ROC area: 0.765
# Bootstrap #764 ROC area: 0.777
# Bootstrap #765 ROC area: 0.794
# Bootstrap #766 ROC area: 0.745
# Bootstrap #767 ROC area: 0.739
# Bootstrap #768 ROC area: 0.762
# Bootstrap #769 ROC area: 0.803
# Bootstrap #770 ROC area: 0.757
# Bootstrap #771 ROC area: 0.787
# Bootstrap #772 ROC area: 0.749
# Bootstrap #773 ROC area: 0.763
# Bootstrap #774 ROC area: 0.665
# Bootstrap #775 ROC area: 0.735
# Bootstrap #776 ROC area: 0.758
# Bootstrap #777 ROC area: 0.789
# Bootstrap #778 ROC area: 0.752
# Bootstrap #779 ROC area: 0.778
# Bootstrap #780 ROC area: 0.785
# Bootstrap #781 ROC area: 0.722
# Bootstrap #782 ROC area: 0.707
# Bootstrap #783 ROC area: 0.731
# Bootstrap #784 ROC area: 0.692
# Bootstrap #785 ROC area: 0.797
# Bootstrap #786 ROC area: 0.730
# Bootstrap #787 ROC area: 0.738
# Bootstrap #788 ROC area: 0.745
# Bootstrap #789 ROC area: 0.768
# Bootstrap #790 ROC area: 0.678
# Bootstrap #791 ROC area: 0.780
# Bootstrap #792 ROC area: 0.799
# Bootstrap #793 ROC area: 0.778
# Bootstrap #794 ROC area: 0.801
# Bootstrap #795 ROC area: 0.751
# Bootstrap #796 ROC area: 0.808
# Bootstrap #797 ROC area: 0.754
# Bootstrap #798 ROC area: 0.745
# Bootstrap #799 ROC area: 0.767
# Bootstrap #800 ROC area: 0.792
# Bootstrap #801 ROC area: 0.786
# Bootstrap #802 ROC area: 0.789
# Bootstrap #803 ROC area: 0.769
# Bootstrap #804 ROC area: 0.784
# Bootstrap #805 ROC area: 0.723
# Bootstrap #806 ROC area: 0.753
# Bootstrap #807 ROC area: 0.869
# Bootstrap #808 ROC area: 0.737
# Bootstrap #809 ROC area: 0.755
# Bootstrap #810 ROC area: 0.731
# Bootstrap #811 ROC area: 0.803
# Bootstrap #812 ROC area: 0.767
# Bootstrap #813 ROC area: 0.708
# Bootstrap #814 ROC area: 0.727
# Bootstrap #815 ROC area: 0.774
# Bootstrap #816 ROC area: 0.756
# Bootstrap #817 ROC area: 0.737
# Bootstrap #818 ROC area: 0.758
# Bootstrap #819 ROC area: 0.736
# Bootstrap #820 ROC area: 0.761
# Bootstrap #821 ROC area: 0.741
# Bootstrap #822 ROC area: 0.764
# Bootstrap #823 ROC area: 0.758
# Bootstrap #824 ROC area: 0.768
# Bootstrap #825 ROC area: 0.743
# Bootstrap #826 ROC area: 0.779
# Bootstrap #827 ROC area: 0.769
# Bootstrap #828 ROC area: 0.810
# Bootstrap #829 ROC area: 0.760
# Bootstrap #830 ROC area: 0.768
# Bootstrap #831 ROC area: 0.768
# Bootstrap #832 ROC area: 0.723
# Bootstrap #833 ROC area: 0.751
# Bootstrap #834 ROC area: 0.793
# Bootstrap #835 ROC area: 0.744
# Bootstrap #836 ROC area: 0.747
# Bootstrap #837 ROC area: 0.727
# Bootstrap #838 ROC area: 0.756
# Bootstrap #839 ROC area: 0.714
# Bootstrap #840 ROC area: 0.732
# Bootstrap #841 ROC area: 0.729
# Bootstrap #842 ROC area: 0.715
# Bootstrap #843 ROC area: 0.790
# Bootstrap #844 ROC area: 0.805
# Bootstrap #845 ROC area: 0.770
# Bootstrap #846 ROC area: 0.771
# Bootstrap #847 ROC area: 0.748
# Bootstrap #848 ROC area: 0.748
# Bootstrap #849 ROC area: 0.696
# Bootstrap #850 ROC area: 0.723
# Bootstrap #851 ROC area: 0.726
# Bootstrap #852 ROC area: 0.785
# Bootstrap #853 ROC area: 0.743
# Bootstrap #854 ROC area: 0.680
# Bootstrap #855 ROC area: 0.729
# Bootstrap #856 ROC area: 0.724
# Bootstrap #857 ROC area: 0.736
# Bootstrap #858 ROC area: 0.730
# Bootstrap #859 ROC area: 0.722
# Bootstrap #860 ROC area: 0.823
# Bootstrap #861 ROC area: 0.744
# Bootstrap #862 ROC area: 0.759
# Bootstrap #863 ROC area: 0.797
# Bootstrap #864 ROC area: 0.717
# Bootstrap #865 ROC area: 0.779
# Bootstrap #866 ROC area: 0.749
# Bootstrap #867 ROC area: 0.747
# Bootstrap #868 ROC area: 0.778
# Bootstrap #869 ROC area: 0.727
# Bootstrap #870 ROC area: 0.774
# Bootstrap #871 ROC area: 0.703
# Bootstrap #872 ROC area: 0.713
# Bootstrap #873 ROC area: 0.815
# Bootstrap #874 ROC area: 0.781
# Bootstrap #875 ROC area: 0.781
# Bootstrap #876 ROC area: 0.791
# Bootstrap #877 ROC area: 0.794
# Bootstrap #878 ROC area: 0.735
# Bootstrap #879 ROC area: 0.748
# Bootstrap #880 ROC area: 0.795
# Bootstrap #881 ROC area: 0.732
# Bootstrap #882 ROC area: 0.796
# Bootstrap #883 ROC area: 0.759
# Bootstrap #884 ROC area: 0.771
# Bootstrap #885 ROC area: 0.751
# Bootstrap #886 ROC area: 0.788
# Bootstrap #887 ROC area: 0.785
# Bootstrap #888 ROC area: 0.793
# Bootstrap #889 ROC area: 0.800
# Bootstrap #890 ROC area: 0.764
# Bootstrap #891 ROC area: 0.702
# Bootstrap #892 ROC area: 0.734
# Bootstrap #893 ROC area: 0.734
# Bootstrap #894 ROC area: 0.721
# Bootstrap #895 ROC area: 0.784
# Bootstrap #896 ROC area: 0.812
# Bootstrap #897 ROC area: 0.744
# Bootstrap #898 ROC area: 0.801
# Bootstrap #899 ROC area: 0.734
# Bootstrap #900 ROC area: 0.746
# Bootstrap #901 ROC area: 0.845
# Bootstrap #902 ROC area: 0.781
# Bootstrap #903 ROC area: 0.789
# Bootstrap #904 ROC area: 0.739
# Bootstrap #905 ROC area: 0.766
# Bootstrap #906 ROC area: 0.762
# Bootstrap #907 ROC area: 0.775
# Bootstrap #908 ROC area: 0.734
# Bootstrap #909 ROC area: 0.760
# Bootstrap #910 ROC area: 0.756
# Bootstrap #911 ROC area: 0.704
# Bootstrap #912 ROC area: 0.755
# Bootstrap #913 ROC area: 0.758
# Bootstrap #914 ROC area: 0.794
# Bootstrap #915 ROC area: 0.799
# Bootstrap #916 ROC area: 0.755
# Bootstrap #917 ROC area: 0.806
# Bootstrap #918 ROC area: 0.740
# Bootstrap #919 ROC area: 0.737
# Bootstrap #920 ROC area: 0.777
# Bootstrap #921 ROC area: 0.749
# Bootstrap #922 ROC area: 0.781
# Bootstrap #923 ROC area: 0.717
# Bootstrap #924 ROC area: 0.700
# Bootstrap #925 ROC area: 0.736
# Bootstrap #926 ROC area: 0.702
# Bootstrap #927 ROC area: 0.798
# Bootstrap #928 ROC area: 0.739
# Bootstrap #929 ROC area: 0.727
# Bootstrap #930 ROC area: 0.830
# Bootstrap #931 ROC area: 0.754
# Bootstrap #932 ROC area: 0.740
# Bootstrap #933 ROC area: 0.722
# Bootstrap #934 ROC area: 0.751
# Bootstrap #935 ROC area: 0.733
# Bootstrap #936 ROC area: 0.755
# Bootstrap #937 ROC area: 0.690
# Bootstrap #938 ROC area: 0.733
# Bootstrap #939 ROC area: 0.751
# Bootstrap #940 ROC area: 0.797
# Bootstrap #941 ROC area: 0.778
# Bootstrap #942 ROC area: 0.772
# Bootstrap #943 ROC area: 0.803
# Bootstrap #944 ROC area: 0.755
# Bootstrap #945 ROC area: 0.780
# Bootstrap #946 ROC area: 0.767
# Bootstrap #947 ROC area: 0.740
# Bootstrap #948 ROC area: 0.724
# Bootstrap #949 ROC area: 0.732
# Bootstrap #950 ROC area: 0.722
# Bootstrap #951 ROC area: 0.771
# Bootstrap #952 ROC area: 0.711
# Bootstrap #953 ROC area: 0.755
# Bootstrap #954 ROC area: 0.780
# Bootstrap #955 ROC area: 0.703
# Bootstrap #956 ROC area: 0.785
# Bootstrap #957 ROC area: 0.813
# Bootstrap #958 ROC area: 0.751
# Bootstrap #959 ROC area: 0.787
# Bootstrap #960 ROC area: 0.764
# Bootstrap #961 ROC area: 0.781
# Bootstrap #962 ROC area: 0.726
# Bootstrap #963 ROC area: 0.703
# Bootstrap #964 ROC area: 0.791
# Bootstrap #965 ROC area: 0.778
# Bootstrap #966 ROC area: 0.785
# Bootstrap #967 ROC area: 0.716
# Bootstrap #968 ROC area: 0.763
# Bootstrap #969 ROC area: 0.732
# Bootstrap #970 ROC area: 0.784
# Bootstrap #971 ROC area: 0.739
# Bootstrap #972 ROC area: 0.777
# Bootstrap #973 ROC area: 0.755
# Bootstrap #974 ROC area: 0.775
# Bootstrap #975 ROC area: 0.777
# Bootstrap #976 ROC area: 0.721
# Bootstrap #977 ROC area: 0.786
# Bootstrap #978 ROC area: 0.734
# Bootstrap #979 ROC area: 0.766
# Bootstrap #980 ROC area: 0.738
# Bootstrap #981 ROC area: 0.745
# Bootstrap #982 ROC area: 0.726
# Bootstrap #983 ROC area: 0.758
# Bootstrap #984 ROC area: 0.804
# Bootstrap #985 ROC area: 0.809
# Bootstrap #986 ROC area: 0.794
# Bootstrap #987 ROC area: 0.767
# Bootstrap #988 ROC area: 0.743
# Bootstrap #989 ROC area: 0.743
# Bootstrap #990 ROC area: 0.761
# Bootstrap #991 ROC area: 0.701
# Bootstrap #992 ROC area: 0.773
# Bootstrap #993 ROC area: 0.818
# Bootstrap #994 ROC area: 0.817
# Bootstrap #995 ROC area: 0.743
# Bootstrap #996 ROC area: 0.782
# Bootstrap #997 ROC area: 0.735
# Bootstrap #998 ROC area: 0.762
# Bootstrap #999 ROC area: 0.772
# Bootstrap #1000 ROC area: 0.740

# %%
sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score on Black patients: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Confidence interval for the score on Black patients: [0.691 - 0.821]

# %% [markdown]
# #### For Hispanic Patient Set

# %%
y_pred_hispanic = model.predict_proba(xTestHisp)
print("Original ROC area: {:0.3f}".format(roc_auc_score(yTestHisp, y_pred_hispanic[:,1])))
# Out:
# Original ROC area: 0.651

# %%
n_bootstraps = 1000
rng_seed = 42  # control reproducibility
bootstrapped_scores = []

rng = np.random.RandomState(rng_seed)
for i in range(n_bootstraps):
    indices = rng.randint(0, len(y_pred_hispanic), len(y_pred_hispanic))

    score = roc_auc_score(yTestHisp.to_numpy()[indices], y_pred_hispanic[indices, 1])
    bootstrapped_scores.append(score)
    print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))
# Out:
# Bootstrap #1 ROC area: 0.716
# Bootstrap #2 ROC area: 0.634
# Bootstrap #3 ROC area: 0.722
# Bootstrap #4 ROC area: 0.605
# Bootstrap #5 ROC area: 0.697
# Bootstrap #6 ROC area: 0.660
# Bootstrap #7 ROC area: 0.604
# Bootstrap #8 ROC area: 0.619
# Bootstrap #9 ROC area: 0.578
# Bootstrap #10 ROC area: 0.555
# Bootstrap #11 ROC area: 0.655
# Bootstrap #12 ROC area: 0.630
# Bootstrap #13 ROC area: 0.701
# Bootstrap #14 ROC area: 0.641
# Bootstrap #15 ROC area: 0.619
# Bootstrap #16 ROC area: 0.722
# Bootstrap #17 ROC area: 0.686
# Bootstrap #18 ROC area: 0.613
# Bootstrap #19 ROC area: 0.674
# Bootstrap #20 ROC area: 0.669
# Bootstrap #21 ROC area: 0.523
# Bootstrap #22 ROC area: 0.565
# Bootstrap #23 ROC area: 0.670
# Bootstrap #24 ROC area: 0.699
# Bootstrap #25 ROC area: 0.616
# Bootstrap #26 ROC area: 0.697
# Bootstrap #27 ROC area: 0.738
# Bootstrap #28 ROC area: 0.653
# Bootstrap #29 ROC area: 0.539
# Bootstrap #30 ROC area: 0.669
# Bootstrap #31 ROC area: 0.527
# Bootstrap #32 ROC area: 0.576
# Bootstrap #33 ROC area: 0.712
# Bootstrap #34 ROC area: 0.619
# Bootstrap #35 ROC area: 0.760
# Bootstrap #36 ROC area: 0.680
# Bootstrap #37 ROC area: 0.556
# Bootstrap #38 ROC area: 0.681
# Bootstrap #39 ROC area: 0.670
# Bootstrap #40 ROC area: 0.670
# Bootstrap #41 ROC area: 0.626
# Bootstrap #42 ROC area: 0.706
# Bootstrap #43 ROC area: 0.651
# Bootstrap #44 ROC area: 0.725
# Bootstrap #45 ROC area: 0.716
# Bootstrap #46 ROC area: 0.712
# Bootstrap #47 ROC area: 0.578
# Bootstrap #48 ROC area: 0.726
# Bootstrap #49 ROC area: 0.629
# Bootstrap #50 ROC area: 0.736
# Bootstrap #51 ROC area: 0.620
# Bootstrap #52 ROC area: 0.556
# Bootstrap #53 ROC area: 0.604
# Bootstrap #54 ROC area: 0.677
# Bootstrap #55 ROC area: 0.640
# Bootstrap #56 ROC area: 0.572
# Bootstrap #57 ROC area: 0.672
# Bootstrap #58 ROC area: 0.634
# Bootstrap #59 ROC area: 0.642
# Bootstrap #60 ROC area: 0.641
# Bootstrap #61 ROC area: 0.726
# Bootstrap #62 ROC area: 0.600
# Bootstrap #63 ROC area: 0.629
# Bootstrap #64 ROC area: 0.634
# Bootstrap #65 ROC area: 0.642
# Bootstrap #66 ROC area: 0.727
# Bootstrap #67 ROC area: 0.662
# Bootstrap #68 ROC area: 0.688
# Bootstrap #69 ROC area: 0.593
# Bootstrap #70 ROC area: 0.685
# Bootstrap #71 ROC area: 0.618
# Bootstrap #72 ROC area: 0.635
# Bootstrap #73 ROC area: 0.671
# Bootstrap #74 ROC area: 0.537
# Bootstrap #75 ROC area: 0.675
# Bootstrap #76 ROC area: 0.633
# Bootstrap #77 ROC area: 0.552
# Bootstrap #78 ROC area: 0.627
# Bootstrap #79 ROC area: 0.635
# Bootstrap #80 ROC area: 0.684
# Bootstrap #81 ROC area: 0.625
# Bootstrap #82 ROC area: 0.785
# Bootstrap #83 ROC area: 0.620
# Bootstrap #84 ROC area: 0.643
# Bootstrap #85 ROC area: 0.689
# Bootstrap #86 ROC area: 0.636
# Bootstrap #87 ROC area: 0.592
# Bootstrap #88 ROC area: 0.617
# Bootstrap #89 ROC area: 0.726
# Bootstrap #90 ROC area: 0.760
# Bootstrap #91 ROC area: 0.654
# Bootstrap #92 ROC area: 0.754
# Bootstrap #93 ROC area: 0.644
# Bootstrap #94 ROC area: 0.643
# Bootstrap #95 ROC area: 0.702
# Bootstrap #96 ROC area: 0.591
# Bootstrap #97 ROC area: 0.630
# Bootstrap #98 ROC area: 0.646
# Bootstrap #99 ROC area: 0.557
# Bootstrap #100 ROC area: 0.666
# Bootstrap #101 ROC area: 0.710
# Bootstrap #102 ROC area: 0.702
# Bootstrap #103 ROC area: 0.670
# Bootstrap #104 ROC area: 0.674
# Bootstrap #105 ROC area: 0.665
# Bootstrap #106 ROC area: 0.621
# Bootstrap #107 ROC area: 0.603
# Bootstrap #108 ROC area: 0.677
# Bootstrap #109 ROC area: 0.699
# Bootstrap #110 ROC area: 0.758
# Bootstrap #111 ROC area: 0.725
# Bootstrap #112 ROC area: 0.712
# Bootstrap #113 ROC area: 0.593
# Bootstrap #114 ROC area: 0.582
# Bootstrap #115 ROC area: 0.714
# Bootstrap #116 ROC area: 0.649
# Bootstrap #117 ROC area: 0.620
# Bootstrap #118 ROC area: 0.580
# Bootstrap #119 ROC area: 0.667
# Bootstrap #120 ROC area: 0.593
# Bootstrap #121 ROC area: 0.598
# Bootstrap #122 ROC area: 0.641
# Bootstrap #123 ROC area: 0.647
# Bootstrap #124 ROC area: 0.623
# Bootstrap #125 ROC area: 0.726
# Bootstrap #126 ROC area: 0.665
# Bootstrap #127 ROC area: 0.635
# Bootstrap #128 ROC area: 0.636
# Bootstrap #129 ROC area: 0.644
# Bootstrap #130 ROC area: 0.594
# Bootstrap #131 ROC area: 0.658
# Bootstrap #132 ROC area: 0.653
# Bootstrap #133 ROC area: 0.653
# Bootstrap #134 ROC area: 0.624
# Bootstrap #135 ROC area: 0.687
# Bootstrap #136 ROC area: 0.646
# Bootstrap #137 ROC area: 0.749
# Bootstrap #138 ROC area: 0.670
# Bootstrap #139 ROC area: 0.646
# Bootstrap #140 ROC area: 0.627
# Bootstrap #141 ROC area: 0.686
# Bootstrap #142 ROC area: 0.667
# Bootstrap #143 ROC area: 0.590
# Bootstrap #144 ROC area: 0.687
# Bootstrap #145 ROC area: 0.649
# Bootstrap #146 ROC area: 0.656
# Bootstrap #147 ROC area: 0.611
# Bootstrap #148 ROC area: 0.651
# Bootstrap #149 ROC area: 0.623
# Bootstrap #150 ROC area: 0.687
# Bootstrap #151 ROC area: 0.697
# Bootstrap #152 ROC area: 0.579
# Bootstrap #153 ROC area: 0.690
# Bootstrap #154 ROC area: 0.662
# Bootstrap #155 ROC area: 0.625
# Bootstrap #156 ROC area: 0.614
# Bootstrap #157 ROC area: 0.625
# Bootstrap #158 ROC area: 0.674
# Bootstrap #159 ROC area: 0.672
# Bootstrap #160 ROC area: 0.657
# Bootstrap #161 ROC area: 0.662
# Bootstrap #162 ROC area: 0.601
# Bootstrap #163 ROC area: 0.597
# Bootstrap #164 ROC area: 0.689
# Bootstrap #165 ROC area: 0.695
# Bootstrap #166 ROC area: 0.553
# Bootstrap #167 ROC area: 0.659
# Bootstrap #168 ROC area: 0.622
# Bootstrap #169 ROC area: 0.600
# Bootstrap #170 ROC area: 0.682
# Bootstrap #171 ROC area: 0.668
# Bootstrap #172 ROC area: 0.626
# Bootstrap #173 ROC area: 0.731
# Bootstrap #174 ROC area: 0.664
# Bootstrap #175 ROC area: 0.722
# Bootstrap #176 ROC area: 0.654
# Bootstrap #177 ROC area: 0.656
# Bootstrap #178 ROC area: 0.728
# Bootstrap #179 ROC area: 0.674
# Bootstrap #180 ROC area: 0.566
# Bootstrap #181 ROC area: 0.755
# Bootstrap #182 ROC area: 0.704
# Bootstrap #183 ROC area: 0.556
# Bootstrap #184 ROC area: 0.588
# Bootstrap #185 ROC area: 0.658
# Bootstrap #186 ROC area: 0.669
# Bootstrap #187 ROC area: 0.663
# Bootstrap #188 ROC area: 0.738
# Bootstrap #189 ROC area: 0.635
# Bootstrap #190 ROC area: 0.673
# Bootstrap #191 ROC area: 0.599
# Bootstrap #192 ROC area: 0.611
# Bootstrap #193 ROC area: 0.620
# Bootstrap #194 ROC area: 0.592
# Bootstrap #195 ROC area: 0.655
# Bootstrap #196 ROC area: 0.680
# Bootstrap #197 ROC area: 0.670
# Bootstrap #198 ROC area: 0.628
# Bootstrap #199 ROC area: 0.623
# Bootstrap #200 ROC area: 0.691
# Bootstrap #201 ROC area: 0.639
# Bootstrap #202 ROC area: 0.641
# Bootstrap #203 ROC area: 0.648
# Bootstrap #204 ROC area: 0.714
# Bootstrap #205 ROC area: 0.721
# Bootstrap #206 ROC area: 0.607
# Bootstrap #207 ROC area: 0.595
# Bootstrap #208 ROC area: 0.722
# Bootstrap #209 ROC area: 0.683
# Bootstrap #210 ROC area: 0.653
# Bootstrap #211 ROC area: 0.655
# Bootstrap #212 ROC area: 0.693
# Bootstrap #213 ROC area: 0.603
# Bootstrap #214 ROC area: 0.645
# Bootstrap #215 ROC area: 0.639
# Bootstrap #216 ROC area: 0.699
# Bootstrap #217 ROC area: 0.542
# Bootstrap #218 ROC area: 0.742
# Bootstrap #219 ROC area: 0.624
# Bootstrap #220 ROC area: 0.733
# Bootstrap #221 ROC area: 0.726
# Bootstrap #222 ROC area: 0.475
# Bootstrap #223 ROC area: 0.704
# Bootstrap #224 ROC area: 0.644
# Bootstrap #225 ROC area: 0.653
# Bootstrap #226 ROC area: 0.594
# Bootstrap #227 ROC area: 0.635
# Bootstrap #228 ROC area: 0.625
# Bootstrap #229 ROC area: 0.577
# Bootstrap #230 ROC area: 0.666
# Bootstrap #231 ROC area: 0.609
# Bootstrap #232 ROC area: 0.696
# Bootstrap #233 ROC area: 0.637
# Bootstrap #234 ROC area: 0.613
# Bootstrap #235 ROC area: 0.647
# Bootstrap #236 ROC area: 0.775
# Bootstrap #237 ROC area: 0.560
# Bootstrap #238 ROC area: 0.701
# Bootstrap #239 ROC area: 0.581
# Bootstrap #240 ROC area: 0.663
# Bootstrap #241 ROC area: 0.682
# Bootstrap #242 ROC area: 0.644
# Bootstrap #243 ROC area: 0.681
# Bootstrap #244 ROC area: 0.692
# Bootstrap #245 ROC area: 0.691
# Bootstrap #246 ROC area: 0.681
# Bootstrap #247 ROC area: 0.620
# Bootstrap #248 ROC area: 0.769
# Bootstrap #249 ROC area: 0.662
# Bootstrap #250 ROC area: 0.664
# Bootstrap #251 ROC area: 0.732
# Bootstrap #252 ROC area: 0.682
# Bootstrap #253 ROC area: 0.643
# Bootstrap #254 ROC area: 0.614
# Bootstrap #255 ROC area: 0.594
# Bootstrap #256 ROC area: 0.685
# Bootstrap #257 ROC area: 0.651
# Bootstrap #258 ROC area: 0.771
# Bootstrap #259 ROC area: 0.632
# Bootstrap #260 ROC area: 0.598
# Bootstrap #261 ROC area: 0.566
# Bootstrap #262 ROC area: 0.626
# Bootstrap #263 ROC area: 0.586
# Bootstrap #264 ROC area: 0.649
# Bootstrap #265 ROC area: 0.620
# Bootstrap #266 ROC area: 0.619
# Bootstrap #267 ROC area: 0.641
# Bootstrap #268 ROC area: 0.634
# Bootstrap #269 ROC area: 0.663
# Bootstrap #270 ROC area: 0.678
# Bootstrap #271 ROC area: 0.724
# Bootstrap #272 ROC area: 0.678
# Bootstrap #273 ROC area: 0.709
# Bootstrap #274 ROC area: 0.673
# Bootstrap #275 ROC area: 0.720
# Bootstrap #276 ROC area: 0.741
# Bootstrap #277 ROC area: 0.708
# Bootstrap #278 ROC area: 0.678
# Bootstrap #279 ROC area: 0.625
# Bootstrap #280 ROC area: 0.668
# Bootstrap #281 ROC area: 0.770
# Bootstrap #282 ROC area: 0.728
# Bootstrap #283 ROC area: 0.553
# Bootstrap #284 ROC area: 0.606
# Bootstrap #285 ROC area: 0.653
# Bootstrap #286 ROC area: 0.704
# Bootstrap #287 ROC area: 0.587
# Bootstrap #288 ROC area: 0.630
# Bootstrap #289 ROC area: 0.735
# Bootstrap #290 ROC area: 0.638
# Bootstrap #291 ROC area: 0.690
# Bootstrap #292 ROC area: 0.709
# Bootstrap #293 ROC area: 0.640
# Bootstrap #294 ROC area: 0.529
# Bootstrap #295 ROC area: 0.599
# Bootstrap #296 ROC area: 0.620
# Bootstrap #297 ROC area: 0.641
# Bootstrap #298 ROC area: 0.690
# Bootstrap #299 ROC area: 0.748
# Bootstrap #300 ROC area: 0.671
# Bootstrap #301 ROC area: 0.621
# Bootstrap #302 ROC area: 0.633
# Bootstrap #303 ROC area: 0.644
# Bootstrap #304 ROC area: 0.700
# Bootstrap #305 ROC area: 0.632
# Bootstrap #306 ROC area: 0.539
# Bootstrap #307 ROC area: 0.663
# Bootstrap #308 ROC area: 0.599
# Bootstrap #309 ROC area: 0.652
# Bootstrap #310 ROC area: 0.685
# Bootstrap #311 ROC area: 0.620
# Bootstrap #312 ROC area: 0.565
# Bootstrap #313 ROC area: 0.560
# Bootstrap #314 ROC area: 0.711
# Bootstrap #315 ROC area: 0.580
# Bootstrap #316 ROC area: 0.616
# Bootstrap #317 ROC area: 0.642
# Bootstrap #318 ROC area: 0.608
# Bootstrap #319 ROC area: 0.649
# Bootstrap #320 ROC area: 0.632
# Bootstrap #321 ROC area: 0.712
# Bootstrap #322 ROC area: 0.670
# Bootstrap #323 ROC area: 0.571
# Bootstrap #324 ROC area: 0.720
# Bootstrap #325 ROC area: 0.677
# Bootstrap #326 ROC area: 0.637
# Bootstrap #327 ROC area: 0.702
# Bootstrap #328 ROC area: 0.642
# Bootstrap #329 ROC area: 0.668
# Bootstrap #330 ROC area: 0.663
# Bootstrap #331 ROC area: 0.660
# Bootstrap #332 ROC area: 0.638
# Bootstrap #333 ROC area: 0.634
# Bootstrap #334 ROC area: 0.596
# Bootstrap #335 ROC area: 0.650
# Bootstrap #336 ROC area: 0.525
# Bootstrap #337 ROC area: 0.608
# Bootstrap #338 ROC area: 0.686
# Bootstrap #339 ROC area: 0.659
# Bootstrap #340 ROC area: 0.655
# Bootstrap #341 ROC area: 0.697
# Bootstrap #342 ROC area: 0.625
# Bootstrap #343 ROC area: 0.704
# Bootstrap #344 ROC area: 0.587
# Bootstrap #345 ROC area: 0.641
# Bootstrap #346 ROC area: 0.682
# Bootstrap #347 ROC area: 0.671
# Bootstrap #348 ROC area: 0.666
# Bootstrap #349 ROC area: 0.708
# Bootstrap #350 ROC area: 0.737
# Bootstrap #351 ROC area: 0.691
# Bootstrap #352 ROC area: 0.686
# Bootstrap #353 ROC area: 0.670
# Bootstrap #354 ROC area: 0.677
# Bootstrap #355 ROC area: 0.558
# Bootstrap #356 ROC area: 0.671
# Bootstrap #357 ROC area: 0.655
# Bootstrap #358 ROC area: 0.677
# Bootstrap #359 ROC area: 0.598
# Bootstrap #360 ROC area: 0.650
# Bootstrap #361 ROC area: 0.537
# Bootstrap #362 ROC area: 0.658
# Bootstrap #363 ROC area: 0.538
# Bootstrap #364 ROC area: 0.731
# Bootstrap #365 ROC area: 0.616
# Bootstrap #366 ROC area: 0.676
# Bootstrap #367 ROC area: 0.624
# Bootstrap #368 ROC area: 0.672
# Bootstrap #369 ROC area: 0.657
# Bootstrap #370 ROC area: 0.729
# Bootstrap #371 ROC area: 0.708
# Bootstrap #372 ROC area: 0.699
# Bootstrap #373 ROC area: 0.693
# Bootstrap #374 ROC area: 0.662
# Bootstrap #375 ROC area: 0.699
# Bootstrap #376 ROC area: 0.718
# Bootstrap #377 ROC area: 0.540
# Bootstrap #378 ROC area: 0.671
# Bootstrap #379 ROC area: 0.646
# Bootstrap #380 ROC area: 0.609
# Bootstrap #381 ROC area: 0.690
# Bootstrap #382 ROC area: 0.655
# Bootstrap #383 ROC area: 0.648
# Bootstrap #384 ROC area: 0.671
# Bootstrap #385 ROC area: 0.674
# Bootstrap #386 ROC area: 0.586
# Bootstrap #387 ROC area: 0.513
# Bootstrap #388 ROC area: 0.714
# Bootstrap #389 ROC area: 0.678
# Bootstrap #390 ROC area: 0.680
# Bootstrap #391 ROC area: 0.642
# Bootstrap #392 ROC area: 0.729
# Bootstrap #393 ROC area: 0.568
# Bootstrap #394 ROC area: 0.577
# Bootstrap #395 ROC area: 0.673
# Bootstrap #396 ROC area: 0.689
# Bootstrap #397 ROC area: 0.655
# Bootstrap #398 ROC area: 0.657
# Bootstrap #399 ROC area: 0.631
# Bootstrap #400 ROC area: 0.693
# Bootstrap #401 ROC area: 0.665
# Bootstrap #402 ROC area: 0.664
# Bootstrap #403 ROC area: 0.642
# Bootstrap #404 ROC area: 0.606
# Bootstrap #405 ROC area: 0.635
# Bootstrap #406 ROC area: 0.702
# Bootstrap #407 ROC area: 0.702
# Bootstrap #408 ROC area: 0.671
# Bootstrap #409 ROC area: 0.609
# Bootstrap #410 ROC area: 0.633
# Bootstrap #411 ROC area: 0.731
# Bootstrap #412 ROC area: 0.614
# Bootstrap #413 ROC area: 0.593
# Bootstrap #414 ROC area: 0.681
# Bootstrap #415 ROC area: 0.674
# Bootstrap #416 ROC area: 0.655
# Bootstrap #417 ROC area: 0.671
# Bootstrap #418 ROC area: 0.617
# Bootstrap #419 ROC area: 0.589
# Bootstrap #420 ROC area: 0.681
# Bootstrap #421 ROC area: 0.559
# Bootstrap #422 ROC area: 0.690
# Bootstrap #423 ROC area: 0.609
# Bootstrap #424 ROC area: 0.646
# Bootstrap #425 ROC area: 0.681
# Bootstrap #426 ROC area: 0.635
# Bootstrap #427 ROC area: 0.663
# Bootstrap #428 ROC area: 0.652
# Bootstrap #429 ROC area: 0.646
# Bootstrap #430 ROC area: 0.650
# Bootstrap #431 ROC area: 0.686
# Bootstrap #432 ROC area: 0.642
# Bootstrap #433 ROC area: 0.632
# Bootstrap #434 ROC area: 0.610
# Bootstrap #435 ROC area: 0.652
# Bootstrap #436 ROC area: 0.582
# Bootstrap #437 ROC area: 0.625
# Bootstrap #438 ROC area: 0.641
# Bootstrap #439 ROC area: 0.631
# Bootstrap #440 ROC area: 0.740
# Bootstrap #441 ROC area: 0.653
# Bootstrap #442 ROC area: 0.692
# Bootstrap #443 ROC area: 0.566
# Bootstrap #444 ROC area: 0.661
# Bootstrap #445 ROC area: 0.619
# Bootstrap #446 ROC area: 0.619
# Bootstrap #447 ROC area: 0.682
# Bootstrap #448 ROC area: 0.678
# Bootstrap #449 ROC area: 0.683
# Bootstrap #450 ROC area: 0.731
# Bootstrap #451 ROC area: 0.731
# Bootstrap #452 ROC area: 0.667
# Bootstrap #453 ROC area: 0.689
# Bootstrap #454 ROC area: 0.727
# Bootstrap #455 ROC area: 0.621
# Bootstrap #456 ROC area: 0.623
# Bootstrap #457 ROC area: 0.753
# Bootstrap #458 ROC area: 0.647
# Bootstrap #459 ROC area: 0.585
# Bootstrap #460 ROC area: 0.710
# Bootstrap #461 ROC area: 0.596
# Bootstrap #462 ROC area: 0.606
# Bootstrap #463 ROC area: 0.651
# Bootstrap #464 ROC area: 0.634
# Bootstrap #465 ROC area: 0.653
# Bootstrap #466 ROC area: 0.662
# Bootstrap #467 ROC area: 0.577
# Bootstrap #468 ROC area: 0.628
# Bootstrap #469 ROC area: 0.670
# Bootstrap #470 ROC area: 0.629
# Bootstrap #471 ROC area: 0.602
# Bootstrap #472 ROC area: 0.711
# Bootstrap #473 ROC area: 0.706
# Bootstrap #474 ROC area: 0.648
# Bootstrap #475 ROC area: 0.626
# Bootstrap #476 ROC area: 0.639
# Bootstrap #477 ROC area: 0.571
# Bootstrap #478 ROC area: 0.763
# Bootstrap #479 ROC area: 0.638
# Bootstrap #480 ROC area: 0.545
# Bootstrap #481 ROC area: 0.601
# Bootstrap #482 ROC area: 0.690
# Bootstrap #483 ROC area: 0.708
# Bootstrap #484 ROC area: 0.617
# Bootstrap #485 ROC area: 0.718
# Bootstrap #486 ROC area: 0.700
# Bootstrap #487 ROC area: 0.711
# Bootstrap #488 ROC area: 0.685
# Bootstrap #489 ROC area: 0.687
# Bootstrap #490 ROC area: 0.682
# Bootstrap #491 ROC area: 0.679
# Bootstrap #492 ROC area: 0.661
# Bootstrap #493 ROC area: 0.636
# Bootstrap #494 ROC area: 0.661
# Bootstrap #495 ROC area: 0.645
# Bootstrap #496 ROC area: 0.690
# Bootstrap #497 ROC area: 0.687
# Bootstrap #498 ROC area: 0.613
# Bootstrap #499 ROC area: 0.637
# Bootstrap #500 ROC area: 0.704
# Bootstrap #501 ROC area: 0.637
# Bootstrap #502 ROC area: 0.675
# Bootstrap #503 ROC area: 0.760
# Bootstrap #504 ROC area: 0.717
# Bootstrap #505 ROC area: 0.550
# Bootstrap #506 ROC area: 0.611
# Bootstrap #507 ROC area: 0.662
# Bootstrap #508 ROC area: 0.532
# Bootstrap #509 ROC area: 0.668
# Bootstrap #510 ROC area: 0.640
# Bootstrap #511 ROC area: 0.633
# Bootstrap #512 ROC area: 0.598
# Bootstrap #513 ROC area: 0.642
# Bootstrap #514 ROC area: 0.671
# Bootstrap #515 ROC area: 0.659
# Bootstrap #516 ROC area: 0.652
# Bootstrap #517 ROC area: 0.703
# Bootstrap #518 ROC area: 0.567
# Bootstrap #519 ROC area: 0.686
# Bootstrap #520 ROC area: 0.654
# Bootstrap #521 ROC area: 0.564
# Bootstrap #522 ROC area: 0.618
# Bootstrap #523 ROC area: 0.587
# Bootstrap #524 ROC area: 0.629
# Bootstrap #525 ROC area: 0.764
# Bootstrap #526 ROC area: 0.759
# Bootstrap #527 ROC area: 0.706
# Bootstrap #528 ROC area: 0.622
# Bootstrap #529 ROC area: 0.563
# Bootstrap #530 ROC area: 0.709
# Bootstrap #531 ROC area: 0.606
# Bootstrap #532 ROC area: 0.539
# Bootstrap #533 ROC area: 0.692
# Bootstrap #534 ROC area: 0.640
# Bootstrap #535 ROC area: 0.685
# Bootstrap #536 ROC area: 0.694
# Bootstrap #537 ROC area: 0.627
# Bootstrap #538 ROC area: 0.646
# Bootstrap #539 ROC area: 0.649
# Bootstrap #540 ROC area: 0.678
# Bootstrap #541 ROC area: 0.665
# Bootstrap #542 ROC area: 0.695
# Bootstrap #543 ROC area: 0.597
# Bootstrap #544 ROC area: 0.627
# Bootstrap #545 ROC area: 0.584
# Bootstrap #546 ROC area: 0.679
# Bootstrap #547 ROC area: 0.517
# Bootstrap #548 ROC area: 0.629
# Bootstrap #549 ROC area: 0.582
# Bootstrap #550 ROC area: 0.633
# Bootstrap #551 ROC area: 0.586
# Bootstrap #552 ROC area: 0.667
# Bootstrap #553 ROC area: 0.805
# Bootstrap #554 ROC area: 0.727
# Bootstrap #555 ROC area: 0.675
# Bootstrap #556 ROC area: 0.694
# Bootstrap #557 ROC area: 0.689
# Bootstrap #558 ROC area: 0.734
# Bootstrap #559 ROC area: 0.644
# Bootstrap #560 ROC area: 0.709
# Bootstrap #561 ROC area: 0.634
# Bootstrap #562 ROC area: 0.630
# Bootstrap #563 ROC area: 0.654
# Bootstrap #564 ROC area: 0.512
# Bootstrap #565 ROC area: 0.658
# Bootstrap #566 ROC area: 0.673
# Bootstrap #567 ROC area: 0.667
# Bootstrap #568 ROC area: 0.640
# Bootstrap #569 ROC area: 0.595
# Bootstrap #570 ROC area: 0.726
# Bootstrap #571 ROC area: 0.596
# Bootstrap #572 ROC area: 0.542
# Bootstrap #573 ROC area: 0.648
# Bootstrap #574 ROC area: 0.672
# Bootstrap #575 ROC area: 0.657
# Bootstrap #576 ROC area: 0.676
# Bootstrap #577 ROC area: 0.597
# Bootstrap #578 ROC area: 0.601
# Bootstrap #579 ROC area: 0.710
# Bootstrap #580 ROC area: 0.586
# Bootstrap #581 ROC area: 0.677
# Bootstrap #582 ROC area: 0.700
# Bootstrap #583 ROC area: 0.644
# Bootstrap #584 ROC area: 0.669
# Bootstrap #585 ROC area: 0.642
# Bootstrap #586 ROC area: 0.719
# Bootstrap #587 ROC area: 0.665
# Bootstrap #588 ROC area: 0.679
# Bootstrap #589 ROC area: 0.657
# Bootstrap #590 ROC area: 0.681
# Bootstrap #591 ROC area: 0.771
# Bootstrap #592 ROC area: 0.614
# Bootstrap #593 ROC area: 0.679
# Bootstrap #594 ROC area: 0.653
# Bootstrap #595 ROC area: 0.584
# Bootstrap #596 ROC area: 0.668
# Bootstrap #597 ROC area: 0.665
# Bootstrap #598 ROC area: 0.603
# Bootstrap #599 ROC area: 0.601
# Bootstrap #600 ROC area: 0.707
# Bootstrap #601 ROC area: 0.567
# Bootstrap #602 ROC area: 0.515
# Bootstrap #603 ROC area: 0.667
# Bootstrap #604 ROC area: 0.662
# Bootstrap #605 ROC area: 0.701
# Bootstrap #606 ROC area: 0.657
# Bootstrap #607 ROC area: 0.577
# Bootstrap #608 ROC area: 0.628
# Bootstrap #609 ROC area: 0.626
# Bootstrap #610 ROC area: 0.653
# Bootstrap #611 ROC area: 0.647
# Bootstrap #612 ROC area: 0.669
# Bootstrap #613 ROC area: 0.675
# Bootstrap #614 ROC area: 0.565
# Bootstrap #615 ROC area: 0.640
# Bootstrap #616 ROC area: 0.654
# Bootstrap #617 ROC area: 0.632
# Bootstrap #618 ROC area: 0.676
# Bootstrap #619 ROC area: 0.610
# Bootstrap #620 ROC area: 0.640
# Bootstrap #621 ROC area: 0.629
# Bootstrap #622 ROC area: 0.714
# Bootstrap #623 ROC area: 0.741
# Bootstrap #624 ROC area: 0.668
# Bootstrap #625 ROC area: 0.660
# Bootstrap #626 ROC area: 0.699
# Bootstrap #627 ROC area: 0.692
# Bootstrap #628 ROC area: 0.688
# Bootstrap #629 ROC area: 0.688
# Bootstrap #630 ROC area: 0.617
# Bootstrap #631 ROC area: 0.596
# Bootstrap #632 ROC area: 0.691
# Bootstrap #633 ROC area: 0.669
# Bootstrap #634 ROC area: 0.612
# Bootstrap #635 ROC area: 0.600
# Bootstrap #636 ROC area: 0.642
# Bootstrap #637 ROC area: 0.718
# Bootstrap #638 ROC area: 0.581
# Bootstrap #639 ROC area: 0.661
# Bootstrap #640 ROC area: 0.661
# Bootstrap #641 ROC area: 0.641
# Bootstrap #642 ROC area: 0.630
# Bootstrap #643 ROC area: 0.674
# Bootstrap #644 ROC area: 0.723
# Bootstrap #645 ROC area: 0.571
# Bootstrap #646 ROC area: 0.645
# Bootstrap #647 ROC area: 0.610
# Bootstrap #648 ROC area: 0.718
# Bootstrap #649 ROC area: 0.582
# Bootstrap #650 ROC area: 0.598
# Bootstrap #651 ROC area: 0.530
# Bootstrap #652 ROC area: 0.545
# Bootstrap #653 ROC area: 0.686
# Bootstrap #654 ROC area: 0.682
# Bootstrap #655 ROC area: 0.640
# Bootstrap #656 ROC area: 0.627
# Bootstrap #657 ROC area: 0.605
# Bootstrap #658 ROC area: 0.736
# Bootstrap #659 ROC area: 0.680
# Bootstrap #660 ROC area: 0.548
# Bootstrap #661 ROC area: 0.712
# Bootstrap #662 ROC area: 0.593
# Bootstrap #663 ROC area: 0.681
# Bootstrap #664 ROC area: 0.722
# Bootstrap #665 ROC area: 0.671
# Bootstrap #666 ROC area: 0.580
# Bootstrap #667 ROC area: 0.743
# Bootstrap #668 ROC area: 0.618
# Bootstrap #669 ROC area: 0.670
# Bootstrap #670 ROC area: 0.649
# Bootstrap #671 ROC area: 0.596
# Bootstrap #672 ROC area: 0.616
# Bootstrap #673 ROC area: 0.562
# Bootstrap #674 ROC area: 0.672
# Bootstrap #675 ROC area: 0.682
# Bootstrap #676 ROC area: 0.646
# Bootstrap #677 ROC area: 0.668
# Bootstrap #678 ROC area: 0.669
# Bootstrap #679 ROC area: 0.706
# Bootstrap #680 ROC area: 0.708
# Bootstrap #681 ROC area: 0.675
# Bootstrap #682 ROC area: 0.634
# Bootstrap #683 ROC area: 0.605
# Bootstrap #684 ROC area: 0.644
# Bootstrap #685 ROC area: 0.691
# Bootstrap #686 ROC area: 0.669
# Bootstrap #687 ROC area: 0.648
# Bootstrap #688 ROC area: 0.606
# Bootstrap #689 ROC area: 0.788
# Bootstrap #690 ROC area: 0.660
# Bootstrap #691 ROC area: 0.685
# Bootstrap #692 ROC area: 0.698
# Bootstrap #693 ROC area: 0.677
# Bootstrap #694 ROC area: 0.620
# Bootstrap #695 ROC area: 0.744
# Bootstrap #696 ROC area: 0.613
# Bootstrap #697 ROC area: 0.691
# Bootstrap #698 ROC area: 0.748
# Bootstrap #699 ROC area: 0.727
# Bootstrap #700 ROC area: 0.670
# Bootstrap #701 ROC area: 0.641
# Bootstrap #702 ROC area: 0.644
# Bootstrap #703 ROC area: 0.647
# Bootstrap #704 ROC area: 0.651
# Bootstrap #705 ROC area: 0.666
# Bootstrap #706 ROC area: 0.645
# Bootstrap #707 ROC area: 0.723
# Bootstrap #708 ROC area: 0.725
# Bootstrap #709 ROC area: 0.608
# Bootstrap #710 ROC area: 0.677
# Bootstrap #711 ROC area: 0.683
# Bootstrap #712 ROC area: 0.633
# Bootstrap #713 ROC area: 0.632
# Bootstrap #714 ROC area: 0.713
# Bootstrap #715 ROC area: 0.664
# Bootstrap #716 ROC area: 0.624
# Bootstrap #717 ROC area: 0.609
# Bootstrap #718 ROC area: 0.581
# Bootstrap #719 ROC area: 0.695
# Bootstrap #720 ROC area: 0.685
# Bootstrap #721 ROC area: 0.700
# Bootstrap #722 ROC area: 0.713
# Bootstrap #723 ROC area: 0.729
# Bootstrap #724 ROC area: 0.609
# Bootstrap #725 ROC area: 0.682
# Bootstrap #726 ROC area: 0.659
# Bootstrap #727 ROC area: 0.724
# Bootstrap #728 ROC area: 0.650
# Bootstrap #729 ROC area: 0.711
# Bootstrap #730 ROC area: 0.694
# Bootstrap #731 ROC area: 0.651
# Bootstrap #732 ROC area: 0.652
# Bootstrap #733 ROC area: 0.682
# Bootstrap #734 ROC area: 0.614
# Bootstrap #735 ROC area: 0.686
# Bootstrap #736 ROC area: 0.678
# Bootstrap #737 ROC area: 0.672
# Bootstrap #738 ROC area: 0.653
# Bootstrap #739 ROC area: 0.613
# Bootstrap #740 ROC area: 0.571
# Bootstrap #741 ROC area: 0.686
# Bootstrap #742 ROC area: 0.570
# Bootstrap #743 ROC area: 0.615
# Bootstrap #744 ROC area: 0.601
# Bootstrap #745 ROC area: 0.635
# Bootstrap #746 ROC area: 0.755
# Bootstrap #747 ROC area: 0.685
# Bootstrap #748 ROC area: 0.569
# Bootstrap #749 ROC area: 0.663
# Bootstrap #750 ROC area: 0.670
# Bootstrap #751 ROC area: 0.516
# Bootstrap #752 ROC area: 0.638
# Bootstrap #753 ROC area: 0.666
# Bootstrap #754 ROC area: 0.625
# Bootstrap #755 ROC area: 0.655
# Bootstrap #756 ROC area: 0.670
# Bootstrap #757 ROC area: 0.681
# Bootstrap #758 ROC area: 0.715
# Bootstrap #759 ROC area: 0.701
# Bootstrap #760 ROC area: 0.604
# Bootstrap #761 ROC area: 0.548
# Bootstrap #762 ROC area: 0.610
# Bootstrap #763 ROC area: 0.693
# Bootstrap #764 ROC area: 0.681
# Bootstrap #765 ROC area: 0.624
# Bootstrap #766 ROC area: 0.740
# Bootstrap #767 ROC area: 0.657
# Bootstrap #768 ROC area: 0.678
# Bootstrap #769 ROC area: 0.643
# Bootstrap #770 ROC area: 0.671
# Bootstrap #771 ROC area: 0.670
# Bootstrap #772 ROC area: 0.711
# Bootstrap #773 ROC area: 0.602
# Bootstrap #774 ROC area: 0.721
# Bootstrap #775 ROC area: 0.690
# Bootstrap #776 ROC area: 0.718
# Bootstrap #777 ROC area: 0.616
# Bootstrap #778 ROC area: 0.579
# Bootstrap #779 ROC area: 0.764
# Bootstrap #780 ROC area: 0.677
# Bootstrap #781 ROC area: 0.639
# Bootstrap #782 ROC area: 0.668
# Bootstrap #783 ROC area: 0.611
# Bootstrap #784 ROC area: 0.591
# Bootstrap #785 ROC area: 0.700
# Bootstrap #786 ROC area: 0.660
# Bootstrap #787 ROC area: 0.622
# Bootstrap #788 ROC area: 0.603
# Bootstrap #789 ROC area: 0.684
# Bootstrap #790 ROC area: 0.646
# Bootstrap #791 ROC area: 0.614
# Bootstrap #792 ROC area: 0.568
# Bootstrap #793 ROC area: 0.628
# Bootstrap #794 ROC area: 0.702
# Bootstrap #795 ROC area: 0.725
# Bootstrap #796 ROC area: 0.655
# Bootstrap #797 ROC area: 0.699
# Bootstrap #798 ROC area: 0.734
# Bootstrap #799 ROC area: 0.664
# Bootstrap #800 ROC area: 0.661
# Bootstrap #801 ROC area: 0.730
# Bootstrap #802 ROC area: 0.708
# Bootstrap #803 ROC area: 0.662
# Bootstrap #804 ROC area: 0.664
# Bootstrap #805 ROC area: 0.579
# Bootstrap #806 ROC area: 0.681
# Bootstrap #807 ROC area: 0.702
# Bootstrap #808 ROC area: 0.687
# Bootstrap #809 ROC area: 0.683
# Bootstrap #810 ROC area: 0.789
# Bootstrap #811 ROC area: 0.660
# Bootstrap #812 ROC area: 0.622
# Bootstrap #813 ROC area: 0.704
# Bootstrap #814 ROC area: 0.659
# Bootstrap #815 ROC area: 0.621
# Bootstrap #816 ROC area: 0.615
# Bootstrap #817 ROC area: 0.695
# Bootstrap #818 ROC area: 0.646
# Bootstrap #819 ROC area: 0.690
# Bootstrap #820 ROC area: 0.685
# Bootstrap #821 ROC area: 0.611
# Bootstrap #822 ROC area: 0.642
# Bootstrap #823 ROC area: 0.616
# Bootstrap #824 ROC area: 0.672
# Bootstrap #825 ROC area: 0.737
# Bootstrap #826 ROC area: 0.550
# Bootstrap #827 ROC area: 0.598
# Bootstrap #828 ROC area: 0.693
# Bootstrap #829 ROC area: 0.687
# Bootstrap #830 ROC area: 0.619
# Bootstrap #831 ROC area: 0.634
# Bootstrap #832 ROC area: 0.613
# Bootstrap #833 ROC area: 0.655
# Bootstrap #834 ROC area: 0.705
# Bootstrap #835 ROC area: 0.634
# Bootstrap #836 ROC area: 0.703
# Bootstrap #837 ROC area: 0.577
# Bootstrap #838 ROC area: 0.625
# Bootstrap #839 ROC area: 0.708
# Bootstrap #840 ROC area: 0.687
# Bootstrap #841 ROC area: 0.616
# Bootstrap #842 ROC area: 0.724
# Bootstrap #843 ROC area: 0.662
# Bootstrap #844 ROC area: 0.724
# Bootstrap #845 ROC area: 0.693
# Bootstrap #846 ROC area: 0.687
# Bootstrap #847 ROC area: 0.746
# Bootstrap #848 ROC area: 0.731
# Bootstrap #849 ROC area: 0.750
# Bootstrap #850 ROC area: 0.651
# Bootstrap #851 ROC area: 0.651
# Bootstrap #852 ROC area: 0.662
# Bootstrap #853 ROC area: 0.696
# Bootstrap #854 ROC area: 0.629
# Bootstrap #855 ROC area: 0.712
# Bootstrap #856 ROC area: 0.565
# Bootstrap #857 ROC area: 0.680
# Bootstrap #858 ROC area: 0.680
# Bootstrap #859 ROC area: 0.733
# Bootstrap #860 ROC area: 0.629
# Bootstrap #861 ROC area: 0.602
# Bootstrap #862 ROC area: 0.634
# Bootstrap #863 ROC area: 0.656
# Bootstrap #864 ROC area: 0.690
# Bootstrap #865 ROC area: 0.704
# Bootstrap #866 ROC area: 0.643
# Bootstrap #867 ROC area: 0.703
# Bootstrap #868 ROC area: 0.705
# Bootstrap #869 ROC area: 0.608
# Bootstrap #870 ROC area: 0.680
# Bootstrap #871 ROC area: 0.615
# Bootstrap #872 ROC area: 0.593
# Bootstrap #873 ROC area: 0.615
# Bootstrap #874 ROC area: 0.642
# Bootstrap #875 ROC area: 0.587
# Bootstrap #876 ROC area: 0.635
# Bootstrap #877 ROC area: 0.644
# Bootstrap #878 ROC area: 0.690
# Bootstrap #879 ROC area: 0.697
# Bootstrap #880 ROC area: 0.698
# Bootstrap #881 ROC area: 0.630
# Bootstrap #882 ROC area: 0.617
# Bootstrap #883 ROC area: 0.676
# Bootstrap #884 ROC area: 0.625
# Bootstrap #885 ROC area: 0.580
# Bootstrap #886 ROC area: 0.674
# Bootstrap #887 ROC area: 0.678
# Bootstrap #888 ROC area: 0.673
# Bootstrap #889 ROC area: 0.628
# Bootstrap #890 ROC area: 0.721
# Bootstrap #891 ROC area: 0.599
# Bootstrap #892 ROC area: 0.661
# Bootstrap #893 ROC area: 0.631
# Bootstrap #894 ROC area: 0.618
# Bootstrap #895 ROC area: 0.667
# Bootstrap #896 ROC area: 0.696
# Bootstrap #897 ROC area: 0.555
# Bootstrap #898 ROC area: 0.642
# Bootstrap #899 ROC area: 0.599
# Bootstrap #900 ROC area: 0.748
# Bootstrap #901 ROC area: 0.720
# Bootstrap #902 ROC area: 0.659
# Bootstrap #903 ROC area: 0.717
# Bootstrap #904 ROC area: 0.632
# Bootstrap #905 ROC area: 0.688
# Bootstrap #906 ROC area: 0.608
# Bootstrap #907 ROC area: 0.693
# Bootstrap #908 ROC area: 0.586
# Bootstrap #909 ROC area: 0.687
# Bootstrap #910 ROC area: 0.729
# Bootstrap #911 ROC area: 0.541
# Bootstrap #912 ROC area: 0.686
# Bootstrap #913 ROC area: 0.644
# Bootstrap #914 ROC area: 0.687
# Bootstrap #915 ROC area: 0.610
# Bootstrap #916 ROC area: 0.574
# Bootstrap #917 ROC area: 0.679
# Bootstrap #918 ROC area: 0.608
# Bootstrap #919 ROC area: 0.577
# Bootstrap #920 ROC area: 0.680
# Bootstrap #921 ROC area: 0.700
# Bootstrap #922 ROC area: 0.644
# Bootstrap #923 ROC area: 0.698
# Bootstrap #924 ROC area: 0.583
# Bootstrap #925 ROC area: 0.577
# Bootstrap #926 ROC area: 0.668
# Bootstrap #927 ROC area: 0.615
# Bootstrap #928 ROC area: 0.748
# Bootstrap #929 ROC area: 0.606
# Bootstrap #930 ROC area: 0.574
# Bootstrap #931 ROC area: 0.681
# Bootstrap #932 ROC area: 0.651
# Bootstrap #933 ROC area: 0.743
# Bootstrap #934 ROC area: 0.633
# Bootstrap #935 ROC area: 0.643
# Bootstrap #936 ROC area: 0.658
# Bootstrap #937 ROC area: 0.715
# Bootstrap #938 ROC area: 0.672
# Bootstrap #939 ROC area: 0.644
# Bootstrap #940 ROC area: 0.606
# Bootstrap #941 ROC area: 0.636
# Bootstrap #942 ROC area: 0.609
# Bootstrap #943 ROC area: 0.716
# Bootstrap #944 ROC area: 0.670
# Bootstrap #945 ROC area: 0.581
# Bootstrap #946 ROC area: 0.653
# Bootstrap #947 ROC area: 0.675
# Bootstrap #948 ROC area: 0.626
# Bootstrap #949 ROC area: 0.639
# Bootstrap #950 ROC area: 0.590
# Bootstrap #951 ROC area: 0.559
# Bootstrap #952 ROC area: 0.551
# Bootstrap #953 ROC area: 0.764
# Bootstrap #954 ROC area: 0.701
# Bootstrap #955 ROC area: 0.782
# Bootstrap #956 ROC area: 0.621
# Bootstrap #957 ROC area: 0.691
# Bootstrap #958 ROC area: 0.646
# Bootstrap #959 ROC area: 0.668
# Bootstrap #960 ROC area: 0.656
# Bootstrap #961 ROC area: 0.697
# Bootstrap #962 ROC area: 0.687
# Bootstrap #963 ROC area: 0.623
# Bootstrap #964 ROC area: 0.534
# Bootstrap #965 ROC area: 0.658
# Bootstrap #966 ROC area: 0.585
# Bootstrap #967 ROC area: 0.657
# Bootstrap #968 ROC area: 0.653
# Bootstrap #969 ROC area: 0.615
# Bootstrap #970 ROC area: 0.651
# Bootstrap #971 ROC area: 0.696
# Bootstrap #972 ROC area: 0.473
# Bootstrap #973 ROC area: 0.660
# Bootstrap #974 ROC area: 0.709
# Bootstrap #975 ROC area: 0.619
# Bootstrap #976 ROC area: 0.655
# Bootstrap #977 ROC area: 0.709
# Bootstrap #978 ROC area: 0.687
# Bootstrap #979 ROC area: 0.617
# Bootstrap #980 ROC area: 0.717
# Bootstrap #981 ROC area: 0.628
# Bootstrap #982 ROC area: 0.602
# Bootstrap #983 ROC area: 0.739
# Bootstrap #984 ROC area: 0.628
# Bootstrap #985 ROC area: 0.670
# Bootstrap #986 ROC area: 0.695
# Bootstrap #987 ROC area: 0.696
# Bootstrap #988 ROC area: 0.577
# Bootstrap #989 ROC area: 0.640
# Bootstrap #990 ROC area: 0.640
# Bootstrap #991 ROC area: 0.643
# Bootstrap #992 ROC area: 0.692
# Bootstrap #993 ROC area: 0.716
# Bootstrap #994 ROC area: 0.592
# Bootstrap #995 ROC area: 0.671
# Bootstrap #996 ROC area: 0.651
# Bootstrap #997 ROC area: 0.779
# Bootstrap #998 ROC area: 0.603
# Bootstrap #999 ROC area: 0.698
# Bootstrap #1000 ROC area: 0.592

# %%
sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()
confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score on Hispanic patients: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Confidence interval for the score on Hispanic patients: [0.545 - 0.75]

# %% [markdown]
# #### For Asian Patient Set

# %%
y_pred_asian = model.predict_proba(xTestAsian)
print("Original ROC area: {:0.3f}".format(roc_auc_score(yTestAsian, y_pred_asian[:,1])))
# Out:
# Original ROC area: 0.729

# %%
n_bootstraps = 1000
rng_seed = 42  # control reproducibility
bootstrapped_scores = []

rng = np.random.RandomState(rng_seed)
for i in range(n_bootstraps):
    indices = rng.randint(0, len(y_pred_asian), len(y_pred_asian))

    score = roc_auc_score(yTestAsian.to_numpy()[indices], y_pred_asian[indices, 1])
    bootstrapped_scores.append(score)
    print("Bootstrap #{} ROC area: {:0.3f}".format(i + 1, score))
# Out:
# Bootstrap #1 ROC area: 0.773
# Bootstrap #2 ROC area: 0.775
# Bootstrap #3 ROC area: 0.613
# Bootstrap #4 ROC area: 0.741
# Bootstrap #5 ROC area: 0.703
# Bootstrap #6 ROC area: 0.762
# Bootstrap #7 ROC area: 0.774
# Bootstrap #8 ROC area: 0.716
# Bootstrap #9 ROC area: 0.739
# Bootstrap #10 ROC area: 0.706
# Bootstrap #11 ROC area: 0.748
# Bootstrap #12 ROC area: 0.755
# Bootstrap #13 ROC area: 0.732
# Bootstrap #14 ROC area: 0.678
# Bootstrap #15 ROC area: 0.712
# Bootstrap #16 ROC area: 0.588
# Bootstrap #17 ROC area: 0.667
# Bootstrap #18 ROC area: 0.631
# Bootstrap #19 ROC area: 0.704
# Bootstrap #20 ROC area: 0.750
# Bootstrap #21 ROC area: 0.761
# Bootstrap #22 ROC area: 0.801
# Bootstrap #23 ROC area: 0.752
# Bootstrap #24 ROC area: 0.697
# Bootstrap #25 ROC area: 0.706
# Bootstrap #26 ROC area: 0.765
# Bootstrap #27 ROC area: 0.817
# Bootstrap #28 ROC area: 0.858
# Bootstrap #29 ROC area: 0.705
# Bootstrap #30 ROC area: 0.730
# Bootstrap #31 ROC area: 0.750
# Bootstrap #32 ROC area: 0.771
# Bootstrap #33 ROC area: 0.640
# Bootstrap #34 ROC area: 0.760
# Bootstrap #35 ROC area: 0.707
# Bootstrap #36 ROC area: 0.743
# Bootstrap #37 ROC area: 0.727
# Bootstrap #38 ROC area: 0.753
# Bootstrap #39 ROC area: 0.756
# Bootstrap #40 ROC area: 0.773
# Bootstrap #41 ROC area: 0.737
# Bootstrap #42 ROC area: 0.765
# Bootstrap #43 ROC area: 0.682
# Bootstrap #44 ROC area: 0.797
# Bootstrap #45 ROC area: 0.701
# Bootstrap #46 ROC area: 0.745
# Bootstrap #47 ROC area: 0.689
# Bootstrap #48 ROC area: 0.659
# Bootstrap #49 ROC area: 0.792
# Bootstrap #50 ROC area: 0.712
# Bootstrap #51 ROC area: 0.754
# Bootstrap #52 ROC area: 0.767
# Bootstrap #53 ROC area: 0.747
# Bootstrap #54 ROC area: 0.710
# Bootstrap #55 ROC area: 0.695
# Bootstrap #56 ROC area: 0.733
# Bootstrap #57 ROC area: 0.813
# Bootstrap #58 ROC area: 0.762
# Bootstrap #59 ROC area: 0.700
# Bootstrap #60 ROC area: 0.692
# Bootstrap #61 ROC area: 0.721
# Bootstrap #62 ROC area: 0.747
# Bootstrap #63 ROC area: 0.776
# Bootstrap #64 ROC area: 0.686
# Bootstrap #65 ROC area: 0.764
# Bootstrap #66 ROC area: 0.702
# Bootstrap #67 ROC area: 0.743
# Bootstrap #68 ROC area: 0.750
# Bootstrap #69 ROC area: 0.686
# Bootstrap #70 ROC area: 0.713
# Bootstrap #71 ROC area: 0.677
# Bootstrap #72 ROC area: 0.761
# Bootstrap #73 ROC area: 0.680
# Bootstrap #74 ROC area: 0.769
# Bootstrap #75 ROC area: 0.709
# Bootstrap #76 ROC area: 0.760
# Bootstrap #77 ROC area: 0.726
# Bootstrap #78 ROC area: 0.797
# Bootstrap #79 ROC area: 0.682
# Bootstrap #80 ROC area: 0.750
# Bootstrap #81 ROC area: 0.773
# Bootstrap #82 ROC area: 0.565
# Bootstrap #83 ROC area: 0.737
# Bootstrap #84 ROC area: 0.599
# Bootstrap #85 ROC area: 0.642
# Bootstrap #86 ROC area: 0.795
# Bootstrap #87 ROC area: 0.824
# Bootstrap #88 ROC area: 0.742
# Bootstrap #89 ROC area: 0.734
# Bootstrap #90 ROC area: 0.737
# Bootstrap #91 ROC area: 0.708
# Bootstrap #92 ROC area: 0.830
# Bootstrap #93 ROC area: 0.735
# Bootstrap #94 ROC area: 0.694
# Bootstrap #95 ROC area: 0.706
# Bootstrap #96 ROC area: 0.758
# Bootstrap #97 ROC area: 0.763
# Bootstrap #98 ROC area: 0.789
# Bootstrap #99 ROC area: 0.689
# Bootstrap #100 ROC area: 0.693
# Bootstrap #101 ROC area: 0.679
# Bootstrap #102 ROC area: 0.711
# Bootstrap #103 ROC area: 0.711
# Bootstrap #104 ROC area: 0.757
# Bootstrap #105 ROC area: 0.623
# Bootstrap #106 ROC area: 0.781
# Bootstrap #107 ROC area: 0.746
# Bootstrap #108 ROC area: 0.802
# Bootstrap #109 ROC area: 0.732
# Bootstrap #110 ROC area: 0.790
# Bootstrap #111 ROC area: 0.738
# Bootstrap #112 ROC area: 0.633
# Bootstrap #113 ROC area: 0.718
# Bootstrap #114 ROC area: 0.743
# Bootstrap #115 ROC area: 0.749
# Bootstrap #116 ROC area: 0.791
# Bootstrap #117 ROC area: 0.750
# Bootstrap #118 ROC area: 0.781
# Bootstrap #119 ROC area: 0.765
# Bootstrap #120 ROC area: 0.690
# Bootstrap #121 ROC area: 0.640
# Bootstrap #122 ROC area: 0.705
# Bootstrap #123 ROC area: 0.716
# Bootstrap #124 ROC area: 0.676
# Bootstrap #125 ROC area: 0.733
# Bootstrap #126 ROC area: 0.758
# Bootstrap #127 ROC area: 0.723
# Bootstrap #128 ROC area: 0.783
# Bootstrap #129 ROC area: 0.744
# Bootstrap #130 ROC area: 0.740
# Bootstrap #131 ROC area: 0.676
# Bootstrap #132 ROC area: 0.719
# Bootstrap #133 ROC area: 0.687
# Bootstrap #134 ROC area: 0.735
# Bootstrap #135 ROC area: 0.778
# Bootstrap #136 ROC area: 0.628
# Bootstrap #137 ROC area: 0.721
# Bootstrap #138 ROC area: 0.742
# Bootstrap #139 ROC area: 0.706
# Bootstrap #140 ROC area: 0.651
# Bootstrap #141 ROC area: 0.816
# Bootstrap #142 ROC area: 0.722
# Bootstrap #143 ROC area: 0.667
# Bootstrap #144 ROC area: 0.678
# Bootstrap #145 ROC area: 0.662
# Bootstrap #146 ROC area: 0.722
# Bootstrap #147 ROC area: 0.753
# Bootstrap #148 ROC area: 0.665
# Bootstrap #149 ROC area: 0.745
# Bootstrap #150 ROC area: 0.772
# Bootstrap #151 ROC area: 0.748
# Bootstrap #152 ROC area: 0.781
# Bootstrap #153 ROC area: 0.780
# Bootstrap #154 ROC area: 0.632
# Bootstrap #155 ROC area: 0.721
# Bootstrap #156 ROC area: 0.758
# Bootstrap #157 ROC area: 0.662
# Bootstrap #158 ROC area: 0.683
# Bootstrap #159 ROC area: 0.730
# Bootstrap #160 ROC area: 0.750
# Bootstrap #161 ROC area: 0.836
# Bootstrap #162 ROC area: 0.667
# Bootstrap #163 ROC area: 0.734
# Bootstrap #164 ROC area: 0.738
# Bootstrap #165 ROC area: 0.765
# Bootstrap #166 ROC area: 0.678
# Bootstrap #167 ROC area: 0.790
# Bootstrap #168 ROC area: 0.767
# Bootstrap #169 ROC area: 0.728
# Bootstrap #170 ROC area: 0.790
# Bootstrap #171 ROC area: 0.645
# Bootstrap #172 ROC area: 0.685
# Bootstrap #173 ROC area: 0.725
# Bootstrap #174 ROC area: 0.710
# Bootstrap #175 ROC area: 0.793
# Bootstrap #176 ROC area: 0.753
# Bootstrap #177 ROC area: 0.689
# Bootstrap #178 ROC area: 0.720
# Bootstrap #179 ROC area: 0.707
# Bootstrap #180 ROC area: 0.750
# Bootstrap #181 ROC area: 0.764
# Bootstrap #182 ROC area: 0.707
# Bootstrap #183 ROC area: 0.650
# Bootstrap #184 ROC area: 0.753
# Bootstrap #185 ROC area: 0.661
# Bootstrap #186 ROC area: 0.700
# Bootstrap #187 ROC area: 0.793
# Bootstrap #188 ROC area: 0.670
# Bootstrap #189 ROC area: 0.652
# Bootstrap #190 ROC area: 0.748
# Bootstrap #191 ROC area: 0.764
# Bootstrap #192 ROC area: 0.739
# Bootstrap #193 ROC area: 0.712
# Bootstrap #194 ROC area: 0.662
# Bootstrap #195 ROC area: 0.749
# Bootstrap #196 ROC area: 0.674
# Bootstrap #197 ROC area: 0.747
# Bootstrap #198 ROC area: 0.639
# Bootstrap #199 ROC area: 0.708
# Bootstrap #200 ROC area: 0.758
# Bootstrap #201 ROC area: 0.706
# Bootstrap #202 ROC area: 0.762
# Bootstrap #203 ROC area: 0.676
# Bootstrap #204 ROC area: 0.755
# Bootstrap #205 ROC area: 0.664
# Bootstrap #206 ROC area: 0.701
# Bootstrap #207 ROC area: 0.667
# Bootstrap #208 ROC area: 0.824
# Bootstrap #209 ROC area: 0.780
# Bootstrap #210 ROC area: 0.713
# Bootstrap #211 ROC area: 0.680
# Bootstrap #212 ROC area: 0.714
# Bootstrap #213 ROC area: 0.701
# Bootstrap #214 ROC area: 0.728
# Bootstrap #215 ROC area: 0.666
# Bootstrap #216 ROC area: 0.676
# Bootstrap #217 ROC area: 0.658
# Bootstrap #218 ROC area: 0.681
# Bootstrap #219 ROC area: 0.716
# Bootstrap #220 ROC area: 0.714
# Bootstrap #221 ROC area: 0.719
# Bootstrap #222 ROC area: 0.734
# Bootstrap #223 ROC area: 0.725
# Bootstrap #224 ROC area: 0.708
# Bootstrap #225 ROC area: 0.719
# Bootstrap #226 ROC area: 0.786
# Bootstrap #227 ROC area: 0.780
# Bootstrap #228 ROC area: 0.704
# Bootstrap #229 ROC area: 0.634
# Bootstrap #230 ROC area: 0.766
# Bootstrap #231 ROC area: 0.713
# Bootstrap #232 ROC area: 0.730
# Bootstrap #233 ROC area: 0.769
# Bootstrap #234 ROC area: 0.746
# Bootstrap #235 ROC area: 0.747
# Bootstrap #236 ROC area: 0.734
# Bootstrap #237 ROC area: 0.703
# Bootstrap #238 ROC area: 0.745
# Bootstrap #239 ROC area: 0.775
# Bootstrap #240 ROC area: 0.785
# Bootstrap #241 ROC area: 0.740
# Bootstrap #242 ROC area: 0.714
# Bootstrap #243 ROC area: 0.666
# Bootstrap #244 ROC area: 0.717
# Bootstrap #245 ROC area: 0.653
# Bootstrap #246 ROC area: 0.754
# Bootstrap #247 ROC area: 0.752
# Bootstrap #248 ROC area: 0.683
# Bootstrap #249 ROC area: 0.717
# Bootstrap #250 ROC area: 0.729
# Bootstrap #251 ROC area: 0.618
# Bootstrap #252 ROC area: 0.685
# Bootstrap #253 ROC area: 0.715
# Bootstrap #254 ROC area: 0.763
# Bootstrap #255 ROC area: 0.747
# Bootstrap #256 ROC area: 0.746
# Bootstrap #257 ROC area: 0.766
# Bootstrap #258 ROC area: 0.777
# Bootstrap #259 ROC area: 0.696
# Bootstrap #260 ROC area: 0.691
# Bootstrap #261 ROC area: 0.648
# Bootstrap #262 ROC area: 0.708
# Bootstrap #263 ROC area: 0.726
# Bootstrap #264 ROC area: 0.639
# Bootstrap #265 ROC area: 0.645
# Bootstrap #266 ROC area: 0.757
# Bootstrap #267 ROC area: 0.748
# Bootstrap #268 ROC area: 0.691
# Bootstrap #269 ROC area: 0.679
# Bootstrap #270 ROC area: 0.776
# Bootstrap #271 ROC area: 0.759
# Bootstrap #272 ROC area: 0.762
# Bootstrap #273 ROC area: 0.744
# Bootstrap #274 ROC area: 0.692
# Bootstrap #275 ROC area: 0.717
# Bootstrap #276 ROC area: 0.709
# Bootstrap #277 ROC area: 0.807
# Bootstrap #278 ROC area: 0.702
# Bootstrap #279 ROC area: 0.716
# Bootstrap #280 ROC area: 0.787
# Bootstrap #281 ROC area: 0.793
# Bootstrap #282 ROC area: 0.744
# Bootstrap #283 ROC area: 0.764
# Bootstrap #284 ROC area: 0.673
# Bootstrap #285 ROC area: 0.768
# Bootstrap #286 ROC area: 0.700
# Bootstrap #287 ROC area: 0.718
# Bootstrap #288 ROC area: 0.802
# Bootstrap #289 ROC area: 0.713
# Bootstrap #290 ROC area: 0.726
# Bootstrap #291 ROC area: 0.734
# Bootstrap #292 ROC area: 0.693
# Bootstrap #293 ROC area: 0.759
# Bootstrap #294 ROC area: 0.718
# Bootstrap #295 ROC area: 0.724
# Bootstrap #296 ROC area: 0.766
# Bootstrap #297 ROC area: 0.734
# Bootstrap #298 ROC area: 0.658
# Bootstrap #299 ROC area: 0.740
# Bootstrap #300 ROC area: 0.693
# Bootstrap #301 ROC area: 0.776
# Bootstrap #302 ROC area: 0.778
# Bootstrap #303 ROC area: 0.701
# Bootstrap #304 ROC area: 0.751
# Bootstrap #305 ROC area: 0.708
# Bootstrap #306 ROC area: 0.799
# Bootstrap #307 ROC area: 0.767
# Bootstrap #308 ROC area: 0.727
# Bootstrap #309 ROC area: 0.729
# Bootstrap #310 ROC area: 0.796
# Bootstrap #311 ROC area: 0.697
# Bootstrap #312 ROC area: 0.730
# Bootstrap #313 ROC area: 0.710
# Bootstrap #314 ROC area: 0.734
# Bootstrap #315 ROC area: 0.706
# Bootstrap #316 ROC area: 0.697
# Bootstrap #317 ROC area: 0.710
# Bootstrap #318 ROC area: 0.783
# Bootstrap #319 ROC area: 0.748
# Bootstrap #320 ROC area: 0.746
# Bootstrap #321 ROC area: 0.702
# Bootstrap #322 ROC area: 0.777
# Bootstrap #323 ROC area: 0.792
# Bootstrap #324 ROC area: 0.719
# Bootstrap #325 ROC area: 0.777
# Bootstrap #326 ROC area: 0.715
# Bootstrap #327 ROC area: 0.707
# Bootstrap #328 ROC area: 0.692
# Bootstrap #329 ROC area: 0.733
# Bootstrap #330 ROC area: 0.693
# Bootstrap #331 ROC area: 0.744
# Bootstrap #332 ROC area: 0.766
# Bootstrap #333 ROC area: 0.708
# Bootstrap #334 ROC area: 0.725
# Bootstrap #335 ROC area: 0.710
# Bootstrap #336 ROC area: 0.751
# Bootstrap #337 ROC area: 0.723
# Bootstrap #338 ROC area: 0.739
# Bootstrap #339 ROC area: 0.773
# Bootstrap #340 ROC area: 0.779
# Bootstrap #341 ROC area: 0.691
# Bootstrap #342 ROC area: 0.716
# Bootstrap #343 ROC area: 0.760
# Bootstrap #344 ROC area: 0.708
# Bootstrap #345 ROC area: 0.742
# Bootstrap #346 ROC area: 0.743
# Bootstrap #347 ROC area: 0.726
# Bootstrap #348 ROC area: 0.723
# Bootstrap #349 ROC area: 0.801
# Bootstrap #350 ROC area: 0.789
# Bootstrap #351 ROC area: 0.754
# Bootstrap #352 ROC area: 0.701
# Bootstrap #353 ROC area: 0.620
# Bootstrap #354 ROC area: 0.650
# Bootstrap #355 ROC area: 0.731
# Bootstrap #356 ROC area: 0.658
# Bootstrap #357 ROC area: 0.651
# Bootstrap #358 ROC area: 0.723
# Bootstrap #359 ROC area: 0.741
# Bootstrap #360 ROC area: 0.704
# Bootstrap #361 ROC area: 0.714
# Bootstrap #362 ROC area: 0.746
# Bootstrap #363 ROC area: 0.684
# Bootstrap #364 ROC area: 0.730
# Bootstrap #365 ROC area: 0.743
# Bootstrap #366 ROC area: 0.723
# Bootstrap #367 ROC area: 0.710
# Bootstrap #368 ROC area: 0.682
# Bootstrap #369 ROC area: 0.679
# Bootstrap #370 ROC area: 0.749
# Bootstrap #371 ROC area: 0.790
# Bootstrap #372 ROC area: 0.756
# Bootstrap #373 ROC area: 0.635
# Bootstrap #374 ROC area: 0.728
# Bootstrap #375 ROC area: 0.785
# Bootstrap #376 ROC area: 0.718
# Bootstrap #377 ROC area: 0.710
# Bootstrap #378 ROC area: 0.680
# Bootstrap #379 ROC area: 0.699
# Bootstrap #380 ROC area: 0.751
# Bootstrap #381 ROC area: 0.659
# Bootstrap #382 ROC area: 0.769
# Bootstrap #383 ROC area: 0.758
# Bootstrap #384 ROC area: 0.786
# Bootstrap #385 ROC area: 0.681
# Bootstrap #386 ROC area: 0.787
# Bootstrap #387 ROC area: 0.717
# Bootstrap #388 ROC area: 0.689
# Bootstrap #389 ROC area: 0.731
# Bootstrap #390 ROC area: 0.735
# Bootstrap #391 ROC area: 0.693
# Bootstrap #392 ROC area: 0.706
# Bootstrap #393 ROC area: 0.643
# Bootstrap #394 ROC area: 0.723
# Bootstrap #395 ROC area: 0.634
# Bootstrap #396 ROC area: 0.676
# Bootstrap #397 ROC area: 0.708
# Bootstrap #398 ROC area: 0.693
# Bootstrap #399 ROC area: 0.656
# Bootstrap #400 ROC area: 0.695
# Bootstrap #401 ROC area: 0.771
# Bootstrap #402 ROC area: 0.726
# Bootstrap #403 ROC area: 0.766
# Bootstrap #404 ROC area: 0.703
# Bootstrap #405 ROC area: 0.761
# Bootstrap #406 ROC area: 0.709
# Bootstrap #407 ROC area: 0.695
# Bootstrap #408 ROC area: 0.754
# Bootstrap #409 ROC area: 0.683
# Bootstrap #410 ROC area: 0.818
# Bootstrap #411 ROC area: 0.701
# Bootstrap #412 ROC area: 0.748
# Bootstrap #413 ROC area: 0.691
# Bootstrap #414 ROC area: 0.755
# Bootstrap #415 ROC area: 0.746
# Bootstrap #416 ROC area: 0.710
# Bootstrap #417 ROC area: 0.703
# Bootstrap #418 ROC area: 0.689
# Bootstrap #419 ROC area: 0.754
# Bootstrap #420 ROC area: 0.764
# Bootstrap #421 ROC area: 0.782
# Bootstrap #422 ROC area: 0.728
# Bootstrap #423 ROC area: 0.706
# Bootstrap #424 ROC area: 0.760
# Bootstrap #425 ROC area: 0.743
# Bootstrap #426 ROC area: 0.682
# Bootstrap #427 ROC area: 0.687
# Bootstrap #428 ROC area: 0.760
# Bootstrap #429 ROC area: 0.711
# Bootstrap #430 ROC area: 0.713
# Bootstrap #431 ROC area: 0.730
# Bootstrap #432 ROC area: 0.719
# Bootstrap #433 ROC area: 0.753
# Bootstrap #434 ROC area: 0.778
# Bootstrap #435 ROC area: 0.723
# Bootstrap #436 ROC area: 0.775
# Bootstrap #437 ROC area: 0.695
# Bootstrap #438 ROC area: 0.725
# Bootstrap #439 ROC area: 0.664
# Bootstrap #440 ROC area: 0.732
# Bootstrap #441 ROC area: 0.748
# Bootstrap #442 ROC area: 0.729
# Bootstrap #443 ROC area: 0.770
# Bootstrap #444 ROC area: 0.746
# Bootstrap #445 ROC area: 0.756
# Bootstrap #446 ROC area: 0.727
# Bootstrap #447 ROC area: 0.701
# Bootstrap #448 ROC area: 0.767
# Bootstrap #449 ROC area: 0.808
# Bootstrap #450 ROC area: 0.745
# Bootstrap #451 ROC area: 0.739
# Bootstrap #452 ROC area: 0.788
# Bootstrap #453 ROC area: 0.638
# Bootstrap #454 ROC area: 0.622
# Bootstrap #455 ROC area: 0.731
# Bootstrap #456 ROC area: 0.781
# Bootstrap #457 ROC area: 0.713
# Bootstrap #458 ROC area: 0.703
# Bootstrap #459 ROC area: 0.748
# Bootstrap #460 ROC area: 0.720
# Bootstrap #461 ROC area: 0.645
# Bootstrap #462 ROC area: 0.719
# Bootstrap #463 ROC area: 0.719
# Bootstrap #464 ROC area: 0.793
# Bootstrap #465 ROC area: 0.818
# Bootstrap #466 ROC area: 0.731
# Bootstrap #467 ROC area: 0.738
# Bootstrap #468 ROC area: 0.681
# Bootstrap #469 ROC area: 0.778
# Bootstrap #470 ROC area: 0.754
# Bootstrap #471 ROC area: 0.735
# Bootstrap #472 ROC area: 0.739
# Bootstrap #473 ROC area: 0.705
# Bootstrap #474 ROC area: 0.767
# Bootstrap #475 ROC area: 0.662
# Bootstrap #476 ROC area: 0.672
# Bootstrap #477 ROC area: 0.794
# Bootstrap #478 ROC area: 0.696
# Bootstrap #479 ROC area: 0.832
# Bootstrap #480 ROC area: 0.750
# Bootstrap #481 ROC area: 0.719
# Bootstrap #482 ROC area: 0.771
# Bootstrap #483 ROC area: 0.681
# Bootstrap #484 ROC area: 0.721
# Bootstrap #485 ROC area: 0.623
# Bootstrap #486 ROC area: 0.746
# Bootstrap #487 ROC area: 0.753
# Bootstrap #488 ROC area: 0.798
# Bootstrap #489 ROC area: 0.700
# Bootstrap #490 ROC area: 0.794
# Bootstrap #491 ROC area: 0.733
# Bootstrap #492 ROC area: 0.682
# Bootstrap #493 ROC area: 0.743
# Bootstrap #494 ROC area: 0.813
# Bootstrap #495 ROC area: 0.747
# Bootstrap #496 ROC area: 0.751
# Bootstrap #497 ROC area: 0.680
# Bootstrap #498 ROC area: 0.791
# Bootstrap #499 ROC area: 0.743
# Bootstrap #500 ROC area: 0.794
# Bootstrap #501 ROC area: 0.779
# Bootstrap #502 ROC area: 0.744
# Bootstrap #503 ROC area: 0.791
# Bootstrap #504 ROC area: 0.651
# Bootstrap #505 ROC area: 0.788
# Bootstrap #506 ROC area: 0.809
# Bootstrap #507 ROC area: 0.704
# Bootstrap #508 ROC area: 0.692
# Bootstrap #509 ROC area: 0.769
# Bootstrap #510 ROC area: 0.755
# Bootstrap #511 ROC area: 0.719
# Bootstrap #512 ROC area: 0.811
# Bootstrap #513 ROC area: 0.603
# Bootstrap #514 ROC area: 0.731
# Bootstrap #515 ROC area: 0.684
# Bootstrap #516 ROC area: 0.758
# Bootstrap #517 ROC area: 0.725
# Bootstrap #518 ROC area: 0.727
# Bootstrap #519 ROC area: 0.791
# Bootstrap #520 ROC area: 0.685
# Bootstrap #521 ROC area: 0.746
# Bootstrap #522 ROC area: 0.755
# Bootstrap #523 ROC area: 0.822
# Bootstrap #524 ROC area: 0.697
# Bootstrap #525 ROC area: 0.706
# Bootstrap #526 ROC area: 0.796
# Bootstrap #527 ROC area: 0.783
# Bootstrap #528 ROC area: 0.729
# Bootstrap #529 ROC area: 0.745
# Bootstrap #530 ROC area: 0.732
# Bootstrap #531 ROC area: 0.785
# Bootstrap #532 ROC area: 0.727
# Bootstrap #533 ROC area: 0.706
# Bootstrap #534 ROC area: 0.729
# Bootstrap #535 ROC area: 0.806
# Bootstrap #536 ROC area: 0.784
# Bootstrap #537 ROC area: 0.753
# Bootstrap #538 ROC area: 0.724
# Bootstrap #539 ROC area: 0.742
# Bootstrap #540 ROC area: 0.665
# Bootstrap #541 ROC area: 0.772
# Bootstrap #542 ROC area: 0.729
# Bootstrap #543 ROC area: 0.709
# Bootstrap #544 ROC area: 0.739
# Bootstrap #545 ROC area: 0.717
# Bootstrap #546 ROC area: 0.754
# Bootstrap #547 ROC area: 0.706
# Bootstrap #548 ROC area: 0.738
# Bootstrap #549 ROC area: 0.782
# Bootstrap #550 ROC area: 0.642
# Bootstrap #551 ROC area: 0.716
# Bootstrap #552 ROC area: 0.711
# Bootstrap #553 ROC area: 0.697
# Bootstrap #554 ROC area: 0.770
# Bootstrap #555 ROC area: 0.724
# Bootstrap #556 ROC area: 0.767
# Bootstrap #557 ROC area: 0.716
# Bootstrap #558 ROC area: 0.680
# Bootstrap #559 ROC area: 0.745
# Bootstrap #560 ROC area: 0.781
# Bootstrap #561 ROC area: 0.742
# Bootstrap #562 ROC area: 0.739
# Bootstrap #563 ROC area: 0.742
# Bootstrap #564 ROC area: 0.684
# Bootstrap #565 ROC area: 0.738
# Bootstrap #566 ROC area: 0.729
# Bootstrap #567 ROC area: 0.691
# Bootstrap #568 ROC area: 0.742
# Bootstrap #569 ROC area: 0.715
# Bootstrap #570 ROC area: 0.705
# Bootstrap #571 ROC area: 0.814
# Bootstrap #572 ROC area: 0.761
# Bootstrap #573 ROC area: 0.709
# Bootstrap #574 ROC area: 0.812
# Bootstrap #575 ROC area: 0.714
# Bootstrap #576 ROC area: 0.788
# Bootstrap #577 ROC area: 0.758
# Bootstrap #578 ROC area: 0.744
# Bootstrap #579 ROC area: 0.711
# Bootstrap #580 ROC area: 0.789
# Bootstrap #581 ROC area: 0.800
# Bootstrap #582 ROC area: 0.677
# Bootstrap #583 ROC area: 0.673
# Bootstrap #584 ROC area: 0.747
# Bootstrap #585 ROC area: 0.656
# Bootstrap #586 ROC area: 0.709
# Bootstrap #587 ROC area: 0.785
# Bootstrap #588 ROC area: 0.648
# Bootstrap #589 ROC area: 0.760
# Bootstrap #590 ROC area: 0.745
# Bootstrap #591 ROC area: 0.720
# Bootstrap #592 ROC area: 0.795
# Bootstrap #593 ROC area: 0.773
# Bootstrap #594 ROC area: 0.675
# Bootstrap #595 ROC area: 0.752
# Bootstrap #596 ROC area: 0.756
# Bootstrap #597 ROC area: 0.700
# Bootstrap #598 ROC area: 0.747
# Bootstrap #599 ROC area: 0.719
# Bootstrap #600 ROC area: 0.823
# Bootstrap #601 ROC area: 0.709
# Bootstrap #602 ROC area: 0.674
# Bootstrap #603 ROC area: 0.753
# Bootstrap #604 ROC area: 0.693
# Bootstrap #605 ROC area: 0.655
# Bootstrap #606 ROC area: 0.732
# Bootstrap #607 ROC area: 0.654
# Bootstrap #608 ROC area: 0.710
# Bootstrap #609 ROC area: 0.594
# Bootstrap #610 ROC area: 0.758
# Bootstrap #611 ROC area: 0.693
# Bootstrap #612 ROC area: 0.793
# Bootstrap #613 ROC area: 0.686
# Bootstrap #614 ROC area: 0.773
# Bootstrap #615 ROC area: 0.795
# Bootstrap #616 ROC area: 0.690
# Bootstrap #617 ROC area: 0.722
# Bootstrap #618 ROC area: 0.724
# Bootstrap #619 ROC area: 0.626
# Bootstrap #620 ROC area: 0.617
# Bootstrap #621 ROC area: 0.813
# Bootstrap #622 ROC area: 0.770
# Bootstrap #623 ROC area: 0.724
# Bootstrap #624 ROC area: 0.787
# Bootstrap #625 ROC area: 0.686
# Bootstrap #626 ROC area: 0.712
# Bootstrap #627 ROC area: 0.700
# Bootstrap #628 ROC area: 0.590
# Bootstrap #629 ROC area: 0.708
# Bootstrap #630 ROC area: 0.688
# Bootstrap #631 ROC area: 0.696
# Bootstrap #632 ROC area: 0.697
# Bootstrap #633 ROC area: 0.753
# Bootstrap #634 ROC area: 0.749
# Bootstrap #635 ROC area: 0.770
# Bootstrap #636 ROC area: 0.683
# Bootstrap #637 ROC area: 0.748
# Bootstrap #638 ROC area: 0.780
# Bootstrap #639 ROC area: 0.720
# Bootstrap #640 ROC area: 0.748
# Bootstrap #641 ROC area: 0.733
# Bootstrap #642 ROC area: 0.733
# Bootstrap #643 ROC area: 0.757
# Bootstrap #644 ROC area: 0.786
# Bootstrap #645 ROC area: 0.776
# Bootstrap #646 ROC area: 0.662
# Bootstrap #647 ROC area: 0.761
# Bootstrap #648 ROC area: 0.688
# Bootstrap #649 ROC area: 0.810
# Bootstrap #650 ROC area: 0.788
# Bootstrap #651 ROC area: 0.788
# Bootstrap #652 ROC area: 0.758
# Bootstrap #653 ROC area: 0.715
# Bootstrap #654 ROC area: 0.680
# Bootstrap #655 ROC area: 0.814
# Bootstrap #656 ROC area: 0.745
# Bootstrap #657 ROC area: 0.758
# Bootstrap #658 ROC area: 0.740
# Bootstrap #659 ROC area: 0.706
# Bootstrap #660 ROC area: 0.741
# Bootstrap #661 ROC area: 0.644
# Bootstrap #662 ROC area: 0.741
# Bootstrap #663 ROC area: 0.638
# Bootstrap #664 ROC area: 0.769
# Bootstrap #665 ROC area: 0.756
# Bootstrap #666 ROC area: 0.738
# Bootstrap #667 ROC area: 0.752
# Bootstrap #668 ROC area: 0.721
# Bootstrap #669 ROC area: 0.803
# Bootstrap #670 ROC area: 0.729
# Bootstrap #671 ROC area: 0.681
# Bootstrap #672 ROC area: 0.782
# Bootstrap #673 ROC area: 0.764
# Bootstrap #674 ROC area: 0.736
# Bootstrap #675 ROC area: 0.742
# Bootstrap #676 ROC area: 0.756
# Bootstrap #677 ROC area: 0.725
# Bootstrap #678 ROC area: 0.685
# Bootstrap #679 ROC area: 0.715
# Bootstrap #680 ROC area: 0.683
# Bootstrap #681 ROC area: 0.763
# Bootstrap #682 ROC area: 0.730
# Bootstrap #683 ROC area: 0.689
# Bootstrap #684 ROC area: 0.689
# Bootstrap #685 ROC area: 0.682
# Bootstrap #686 ROC area: 0.648
# Bootstrap #687 ROC area: 0.715
# Bootstrap #688 ROC area: 0.761
# Bootstrap #689 ROC area: 0.642
# Bootstrap #690 ROC area: 0.786
# Bootstrap #691 ROC area: 0.748
# Bootstrap #692 ROC area: 0.778
# Bootstrap #693 ROC area: 0.727
# Bootstrap #694 ROC area: 0.693
# Bootstrap #695 ROC area: 0.707
# Bootstrap #696 ROC area: 0.741
# Bootstrap #697 ROC area: 0.635
# Bootstrap #698 ROC area: 0.731
# Bootstrap #699 ROC area: 0.707
# Bootstrap #700 ROC area: 0.743
# Bootstrap #701 ROC area: 0.739
# Bootstrap #702 ROC area: 0.687
# Bootstrap #703 ROC area: 0.819
# Bootstrap #704 ROC area: 0.704
# Bootstrap #705 ROC area: 0.792
# Bootstrap #706 ROC area: 0.734
# Bootstrap #707 ROC area: 0.683
# Bootstrap #708 ROC area: 0.760
# Bootstrap #709 ROC area: 0.742
# Bootstrap #710 ROC area: 0.625
# Bootstrap #711 ROC area: 0.768
# Bootstrap #712 ROC area: 0.699
# Bootstrap #713 ROC area: 0.760
# Bootstrap #714 ROC area: 0.711
# Bootstrap #715 ROC area: 0.734
# Bootstrap #716 ROC area: 0.753
# Bootstrap #717 ROC area: 0.670
# Bootstrap #718 ROC area: 0.634
# Bootstrap #719 ROC area: 0.706
# Bootstrap #720 ROC area: 0.744
# Bootstrap #721 ROC area: 0.817
# Bootstrap #722 ROC area: 0.737
# Bootstrap #723 ROC area: 0.658
# Bootstrap #724 ROC area: 0.696
# Bootstrap #725 ROC area: 0.796
# Bootstrap #726 ROC area: 0.699
# Bootstrap #727 ROC area: 0.797
# Bootstrap #728 ROC area: 0.646
# Bootstrap #729 ROC area: 0.705
# Bootstrap #730 ROC area: 0.710
# Bootstrap #731 ROC area: 0.697
# Bootstrap #732 ROC area: 0.714
# Bootstrap #733 ROC area: 0.691
# Bootstrap #734 ROC area: 0.681
# Bootstrap #735 ROC area: 0.679
# Bootstrap #736 ROC area: 0.765
# Bootstrap #737 ROC area: 0.730
# Bootstrap #738 ROC area: 0.760
# Bootstrap #739 ROC area: 0.730
# Bootstrap #740 ROC area: 0.734
# Bootstrap #741 ROC area: 0.783
# Bootstrap #742 ROC area: 0.716
# Bootstrap #743 ROC area: 0.764
# Bootstrap #744 ROC area: 0.757
# Bootstrap #745 ROC area: 0.714
# Bootstrap #746 ROC area: 0.775
# Bootstrap #747 ROC area: 0.774
# Bootstrap #748 ROC area: 0.654
# Bootstrap #749 ROC area: 0.628
# Bootstrap #750 ROC area: 0.619
# Bootstrap #751 ROC area: 0.725
# Bootstrap #752 ROC area: 0.699
# Bootstrap #753 ROC area: 0.743
# Bootstrap #754 ROC area: 0.644
# Bootstrap #755 ROC area: 0.766
# Bootstrap #756 ROC area: 0.726
# Bootstrap #757 ROC area: 0.651
# Bootstrap #758 ROC area: 0.751
# Bootstrap #759 ROC area: 0.721
# Bootstrap #760 ROC area: 0.707
# Bootstrap #761 ROC area: 0.739
# Bootstrap #762 ROC area: 0.636
# Bootstrap #763 ROC area: 0.789
# Bootstrap #764 ROC area: 0.753
# Bootstrap #765 ROC area: 0.708
# Bootstrap #766 ROC area: 0.727
# Bootstrap #767 ROC area: 0.710
# Bootstrap #768 ROC area: 0.749
# Bootstrap #769 ROC area: 0.672
# Bootstrap #770 ROC area: 0.588
# Bootstrap #771 ROC area: 0.770
# Bootstrap #772 ROC area: 0.665
# Bootstrap #773 ROC area: 0.731
# Bootstrap #774 ROC area: 0.696
# Bootstrap #775 ROC area: 0.741
# Bootstrap #776 ROC area: 0.730
# Bootstrap #777 ROC area: 0.761
# Bootstrap #778 ROC area: 0.805
# Bootstrap #779 ROC area: 0.709
# Bootstrap #780 ROC area: 0.752
# Bootstrap #781 ROC area: 0.730
# Bootstrap #782 ROC area: 0.785
# Bootstrap #783 ROC area: 0.692
# Bootstrap #784 ROC area: 0.775
# Bootstrap #785 ROC area: 0.784
# Bootstrap #786 ROC area: 0.730
# Bootstrap #787 ROC area: 0.732
# Bootstrap #788 ROC area: 0.708
# Bootstrap #789 ROC area: 0.724
# Bootstrap #790 ROC area: 0.732
# Bootstrap #791 ROC area: 0.756
# Bootstrap #792 ROC area: 0.766
# Bootstrap #793 ROC area: 0.771
# Bootstrap #794 ROC area: 0.705
# Bootstrap #795 ROC area: 0.743
# Bootstrap #796 ROC area: 0.781
# Bootstrap #797 ROC area: 0.767
# Bootstrap #798 ROC area: 0.641
# Bootstrap #799 ROC area: 0.682
# Bootstrap #800 ROC area: 0.731
# Bootstrap #801 ROC area: 0.722
# Bootstrap #802 ROC area: 0.692
# Bootstrap #803 ROC area: 0.790
# Bootstrap #804 ROC area: 0.712
# Bootstrap #805 ROC area: 0.695
# Bootstrap #806 ROC area: 0.724
# Bootstrap #807 ROC area: 0.762
# Bootstrap #808 ROC area: 0.759
# Bootstrap #809 ROC area: 0.654
# Bootstrap #810 ROC area: 0.765
# Bootstrap #811 ROC area: 0.670
# Bootstrap #812 ROC area: 0.727
# Bootstrap #813 ROC area: 0.795
# Bootstrap #814 ROC area: 0.669
# Bootstrap #815 ROC area: 0.699
# Bootstrap #816 ROC area: 0.814
# Bootstrap #817 ROC area: 0.656
# Bootstrap #818 ROC area: 0.698
# Bootstrap #819 ROC area: 0.737
# Bootstrap #820 ROC area: 0.761
# Bootstrap #821 ROC area: 0.742
# Bootstrap #822 ROC area: 0.713
# Bootstrap #823 ROC area: 0.666
# Bootstrap #824 ROC area: 0.695
# Bootstrap #825 ROC area: 0.690
# Bootstrap #826 ROC area: 0.741
# Bootstrap #827 ROC area: 0.752
# Bootstrap #828 ROC area: 0.693
# Bootstrap #829 ROC area: 0.759
# Bootstrap #830 ROC area: 0.707
# Bootstrap #831 ROC area: 0.652
# Bootstrap #832 ROC area: 0.707
# Bootstrap #833 ROC area: 0.699
# Bootstrap #834 ROC area: 0.653
# Bootstrap #835 ROC area: 0.599
# Bootstrap #836 ROC area: 0.683
# Bootstrap #837 ROC area: 0.739
# Bootstrap #838 ROC area: 0.758
# Bootstrap #839 ROC area: 0.681
# Bootstrap #840 ROC area: 0.652
# Bootstrap #841 ROC area: 0.778
# Bootstrap #842 ROC area: 0.697
# Bootstrap #843 ROC area: 0.712
# Bootstrap #844 ROC area: 0.704
# Bootstrap #845 ROC area: 0.786
# Bootstrap #846 ROC area: 0.695
# Bootstrap #847 ROC area: 0.669
# Bootstrap #848 ROC area: 0.731
# Bootstrap #849 ROC area: 0.715
# Bootstrap #850 ROC area: 0.717
# Bootstrap #851 ROC area: 0.782
# Bootstrap #852 ROC area: 0.716
# Bootstrap #853 ROC area: 0.763
# Bootstrap #854 ROC area: 0.690
# Bootstrap #855 ROC area: 0.739
# Bootstrap #856 ROC area: 0.756
# Bootstrap #857 ROC area: 0.711
# Bootstrap #858 ROC area: 0.747
# Bootstrap #859 ROC area: 0.677
# Bootstrap #860 ROC area: 0.696
# Bootstrap #861 ROC area: 0.633
# Bootstrap #862 ROC area: 0.717
# Bootstrap #863 ROC area: 0.788
# Bootstrap #864 ROC area: 0.752
# Bootstrap #865 ROC area: 0.751
# Bootstrap #866 ROC area: 0.748
# Bootstrap #867 ROC area: 0.751
# Bootstrap #868 ROC area: 0.737
# Bootstrap #869 ROC area: 0.649
# Bootstrap #870 ROC area: 0.746
# Bootstrap #871 ROC area: 0.637
# Bootstrap #872 ROC area: 0.640
# Bootstrap #873 ROC area: 0.719
# Bootstrap #874 ROC area: 0.745
# Bootstrap #875 ROC area: 0.621
# Bootstrap #876 ROC area: 0.732
# Bootstrap #877 ROC area: 0.684
# Bootstrap #878 ROC area: 0.690
# Bootstrap #879 ROC area: 0.699
# Bootstrap #880 ROC area: 0.714
# Bootstrap #881 ROC area: 0.656
# Bootstrap #882 ROC area: 0.729
# Bootstrap #883 ROC area: 0.650
# Bootstrap #884 ROC area: 0.780
# Bootstrap #885 ROC area: 0.725
# Bootstrap #886 ROC area: 0.735
# Bootstrap #887 ROC area: 0.730
# Bootstrap #888 ROC area: 0.783
# Bootstrap #889 ROC area: 0.691
# Bootstrap #890 ROC area: 0.759
# Bootstrap #891 ROC area: 0.778
# Bootstrap #892 ROC area: 0.710
# Bootstrap #893 ROC area: 0.779
# Bootstrap #894 ROC area: 0.715
# Bootstrap #895 ROC area: 0.642
# Bootstrap #896 ROC area: 0.742
# Bootstrap #897 ROC area: 0.777
# Bootstrap #898 ROC area: 0.748
# Bootstrap #899 ROC area: 0.691
# Bootstrap #900 ROC area: 0.796
# Bootstrap #901 ROC area: 0.809
# Bootstrap #902 ROC area: 0.732
# Bootstrap #903 ROC area: 0.746
# Bootstrap #904 ROC area: 0.686
# Bootstrap #905 ROC area: 0.705
# Bootstrap #906 ROC area: 0.656
# Bootstrap #907 ROC area: 0.743
# Bootstrap #908 ROC area: 0.780
# Bootstrap #909 ROC area: 0.812
# Bootstrap #910 ROC area: 0.773
# Bootstrap #911 ROC area: 0.711
# Bootstrap #912 ROC area: 0.722
# Bootstrap #913 ROC area: 0.775
# Bootstrap #914 ROC area: 0.736
# Bootstrap #915 ROC area: 0.721
# Bootstrap #916 ROC area: 0.728
# Bootstrap #917 ROC area: 0.718
# Bootstrap #918 ROC area: 0.709
# Bootstrap #919 ROC area: 0.777
# Bootstrap #920 ROC area: 0.637
# Bootstrap #921 ROC area: 0.709
# Bootstrap #922 ROC area: 0.753
# Bootstrap #923 ROC area: 0.788
# Bootstrap #924 ROC area: 0.734
# Bootstrap #925 ROC area: 0.747
# Bootstrap #926 ROC area: 0.742
# Bootstrap #927 ROC area: 0.846
# Bootstrap #928 ROC area: 0.675
# Bootstrap #929 ROC area: 0.740
# Bootstrap #930 ROC area: 0.671
# Bootstrap #931 ROC area: 0.741
# Bootstrap #932 ROC area: 0.735
# Bootstrap #933 ROC area: 0.653
# Bootstrap #934 ROC area: 0.739
# Bootstrap #935 ROC area: 0.807
# Bootstrap #936 ROC area: 0.680
# Bootstrap #937 ROC area: 0.716
# Bootstrap #938 ROC area: 0.735
# Bootstrap #939 ROC area: 0.713
# Bootstrap #940 ROC area: 0.731
# Bootstrap #941 ROC area: 0.813
# Bootstrap #942 ROC area: 0.595
# Bootstrap #943 ROC area: 0.747
# Bootstrap #944 ROC area: 0.716
# Bootstrap #945 ROC area: 0.777
# Bootstrap #946 ROC area: 0.786
# Bootstrap #947 ROC area: 0.642
# Bootstrap #948 ROC area: 0.755
# Bootstrap #949 ROC area: 0.832
# Bootstrap #950 ROC area: 0.832
# Bootstrap #951 ROC area: 0.792
# Bootstrap #952 ROC area: 0.819
# Bootstrap #953 ROC area: 0.735
# Bootstrap #954 ROC area: 0.743
# Bootstrap #955 ROC area: 0.753
# Bootstrap #956 ROC area: 0.785
# Bootstrap #957 ROC area: 0.732
# Bootstrap #958 ROC area: 0.735
# Bootstrap #959 ROC area: 0.733
# Bootstrap #960 ROC area: 0.690
# Bootstrap #961 ROC area: 0.760
# Bootstrap #962 ROC area: 0.781
# Bootstrap #963 ROC area: 0.681
# Bootstrap #964 ROC area: 0.748
# Bootstrap #965 ROC area: 0.717
# Bootstrap #966 ROC area: 0.657
# Bootstrap #967 ROC area: 0.638
# Bootstrap #968 ROC area: 0.702
# Bootstrap #969 ROC area: 0.728
# Bootstrap #970 ROC area: 0.777
# Bootstrap #971 ROC area: 0.798
# Bootstrap #972 ROC area: 0.725
# Bootstrap #973 ROC area: 0.695
# Bootstrap #974 ROC area: 0.648
# Bootstrap #975 ROC area: 0.786
# Bootstrap #976 ROC area: 0.740
# Bootstrap #977 ROC area: 0.667
# Bootstrap #978 ROC area: 0.702
# Bootstrap #979 ROC area: 0.766
# Bootstrap #980 ROC area: 0.805
# Bootstrap #981 ROC area: 0.724
# Bootstrap #982 ROC area: 0.775
# Bootstrap #983 ROC area: 0.770
# Bootstrap #984 ROC area: 0.720
# Bootstrap #985 ROC area: 0.690
# Bootstrap #986 ROC area: 0.755
# Bootstrap #987 ROC area: 0.719
# Bootstrap #988 ROC area: 0.743
# Bootstrap #989 ROC area: 0.742
# Bootstrap #990 ROC area: 0.752
# Bootstrap #991 ROC area: 0.714
# Bootstrap #992 ROC area: 0.705
# Bootstrap #993 ROC area: 0.758
# Bootstrap #994 ROC area: 0.715
# Bootstrap #995 ROC area: 0.707
# Bootstrap #996 ROC area: 0.797
# Bootstrap #997 ROC area: 0.703
# Bootstrap #998 ROC area: 0.733
# Bootstrap #999 ROC area: 0.709
# Bootstrap #1000 ROC area: 0.719

# %%
sorted_scores = np.array(bootstrapped_scores)
sorted_scores.sort()

confidence_lower = sorted_scores[int(0.025 * len(sorted_scores))]
confidence_upper = sorted_scores[int(0.975 * len(sorted_scores))]
print("Confidence interval for the score on Asian patients: [{:0.3f} - {:0.3}]".format(
    confidence_lower, confidence_upper))
# Out:
# Confidence interval for the score on Asian patients: [0.633 - 0.813]
